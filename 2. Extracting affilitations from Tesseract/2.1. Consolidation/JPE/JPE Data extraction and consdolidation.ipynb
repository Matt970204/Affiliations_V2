# %% [markdown]
# # Extracting JPE affiliation data from base tesseract data

# %% [markdown]
# First the JSON output file from tesseract is read in and made into a useable dataframe

# %%
#Importing the libraries
import json
import pandas as pd
import requests
import re

# Import JSON file from Github repository
tesseract_input = requests.get('https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/1.%20Input%20Data/Tesseract%20affiliation%20output/JPE/JPE_affiliation_output_1940_2010.json')
json_data = tesseract_input.json()

#Use the 2 lines below for a local import of the data
#tesseract_input = open('/Users/MattJohnson/Desktop/Affiliations/1_Input files and processing input files/1_1_Input files/Tesseract affiliation output/JPE/JPE_affiliation_output_1940_2010.json')
#json_data = json.load(tesseract_input)

# Define Journal and Dataframe
Journal_Name = 'JPE'
Reference_Data_List = []

# Extract Json Data into dataframe
for key1, value1 in json_data.items():
    Article_ID = key1
    content_type = value1["content_type"]
    author_list = value1["authors"]
    authorsNo = len(author_list)
    stable_url = value1["stable_url"]
    for key2 in value1["affiliations"]:
        Ref_type = key2
        if key2 == "found":
            ref_string = value1["affiliations"][key2]
        else: 
            for key3 in value1["affiliations"]["raw"]:
                #if len(value1["affiliations"]["raw"]) > 1:
                    #print(key1, "   ",len(value1["affiliations"]["raw"]))
                if key3 == "1":
                    #print(key3)
                    ref_string = value1["affiliations"][key2][key3]
                    #print(ref_string)

    Reference_Data_List.append({'Journal_Name' : Journal_Name,
    'Authors_count' : authorsNo, 
    'Authors_list' : author_list,
    'Article_ID' : Article_ID, 'content_type' : content_type,
    'stable_url' : stable_url, 
    'Ref_type': Ref_type,  'ref_string':ref_string })

# Create a dataframe from the extracted data
JPE_aff_ref_output_1940_2010 = pd.DataFrame.from_records(Reference_Data_List)

#Basice view of data
print(JPE_aff_ref_output_1940_2010.head())
print(JPE_aff_ref_output_1940_2010.shape)

#Use line below to send data to excel to view full file
#JPE_aff_ref_output_1940_2010.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/Working files/JPE_aff_ref_output_1940_2010.xlsx')
# Out:
#   Journal_Name  Authors_count  \
# 0          JPE              2
# 1          JPE              2
# 2          JPE              2
# 3          JPE              3
# 4          JPE              1
#
#                                         Authors_list Article_ID content_type  \
# 0              [Johannes Hörner,  Andrzej Skrzypacz]   26549911      Article
# 1    [Gabriel Chodorow-Reich,  Loukas Karabarbounis]   26549912      Article
# 2                     [David Gill,  Victoria Prowse]   26549913      Article
# 3  [Tobias J. Klein,  Christian Lambertz,  Konrad...   26549914      Article
# 4                                      [David Mitch]   26549915      Article
#
#                               stable_url Ref_type  \
# 0  https://www.jstor.org/stable/26549911    found
# 1  https://www.jstor.org/stable/26549912    found
# 2  https://www.jstor.org/stable/26549913    found
# 3  https://www.jstor.org/stable/26549914    found
# 4  https://www.jstor.org/stable/26549915    found
#
#                                           ref_string
# 0  Johannes Hórner\n\nYale University\n\nAndrzej ...
# 1  Gabriel Chodorow-Reich\n\nHarvard University a...
# 2  David Gill\n\nPurdue University\n\nVictoria Pr...
# 3  Tobias J. Klein\n\nTilburg University\n\nChris...
# 4  David Mitch\n\nUniversity of Maryland, Baltimo...
# (4327, 8)

# %%
# Cleaning the reference data from tesseract removing some formatting as well as correcting to title case and stripping white space
import re
testdata = JPE_aff_ref_output_1940_2010

for i in range(len(testdata)):
    if testdata.iloc[i]['Ref_type'] == "raw":
        joined =  " ".join(testdata.iloc[i]['ref_string'])
        ref_string = joined.strip().title()
        clean_ref_string = re.sub('\?|\:|\"', '', ref_string)
        testdata.loc[i,['ref_string_clean1']] = clean_ref_string
    else:
        ref_string = testdata.iloc[i]['ref_string'].strip().title()
        clean_ref_string = re.sub('\?|\:|\"', '', ref_string)
        testdata.loc[i,['ref_string_clean1']] = clean_ref_string

    #print(testdata.loc[i,['ref_string_clean1']])
print(testdata.columns.values)
# Out:
# ['Journal_Name' 'Authors_count' 'Authors_list' 'Article_ID' 'content_type'
#  'stable_url' 'Ref_type' 'ref_string' 'ref_string_clean1']

# %%
#Reading in the master file and correctly formatting the article ID to match back onto the melted file

#Load in master from Github
JPE_master = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/1.%20Input%20Data/Processed/JPE_processed.xlsx")
#JPE_master = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/1_Input files and processing input files/1_1_Input files/Master lists/Processed/JPE_processed.xlsx')

for i in range(len(JPE_master)):
    JPE_master.loc[i,['Article_ID']] = JPE_master.loc[i,['stable_url']].to_string().rsplit('/',1)[-1]

JPE_master_condenced  = JPE_master[['Article_ID','year']]
JPE_master_condenced['year'] = JPE_master_condenced['year'].astype('int')
JPE_master_condenced.head()
# Out:
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_71684/88867838.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   JPE_master_condenced['year'] = JPE_master_condenced['year'].astype('int')
#   Article_ID  year
# 0   26549909  2016
# 1   26549910  2016
# 2   26549911  2016
# 3   26549912  2016
# 4   26549913  2016

# %%
# Merging the masterfile onto the data in order to get the year
testdata_merged = testdata.merge(JPE_master_condenced, how = 'left', on = 'Article_ID')
testdata_merged = testdata_merged.sort_values(by=['year'])
testdata = testdata_merged.reset_index(drop = True)
print(testdata.shape)
# Out:
# (4327, 10)

# %%
# Filter out the non articles from the tesseract data in JPE
list = []
for i in range(1940,2011):
    list.append(i)

mask_year = testdata['year'].isin(list)
testdata = testdata[mask_year]

mask_type = testdata['content_type'].isin(['Article'])
testdata = testdata[mask_type]

testdata = testdata.reset_index(drop = True)
print(testdata.shape)
# Out:
# (3823, 10)

# %% [markdown]
# The next chunk of code uses fuzzy matching to find the authors names in the affiliation string. This seperates the affiliations assoicted with each author into their own data chunk

# %%
import re
from rapidfuzz import fuzz
import math

for x in range(len(testdata)):
    # Read in authors
    authors = testdata.iloc[x]['Authors_list']
    str1 = testdata.iloc[x]['ref_string_clean1']

    # Split on new line as well as don't include blank lines
    ref_split = re.split(r"\n",str1 )
    while("" in ref_split):
        ref_split.remove("")

#Finding the authors name and corrosponding affiliations
    count_found = 0
    #Loop through author names in author list
    for d in range(len(authors)):
        #Loop through the data that is split into possible authors affiliations
        for j in range(len(ref_split)):
            #Check if the author name is in the split string
            ratio_author  = fuzz.partial_ratio(ref_split[j], authors[d])
            # Confiring if author name is in the affiliaton
            if ratio_author > 93:
                count_found = count_found +1
                #append the next line of the document to a column for each author
                if j+1 < len(ref_split):
                    testdata.loc[x, str(d)+'_author'] = authors[d]
                    # checking for short erroenous splits, if a line has a article on it
                    if len(ref_split[j+1]) > 3:
                        testdata.loc[x, str(d)+'_author_affs'] = ref_split[j+1]
                    else:
                        testdata.loc[x, str(d)+'_author_affs'] = ''
            # Prevents double finding of author name, sometimes name occurs twice 
            # but first occurance is the affiliation
            if count_found == len(authors):
                break
                #else:

# %%
# Creating a dictionary for consolidation
# Read in from Excel sheet, 2 columns first one with incorrect spelling and second one with correct spellig

cities = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/1.%20Input%20Data/Consolidated%20Affiliations/Consolidated%20Affiliations.xlsx", 'Cities')
#cities = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/consolidated list Final Use.xlsx', 'Cities')
cities = cities[['Incorrect spelling', 'Correct spelling']]
#print(cities.shape)

comma_in_name = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/1.%20Input%20Data/Consolidated%20Affiliations/Consolidated%20Affiliations.xlsx", 'Comma in name')
#comma_in_name = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/consolidated list Final Use.xlsx', 'Comma in name')
comma_in_name = comma_in_name[['Incorrect spelling', 'Correct spelling']]
#print(comma_in_name.shape)

misspellings = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/1.%20Input%20Data/Consolidated%20Affiliations/Consolidated%20Affiliations.xlsx", 'Misspellings')
#misspellings = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/consolidated list Final Use.xlsx', 'Misspellings')
misspellings = misspellings[['Incorrect spelling', 'Correct spelling']]

colleges = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/1.%20Input%20Data/Consolidated%20Affiliations/Consolidated%20Affiliations.xlsx", 'Colleges')
#colleges = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/consolidated list Final Use.xlsx', 'Colleges')
colleges = colleges[['Incorrect spelling', 'Correct spelling']]

colleges_full = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/1.%20Input%20Data/Consolidated%20Affiliations/Consolidated%20Affiliations.xlsx", 'Colleges Full')
#colleges_full = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/consolidated list Final Use.xlsx', 'Colleges Full')
colleges_full = colleges_full[['Incorrect spelling', 'Correct spelling']]

correct = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/1.%20Input%20Data/Consolidated%20Affiliations/Consolidated%20Affiliations.xlsx", 'Correct')
#correct = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/University list/consolidated list.xlsx', 'Correct')
correct = correct[['Incorrect spelling', 'Correct spelling']]

frames = [cities, misspellings, comma_in_name,colleges_full ,colleges,correct]
consolidated_affiliations = pd.concat(frames)
print(consolidated_affiliations.shape)

for i in range(len(consolidated_affiliations)):
    #Replaceing title case and stripping leading space
    #affs.iat[i,0] = affs.iat[i,0].strip().title()
    consolidated_affiliations.iloc[i]['Incorrect spelling'] = consolidated_affiliations.iloc[i]['Incorrect spelling'].strip().title()
    #affs.iat[i,0] = affs.iat[i,0].strip().upper()

consolidated_affiliations_dict = consolidated_affiliations.set_index('Incorrect spelling').to_dict()['Correct spelling']
print(consolidated_affiliations_dict)
# Out:
# (1714, 2)
# {'Ames, Iowa': 'Ames Iowa United States (City)', 'Ames, Iowa, Usa': 'Ames Iowa United States (City)', 'Antwerp': 'Antwerp Belguim (City)', 'Auckland, New Zealand': 'Auckland New Zealand (City)', 'Auckland, Nz': 'Auckland New Zealand (City)', 'Baghdad': 'Baghdad Iraq (City)', 'Baltimore': 'Baltimore Maryland (City)', 'Baltimore, Usa Kzlvin J Lancaster': 'Baltimore Maryland (City)', 'Belfast': 'Belfast Ireland (City)', 'Berkeley': 'Berkeley California United States (City)', 'Berkeley, California': 'Berkeley California United States (City)', 'Birmingham': 'Birmingham United Kingdom (City)', 'Birmingham And Ames, Iowa': 'Birmingham United Kingdom (City)', 'Bloomington, Indiana': 'Bloomington Indiana United States (City)', 'Bristol': 'Bristol United Kingdom (City)', 'Brooklyn, New York': 'Brooklyn New York United States (City)', 'Brunswick, Maine Davidp Braybrooke': 'Brunswick Maine United States (City)', 'Brussels': 'Brussels Belgium (City)', 'Brussels, Belgium': 'Brussels Belgium (City)', 'California': 'California United States (State)', 'Cambridge': 'Cambridge Massachusetts United States (City)', 'Cambridge ,': 'Cambridge Massachusetts United States (City)', 'Cambridge And Salisbury, Rhodesia': 'Cambridge Massachusetts United States (City)', 'Cambridge Bungess Cameron': 'Cambridge Massachusetts United States (City)', 'Cambridge Nicholas Kaaldom': 'Cambridge Massachusetts United States (City)', 'Cambridge, Mass': 'Cambridge Massachusetts United States (City)', 'Cambridge, Mass  And Washington, Dc': 'Cambridge Massachusetts United States (City)', 'Cambridge, Mass Rosert M Solow': 'Cambridge Massachusetts United States (City)', 'Cambridge, Mass Rosert M Solow,': 'Cambridge Massachusetts United States (City)', 'Cambridge, Massachusetts': 'Cambridge Massachusetts United States (City)', 'Cambridge, Massachusetts *': 'Cambridge Massachusetts United States (City)', 'Canberra': 'Canberra Australia (CIty)', 'Cardiff': 'Cardiff United Kingdom (CIty)', 'Chicago': 'Chicago Illinois United States (City)', 'Chicago Lzster G Telser': 'Chicago Illinois United States (City)', 'Chicago, Illinoi': 'University Of Illinois Chicago', 'Chicago, Illinois': 'Chicago Illinois United States (City)', 'Chicago, Illinois, Usa': 'Chicago Illinois United States (City)', 'Columbus, Ohio Beénjamin Caplan': 'Columbus Ohio United States (CIty)', 'Diakarta, Indonesia *': 'Jakarta Indonesia (City)', 'Durham, N Carolina': 'Durham, North Carolina United States (City)', 'Durham, North Carolina': 'Durham, North Carolina United States (City)', 'Durham, North Carolina Lionel W Mcckenzie': 'Durham, North Carolina United States (City)', 'Edinburgh': 'Edinburgh United Kingdom (City)', 'Exeter': 'Exeter United Kingdom (City)', 'Geneva': 'Geneva Switzerland (CIty)', 'Glasgow': 'Glasgow United Kingdom (City)', 'Glasgow E M Chossudowsskky': 'Glasgow United Kingdom (City)', 'Hague, Holland': 'Hague Holland (City)', 'Hanover, New Hampshire': 'Hanover New Hampshire United States (City)', 'Harvard Epward H Chamberlin': 'Harvard (City)', 'Helsinki G': 'Helsinki Finland (City)', 'Ibadan, Nigeria': 'Ibadan Nigeria (City)', 'Jamaica': 'Jamaica (Country)', 'Jerusalem': 'Jerusalem Israel (City)', 'Jerusalem, Israel': 'Jerusalem Israel (City)', 'Kingston, Jamaica': 'Kingston Jamaica (City)', 'Lafayette, Indiana': 'Lafayette Indiana United States (City)', 'Lake Success, Ny': 'New York United States (City)', 'Liverpool': 'Liverpool United Kingdom (City)', 'London': 'London United Kingdom (City)', 'London And Jerusalem': 'London United Kingdom (City)', 'London G L S Shacele': 'London United Kingdom (City)', 'London K': 'London United Kingdom (City)', 'London K K F Zawadzei': 'London United Kingdom (City)', 'Long Island City': 'New York United States (City)', 'Makerere College !': 'Makerere College', 'Manchester': 'Manchester United Kingdom(City)', 'Manchester, England': 'Manchester United Kingdom(City)', 'Melbourne': 'Melbourne Australia (City)', 'Melbourne, Australia': 'Melbourne Australia (C ...

# %%
import numpy as np
#Replacing the nan values with a blank string so string processing can be used
testdata = testdata.replace(np.nan, '', regex=True)

#Creating the balnk columns that will be filled in during the splitting and consolidation
testdata["4_author_affs"] = ""
testdata["5_author_affs"] = ""

testdata["0_author_affs_consolidated"] = ""
testdata["0_author_affs_consolidated_0"] = ""
testdata["0_author_affs_consolidated_1"] = ""
testdata["0_author_affs_consolidated_2"] = ""
testdata["0_author_affs_consolidated_3"] = ""
testdata["0_author_affs_consolidated_4"] = ""

testdata["1_author_affs_consolidated"] = ""
testdata["1_author_affs_consolidated_0"] = ""
testdata["1_author_affs_consolidated_1"] = ""
testdata["1_author_affs_consolidated_2"] = ""
testdata["1_author_affs_consolidated_3"] = ""
testdata["1_author_affs_consolidated_4"] = ""

testdata["2_author_affs_consolidated"] = ""
testdata["2_author_affs_consolidated_0"] = ""
testdata["2_author_affs_consolidated_1"] = ""
testdata["2_author_affs_consolidated_2"] = ""
testdata["2_author_affs_consolidated_3"] = ""
testdata["2_author_affs_consolidated_4"] = ""

testdata["3_author_affs_consolidated"] = ""
testdata["3_author_affs_consolidated_0"] = ""
testdata["3_author_affs_consolidated_1"] = ""
testdata["3_author_affs_consolidated_2"] = ""
testdata["3_author_affs_consolidated_3"] = ""
testdata["3_author_affs_consolidated_4"] = ""

testdata["4_author_affs_consolidated"] = ""
testdata["4_author_affs_consolidated_0"] = ""
testdata["4_author_affs_consolidated_1"] = ""
testdata["4_author_affs_consolidated_2"] = ""
testdata["4_author_affs_consolidated_3"] = ""

testdata["5_author_affs_consolidated"] = ""
testdata["5_author_affs_consolidated_0"] = ""

for i in range(len(testdata)):
#for i in range(3430,3431):
#for i in range(3715,3716):
    authors = testdata.iloc[i]['Authors_list']
    for auth_no in range(len(authors)):
        #print(testdata.iloc[i]['0_author_affs'])
        testdata.loc[i,str(auth_no)+'_author_affs'] =  re.sub(r'\.','',testdata.iloc[i][str(auth_no)+'_author_affs']).title()
        testdata.loc[i,str(auth_no)+'_author_affs'] =  re.sub(r'The ','',testdata.iloc[i][str(auth_no)+'_author_affs']).title()
        #print(testdata.iloc[i]['0_author_affs'])
        list = []

    #Loop through the list of incorrect spellings and replace with corrected spellings
        for key in consolidated_affiliations_dict.keys():
            if key in testdata.iloc[i][str(auth_no)+'_author_affs']:
                list.append(key)
                print((key))
                print(list)

    #If there is more than 1 match in the consolidation it needs to match on the longer one, solves for college issue
                if len(list) <= 1:
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated']  = re.sub(key, consolidated_affiliations_dict[key],testdata.iloc[i][str(auth_no)+'_author_affs']).strip().rstrip(',')
                else:
                    print(consolidated_affiliations_dict[list[0]])
                    print(consolidated_affiliations_dict[list[1]])
                    # For colleges
                    if(len(consolidated_affiliations_dict[list[0]]) == len(consolidated_affiliations_dict[list[1]])):
                        #print("HERE")
                        if len(list[0]) > len(list[1]):
                            print("If")
                            testdata.loc[i,str(auth_no)+'_author_affs_consolidated']  = re.sub(list[0], consolidated_affiliations_dict[list[0]],testdata.iloc[i][str(auth_no)+'_author_affs']).strip().rstrip(',')
                            #print(list[0])
                        # Full  University Of Illinois System Urbana-Champaign issue
                        elif len(list[1]) > len(list[0]):
                            print("Elif")
                            testdata.loc[i,str(auth_no)+'_author_affs_consolidated']  = re.sub(list[1], consolidated_affiliations_dict[list[1]],testdata.iloc[i][str(auth_no)+'_author_affs']).strip().rstrip(',')
                        else:
                            print("else")
                            first_fix = re.sub(list[1], consolidated_affiliations_dict[list[1]],testdata.iloc[i][str(auth_no)+'_author_affs']).strip().rstrip(',') 
                            testdata.loc[i,str(auth_no)+'_author_affs_consolidated']  = re.sub(key, consolidated_affiliations_dict[key],first_fix).strip().rstrip(',') 
                    else:
                        first_fix = re.sub(list[0], consolidated_affiliations_dict[list[0]],testdata.iloc[i][str(auth_no)+'_author_affs']).strip().rstrip(',') 
                        #print(first_fix)
                        testdata.loc[i,str(auth_no)+'_author_affs_consolidated']  = re.sub(key, consolidated_affiliations_dict[key],first_fix).strip().rstrip(',') 
        print(i)
        print('Full ',testdata.loc[i,str(auth_no)+'_author_affs_consolidated'])
        #else: 
        #    print("non existant")
        auths_affs_split_And = re.split(' And ', testdata.iloc[i][str(auth_no)+'_author_affs_consolidated'])
        #print(auths_affs_split_And)
        #print(len(auths_affs_split_And))

        for aff in range(len(auths_affs_split_And)):
            testdata.loc[i,str(auth_no)+'_author_affs_consolidated_'+str(aff)]  = auths_affs_split_And[aff].strip().rstrip(',') 
            print('Auth', str(auth_no), str(aff) , testdata.loc[i,str(auth_no)+'_author_affs_consolidated_'+str(aff)])

        auths_affs_split_comma = re.split(',', testdata.iloc[i][str(auth_no)+'_author_affs_consolidated_0'])
        #print(auths_affs_split_And)
        #print(len(auths_affs_split_And))
        if len(auths_affs_split_comma) == 2:
            for affcomma in range(len(auths_affs_split_comma)):
                testdata.loc[i,str(auth_no)+'_author_affs_consolidated_0']  = auths_affs_split_comma[0].strip().rstrip(',')
                if  testdata.loc[i,str(auth_no)+'_author_affs_consolidated_1'] == '':
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_1']  = auths_affs_split_comma[1].strip().rstrip(',')
                else:
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2']  = auths_affs_split_comma[1].strip().rstrip(',')
                print('Auth', str(auth_no), str(affcomma) , testdata.loc[i,str(auth_no)+'_author_affs_consolidated_'+str(affcomma)])
                print(testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2'])
        if len(auths_affs_split_comma) == 3:
            for affcomma in range(len(auths_affs_split_comma)):
                testdata.loc[i,str(auth_no)+'_author_affs_consolidated_0']  = auths_affs_split_comma[0].strip().rstrip(',')
                if  testdata.loc[i,str(auth_no)+'_author_affs_consolidated_1'] == '':
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_1']  = auths_affs_split_comma[1].strip().rstrip(',')
                else:
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2']  = auths_affs_split_comma[1].strip().rstrip(',')
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_3']  = auths_affs_split_comma[2].strip().rstrip(',')
                print('Auth', str(auth_no), str(affcomma) , testdata.loc[i,str(auth_no)+'_author_affs_consolidated_'+str(affcomma)])
                print(testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2'])
        if len(auths_affs_split_comma) == 4:
            for affcomma in range(len(auths_affs_split_comma)):
                testdata.loc[i,str(auth_no)+'_author_affs_consolidated_0']  = auths_affs_split_comma[0].strip().rstrip(',')
                if  testdata.loc[i,str(auth_no)+'_author_affs_consolidated_1'] == '':
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_1']  = auths_affs_split_comma[1].strip().rstrip(',')
                else:
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2']  = auths_affs_split_comma[1].strip().rstrip(',')
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_3']  = auths_affs_split_comma[2].strip().rstrip(',')
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_4']  = auths_affs_split_comma[3].strip().rstrip(',')

                print('Auth', str(auth_no), str(affcomma) , testdata.loc[i,str(auth_no)+'_author_affs_consolidated_'+str(affcomma)])
                print(testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2'])

    print(i)
# Out:
# Washington, Dc
# ['Washington, Dc']
# 0
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 0
# New York
# ['New York']
# New York University
# ['New York', 'New York University']
# New York United States (City)
# New York University
# York University
# ['New York', 'New York University', 'York University']
# New York United States (City)
# New York University
# 1
# Full  New York United States (City) University
# Auth 0 0 New York United States (City) University
# 1
# Berkeley
# ['Berkeley']
# California
# ['Berkeley', 'California']
# Berkeley California United States (City)
# California United States (State)
# University Of California, Berkeley
# ['Berkeley', 'California', 'University Of California, Berkeley']
# Berkeley California United States (City)
# California United States (State)
# University Of California
# ['Berkeley', 'California', 'University Of California, Berkeley', 'University Of California']
# Berkeley California United States (City)
# California United States (State)
# 2
# Full  University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System
#
# Auth 0 1 Berkeley California United States (City)
# Berkeley California United States (City)
# Berkeley
# ['Berkeley']
# California
# ['Berkeley', 'California']
# Berkeley California United States (City)
# California United States (State)
# University Of California, Berkeley
# ['Berkeley', 'California', 'University Of California, Berkeley']
# Berkeley California United States (City)
# California United States (State)
# University Of California
# ['Berkeley', 'California', 'University Of California, Berkeley', 'University Of California']
# Berkeley California United States (City)
# California United States (State)
# 2
# Full  University Of California System, Berkeley California United States (City)
# Auth 1 0 University Of California System, Berkeley California United States (City)
# Auth 1 0 University Of California System
#
# Auth 1 1 Berkeley California United States (City)
# Berkeley California United States (City)
# 2
# New York
# ['New York']
# New York University
# ['New York', 'New York University']
# New York United States (City)
# New York University
# York University
# ['New York', 'New York University', 'York University']
# New York United States (City)
# New York University
# 3
# Full  New York United States (City) University
# Auth 0 0 New York United States (City) University
# 3
# University Of Minnesota
# ['University Of Minnesota']
# 4
# Full  University Of Minnesota
# Auth 0 0 University Of Minnesota
# 4
# Ohio State University
# ['Ohio State University']
# 5
# Full  Ohio State University
# Auth 0 0 Ohio State University
# 5
# Stanford University
# ['Stanford University']
# 6
# Full  Stanford University
# Auth 0 0 Stanford University
# 6
# Harvard University
# ['Harvard University']
# 7
# Full  Harvard University
# Auth 0 0 Harvard University
# 7
# New York
# ['New York']
# New York University
# ['New York', 'New York University']
# New York United States (City)
# New York University
# York University
# ['New York', 'New York University', 'York University']
# New York United States (City)
# New York University
# 8
# Full  New York United States (City) University
# Auth 0 0 New York United States (City) University
# New York
# ['New York']
# New York University
# ['New York', 'New York University']
# New York United States (City)
# New York University
# York University
# ['New York', 'New York University', 'York University']
# New York United States (City)
# New York University
# 8
# Full  New York United States (City) University
# Auth 1 0 New York United States (City) University
# 8
# New York
# ['New York']
# New York University
# ['New York', 'New York University']
# New York United States (City)
# New York University
# York University
# ['New York', 'New York University', 'York University']
# New York United States (City)
# New York University
# 9
# Full  New York United States (City) University
# Auth 0 0 New York United States (City) University
# 9
# Iowa State College
# ['Iowa State College']
# 10
# Full  Iowa State College
# Auth 0 0 Iowa State College
# 10
# Colgate University
# ['Colgate University']
# 11
# Full  Colgate University
# Auth 0 0 Colgate University
# 11
# Harvard University
# ['Harvard University']
# 12
# Full  Harvard University
# Auth 0 0 Harvard University
# 12
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 13
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 13
# University Of Maryland
# ['University Of Maryland']
# 14
# Full  University Of Maryland System
# Auth 0 0 University Of Maryland System
# 14
# Us Department Of Agriculture
# ['Us Department Of Agriculture']
# 15
# Full  US Department Of Agriculture
# Auth 0 0 US Department Of Agriculture
# Us Department Of Agriculture
# ['Us Department Of Agriculture']
# 15
# Full  US Department Of Agriculture
# Auth 1 0 US Department Of Agriculture
# 15
# Ohio State University
# ['Ohio State University']
# 16
# Full  Ohio State University
# Auth 0 0 Ohio State University
# 16
# Iowa State College
# ['Iowa State College']
# 17
# Full  Iowa State College
# Auth 0 0 Iowa State College
# 17
# Duke University
# ['Duke University']
# 18
# Full  Duke University
# Auth 0 0 Duke University
# 18
# University Of North Carolina
# ['University Of North Carolina']
# 19
# Full  University Of North Carolina System
# Auth 0 0 University Of North Carolina System
# 19
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 20
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 20
# Vienna
# ['Vienna']
# 21
# Full  Vienna Austria (City)
# Auth 0 0 Vienna Austria (City)
# 21
# University Of Arizona
# ['University Of Arizona']
# 22
# Full  University Of Arizona
# Auth 0 0 University Of Arizona
# 22
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 23
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 23
# 24
# Full
# Auth 0 0
# 24
# Cornell University
# ['Cornell University']
# 25
# Full  Cornell University
# Auth 0 0 Cornell University
# 25
# Edinburgh
# ['Edinburgh']
# University Of Edinburgh
# ['Edinburgh', 'University Of Edinburgh']
# Edinburgh United Kingdom (City)
# University Of Edinburgh
# 26
# Full  University Of Edinburgh United Kingdom (City)
# Auth 0 0 University Of Edinburgh United Kingdom (City)
# 26
# University Of Minnesota
# ['University Of Minnesota']
# 27
# Full  University Of Minnesota
# Auth 0 0 University Of Minnesota
# 27
# New York
# ['New York']
# 28
# Full  New York United States (City) City
# Auth 0 0 New York United States (City) City
# 28
# Indiana Central College
# ['Indiana Central College']
# 29
# Full  Indiana University
# Auth 0 0 Indiana University
# 29
# University Of Arkansas
# ['University Of Arkansas']
# 30
# Full  University Of Arkansas
# Auth 0 0 University Of Arkansas
# 30
# University Of Illinois
# ['University Of Illinois']
# 31
# Full  University Of Illinois System
# Auth 0 0 University Of Illinois System
# 31
# Duke University
# ['Duke University']
# 32
# Full  Duke University
# Auth 0 0 Duke University
# 32
# 33
# Full
# Auth 0 0
# 33
# New York
# ['New York']
# 34
# Full  New York United States (City) City
# Auth 0 0 New York United States (City) City
# 34
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 35
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 35
# Duke University
# ['Duke University']
# 36
# Full  Duke University
# Auth 0 0 Duke University
# 36
# Washington, Dc
# ['Washington, Dc']
# 37
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 37
# Chicago
# ['Chicago']
# Central Ymca College, Chicago
# ['Chicago', 'Central Ymca College, Chicago']
# Chicago Illinois United States (City)
# Central YMCA Community College
# 38
# Full  Central YMCA Community College Illinois United States (City)
# Auth 0 0 Central YMCA Community College Illinois United States (City)
# 38
# Brown University
# ['Brown University']
# 39
# Full  Brown University
# Auth 0 0 Brown University
# 39
# Brown University
# ['Brown University']
# 40
# Full  Brown University
# Auth 0 0 Brown University
# 40
# Iowa State College
# ['Iowa State College']
# 41
# Full  Iowa State College
# Auth 0 0 Iowa State College
# 41
# Washington, Dc
# ['Washington, Dc']
# 42
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 42
# New York
# ['New York']
# 43
# Full  New York United States (City) City
# Auth 0 0 New York United States (City) City
# 43
# Pennsylvania
# ['Pennsylvania']
# Pennsylvania State College
# ['Pennsylvania', 'Pennsylvania State College']
# Pittsburgh Pennslyvania United States (City)
# Pennsylvania State University
# 44
# Full  Pittsburgh Pennslyvania United States (City) State College
# Auth 0 0 Pittsburgh Pennslyvania United States (City) State College
# 44
# Brown University
# ['Brown University']
# 45
# Full  Brown University
# Auth 0 0 Brown University
# 45
# Long Island City
# ['Long Island City']
# 46
# Full  New York United States (City)
# Auth 0 0 New York United States (City)
# 46
# Columbia University
# ['Columbia University']
# 47
# Full  Columbia University
# Auth 0 0 Columbia University
# 47
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 48
# Full  University Of Chicago Illinois United States (City) And Cowles Commission
# Auth 0 0 University Of Chicago Illinois United States (City)
# Auth 0 1 Cowles Commission
# 48
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 49
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 49
# Columbia University
# ['Columbia University']
# 50
# Full  Columbia University
# Auth 0 0 Columbia University
# 50
# Washington, Dc
# ['Washington, Dc']
# 51
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 51
# Brooklyn, New York
# ['Brooklyn, New York']
# New York
# ['Brooklyn, New York', 'New York']
# Brooklyn New York United States (City)
# New York United States (City)
# 52
# Full  Brooklyn New York United States (City) United States (City)
# Auth 0 0 Brooklyn New York United States (City) United States (City)
# 52
# 53
# Full
# Auth 0 0
# 53
# 54
# Full
# Auth 0 0
# 54
# Washington, Dc
# ['Washington, Dc']
# 55
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 55
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 56
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 56
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 57
# Full  Princeton University
# Auth 0 0 Princeton University
# 57
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 58
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 58
# Babson Institute
# ['Babson Institute']
# 59
# Full  Babson Institute
# Auth 0 0 Babson Institute
# 59
# Cambridge
# ['Cambridge']
# Cambridge, Mass
# ['Cambridge', 'Cambridge, Mass']
# Cambridge Massachusetts United States (City)
# Cambridge Massachusetts United States (City)
# Elif
# Cambridge, Massachusetts
# ['Cambridge', 'Cambridge, Mass', 'Cambridge, Massachusetts']
# Cambridge Massachusetts United States (City)
# Cambridge Massachusetts United States (City)
# Elif
# 60
# Full  Cambridge Massachusetts United States (City)achusetts
# Auth 0 0 Cambridge Massachusetts United States (City)achusetts
# 60
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 61
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 61
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 62
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 62
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 63
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 63
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 64
# Full  Princeton University
# Auth 0 0 Princeton University
# 64
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 65
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 65
# Washington, Dc
# ['Washington, Dc']
# 66
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 66
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 67
# Full  Princeton University
# Auth 0 0 Princeton University
# 67
# Lehigh University
# ['Lehigh University']
# 68
# Full  Lehigh University
# Auth 0 0 Lehigh University
# 68
# Brown University
# ['Brown University']
# 69
# Full  Brown University
# Auth 0 0 Brown University
# 69
# Washington, Dc
# ['Washington, Dc']
# 70
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 70
# 71
# Full
# Auth 0 0
# 71
# Full
# Auth 1 0
# 71
# Department Of Finance, Ottawa
# ['Department Of Finance, Ottawa']
# 72
# Full  Department Of Finance Canada
# University Of Pennsylvania
# ['Pennsylvania', 'University Of Pennsylvania']
# Pittsburgh Pennslyvania United States (City)
# University Of Pennsylvania
# 87
# Full  University Of Pittsburgh Pennslyvania United States (City)
# Auth 3 0 University Of Pittsburgh Pennslyvania United States (City)
# 87
# Haverford College
# ['Haverford College']
# 88
# Full  Haverford College
# Auth 0 0 Haverford College
# 88
# Vassar College
# ['Vassar College']
# 89
# Full  Vassar College
# Auth 0 0 Vassar College
# 89
# 90
# Full
# Auth 0 0
# 90
# Full
# Auth 1 0
# 90
# National Bureau Of Economic Research
# ['National Bureau Of Economic Research']
# 91
# Full  National Bureau Of Economic Research, Inc
# Auth 0 0 National Bureau Of Economic Research, Inc
# Auth 0 0 National Bureau Of Economic Research
#
# Auth 0 1 Inc
# Inc
# 91
# Columbia University
# ['Columbia University']
# 92
# Full  Columbia University
# Auth 0 0 Columbia University
# 92
# Brown University
# ['Brown University']
# 93
# Full  Brown University
# Auth 0 0 Brown University
# 93
# Harvard University
# ['Harvard University']
# 94
# Full  Harvard University
# Auth 0 0 Harvard University
# 94
# Washington, Dc
# ['Washington, Dc']
# 95
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 95
# Bowdoin College
# ['Bowdoin College']
# 96
# Full  Bowdoin College
# Auth 0 0 Bowdoin College
# 96
# Washington, Dc
# ['Washington, Dc']
# 97
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 97
# Washington, Dc
# ['Washington, Dc']
# Harvard University
# ['Washington, Dc', 'Harvard University']
# Washington DC United States (City)
# Harvard University
# 98
# Full  Harvard University And Washington DC United States (City)
# Auth 0 0 Harvard University
# Auth 0 1 Washington DC United States (City)
# Washington, Dc
# ['Washington, Dc']
# Harvard University
# ['Washington, Dc', 'Harvard University']
# Washington DC United States (City)
# Harvard University
# 98
# Full  Harvard University And Washington DC United States (City)
# Auth 1 0 Harvard University
# Auth 1 1 Washington DC United States (City)
# 98
# Wayland, Massachusetts
# ['Wayland, Massachusetts']
# 99
# Full  Wayland Massachusetts United States (City)
# Auth 0 0 Wayland Massachusetts United States (City)
# 99
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 100
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 100
# University Of Virginia
# ['University Of Virginia']
# 101
# Full  University Of Virginia
# Auth 0 0 University Of Virginia
# 101
# St John'S University
# ["St John'S University"]
# 102
# Full  St John's University
# Auth 0 0 St John's University
# 102
# Washington, Dc
# ['Washington, Dc']
# 103
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 103
# Harvard University
# ['Harvard University']
# 104
# Full  Harvard University
# Auth 0 0 Harvard University
# 104
# California
# ['California']
# University Of Southern California
# ['California', 'University Of Southern California']
# California United States (State)
# University Of Southern California
# 105
# Full  University Of Southern California United States (State)
# Auth 0 0 University Of Southern California United States (State)
# 105
# University Of Texas
# ['University Of Texas']
# 106
# Full  University Of Texas System
# Full
# Auth 0 0
# 306
# 307
# Full
# Auth 0 0
# 307
# 308
# Full
# Auth 0 0
# 308
# 309
# Full
# Auth 0 0
# 309
# 310
# Full
# Auth 0 0
# 310
# 311
# Full
# Auth 0 0
# 311
# 312
# Full
# Auth 0 0
# 312
# 313
# Full
# Auth 0 0
# 313
# 314
# Full
# Auth 0 0
# 314
# 315
# Full
# Auth 0 0
# 315
# 316
# Full
# Auth 0 0
# 316
# 317
# Full
# Auth 0 0
# 317
# 318
# Full
# Auth 0 0
# 318
# 319
# Full
# Auth 0 0
# 319
# 320
# Full
# Auth 0 0
# 320
# 321
# Full
# Auth 0 0
# 321
# Full
# Auth 1 0
# 321
# 322
# Full
# Auth 0 0
# 322
# Full
# Auth 1 0
# 322
# 323
# Full
# Auth 0 0
# 323
# 324
# Full
# Auth 0 0
# 324
# 325
# Full
# Auth 0 0
# 325
# 326
# Full
# Auth 0 0
# 326
# 327
# Full
# Auth 0 0
# 327
# 328
# Full
# Auth 0 0
# 328
# Full
# Auth 1 0
# 328
# 329
# Full
# Auth 0 0
# 329
# 330
# Full
# Auth 0 0
# 330
# 331
# Full
# Auth 0 0
# 331
# Duke University
# ['Duke University']
# 332
# Full  Duke University
# Auth 0 0 Duke University
# 332
# Stanford University
# ['Stanford University']
# 333
# Full  Stanford University
# Auth 0 0 Stanford University
# 333
# Columbia University
# ['Columbia University']
# 334
# Full  Columbia University
# Auth 0 0 Columbia University
# 334
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 335
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 335
# Tokyo
# ['Tokyo']
# Tokyo, Japan
# ['Tokyo', 'Tokyo, Japan']
# Tokyo Japan (City)
# Tokyo Japan (City)
# Elif
# University Of Wisconsin
# ['Tokyo', 'Tokyo, Japan', 'University Of Wisconsin']
# Tokyo Japan (City)
# Tokyo Japan (City)
# Elif
# 336
# Full  University Of Wisconsin; Pro Tem, Tokyo Japan (City)
# Auth 0 0 University Of Wisconsin; Pro Tem, Tokyo Japan (City)
# Auth 0 0 University Of Wisconsin; Pro Tem
#
# Auth 0 1 Tokyo Japan (City)
# Tokyo Japan (City)
# 336
# University Of Washington
# ['University Of Washington']
# 337
# Full  University Of Washington
# Auth 0 0 University Of Washington
# University Of Washington
# ['University Of Washington']
# 337
# Full  University Of Washington
# Auth 1 0 University Of Washington
# University Of Washington
# ['University Of Washington']
# 337
# Full  University Of Washington
# Auth 2 0 University Of Washington
# 337
# Harvard University
# ['Harvard University']
# 338
# Full  Harvard University
# Auth 0 0 Harvard University
# 338
# University Of Virginia
# ['University Of Virginia']
# 339
# Full  University Of Virginia
# Auth 0 0 University Of Virginia
# 339
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 340
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 340
# Columbia University
# ['Columbia University']
# 341
# Full  Columbia University
# Auth 0 0 Columbia University
# 341
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 342
# Full  Princeton University
# Auth 0 0 Princeton University
# 342
# University Of Buffalo
# ['University Of Buffalo']
# 343
# Full  University Of Buffalo
# Auth 0 0 University Of Buffalo
# 343
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 344
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 344
# 345
# Full
# Auth 0 0
# 345
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 346
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 346
# University Of Minnesota
# ['University Of Minnesota']
# 347
# Full  University Of Minnesota
# Auth 0 0 University Of Minnesota
# 347
# Duke University
# ['Duke University']
# 348
# Full  Duke University
# Auth 0 0 Duke University
# 348
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 349
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 349
# California
# ['California']
# University Of California At Los Angeles
# ['California', 'University Of California At Los Angeles']
# California United States (State)
# UCLA
# University Of California
# ['California', 'University Of California At Los Angeles', 'University Of California']
# California United States (State)
# UCLA
# 350
# Full  University Of California System United States (State) At Los Angeles
# Auth 0 0 University Of California System United States (State) At Los Angeles
# 350
# Rutgers University
# ['Rutgers University']
# 351
# Full  Rutgers University
# Auth 0 0 Rutgers University
# 351
# 352
# Full
# Auth 0 0
# 352
# Full
# Auth 1 0
# 352
# California
# ['California']
# University Of California, Los Angeles
# ['California', 'University Of California, Los Angeles']
# California United States (State)
# UCLA
# University Of California
# ['California', 'University Of California, Los Angeles', 'University Of California']
# California United States (State)
# UCLA
# 353
# Full  University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State)
#
# Auth 0 1 Los Angeles
# Los Angeles
# 353
# Johns Hopkins University
# ['Johns Hopkins University']
# 354
# Full  Johns Hopkins University
# Auth 0 0 Johns Hopkins University
# 354
# Butler University
# ['Butler University']
# 355
# Full  Butler University
# Auth 0 0 Butler University
# 355
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 356
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 356
# 357
# Full
# Auth 0 0
# 357
# Toronto
# ['Toronto']
# University Of Toronto
# ['Toronto', 'University Of Toronto']
# Toronoto Canada (City)
# University Of Toronto
# 358
# Full  University Of Toronoto Canada (City)
# Auth 0 0 University Of Toronoto Canada (City)
# 358
# Massachusetts Institute Of Technology
# ['Massachusetts Institute Of Technology']
# 359
# Full  Massachusetts Institute Of Technology
# Auth 0 0 Massachusetts Institute Of Technology
# 359
# Duke University
# ['Duke University']
# 360
# Full  Duke University
# Auth 0 0 Duke University
# 360
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 361
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 361
# Ohio State University
# ['Ohio State University']
# 362
# Full  Ohio State University
# Auth 0 0 Ohio State University
# 362
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 363
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 363
# Northwestern University
# ['Northwestern University']
# 364
# Full  Northwestern University
# Auth 0 0 Northwestern University
# 364
# United States Treasury Department
# ['United States Treasury Department']
# 365
# Full  United States Treasury Department
# Auth 0 0 United States Treasury Department
# 365
# 366
# Full
# Auth 0 0
# 366
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 367
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 367
# Duke University
# ['Duke University']
# 368
# Full  Duke University
# Auth 0 0 Duke University
# 368
# Texas A And M College
# ['Texas A And M College']
# 369
# Full  Texas A & M University
# Auth 0 0 Texas A & M University
# 369
# Washington, Dc
# ['Washington, Dc']
# 370
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 370
# Columbia University
# ['Columbia University']
# 371
# Full  Columbia University
# Auth 0 0 Columbia University
# Columbia University
# ['Columbia University']
# 371
# Full  Columbia University
# Auth 1 0 Columbia University
# 371
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 372
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 372
# Drake University
# ['Drake University']
# 373
# Full  Drake University
# Auth 0 0 Drake University
# 373
# Vanderbilt University
# ['Vanderbilt University']
# 374
# Full  Vanderbilt University
# Auth 0 0 Vanderbilt University
# 374
# Food Research Institute, Stanford University
# ['Food Research Institute, Stanford University']
# Food Research Institute
# ['Food Research Institute, Stanford University', 'Food Research Institute']
# Stanford University
# Food Research Institute
# Stanford University
# ['Food Research Institute, Stanford University', 'Food Research Institute', 'Stanford University']
# Stanford University
# Food Research Institute
# 375
# Full  Stanford University
# Auth 0 0 Stanford University
# 375
# Harvard University
# ['Harvard University']
# 376
# Full  Harvard University
# Auth 0 0 Harvard University
# Harvard University
# ['Harvard University']
# 376
# Full  Harvard University
# Auth 1 0 Harvard University
# 376
# Harvard University
# ['Harvard University']
# 377
# Full  Harvard University
# Auth 0 0 Harvard University
# 377
# Michigan
# ['Michigan']
# Survey Research Center, University Of Michigan
# ['Michigan', 'Survey Research Center, University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# University Of Michigan
# ['Michigan', 'Survey Research Center, University Of Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 378
# Full  Survey Research Center, University Of Michigan United States (State)
# Auth 0 0 Survey Research Center, University Of Michigan United States (State)
# Auth 0 0 Survey Research Center
#
# Auth 0 1 University Of Michigan United States (State)
# University Of Michigan United States (State)
# 378
# California
# ['California']
# University Of California, Los Angeles
# ['California', 'University Of California, Los Angeles']
# California United States (State)
# UCLA
# University Of California
# ['California', 'University Of California, Los Angeles', 'University Of California']
# California United States (State)
# UCLA
# 379
# Full  University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State)
#
# Auth 0 1 Los Angeles
# Los Angeles
# 379
# University Of Arkansas
# ['University Of Arkansas']
# 380
# Full  University Of Arkansas
# Auth 0 0 University Of Arkansas
# 380
# Washington, Dc
# ['Washington, Dc']
# 381
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 381
# University Of Wisconsin
# ['University Of Wisconsin']
# 382
# Full  University Of Wisconsin
# Auth 0 0 University Of Wisconsin
# 382
# Food Research Institute, Stanford University
# ['Food Research Institute, Stanford University']
# Food Research Institute
# ['Food Research Institute, Stanford University', 'Food Research Institute']
# Stanford University
# Food Research Institute
# Stanford University
# ['Food Research Institute, Stanford University', 'Food Research Institute', 'Stanford University']
# Stanford University
# Food Research Institute
# 383
# Full  Stanford University
# Auth 0 0 Stanford University
# 383
# Iowa State College
# ['Iowa State College']
# 384
# Full  Iowa State College
# Auth 0 0 Iowa State College
# 384
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 385
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 385
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 386
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 386
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 387
# Full  Princeton University
# Auth 0 0 Princeton University
# 387
# Iowa State College
# ['Iowa State College']
# 388
# Full  Iowa State College
# Auth 0 0 Iowa State College
# 388
# Massachusetts Institute Of Technology
# ['Massachusetts Institute Of Technology']
# 389
# Full  Massachusetts Institute Of Technology
# Auth 0 0 Massachusetts Institute Of Technology
# 389
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 390
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 390
# Duke University
# ['Duke University']
# 391
# Full  Duke University
# Auth 0 0 Duke University
# 391
# Berkeley
# ['Berkeley']
# California
# ['Berkeley', 'California']
# Berkeley California United States (City)
# California United States (State)
# University Of California (Berkeley)
# ['Berkeley', 'California', 'University Of California (Berkeley)']
# Berkeley California United States (City)
# California United States (State)
# University Of California
# ['Berkeley', 'California', 'University Of California (Berkeley)', 'University Of California']
# Berkeley California United States (City)
# California United States (State)
# 392
# Full  University Of California System (Berkeley California United States (City))
# Auth 0 0 University Of California System (Berkeley California United States (City))
# 392
# Columbia University
# ['Columbia University']
# 393
# Full  Columbia University
# Auth 0 0 Columbia University
# 393
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 394
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 394
# American University
# ['American University']
# 395
# Full  American University
# Auth 0 0 American University
# 395
# 396
# Full
# Auth 0 0
# 396
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 397
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 397
# University Of Wisconsin
# ['University Of Wisconsin']
# 398
# Full  University Of Wisconsin
# Auth 0 0 University Of Wisconsin
# 398
# Michigan
# ['Michigan']
# Michigan State College
# ['Michigan', 'Michigan State College']
# Michigan United States (State)
# Michigan State College
# 399
# Full  Michigan United States (State) State College
# Auth 0 0 Michigan United States (State) State College
# 399
# 400
# Full
# Auth 0 0
# 400
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 401
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 401
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 402
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 402
# Berkeley
# ['Berkeley']
# California
# ['Berkeley', 'California']
# Berkeley California United States (City)
# California United States (State)
# University Of California, Berkeley
# ['Berkeley', 'California', 'University Of California, Berkeley']
# Berkeley California United States (City)
# California United States (State)
# University Of California
# ['Berkeley', 'California', 'University Of California, Berkeley', 'University Of California']
# Berkeley California United States (City)
# California United States (State)
# 403
# Full  University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System
#
# Auth 0 1 Berkeley California United States (City)
# Berkeley California United States (City)
# 403
# Duke University
# ['Duke University']
# 404
# Full  Duke University
# Auth 0 0 Duke University
# 404
# University Of Florida
# ['University Of Florida']
# 405
# Full  University Of Florida
# Auth 0 0 University Of Florida
# 405
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 406
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 406
# Marquette University
# ['Marquette University']
# 407
# Full  Marquette University
# Auth 0 0 Marquette University
# 407
# Oxford
# ['Oxford']
# Oxford University
# ['Oxford', 'Oxford University']
# University Of Oxford
# University Of Oxford
# Elif
# Trinity College, Oxford
# ['Oxford', 'Oxford University', 'Trinity College, Oxford']
# University Of Oxford
# University Of Oxford
# Elif
# Trinity College
# ['Oxford', 'Oxford University', 'Trinity College, Oxford', 'Trinity College']
# University Of Oxford
# University Of Oxford
# Elif
# Trinity College, Oxford University
# ['Oxford', 'Oxford University', 'Trinity College, Oxford', 'Trinity College', 'Trinity College, Oxford University']
# University Of Oxford
# University Of Oxford
# Elif
# 408
# Full  Trinity College, University Of Oxford
# Auth 0 0 Trinity College, University Of Oxford
# Auth 0 0 Trinity College
#
# Auth 0 1 University Of Oxford
# University Of Oxford
# 408
# California
# ['California']
# University Of California, Los Angeles
# ['California', 'University Of California, Los Angeles']
# California United States (State)
# UCLA
# University Of California
# ['California', 'University Of California, Los Angeles', 'University Of California']
# California United States (State)
# UCLA
# 409
# Full  University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State)
#
# Auth 0 1 Los Angeles
# Los Angeles
# 409
# Oberlin College
# ['Oberlin College']
# 410
# Full  Oberlin College
# Auth 0 0 Oberlin College
# 410
# London
# ['London']
# London School Of Economics
# ['London', 'London School Of Economics']
# London United Kingdom (City)
# London School Of Economics & Political Sciences
# 411
# Full  London United Kingdom (City) School Of Economics And Political Science
# Auth 0 0 London United Kingdom (City) School Of Economics
# Auth 0 1 Political Science
# 411
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 412
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 412
# Full  University Of Michigan United States (State)
# Auth 1 0 University Of Michigan United States (State)
# 412
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 413
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 413
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 414
# Full  Princeton University
# Auth 0 0 Princeton University
# 414
# University Of Wisconsin
# ['University Of Wisconsin']
# 415
# Full  University Of Wisconsin
# Auth 0 0 University Of Wisconsin
# 415
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 416
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 416
# Johns Hopkins University
# ['Johns Hopkins University']
# 417
# Full  Johns Hopkins University
# Auth 0 0 Johns Hopkins University
# Johns Hopkins University
# ['Johns Hopkins University']
# 417
# Full  Johns Hopkins University
# Auth 1 0 Johns Hopkins University
# 417
# California
# ['California']
# University Of California, Los Angeles
# ['California', 'University Of California, Los Angeles']
# California United States (State)
# UCLA
# University Of California
# ['California', 'University Of California, Los Angeles', 'University Of California']
# California United States (State)
# UCLA
# 418
# Full  University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State)
#
# Auth 0 1 Los Angeles
# Los Angeles
# 418
# 419
# Full
# Auth 0 0
# 419
# Full
# Auth 1 0
# 419
# Columbia University
# ['Columbia University']
# 420
# Full  Columbia University
# Auth 0 0 Columbia University
# 420
# Vanderbilt University
# ['Vanderbilt University']
# 421
# Full  Vanderbilt University
# Auth 0 0 Vanderbilt University
# 421
# Rand Corporation
# ['Rand Corporation']
# 422
# Full  Rand Corporation
# Auth 0 0 Rand Corporation
# 422
# Berkeley
# ['Berkeley']
# California
# ['Berkeley', 'California']
# Berkeley California United States (City)
# California United States (State)
# University Of California, Berkeley
# ['Berkeley', 'California', 'University Of California, Berkeley']
# Berkeley California United States (City)
# California United States (State)
# University Of California
# ['Berkeley', 'California', 'University Of California, Berkeley', 'University Of California']
# Berkeley California United States (City)
# California United States (State)
# 423
# Full  University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System
#
# Auth 0 1 Berkeley California United States (City)
# Berkeley California United States (City)
# 423
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 424
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 424
# Columbia University
# ['Columbia University']
# 425
# Full  Columbia University
# Auth 0 0 Columbia University
# 425
# Rand Corporation
# ['Rand Corporation']
# 426
# Full  Rand Corporation
# Auth 0 0 Rand Corporation
# 426
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 427
# ...
# Auth 1 1 US Department Of Commerce
# Dartmouth College
# ['Dartmouth College']
# 3794
# Full  Dartmouth College
# Auth 2 0 Dartmouth College
# 3794
# University Of Utah
# ['University Of Utah']
# 3795
# Full  University Of Utah
# Auth 0 0 University Of Utah
# Stanford University
# ['Stanford University']
# 3795
# Full  Stanford University
# Auth 1 0 Stanford University
# 3795
# Harvard University
# ['Harvard University']
# Toulouse School Of Economics
# ['Harvard University', 'Toulouse School Of Economics']
# Harvard University
# Toulouse School Of Economics
# 3796
# Full  Harvard University And Toulouse School Of Economics
# Auth 0 0 Harvard University
# Auth 0 1 Toulouse School Of Economics
# 3796
# Stamford University
# ['Stamford University']
# National Bureau Of Economic Research
# ['Stamford University', 'National Bureau Of Economic Research']
# Stanford University
# National Bureau Of Economic Research
# 3797
# Full  Stanford University And National Bureau Of Economic Research
# Auth 0 0 Stanford University
# Auth 0 1 National Bureau Of Economic Research
# California
# ['California']
# National Bureau Of Economic Research
# ['California', 'National Bureau Of Economic Research']
# California United States (State)
# National Bureau Of Economic Research
# 3797
# Full  Univesity Of California United States (State), Los Angeles And National Bureau Of Economic Research
# Auth 1 0 Univesity Of California United States (State), Los Angeles
# Auth 1 1 National Bureau Of Economic Research
# Auth 1 0 Univesity Of California United States (State)
# Los Angeles
# 3812
# Full  Yale University
# Auth 1 0 Yale University
# Chinese University Of Hong Kong
# ['Chinese University Of Hong Kong']
# University Of Hong Kong
# ['Chinese University Of Hong Kong', 'University Of Hong Kong']
# Chinese University Of Hong Kong
# University Of Hong Kong
# 3812
# Full  Chinese University Of Hong Kong
# Auth 2 0 Chinese University Of Hong Kong
# 3812
# Massachusetts Institute Of Technology
# ['Massachusetts Institute Of Technology']
# 3813
# Full  Massachusetts Institute Of Technology
# Auth 0 0 Massachusetts Institute Of Technology
# Stockholm University
# ['Stockholm University']
# 3813
# Full  Stockholm University
# Auth 1 0 Stockholm University
# 3813
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 3814
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 3814
# Toronto
# ['Toronto']
# University Of Toronto
# ['Toronto', 'University Of Toronto']
# Toronoto Canada (City)
# University Of Toronto
# 3815
# Full  University Of Toronoto Canada (City)
# Auth 0 0 University Of Toronoto Canada (City)
# Toronto
# ['Toronto']
# University Of Toronto
# ['Toronto', 'University Of Toronto']
# Toronoto Canada (City)
# University Of Toronto
# 3815
# Full  University Of Toronoto Canada (City)
# Auth 1 0 University Of Toronoto Canada (City)
# 3815
# Bristol
# ['Bristol']
# Public Organisation, Imperial College
# ['Bristol', 'Public Organisation, Imperial College']
# Bristol United Kingdom (City)
# Imperial College London
# Imperial College
# ['Bristol', 'Public Organisation, Imperial College', 'Imperial College']
# Bristol United Kingdom (City)
# Imperial College London
# University Of Bristol
# ['Bristol', 'Public Organisation, Imperial College', 'Imperial College', 'University Of Bristol']
# Bristol United Kingdom (City)
# Imperial College London
# 3816
# Full  University Of Bristol United Kingdom (City), Centre For Market And Public Organisation, Imperial College, And Centre For
# Auth 0 0 University Of Bristol United Kingdom (City), Centre For Market
# Auth 0 1 Public Organisation, Imperial College
# Auth 0 2 Centre For
# Auth 0 0 University Of Bristol United Kingdom (City)
# Centre For Market
# Auth 0 1 Public Organisation, Imperial College
# Centre For Market
# London
# ['London']
# London School Of Economics
# ['London', 'London School Of Economics']
# London United Kingdom (City)
# London School Of Economics & Political Sciences
# 3816
# Full  London United Kingdom (City) School Of Economics, Centre For Economic Performance, National Bureau Of Economic
# Auth 1 0 London United Kingdom (City) School Of Economics, Centre For Economic Performance, National Bureau Of Economic
# Auth 1 0 London United Kingdom (City) School Of Economics
#
# Auth 1 1 Centre For Economic Performance
# Centre For Economic Performance
# Auth 1 2 Centre For Economic Performance
# Centre For Economic Performance
# 3816
# Paris
# ['Paris']
# Paris School Of Economics
# ['Paris', 'Paris School Of Economics']
# Paris France (City)
# Paris School Of Economics
# 3817
# Full  Paris France (City) School Of Economics
# Auth 0 0 Paris France (City) School Of Economics
# London
# ['London']
# Paris
# ['London', 'Paris']
# London United Kingdom (City)
# Paris France (City)
# Paris School Of Economics
# ['London', 'Paris', 'Paris School Of Economics']
# London United Kingdom (City)
# Paris France (City)
# University College London
# Auth 1 0 University Of California System United States (State), Los Angeles
# Auth 1 1 National Bureau Of Economic Research
# Auth 1 0 University Of California System United States (State)
# Los Angeles
# Auth 1 1 National Bureau Of Economic Research
# Los Angeles
# 3821
# Columbia University
# ['Columbia University']
# 3822
# Full  Columbia University
# Auth 0 0 Columbia University
# 3822
# Full
# Auth 1 0
# 3822
# Full
# Auth 2 0
# Columbia University
# ['Columbia University']
# 3822
# Full  Columbia University
# Auth 3 0 Columbia University
# 3822

# %%
#Checking the newly created column names
print(testdata.columns.values)
# Out:
# ['Journal_Name' 'Authors_count' 'Authors_list' 'Article_ID' 'content_type'
#  'stable_url' 'Ref_type' 'ref_string' 'ref_string_clean1' 'year'
#  '0_author' '0_author_affs' '1_author' '1_author_affs' '2_author'
#  '2_author_affs' '3_author' '3_author_affs' '4_author' '4_author_affs'
#  '5_author_affs' '0_author_affs_consolidated'
#  '0_author_affs_consolidated_0' '0_author_affs_consolidated_1'
#  '0_author_affs_consolidated_2' '0_author_affs_consolidated_3'
#  '0_author_affs_consolidated_4' '1_author_affs_consolidated'
#  '1_author_affs_consolidated_0' '1_author_affs_consolidated_1'
#  '1_author_affs_consolidated_2' '1_author_affs_consolidated_3'
#  '1_author_affs_consolidated_4' '2_author_affs_consolidated'
#  '2_author_affs_consolidated_0' '2_author_affs_consolidated_1'
#  '2_author_affs_consolidated_2' '2_author_affs_consolidated_3'
#  '2_author_affs_consolidated_4' '3_author_affs_consolidated'
#  '3_author_affs_consolidated_0' '3_author_affs_consolidated_1'
#  '3_author_affs_consolidated_2' '3_author_affs_consolidated_3'
#  '3_author_affs_consolidated_4' '4_author_affs_consolidated'
#  '4_author_affs_consolidated_0' '4_author_affs_consolidated_1'
#  '4_author_affs_consolidated_2' '4_author_affs_consolidated_3'
#  '5_author_affs_consolidated' '5_author_affs_consolidated_0']

# %%
# Only keeping the desired columns
testdata = testdata[['Journal_Name' ,'Authors_count', 'Authors_list', 'Article_ID', 'content_type',
 'stable_url', 'Ref_type' ,'ref_string', 'ref_string_clean1', 'year',
 '0_author_affs', 
 '0_author_affs_consolidated',
 '0_author_affs_consolidated_0',
 '0_author_affs_consolidated_1', 
 '0_author_affs_consolidated_2', 
 '1_author_affs', 
 '1_author_affs_consolidated',
 '1_author_affs_consolidated_0',
 '1_author_affs_consolidated_1',
  '1_author_affs_consolidated_2',
 '2_author_affs',
 '2_author_affs_consolidated',
 '2_author_affs_consolidated_0',
 '2_author_affs_consolidated_1', 
 '2_author_affs_consolidated_2' ,
 '3_author_affs',
 '3_author_affs_consolidated', 
 '3_author_affs_consolidated_0',
 '3_author_affs_consolidated_1',
 '4_author_affs',
 '4_author_affs_consolidated',
 '4_author_affs_consolidated_0',
 '5_author_affs', 
 '5_author_affs_consolidated']]

# %%
# Excel output to get an overview of the data
#This Should be changed to output to your local storage
testdata.to_excel('/Users/MattJohnson/Desktop/Affiliations/2. Extracting affilitations from Tesseract/2.1. Consolidation/2.1.A. Data created in 2.1/JPE first pass tesseract affiliations.xlsx')
