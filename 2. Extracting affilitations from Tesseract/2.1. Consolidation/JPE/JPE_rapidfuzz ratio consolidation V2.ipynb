# %% [markdown]
# # Using rapidfuzz to extract affiliatuons from JPE

# %% [markdown]
# First the JSON output file from tezseract is read in and made into a useable dataframe

# %%
#Importing the libraries
import json
import pandas as pd
import requests
import re

# Import JSON file from Github repository
tesseract_input = requests.get('https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/1_Input%20files%20and%20processing%20input%20files/1_1_Input%20files/Tesseract%20affiliation%20output/JPE/JPE_affiliation_output_1940_2010.json')
json_data = tesseract_input.json()

#Use the 2 lines below for a local import of the data
#tesseract_input = open('/Users/MattJohnson/Desktop/Affiliations/1_Input files and processing input files/1_1_Input files/Tesseract affiliation output/JPE/JPE_affiliation_output_1940_2010.json')
#json_data = json.load(tesseract_input)

# Define Journal and Dataframe
Journal_Name = 'JPE'
Reference_Data_List = []

# Extract Json Data into dataframe
for key1, value1 in json_data.items():
    Article_ID = key1
    content_type = value1["content_type"]
    author_list = value1["authors"]
    authorsNo = len(author_list)
    stable_url = value1["stable_url"]
    for key2 in value1["affiliations"]:
        Ref_type = key2
        if key2 == "found":
            ref_string = value1["affiliations"][key2]
        else: 
            for key3 in value1["affiliations"]["raw"]:
                #if len(value1["affiliations"]["raw"]) > 1:
                    #print(key1, "   ",len(value1["affiliations"]["raw"]))
                if key3 == "1":
                    #print(key3)
                    ref_string = value1["affiliations"][key2][key3]
                    #print(ref_string)

    Reference_Data_List.append({'Journal_Name' : Journal_Name,
    'Authors_count' : authorsNo, 
    'Authors_list' : author_list,
    'Article_ID' : Article_ID, 'content_type' : content_type,
    'stable_url' : stable_url, 
    'Ref_type': Ref_type,  'ref_string':ref_string })

# Create a dataframe from the extracted data
JPE_aff_ref_output_1940_2010 = pd.DataFrame.from_records(Reference_Data_List)

#Basice view of data
print(JPE_aff_ref_output_1940_2010.head())
print(JPE_aff_ref_output_1940_2010.shape)

#Use line below to send data to excel to view full file
#JPE_aff_ref_output_1940_2010.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/Working files/JPE_aff_ref_output_1940_2010.xlsx')
# Out:
#   Journal_Name  Authors_count  \
# 0          JPE              2
# 1          JPE              2
# 2          JPE              2
# 3          JPE              3
# 4          JPE              1
#
#                                         Authors_list Article_ID content_type  \
# 0              [Johannes Hörner,  Andrzej Skrzypacz]   26549911      Article
# 1    [Gabriel Chodorow-Reich,  Loukas Karabarbounis]   26549912      Article
# 2                     [David Gill,  Victoria Prowse]   26549913      Article
# 3  [Tobias J. Klein,  Christian Lambertz,  Konrad...   26549914      Article
# 4                                      [David Mitch]   26549915      Article
#
#                               stable_url Ref_type  \
# 0  https://www.jstor.org/stable/26549911    found
# 1  https://www.jstor.org/stable/26549912    found
# 2  https://www.jstor.org/stable/26549913    found
# 3  https://www.jstor.org/stable/26549914    found
# 4  https://www.jstor.org/stable/26549915    found
#
#                                           ref_string
# 0  Johannes Hórner\n\nYale University\n\nAndrzej ...
# 1  Gabriel Chodorow-Reich\n\nHarvard University a...
# 2  David Gill\n\nPurdue University\n\nVictoria Pr...
# 3  Tobias J. Klein\n\nTilburg University\n\nChris...
# 4  David Mitch\n\nUniversity of Maryland, Baltimo...
# (4327, 8)

# %% [markdown]
# Next the Unique list of universities is read in, this is used as a database to check the affiliton string against using rapidfuzz.

# %%
# Load in the list of unique Universites from github stored in 2_fuzzy matching
affs = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/main/2_Extracting%20affilitations/2_Fuzzy%20matching/University%20list/Unique%20Universities.xlsx")

#Use for local storage of data
#affs = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/University list/Unique Universities.xlsx')
print(affs.shape)

for i in range(len(affs)):
    #Replaceing title case and stripping leading space
    affs.iloc[i]['Affilliation'] = affs.iloc[i]['Affilliation'].strip().title()

Affiliation_choices = affs['Affilliation'].values.tolist()

print(affs['Affilliation'].head())
# Out:
# (842, 14)
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_27418/820835721.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   affs.iloc[i]['Affilliation'] = affs.iloc[i]['Affilliation'].strip().title()
# 0      Yale University
# 1            Cambridge
# 2              Harvard
# 3               Oxford
# 4    Oxford University
# Name: Affilliation, dtype: object

# %%
import re
testdata = JPE_aff_ref_output_1940_2010

for i in range(len(testdata)):
    if testdata.iloc[i]['Ref_type'] == "raw":
        joined =  " ".join(testdata.iloc[i]['ref_string'])
        ref_string = joined.strip().title()
        clean_ref_string = re.sub('\?|\:|\"', '', ref_string)
        testdata.loc[i,['ref_string_clean1']] = clean_ref_string
    else:
        ref_string = testdata.iloc[i]['ref_string'].strip().title()
        clean_ref_string = re.sub('\?|\:|\"', '', ref_string)
        testdata.loc[i,['ref_string_clean1']] = clean_ref_string

    #print(testdata.loc[i,['ref_string_clean1']])
print(testdata.columns.values)
# Out:
# ['Journal_Name' 'Authors_count' 'Authors_list' 'Article_ID' 'content_type'
#  'stable_url' 'Ref_type' 'ref_string' 'ref_string_clean1']

# %%
#Reading in the master file and correctly formatting the article ID to match back onto the melted file

#Load in master from Github
JPE_master = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/main/1_Input%20files%20and%20processing%20input%20files/1_1_Input%20files/Master%20lists/Processed/JPE_processed.xlsx")

#Local store of AER_master
#JPE_master = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/1_Input files and processing input files/1_1_Input files/Master lists/Processed/JPE_processed.xlsx')

for i in range(len(JPE_master)):
    JPE_master.loc[i,['Article_ID']] = JPE_master.loc[i,['stable_url']].to_string().rsplit('/',1)[-1]

JPE_master_condenced  = JPE_master[['Article_ID','year']]
JPE_master_condenced['year'] = JPE_master_condenced['year'].astype('int')
JPE_master_condenced.head()
# Out:
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_27418/1981081840.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   JPE_master_condenced['year'] = JPE_master_condenced['year'].astype('int')
#   Article_ID  year
# 0   26549909  2016
# 1   26549910  2016
# 2   26549911  2016
# 3   26549912  2016
# 4   26549913  2016

# %%
# Merging the masterfile onto the new melted file to get additional data
testdata_merged = testdata.merge(JPE_master_condenced, how = 'left', on = 'Article_ID')
testdata_merged = testdata_merged.sort_values(by=['year'])
testdata = testdata_merged.reset_index(drop = True)

# %%
# Excel output to get an overview of the data
#testdata.head
#testdata.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/JPE/Test files/JPE_aff_ref_output_1940_2010_affs_out setup.xlsx') 
print(testdata.head())
# Out:
#   Journal_Name  Authors_count                         Authors_list Article_ID  \
# 0          JPE              1                       [Gerhard Colm]    1825913
# 1          JPE              1                      [Jules Backman]    1825487
# 2          JPE              2  [William Fellner,  Howard S. Ellis]    1825486
# 3          JPE              1                      [Harvey Pinney]    1825485
# 4          JPE              1                  [George J. Stigler]    1825484
#
#   content_type                            stable_url Ref_type  \
# 0      Article  https://www.jstor.org/stable/1825913    found
# 1      Article  https://www.jstor.org/stable/1825487    found
# 2      Article  https://www.jstor.org/stable/1825486    found
# 3      Article  https://www.jstor.org/stable/1825485      raw
# 4      Article  https://www.jstor.org/stable/1825484    found
#
#                                           ref_string  \
# 0  COMMENTS ON W. I. KING: "ARE WE SUFFERING\nFRO...
# 1  FLEXIBILITY OF CHEESE PRICES\n\nJULES BACKMAN\...
# 2  HICKS AND THE TIME-PERIOD CONTROVERSY\n\nWILLI...
# 3  [THE INSTITUTIONAL MAN\n\nHARVEY PINNEV\nNew Y...
# 4  NOTES ON THE THEORY OF DUOPOLY\n\nGEORGE J. ST...
#
#                                    ref_string_clean1  year
# 0  Comments On W. I. King Are We Suffering\nFrom ...  1940
# 1  Flexibility Of Cheese Prices\n\nJules Backman\...  1940
# 2  Hicks And The Time-Period Controversy\n\nWilli...  1940
# 3  The Institutional Man\n\nHarvey Pinnev\nNew Yo...  1940
# 4  Notes On The Theory Of Duopoly\n\nGeorge J. St...  1940

# %%
import re
from rapidfuzz import fuzz
import math

for x in range(len(testdata)):
    # Read in authors
    authors = testdata.iloc[x]['Authors_list']
    str1 = testdata.iloc[x]['ref_string_clean1']

    # Split on new line as well as don't include blank lines
    ref_split = re.split(r"\n",str1 )
    while("" in ref_split):
        ref_split.remove("")

#Finding the authors name and corrosponding affiliations
    count_found = 0
    #Loop through author names in author list
    for d in range(len(authors)):
        #Loop through the data that is split into possible authors affiliations
        for j in range(len(ref_split)):
            #Check if the author name is in the split string
            ratio_author  = fuzz.partial_ratio(ref_split[j], authors[d])
            # Confiring if author name is in the affiliaton
            if ratio_author > 93:
                count_found = count_found +1
                #append the next line of the document to a column for each author
                if j+1 < len(ref_split):
                    testdata.loc[x, str(d)+'_author'] = authors[d]
                    # checking for short erroenous splits, if a line has a article on it
                    if len(ref_split[j+1]) > 3:
                        testdata.loc[x, str(d)+'_author_affs'] = ref_split[j+1]
                    else:
                        testdata.loc[x, str(d)+'_author_affs'] = ''
            # Prevents double finding of author name, sometimes name occurs twice 
            # but first occurance is the affiliation
            if count_found == len(authors):
                break
                #else:

# %%
consol = pd.read_excel('https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/2_Extracting%20affilitations/3_consolidation/Files/Consolidated_list_Final.xlsx')

# %%
# Creating a dictionary for consolidation
# Read in from Excel sheet, 2 columns first one with incorrect spelling and second one with correct spellig

cities = pd.read_excel('https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/2_Extracting%20affilitations/3_consolidation/Files/Consolidated_list_Final.xlsx', 'Cities')
#cities = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/University list/consolidated list.xlsx', 'Cities')
cities = cities[['Incorrect spelling', 'Correct spelling']]

misspellings = pd.read_excel('https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/2_Extracting%20affilitations/3_consolidation/Files/Consolidated_list_Final.xlsx', 'Misspellings')
#misspellings = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/University list/consolidated list.xlsx', 'Misspellings')
misspellings = misspellings[['Incorrect spelling', 'Correct spelling']]

comma_in_name = pd.read_excel('https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/2_Extracting%20affilitations/3_consolidation/Files/Consolidated_list_Final.xlsx', 'Comma in name')
#comma_in_name = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/University list/consolidated list.xlsx', 'Comma in name')
comma_in_name = comma_in_name[['Incorrect spelling', 'Correct spelling']]

colleges_full = pd.read_excel('https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/2_Extracting%20affilitations/3_consolidation/Files/Consolidated_list_Final.xlsx', 'Colleges Full')
#colleges_full = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/University list/consolidated list.xlsx', 'Colleges Full')
colleges_full = colleges_full[['Incorrect spelling', 'Correct spelling']]

colleges = pd.read_excel('https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/2_Extracting%20affilitations/3_consolidation/Files/Consolidated_list_Final.xlsx', 'Colleges')
#colleges = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/University list/consolidated list.xlsx', 'Colleges')

correct = pd.read_excel('https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/2_Extracting%20affilitations/3_consolidation/Files/Consolidated_list_Final.xlsx', 'Correct')
#correct = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/University list/consolidated list.xlsx', 'Correct')

frames = [cities, misspellings, comma_in_name,colleges_full ,colleges,correct]
consolidated_affiliations = pd.concat(frames)
print(consolidated_affiliations.shape)

for i in range(len(consolidated_affiliations)):
    #Replaceing title case and stripping leading space
    #affs.iat[i,0] = affs.iat[i,0].strip().title()
    consolidated_affiliations.iloc[i]['Incorrect spelling'] = consolidated_affiliations.iloc[i]['Incorrect spelling'].strip().title()
    #affs.iat[i,0] = affs.iat[i,0].strip().upper()

consolidated_affiliations_dict = consolidated_affiliations.set_index('Incorrect spelling').to_dict()['Correct spelling']
print(consolidated_affiliations_dict)
# Out:
# (1716, 2)
# {'Ames, Iowa': 'Ames Iowa United States (City)', 'Ames, Iowa, Usa': 'Ames Iowa United States (City)', 'Antwerp': 'Antwerp Belguim (City)', 'Auckland, New Zealand': 'Auckland New Zealand (City)', 'Auckland, Nz': 'Auckland New Zealand (City)', 'Baghdad': 'Baghdad Iraq (City)', 'Baltimore': 'Baltimore Maryland (City)', 'Baltimore, Usa Kzlvin J Lancaster': 'Baltimore Maryland (City)', 'Belfast': 'Belfast Ireland (City)', 'Berkeley': 'Berkeley California United States (City)', 'Berkeley, California': 'Berkeley California United States (City)', 'Birmingham': 'Birmingham United Kingdom (City)', 'Birmingham And Ames, Iowa': 'Birmingham United Kingdom (City)', 'Bloomington, Indiana': 'Bloomington Indiana United States (City)', 'Bristol': 'Bristol United Kingdom (City)', 'Brooklyn, New York': 'Brooklyn New York United States (City)', 'Brunswick, Maine Davidp Braybrooke': 'Brunswick Maine United States (City)', 'Brussels': 'Brussels Belgium (City)', 'Brussels, Belgium': 'Brussels Belgium (City)', 'California': 'California United States (State)', 'Cambridge': 'Cambridge Massachusetts United States (City)', 'Cambridge ,': 'Cambridge Massachusetts United States (City)', 'Cambridge And Salisbury, Rhodesia': 'Cambridge Massachusetts United States (City)', 'Cambridge Bungess Cameron': 'Cambridge Massachusetts United States (City)', 'Cambridge Nicholas Kaaldom': 'Cambridge Massachusetts United States (City)', 'Cambridge, Mass': 'Cambridge Massachusetts United States (City)', 'Cambridge, Mass  And Washington, Dc': 'Cambridge Massachusetts United States (City)', 'Cambridge, Mass Rosert M Solow': 'Cambridge Massachusetts United States (City)', 'Cambridge, Mass Rosert M Solow,': 'Cambridge Massachusetts United States (City)', 'Cambridge, Massachusetts': 'Cambridge Massachusetts United States (City)', 'Cambridge, Massachusetts *': 'Cambridge Massachusetts United States (City)', 'Canberra': 'Canberra Australia (CIty)', 'Cardiff': 'Cardiff United Kingdom (CIty)', 'Chicago': 'Chicago Illinois United States (City)', 'Chicago Lzster G Telser': 'Chicago Illinois United States (City)', 'Chicago, Illinoi': 'University Of Illinois Chicago', 'Chicago, Illinois': 'Chicago Illinois United States (City)', 'Chicago, Illinois, Usa': 'Chicago Illinois United States (City)', 'Columbus, Ohio Beénjamin Caplan': 'Columbus Ohio United States (CIty)', 'Diakarta, Indonesia *': 'Jakarta Indonesia (City)', 'Durham, N Carolina': 'Durham, North Carolina United States (City)', 'Durham, North Carolina': 'Durham, North Carolina United States (City)', 'Durham, North Carolina Lionel W Mcckenzie': 'Durham, North Carolina United States (City)', 'Edinburgh': 'Edinburgh United Kingdom (City)', 'Exeter': 'Exeter United Kingdom (City)', 'Geneva': 'Geneva Switzerland (CIty)', 'Glasgow': 'Glasgow United Kingdom (City)', 'Glasgow E M Chossudowsskky': 'Glasgow United Kingdom (City)', 'Hague, Holland': 'Hague Holland (City)', 'Hanover, New Hampshire': 'Hanover New Hampshire United States (City)', 'Harvard Epward H Chamberlin': 'Harvard (City)', 'Helsinki G': 'Helsinki Finland (City)', 'Ibadan, Nigeria': 'Ibadan Nigeria (City)', 'Jamaica': 'Jamaica (Country)', 'Jerusalem': 'Jerusalem Israel (City)', 'Jerusalem, Israel': 'Jerusalem Israel (City)', 'Kingston, Jamaica': 'Kingston Jamaica (City)', 'Lafayette, Indiana': 'Lafayette Indiana United States (City)', 'Lake Success, Ny': 'New York United States (City)', 'Liverpool': 'Liverpool United Kingdom (City)', 'London': 'London United Kingdom (City)', 'London And Jerusalem': 'London United Kingdom (City)', 'London G L S Shacele': 'London United Kingdom (City)', 'London K': 'London United Kingdom (City)', 'London K K F Zawadzei': 'London United Kingdom (City)', 'Long Island City': 'New York United States (City)', 'Makerere College !': 'Makerere College', 'Manchester': 'Manchester United Kingdom(City)', 'Manchester, England': 'Manchester United Kingdom(City)', 'Melbourne': 'Melbourne Australia (City)', 'Melbourne, Australia': 'Melbourne Australia (C ...

# %%
import numpy as np
#Replacing the nan values with a blank string so string processing can be used
testdata = testdata.replace(np.nan, '', regex=True)

#Creating the balnk columns that will be filled in during the splitting and consolidation
testdata["4_author_affs"] = ""
testdata["5_author_affs"] = ""

testdata["0_author_affs_consolidated"] = ""
testdata["0_author_affs_consolidated_0"] = ""
testdata["0_author_affs_consolidated_1"] = ""
testdata["0_author_affs_consolidated_2"] = ""
testdata["0_author_affs_consolidated_3"] = ""
testdata["0_author_affs_consolidated_4"] = ""

testdata["1_author_affs_consolidated"] = ""
testdata["1_author_affs_consolidated_0"] = ""
testdata["1_author_affs_consolidated_1"] = ""
testdata["1_author_affs_consolidated_2"] = ""
testdata["1_author_affs_consolidated_3"] = ""
testdata["1_author_affs_consolidated_4"] = ""

testdata["2_author_affs_consolidated"] = ""
testdata["2_author_affs_consolidated_0"] = ""
testdata["2_author_affs_consolidated_1"] = ""
testdata["2_author_affs_consolidated_2"] = ""
testdata["2_author_affs_consolidated_3"] = ""
testdata["2_author_affs_consolidated_4"] = ""

testdata["3_author_affs_consolidated"] = ""
testdata["3_author_affs_consolidated_0"] = ""
testdata["3_author_affs_consolidated_1"] = ""
testdata["3_author_affs_consolidated_2"] = ""
testdata["3_author_affs_consolidated_3"] = ""
testdata["3_author_affs_consolidated_4"] = ""

testdata["4_author_affs_consolidated"] = ""
testdata["4_author_affs_consolidated_0"] = ""
testdata["4_author_affs_consolidated_1"] = ""
testdata["4_author_affs_consolidated_2"] = ""
testdata["4_author_affs_consolidated_3"] = ""

testdata["5_author_affs_consolidated"] = ""
testdata["5_author_affs_consolidated_0"] = ""

for i in range(len(testdata)):
#for i in range(3430,3431):
#for i in range(3715,3716):
    authors = testdata.iloc[i]['Authors_list']
    for auth_no in range(len(authors)):
        #print(testdata.iloc[i]['0_author_affs'])
        testdata.loc[i,str(auth_no)+'_author_affs'] =  re.sub(r'\.','',testdata.iloc[i][str(auth_no)+'_author_affs']).title()
        testdata.loc[i,str(auth_no)+'_author_affs'] =  re.sub(r'The ','',testdata.iloc[i][str(auth_no)+'_author_affs']).title()
        #print(testdata.iloc[i]['0_author_affs'])
        list = []

    #Loop through the list of incorrect spellings and replace with corrected spellings
        for key in consolidated_affiliations_dict.keys():
            if key in testdata.iloc[i][str(auth_no)+'_author_affs']:
                list.append(key)
                print((key))
                print(list)

    #If there is more than 1 match in the consolidation it needs to match on the longer one, solves for college issue
                if len(list) <= 1:
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated']  = re.sub(key, consolidated_affiliations_dict[key],testdata.iloc[i][str(auth_no)+'_author_affs']).strip().rstrip(',')
                else:
                    print(consolidated_affiliations_dict[list[0]])
                    print(consolidated_affiliations_dict[list[1]])
                    # For colleges
                    if(len(consolidated_affiliations_dict[list[0]]) == len(consolidated_affiliations_dict[list[1]])):
                        #print("HERE")
                        if len(list[0]) > len(list[1]):
                            print("If")
                            testdata.loc[i,str(auth_no)+'_author_affs_consolidated']  = re.sub(list[0], consolidated_affiliations_dict[list[0]],testdata.iloc[i][str(auth_no)+'_author_affs']).strip().rstrip(',')
                            #print(list[0])
                        # Full  University Of Illinois System Urbana-Champaign issue
                        elif len(list[1]) > len(list[0]):
                            print("Elif")
                            testdata.loc[i,str(auth_no)+'_author_affs_consolidated']  = re.sub(list[1], consolidated_affiliations_dict[list[1]],testdata.iloc[i][str(auth_no)+'_author_affs']).strip().rstrip(',')
                        else:
                            print("else")
                            first_fix = re.sub(list[1], consolidated_affiliations_dict[list[1]],testdata.iloc[i][str(auth_no)+'_author_affs']).strip().rstrip(',') 
                            testdata.loc[i,str(auth_no)+'_author_affs_consolidated']  = re.sub(key, consolidated_affiliations_dict[key],first_fix).strip().rstrip(',') 
                    else:
                        first_fix = re.sub(list[0], consolidated_affiliations_dict[list[0]],testdata.iloc[i][str(auth_no)+'_author_affs']).strip().rstrip(',') 
                        #print(first_fix)
                        testdata.loc[i,str(auth_no)+'_author_affs_consolidated']  = re.sub(key, consolidated_affiliations_dict[key],first_fix).strip().rstrip(',') 
        print(i)
        print('Full ',testdata.loc[i,str(auth_no)+'_author_affs_consolidated'])
        #else: 
        #    print("non existant")
        auths_affs_split_And = re.split(' And ', testdata.iloc[i][str(auth_no)+'_author_affs_consolidated'])
        #print(auths_affs_split_And)
        #print(len(auths_affs_split_And))

        for aff in range(len(auths_affs_split_And)):
            testdata.loc[i,str(auth_no)+'_author_affs_consolidated_'+str(aff)]  = auths_affs_split_And[aff].strip().rstrip(',') 
            print('Auth', str(auth_no), str(aff) , testdata.loc[i,str(auth_no)+'_author_affs_consolidated_'+str(aff)])

        auths_affs_split_comma = re.split(',', testdata.iloc[i][str(auth_no)+'_author_affs_consolidated_0'])
        #print(auths_affs_split_And)
        #print(len(auths_affs_split_And))
        if len(auths_affs_split_comma) == 2:
            for affcomma in range(len(auths_affs_split_comma)):
                testdata.loc[i,str(auth_no)+'_author_affs_consolidated_0']  = auths_affs_split_comma[0].strip().rstrip(',')
                if  testdata.loc[i,str(auth_no)+'_author_affs_consolidated_1'] == '':
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_1']  = auths_affs_split_comma[1].strip().rstrip(',')
                else:
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2']  = auths_affs_split_comma[1].strip().rstrip(',')
                print('Auth', str(auth_no), str(affcomma) , testdata.loc[i,str(auth_no)+'_author_affs_consolidated_'+str(affcomma)])
                print(testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2'])
        if len(auths_affs_split_comma) == 3:
            for affcomma in range(len(auths_affs_split_comma)):
                testdata.loc[i,str(auth_no)+'_author_affs_consolidated_0']  = auths_affs_split_comma[0].strip().rstrip(',')
                if  testdata.loc[i,str(auth_no)+'_author_affs_consolidated_1'] == '':
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_1']  = auths_affs_split_comma[1].strip().rstrip(',')
                else:
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2']  = auths_affs_split_comma[1].strip().rstrip(',')
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_3']  = auths_affs_split_comma[2].strip().rstrip(',')
                print('Auth', str(auth_no), str(affcomma) , testdata.loc[i,str(auth_no)+'_author_affs_consolidated_'+str(affcomma)])
                print(testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2'])
        if len(auths_affs_split_comma) == 4:
            for affcomma in range(len(auths_affs_split_comma)):
                testdata.loc[i,str(auth_no)+'_author_affs_consolidated_0']  = auths_affs_split_comma[0].strip().rstrip(',')
                if  testdata.loc[i,str(auth_no)+'_author_affs_consolidated_1'] == '':
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_1']  = auths_affs_split_comma[1].strip().rstrip(',')
                else:
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2']  = auths_affs_split_comma[1].strip().rstrip(',')
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_3']  = auths_affs_split_comma[2].strip().rstrip(',')
                    testdata.loc[i,str(auth_no)+'_author_affs_consolidated_4']  = auths_affs_split_comma[3].strip().rstrip(',')

                print('Auth', str(auth_no), str(affcomma) , testdata.loc[i,str(auth_no)+'_author_affs_consolidated_'+str(affcomma)])
                print(testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2'])

    print(i)
# Out:
# Washington, Dc
# ['Washington, Dc']
# 0
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 0
# New York
# ['New York']
# New York University
# ['New York', 'New York University']
# New York United States (City)
# New York University
# York University
# ['New York', 'New York University', 'York University']
# New York United States (City)
# New York University
# 1
# Full  New York United States (City) University
# Auth 0 0 New York United States (City) University
# 1
# Berkeley
# ['Berkeley']
# California
# ['Berkeley', 'California']
# Berkeley California United States (City)
# California United States (State)
# University Of California, Berkeley
# ['Berkeley', 'California', 'University Of California, Berkeley']
# Berkeley California United States (City)
# California United States (State)
# University Of California
# ['Berkeley', 'California', 'University Of California, Berkeley', 'University Of California']
# Berkeley California United States (City)
# California United States (State)
# 2
# Full  University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System
#
# Auth 0 1 Berkeley California United States (City)
# Berkeley California United States (City)
# Berkeley
# ['Berkeley']
# California
# ['Berkeley', 'California']
# Berkeley California United States (City)
# California United States (State)
# University Of California, Berkeley
# ['Berkeley', 'California', 'University Of California, Berkeley']
# Berkeley California United States (City)
# California United States (State)
# University Of California
# ['Berkeley', 'California', 'University Of California, Berkeley', 'University Of California']
# Berkeley California United States (City)
# California United States (State)
# 2
# Full  University Of California System, Berkeley California United States (City)
# Auth 1 0 University Of California System, Berkeley California United States (City)
# Auth 1 0 University Of California System
#
# Auth 1 1 Berkeley California United States (City)
# Berkeley California United States (City)
# 2
# New York
# ['New York']
# New York University
# ['New York', 'New York University']
# New York United States (City)
# New York University
# York University
# ['New York', 'New York University', 'York University']
# New York United States (City)
# New York University
# 3
# Full  New York United States (City) University
# Auth 0 0 New York United States (City) University
# 3
# University Of Minnesota
# ['University Of Minnesota']
# 4
# Full  University Of Minnesota
# Auth 0 0 University Of Minnesota
# 4
# Ohio State University
# ['Ohio State University']
# 5
# Full  Ohio State University
# Auth 0 0 Ohio State University
# 5
# Stanford University
# ['Stanford University']
# 6
# Full  Stanford University
# Auth 0 0 Stanford University
# 6
# Mountain Lakes, New Jersey
# ['Mountain Lakes, New Jersey']
# 7
# Full  Mountain Lakes New Jersey United States (City)
# Auth 0 0 Mountain Lakes New Jersey United States (City)
# 7
# Antwerp
# ['Antwerp']
# 8
# Full  Antwerp Belguim (City)
# Auth 0 0 Antwerp Belguim (City)
# 8
# Harvard University
# ['Harvard University']
# 9
# Full  Harvard University
# Auth 0 0 Harvard University
# 9
# Washington, Dc
# ['Washington, Dc']
# 10
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 10
# New York
# ['New York']
# New York University
# ['New York', 'New York University']
# New York United States (City)
# New York University
# York University
# ['New York', 'New York University', 'York University']
# New York United States (City)
# New York University
# 11
# Full  New York United States (City) University
# Auth 0 0 New York United States (City) University
# New York
# ['New York']
# New York University
# ['New York', 'New York University']
# New York United States (City)
# New York University
# York University
# ['New York', 'New York University', 'York University']
# New York United States (City)
# New York University
# 11
# Full  New York United States (City) University
# Auth 1 0 New York United States (City) University
# 11
# New York
# ['New York']
# New York University
# ['New York', 'New York University']
# New York United States (City)
# New York University
# York University
# ['New York', 'New York University', 'York University']
# New York United States (City)
# New York University
# 12
# Full  New York United States (City) University
# Auth 0 0 New York United States (City) University
# 12
# Iowa State College
# ['Iowa State College']
# 13
# Full  Iowa State College
# Auth 0 0 Iowa State College
# 13
# Colgate University
# ['Colgate University']
# 14
# Full  Colgate University
# Auth 0 0 Colgate University
# 14
# Harvard University
# ['Harvard University']
# 15
# Full  Harvard University
# Auth 0 0 Harvard University
# 15
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 16
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 16
# University Of Maryland
# ['University Of Maryland']
# 17
# Full  University Of Maryland System
# Auth 0 0 University Of Maryland System
# 17
# Us Department Of Agriculture
# ['Us Department Of Agriculture']
# 18
# Full  US Department Of Agriculture
# Auth 0 0 US Department Of Agriculture
# Us Department Of Agriculture
# ['Us Department Of Agriculture']
# 18
# Full  US Department Of Agriculture
# Auth 1 0 US Department Of Agriculture
# 18
# Ohio State University
# ['Ohio State University']
# 19
# Full  Ohio State University
# Auth 0 0 Ohio State University
# 19
# Iowa State College
# ['Iowa State College']
# 20
# Full  Iowa State College
# Auth 0 0 Iowa State College
# 20
# Duke University
# ['Duke University']
# 21
# Full  Duke University
# Auth 0 0 Duke University
# 21
# University Of North Carolina
# ['University Of North Carolina']
# 22
# Full  University Of North Carolina System
# Auth 0 0 University Of North Carolina System
# 22
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 23
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 23
# Vienna
# ['Vienna']
# 24
# Full  Vienna Austria (City)
# Auth 0 0 Vienna Austria (City)
# 24
# University Of Arizona
# ['University Of Arizona']
# 25
# Full  University Of Arizona
# Auth 0 0 University Of Arizona
# 25
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 26
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 26
# 27
# Full
# Auth 0 0
# 27
# Cambridge
# ['Cambridge']
# Trinity College
# ['Cambridge', 'Trinity College']
# Cambridge Massachusetts United States (City)
# University of Cambridge
# 28
# Full  University of Cambridge, Cambridge Massachusetts United States (City)
# Auth 0 0 University of Cambridge, Cambridge Massachusetts United States (City)
# Auth 0 0 University of Cambridge
#
# Auth 0 1 Cambridge Massachusetts United States (City)
# Cambridge Massachusetts United States (City)
# 28
# Cornell University
# ['Cornell University']
# 29
# Full  Cornell University
# Auth 0 0 Cornell University
# 29
# Edinburgh
# ['Edinburgh']
# University Of Edinburgh
# ['Edinburgh', 'University Of Edinburgh']
# Edinburgh United Kingdom (City)
# University Of Edinburgh
# 30
# Full  University Of Edinburgh United Kingdom (City)
# Auth 0 0 University Of Edinburgh United Kingdom (City)
# 30
# University Of Minnesota
# ['University Of Minnesota']
# 31
# Full  University Of Minnesota
# Auth 0 0 University Of Minnesota
# 31
# New York
# ['New York']
# 32
# Full  New York United States (City) City
# Auth 0 0 New York United States (City) City
# 32
# Indiana Central College
# ['Indiana Central College']
# 33
# Full  Indiana University
# Auth 0 0 Indiana University
# 33
# University Of Arkansas
# ['University Of Arkansas']
# 34
# Full  University Of Arkansas
# Auth 0 0 University Of Arkansas
# 34
# University Of Illinois
# ['University Of Illinois']
# 35
# Full  University Of Illinois System
# Auth 0 0 University Of Illinois System
# 35
# Duke University
# ['Duke University']
# 36
# Full  Duke University
# Auth 0 0 Duke University
# 36
# 37
# Full
# Auth 0 0
# 37
# New York
# ['New York']
# 38
# Full  New York United States (City) City
# Auth 0 0 New York United States (City) City
# 38
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 39
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 39
# Duke University
# ['Duke University']
# 40
# Full  Duke University
# Auth 0 0 Duke University
# 40
# Washington, Dc
# ['Washington, Dc']
# 41
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 41
# Chicago
# ['Chicago']
# Central Ymca College, Chicago
# ['Chicago', 'Central Ymca College, Chicago']
# Chicago Illinois United States (City)
# Central YMCA Community College
# 42
# Full  Central YMCA Community College Illinois United States (City)
# Auth 0 0 Central YMCA Community College Illinois United States (City)
# 42
# Brown University
# ['Brown University']
# 43
# Full  Brown University
# Auth 0 0 Brown University
# 43
# Brown University
# ['Brown University']
# 44
# Full  Brown University
# Auth 0 0 Brown University
# 44
# Iowa State College
# ['Iowa State College']
# 45
# Full  Iowa State College
# Auth 0 0 Iowa State College
# 45
# 46
# Full
# Auth 0 0
# 46
# Baghdad
# ['Baghdad']
# 47
# Full  Baghdad Iraq (City)
# Auth 0 0 Baghdad Iraq (City)
# 47
# Washington, Dc
# ['Washington, Dc']
# 48
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 48
# New York
# ['New York']
# 49
# Full  New York United States (City) City
# Auth 0 0 New York United States (City) City
# 49
# Pennsylvania
# ['Pennsylvania']
# Pennsylvania State College
# ['Pennsylvania', 'Pennsylvania State College']
# Pittsburgh Pennslyvania United States (City)
# Pennsylvania State University
# 50
# Full  Pittsburgh Pennslyvania United States (City) State College
# Auth 0 0 Pittsburgh Pennslyvania United States (City) State College
# 50
# Brown University
# ['Brown University']
# 51
# Full  Brown University
# Auth 0 0 Brown University
# 51
# Long Island City
# ['Long Island City']
# 52
# Full  New York United States (City)
# Auth 0 0 New York United States (City)
# 52
# Columbia University
# ['Columbia University']
# 53
# Full  Columbia University
# Auth 0 0 Columbia University
# 53
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 54
# Full  University Of Chicago Illinois United States (City) And Cowles Commission
# Auth 0 0 University Of Chicago Illinois United States (City)
# Auth 0 1 Cowles Commission
# 54
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 55
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 55
# Columbia University
# ['Columbia University']
# 56
# Full  Columbia University
# Auth 0 0 Columbia University
# 56
# Washington, Dc
# ['Washington, Dc']
# 57
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 57
# Brooklyn, New York
# ['Brooklyn, New York']
# New York
# ['Brooklyn, New York', 'New York']
# Brooklyn New York United States (City)
# New York United States (City)
# 58
# Full  Brooklyn New York United States (City) United States (City)
# Auth 0 0 Brooklyn New York United States (City) United States (City)
# 58
# 59
# Full
# Auth 0 0
# 59
# 60
# Full
# Auth 0 0
# 60
# Washington, Dc
# ['Washington, Dc']
# 61
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 61
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 62
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 62
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 63
# Full  Princeton University
# Auth 0 0 Princeton University
# 63
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 64
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 64
# Babson Institute
# ['Babson Institute']
# 65
# Full  Babson Institute
# Auth 0 0 Babson Institute
# 65
# Cambridge
# ['Cambridge']
# Cambridge, Mass
# ['Cambridge', 'Cambridge, Mass']
# Cambridge Massachusetts United States (City)
# Cambridge Massachusetts United States (City)
# Elif
# Cambridge, Massachusetts
# ['Cambridge', 'Cambridge, Mass', 'Cambridge, Massachusetts']
# Cambridge Massachusetts United States (City)
# Cambridge Massachusetts United States (City)
# Elif
# 66
# Full  Cambridge Massachusetts United States (City)achusetts
# Auth 0 0 Cambridge Massachusetts United States (City)achusetts
# 66
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 67
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 67
# Northwestern University
# ['Northwestern University']
# 68
# Full  Northwestern University
# Auth 0 0 Northwestern University
# 68
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 69
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 69
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 70
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 70
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 71
# Full  Princeton University
# Auth 0 0 Princeton University
# 71
# New School For Social Research
# ['New School For Social Research']
# 72
# Full  New School For Social Research
# Auth 0 0 New School For Social Research
# 72
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 73
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 73
# Washington, Dc
# ['Washington, Dc']
# 74
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 74
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 75
# Full  Princeton University
# Auth 0 0 Princeton University
# 75
# Lehigh University
# ['Lehigh University']
# 76
# Full  Lehigh University
# Auth 0 0 Lehigh University
# 76
# Brown University
# ['Brown University']
# 77
# Full  Brown University
# Auth 0 0 Brown University
# 77
# Washington, Dc
# ['Washington, Dc']
# 78
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 78
# 79
# Full
# Auth 0 0
# 79
# Full
# Auth 1 0
# 79
# Department Of Finance, Ottawa
# ['Department Of Finance, Ottawa']
# 80
# Full  Department Of Finance Canada
# Auth 0 0 Department Of Finance Canada
# 80
# 81
# Full
# Auth 0 0
# 81
# California
# ['California']
# University Of California
# ['California', 'University Of California']
# California United States (State)
# University Of California System
# 82
# Full  University Of California System United States (State)
# Auth 0 0 University Of California System United States (State)
# 82
# Washington, Dc
# ['Washington, Dc']
# 83
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 83
# 84
# Full
# Auth 0 0
# New York
# ['New York']
# 84
# Full  New York United States (City) City
# Auth 1 0 New York United States (City) City
# 84
# Chicago
# ['Chicago']
# Federal Reserve Bank Of Chicago
# ['Chicago', 'Federal Reserve Bank Of Chicago']
# Chicago Illinois United States (City)
# Federal Reserve Bank Of Chicago
# 85
# Full  Federal Reserve Bank Of Chicago Illinois United States (City)
# Auth 0 0 Federal Reserve Bank Of Chicago Illinois United States (City)
# 85
# Howard University
# ['Howard University']
# 86
# Full  Howard University
# Auth 0 0 Howard University
# 86
# Iowa State College
# ['Iowa State College']
# 87
# Full  Iowa State College
# Auth 0 0 Iowa State College
# 87
# University Of Oregon
# ['University Of Oregon']
# 88
# Full  University Of Oregon
# Auth 0 0 University Of Oregon
# 88
# Washington, Dc
# ['Washington, Dc']
# 89
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 89
# Wesleyan University
# ['Wesleyan University']
# 90
# Full  Wesleyan University
# Auth 0 0 Wesleyan University
# 90
# Washington, Dc
# ['Washington, Dc']
# 91
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 91
# Brooklyn, New York
# ['Brooklyn, New York']
# New York
# ['Brooklyn, New York', 'New York']
# Brooklyn New York United States (City)
# New York United States (City)
# 92
# Full  Brooklyn New York United States (City) United States (City)
# Auth 0 0 Brooklyn New York United States (City) United States (City)
# 92
# Washington, Dc
# ['Washington, Dc']
# 93
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 93
# Massachusetts Institute Of Technology
# ['Massachusetts Institute Of Technology']
# 94
# Full  Massachusetts Institute Of Technology
# Auth 0 0 Massachusetts Institute Of Technology
# 94
# Pennsylvania
# ['Pennsylvania']
# University Of Pennsylvania
# ['Pennsylvania', 'University Of Pennsylvania']
# Pittsburgh Pennslyvania United States (City)
# University Of Pennsylvania
# 95
# Full  University Of Pittsburgh Pennslyvania United States (City)
# Auth 0 0 University Of Pittsburgh Pennslyvania United States (City)
# Pennsylvania
# ['Pennsylvania']
# University Of Pennsylvania
# ['Pennsylvania', 'University Of Pennsylvania']
# Pittsburgh Pennslyvania United States (City)
# University Of Pennsylvania
# 95
# Full  University Of Pittsburgh Pennslyvania United States (City)
# Auth 1 0 University Of Pittsburgh Pennslyvania United States (City)
# Pennsylvania
# ['Pennsylvania']
# University Of Pennsylvania
# ['Pennsylvania', 'University Of Pennsylvania']
# Pittsburgh Pennslyvania United States (City)
# University Of Pennsylvania
# 95
# Full  University Of Pittsburgh Pennslyvania United States (City)
# Auth 2 0 University Of Pittsburgh Pennslyvania United States (City)
# Pennsylvania
# ['Pennsylvania']
# University Of Pennsylvania
# ['Pennsylvania', 'University Of Pennsylvania']
# Pittsburgh Pennslyvania United States (City)
# University Of Pennsylvania
# 95
# Full  University Of Pittsburgh Pennslyvania United States (City)
# Auth 3 0 University Of Pittsburgh Pennslyvania United States (City)
# 95
# Haverford College
# ['Haverford College']
# 96
# Full  Haverford College
# Auth 0 0 Haverford College
# 96
# Vassar College
# ['Vassar College']
# 97
# Full  Vassar College
# Auth 0 0 Vassar College
# 97
# 98
# Full
# Auth 0 0
# 98
# Full
# Auth 1 0
# 98
# National Bureau Of Economic Research
# ['National Bureau Of Economic Research']
# 99
# Full  National Bureau Of Economic Research, Inc
# Auth 0 0 National Bureau Of Economic Research, Inc
# Auth 0 0 National Bureau Of Economic Research
#
# Auth 0 1 Inc
# Inc
# 99
# Columbia University
# ['Columbia University']
# 100
# Full  Columbia University
# Auth 0 0 Columbia University
# 100
# Brown University
# ['Brown University']
# 101
# Full  Brown University
# Auth 0 0 Brown University
# 101
# Harvard University
# ['Harvard University']
# 102
# Full  Harvard University
# Auth 0 0 Harvard University
# 102
# Washington, Dc
# ['Washington, Dc']
# 103
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 103
# Bowdoin College
# ['Bowdoin College']
# 104
# Full  Bowdoin College
# Auth 0 0 Bowdoin College
# 104
# Washington, Dc
# ['Washington, Dc']
# 105
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 105
# Washington, Dc
# ['Washington, Dc']
# Harvard University
# ['Washington, Dc', 'Harvard University']
# Washington DC United States (City)
# Harvard University
# 106
# Full  Harvard University And Washington DC United States (City)
# Auth 0 0 Harvard University
# Auth 0 1 Washington DC United States (City)
# Washington, Dc
# ['Washington, Dc']
# Harvard University
# ['Washington, Dc', 'Harvard University']
# Washington DC United States (City)
# Harvard University
# 106
# Full  Harvard University And Washington DC United States (City)
# Auth 1 0 Harvard University
# Auth 1 1 Washington DC United States (City)
# 106
# Wayland, Massachusetts
# ['Wayland, Massachusetts']
# 107
# Full  Wayland Massachusetts United States (City)
# Auth 0 0 Wayland Massachusetts United States (City)
# 107
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 108
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 108
# University Of Virginia
# ['University Of Virginia']
# 109
# Full  University Of Virginia
# Auth 0 0 University Of Virginia
# 109
# St John'S University
# ["St John'S University"]
# 110
# Full  St John's University
# Auth 0 0 St John's University
# 110
# Washington, Dc
# ['Washington, Dc']
# 111
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 111
# Harvard University
# ['Harvard University']
# 112
# Full  Harvard University
# Auth 0 0 Harvard University
# 112
# California
# ['California']
# University Of Southern California
# ['California', 'University Of Southern California']
# California United States (State)
# University Of Southern California
# 113
# Full  University Of Southern California United States (State)
# Auth 0 0 University Of Southern California United States (State)
# 113
# University Of Texas
# ['University Of Texas']
# 114
# Full  University Of Texas System
# Auth 0 0 University Of Texas System
# 114
# Williams College
# ['Williams College']
# 115
# Full  Williams College
# Auth 0 0 Williams College
# 115
# 116
# Full
# Auth 0 0
# 116
# 117
# Full
# Auth 0 0
# 117
# 118
# Full
# Auth 0 0
# 118
# 119
# Full
# Auth 0 0
# 119
# Full
# Auth 1 0
# 119
# 120
# Full
# Auth 0 0
# 120
# 121
# Full
# Auth 0 0
# 121
# 122
# Full
# Auth 0 0
# 122
# 123
# Full
# Auth 0 0
# 123
# Full
# Auth 1 0
# 123
# Full
# Auth 2 0
# 123
# 124
# Full
# Auth 0 0
# 124
# 125
# Full
# Auth 0 0
# 125
# 126
# Full
# Auth 0 0
# 126
# 127
# Full
# Auth 0 0
# 127
# 128
# Full
# Auth 0 0
# 128
# 129
# Full
# Auth 0 0
# 129
# 130
# Full
# Auth 0 0
# 130
# Full
# Auth 1 0
# 130
# 131
# Full
# Auth 0 0
# 131
# 132
# Full
# Auth 0 0
# 132
# 133
# Full
# Auth 0 0
# 133
# 134
# Full
# Auth 0 0
# 134
# 135
# Full
# Auth 0 0
# 135
# 136
# Full
# Auth 0 0
# 136
# 137
# Full
# Auth 0 0
# 137
# Full
# Auth 1 0
# 137
# 138
# Full
# Auth 0 0
# 138
# 139
# Full
# Auth 0 0
# 139
# 140
# Full
# Auth 0 0
# 140
# Full
# Auth 1 0
# 140
# Full
# Auth 2 0
# 140
# 141
# Full
# Auth 0 0
# 141
# 142
# Full
# Auth 0 0
# 142
# 143
# Full
# Auth 0 0
# 143
# 144
# Full
# Auth 0 0
# 144
# Full
# Auth 1 0
# 144
# 145
# Full
# Auth 0 0
# 145
# 146
# Full
# Auth 0 0
# 146
# 147
# Full
# Auth 0 0
# 147
# 148
# Full
# Auth 0 0
# 148
# 149
# Full
# Auth 0 0
# 149
# 150
# Full
# Auth 0 0
# 150
# 151
# Full
# Auth 0 0
# 151
# 152
# Full
# Auth 0 0
# 152
# 153
# Full
# Auth 0 0
# 153
# 154
# Full
# Auth 0 0
# 154
# 155
# Full
# Auth 0 0
# 155
# 156
# Full
# Auth 0 0
# 156
# 157
# Full
# Auth 0 0
# 157
# 158
# Full
# Auth 0 0
# 158
# 159
# Full
# Auth 0 0
# 159
# 160
# Full
# Auth 0 0
# 160
# 161
# Full
# Auth 0 0
# 161
# 162
# Full
# Auth 0 0
# 162
# 163
# Full
# Auth 0 0
# 163
# 164
# Full
# Auth 0 0
# 164
# 165
# Full
# Auth 0 0
# 165
# 166
# Full
# Auth 0 0
# 166
# 167
# Full
# Auth 0 0
# 167
# 168
# Full
# Auth 0 0
# 168
# 169
# Full
# Auth 0 0
# 169
# 170
# Full
# Auth 0 0
# 170
# 171
# Full
# Auth 0 0
# 171
# 172
# Full
# Auth 0 0
# 172
# 173
# Full
# Auth 0 0
# 173
# 174
# Full
# Auth 0 0
# 174
# 175
# Full
# Auth 0 0
# 175
# 176
# Full
# Auth 0 0
# 176
# 177
# Full
# Auth 0 0
# 177
# 178
# Full
# Auth 0 0
# 178
# 179
# Full
# Auth 0 0
# 179
# 180
# Full
# Auth 0 0
# 180
# 181
# Full
# Auth 0 0
# 181
# 182
# Full
# Auth 0 0
# 182
# 183
# Full
# Auth 0 0
# 183
# 184
# Full
# Auth 0 0
# 184
# 185
# Full
# Auth 0 0
# 185
# 186
# Full
# Auth 0 0
# 186
# 187
# Full
# Auth 0 0
# 187
# 188
# Full
# Auth 0 0
# 188
# Paris
# ['Paris']
# 189
# Full  Career Of David Paris France (City)h, Journal Of Economic His-
# Auth 0 0 Career Of David Paris France (City)h, Journal Of Economic His-
# Auth 0 0 Career Of David Paris France (City)h
#
# Auth 0 1 Journal Of Economic His-
# Journal Of Economic His-
# 189
# Full
# Auth 1 0
# 189
# 190
# Full
# Auth 0 0
# 190
# 191
# Full
# Auth 0 0
# 191
# 192
# Full
# Auth 0 0
# 192
# 193
# Full
# Auth 0 0
# 193
# 194
# Full
# Auth 0 0
# 194
# 195
# Full
# Auth 0 0
# 195
# 196
# Full
# Auth 0 0
# 196
# 197
# Full
# Auth 0 0
# 197
# Full
# Auth 1 0
# 197
# 198
# Full
# Auth 0 0
# 198
# 199
# Full
# Auth 0 0
# 199
# 200
# Full
# Auth 0 0
# 200
# 201
# Full
# Auth 0 0
# 201
# Full
# Auth 1 0
# 201
# 202
# Full
# Auth 0 0
# 202
# 203
# Full
# Auth 0 0
# 203
# 204
# Full
# Auth 0 0
# 204
# 205
# Full
# Auth 0 0
# 205
# 206
# Full
# Auth 0 0
# 206
# 207
# Full
# Auth 0 0
# 207
# 208
# Full
# Auth 0 0
# 208
# 209
# Full
# Auth 0 0
# 209
# 210
# Full
# Auth 0 0
# 210
# 211
# Full
# Auth 0 0
# 211
# 212
# Full
# Auth 0 0
# 212
# 213
# Full
# Auth 0 0
# 213
# 214
# Full
# Auth 0 0
# 214
# 215
# Full
# Auth 0 0
# 215
# 216
# Full
# Auth 0 0
# 216
# 217
# Full
# Auth 0 0
# 217
# 218
# Full
# Auth 0 0
# 218
# 219
# Full
# Auth 0 0
# 219
# 220
# Full
# Auth 0 0
# 220
# 221
# Full
# Auth 0 0
# 221
# 222
# Full
# Auth 0 0
# 222
# 223
# Full
# Auth 0 0
# 223
# 224
# Full
# Auth 0 0
# 224
# 225
# Full
# Auth 0 0
# 225
# 226
# Full
# Auth 0 0
# 226
# 227
# Full
# Auth 0 0
# 227
# 228
# Full
# Auth 0 0
# 228
# 229
# Full
# Auth 0 0
# 229
# 230
# Full
# Auth 0 0
# 230
# 231
# Full
# Auth 0 0
# 231
# 232
# Full
# Auth 0 0
# 232
# 233
# Full
# Auth 0 0
# 233
# 234
# Full
# Auth 0 0
# 234
# 235
# Full
# Auth 0 0
# 235
# 236
# Full
# Auth 0 0
# 236
# 237
# Full
# Auth 0 0
# 237
# 238
# Full
# Auth 0 0
# 238
# 239
# Full
# Auth 0 0
# 239
# 240
# Full
# Auth 0 0
# 240
# 241
# Full
# Auth 0 0
# 241
# 242
# Full
# Auth 0 0
# 242
# 243
# Full
# Auth 0 0
# 243
# 244
# Full
# Auth 0 0
# 244
# 245
# Full
# Auth 0 0
# 245
# Full
# Auth 1 0
# 245
# 246
# Full
# Auth 0 0
# 246
# 247
# Full
# Auth 0 0
# 247
# 248
# Full
# Auth 0 0
# 248
# 249
# Full
# Auth 0 0
# 249
# 250
# Full
# Auth 0 0
# 250
# 251
# Full
# Auth 0 0
# 251
# 252
# Full
# Auth 0 0
# 252
# 253
# Full
# Auth 0 0
# 253
# 254
# Full
# Auth 0 0
# 254
# 255
# Full
# Auth 0 0
# 255
# 256
# Full
# Auth 0 0
# 256
# 257
# Full
# Auth 0 0
# 257
# 258
# Full
# Auth 0 0
# 258
# 259
# Full
# Auth 0 0
# 259
# 260
# Full
# Auth 0 0
# 260
# 261
# Full
# Auth 0 0
# 261
# 262
# Full
# Auth 0 0
# 262
# 263
# Full
# Auth 0 0
# 263
# Full
# Auth 1 0
# 263
# 264
# Full
# Auth 0 0
# 264
# 265
# Full
# Auth 0 0
# 265
# 266
# Full
# Auth 0 0
# 266
# 267
# Full
# Auth 0 0
# 267
# 268
# Full
# Auth 0 0
# 268
# 269
# Full
# Auth 0 0
# 269
# Full
# Auth 1 0
# 269
# 270
# Full
# Auth 0 0
# 270
# 271
# Full
# Auth 0 0
# 271
# 272
# Full
# Auth 0 0
# 272
# Full
# Auth 1 0
# 272
# 273
# Full
# Auth 0 0
# 273
# 274
# Full
# Auth 0 0
# 274
# 275
# Full
# Auth 0 0
# 275
# 276
# Full
# Auth 0 0
# 276
# 277
# Full
# Auth 0 0
# 277
# 278
# Full
# Auth 0 0
# 278
# 279
# Full
# Auth 0 0
# 279
# 280
# Full
# Auth 0 0
# 280
# 281
# Full
# Auth 0 0
# 281
# 282
# Full
# Auth 0 0
# 282
# 283
# Full
# Auth 0 0
# 283
# 284
# Full
# Auth 0 0
# 284
# Full
# Auth 1 0
# 284
# 285
# Full
# Auth 0 0
# 285
# 286
# Full
# Auth 0 0
# 286
# Full
# Auth 1 0
# 286
# 287
# Full
# Auth 0 0
# 287
# 288
# Full
# Auth 0 0
# 288
# 289
# Full
# Auth 0 0
# 289
# 290
# Full
# Auth 0 0
# 290
# 291
# Full
# Auth 0 0
# 291
# 292
# Full
# Auth 0 0
# 292
# 293
# Full
# Auth 0 0
# 293
# 294
# Full
# Auth 0 0
# 294
# 295
# Full
# Auth 0 0
# 295
# 296
# Full
# Auth 0 0
# 296
# 297
# Full
# Auth 0 0
# 297
# 298
# Full
# Auth 0 0
# 298
# 299
# Full
# Auth 0 0
# 299
# 300
# Full
# Auth 0 0
# 300
# 301
# Full
# Auth 0 0
# 301
# 302
# Full
# Auth 0 0
# 302
# 303
# Full
# Auth 0 0
# 303
# 304
# Full
# Auth 0 0
# 304
# 305
# Full
# Auth 0 0
# 305
# 306
# Full
# Auth 0 0
# 306
# 307
# Full
# Auth 0 0
# 307
# 308
# Full
# Auth 0 0
# 308
# 309
# Full
# Auth 0 0
# 309
# 310
# Full
# Auth 0 0
# 310
# 311
# Full
# Auth 0 0
# 311
# 312
# Full
# Auth 0 0
# 312
# 313
# Full
# Auth 0 0
# 313
# 314
# Full
# Auth 0 0
# 314
# 315
# Full
# Auth 0 0
# 315
# 316
# Full
# Auth 0 0
# 316
# 317
# Full
# Auth 0 0
# 317
# 318
# Full
# Auth 0 0
# 318
# 319
# Full
# Auth 0 0
# 319
# 320
# Full
# Auth 0 0
# 320
# 321
# Full
# Auth 0 0
# 321
# 322
# Full
# Auth 0 0
# 322
# 323
# Full
# Auth 0 0
# 323
# 324
# Full
# Auth 0 0
# 324
# 325
# Full
# Auth 0 0
# 325
# 326
# Full
# Auth 0 0
# 326
# 327
# Full
# Auth 0 0
# 327
# 328
# Full
# Auth 0 0
# 328
# 329
# Full
# Auth 0 0
# 329
# 330
# Full
# Auth 0 0
# 330
# 331
# Full
# Auth 0 0
# 331
# 332
# Full
# Auth 0 0
# 332
# 333
# Full
# Auth 0 0
# 333
# 334
# Full
# Auth 0 0
# 334
# 335
# Full
# Auth 0 0
# 335
# 336
# Full
# Auth 0 0
# 336
# 337
# Full
# Auth 0 0
# 337
# 338
# Full
# Auth 0 0
# 338
# 339
# Full
# Auth 0 0
# 339
# 340
# Full
# Auth 0 0
# 340
# Full
# Auth 1 0
# 340
# 341
# Full
# Auth 0 0
# 341
# Full
# Auth 1 0
# 341
# 342
# Full
# Auth 0 0
# 342
# University Of Wisconsin
# ['University Of Wisconsin']
# 343
# Full  University Of Wisconsin System
# Auth 0 0 University Of Wisconsin System
# 343
# 344
# Full
# Auth 0 0
# 344
# 345
# Full
# Auth 0 0
# 345
# 346
# Full
# Auth 0 0
# 346
# 347
# Full
# Auth 0 0
# 347
# 348
# Full
# Auth 0 0
# 348
# 349
# Full
# Auth 0 0
# 349
# 350
# Full
# Auth 0 0
# 350
# 351
# Full
# Auth 0 0
# 351
# Full
# Auth 1 0
# 351
# 352
# Full
# Auth 0 0
# 352
# 353
# Full
# Auth 0 0
# 353
# 354
# Full
# Auth 0 0
# 354
# Duke University
# ['Duke University']
# 355
# Full  Duke University
# Auth 0 0 Duke University
# 355
# Stanford University
# ['Stanford University']
# 356
# Full  Stanford University
# Auth 0 0 Stanford University
# 356
# Columbia University
# ['Columbia University']
# 357
# Full  Columbia University
# Auth 0 0 Columbia University
# 357
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 358
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 358
# Tokyo
# ['Tokyo']
# Tokyo, Japan
# ['Tokyo', 'Tokyo, Japan']
# Tokyo Japan (City)
# Tokyo Japan (City)
# Elif
# University Of Wisconsin
# ['Tokyo', 'Tokyo, Japan', 'University Of Wisconsin']
# Tokyo Japan (City)
# Tokyo Japan (City)
# Elif
# 359
# Full  University Of Wisconsin; Pro Tem, Tokyo Japan (City)
# Auth 0 0 University Of Wisconsin; Pro Tem, Tokyo Japan (City)
# Auth 0 0 University Of Wisconsin; Pro Tem
#
# Auth 0 1 Tokyo Japan (City)
# Tokyo Japan (City)
# 359
# University Of Washington
# ['University Of Washington']
# 360
# Full  University Of Washington
# Auth 0 0 University Of Washington
# University Of Washington
# ['University Of Washington']
# 360
# Full  University Of Washington
# Auth 1 0 University Of Washington
# University Of Washington
# ['University Of Washington']
# 360
# Full  University Of Washington
# Auth 2 0 University Of Washington
# 360
# Harvard University
# ['Harvard University']
# 361
# Full  Harvard University
# Auth 0 0 Harvard University
# 361
# University Of Virginia
# ['University Of Virginia']
# 362
# Full  University Of Virginia
# Auth 0 0 University Of Virginia
# 362
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 363
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 363
# Columbia University
# ['Columbia University']
# 364
# Full  Columbia University
# Auth 0 0 Columbia University
# 364
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 365
# Full  Princeton University
# Auth 0 0 Princeton University
# 365
# University Of Buffalo
# ['University Of Buffalo']
# 366
# Full  University Of Buffalo
# Auth 0 0 University Of Buffalo
# 366
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 367
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 367
# 368
# Full
# Auth 0 0
# 368
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 369
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 369
# University Of Minnesota
# ['University Of Minnesota']
# 370
# Full  University Of Minnesota
# Auth 0 0 University Of Minnesota
# 370
# Duke University
# ['Duke University']
# 371
# Full  Duke University
# Auth 0 0 Duke University
# 371
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 372
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 372
# California
# ['California']
# University Of California At Los Angeles
# ['California', 'University Of California At Los Angeles']
# California United States (State)
# UCLA
# University Of California
# ['California', 'University Of California At Los Angeles', 'University Of California']
# California United States (State)
# UCLA
# 373
# Full  University Of California System United States (State) At Los Angeles
# Auth 0 0 University Of California System United States (State) At Los Angeles
# 373
# Rutgers University
# ['Rutgers University']
# 374
# Full  Rutgers University
# Auth 0 0 Rutgers University
# 374
# 375
# Full
# Auth 0 0
# 375
# Full
# Auth 1 0
# 375
# California
# ['California']
# University Of California, Los Angeles
# ['California', 'University Of California, Los Angeles']
# California United States (State)
# UCLA
# University Of California
# ['California', 'University Of California, Los Angeles', 'University Of California']
# California United States (State)
# UCLA
# 376
# Full  University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State)
#
# Auth 0 1 Los Angeles
# Los Angeles
# 376
# Johns Hopkins University
# ['Johns Hopkins University']
# 377
# Full  Johns Hopkins University
# Auth 0 0 Johns Hopkins University
# 377
# Butler University
# ['Butler University']
# 378
# Full  Butler University
# Auth 0 0 Butler University
# 378
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 379
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 379
# 380
# Full
# Auth 0 0
# 380
# Toronto
# ['Toronto']
# University Of Toronto
# ['Toronto', 'University Of Toronto']
# Toronoto Canada (City)
# University Of Toronto
# 381
# Full  University Of Toronoto Canada (City)
# Auth 0 0 University Of Toronoto Canada (City)
# 381
# Massachusetts Institute Of Technology
# ['Massachusetts Institute Of Technology']
# 382
# Full  Massachusetts Institute Of Technology
# Auth 0 0 Massachusetts Institute Of Technology
# 382
# Duke University
# ['Duke University']
# 383
# Full  Duke University
# Auth 0 0 Duke University
# 383
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 384
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 384
# Ohio State University
# ['Ohio State University']
# 385
# Full  Ohio State University
# Auth 0 0 Ohio State University
# 385
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 386
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 386
# Northwestern University
# ['Northwestern University']
# 387
# Full  Northwestern University
# Auth 0 0 Northwestern University
# 387
# United States Treasury Department
# ['United States Treasury Department']
# 388
# Full  United States Treasury Department
# Auth 0 0 United States Treasury Department
# 388
# 389
# Full
# Auth 0 0
# 389
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 390
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 390
# Duke University
# ['Duke University']
# 391
# Full  Duke University
# Auth 0 0 Duke University
# 391
# Texas A And M College
# ['Texas A And M College']
# 392
# Full  Texas A & M University
# Auth 0 0 Texas A & M University
# 392
# Washington, Dc
# ['Washington, Dc']
# 393
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 393
# Columbia University
# ['Columbia University']
# 394
# Full  Columbia University
# Auth 0 0 Columbia University
# Columbia University
# ['Columbia University']
# 394
# Full  Columbia University
# Auth 1 0 Columbia University
# 394
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 395
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 395
# Drake University
# ['Drake University']
# 396
# Full  Drake University
# Auth 0 0 Drake University
# 396
# Vanderbilt University
# ['Vanderbilt University']
# 397
# Full  Vanderbilt University
# Auth 0 0 Vanderbilt University
# 397
# Food Research Institute, Stanford University
# ['Food Research Institute, Stanford University']
# Food Research Institute
# ['Food Research Institute, Stanford University', 'Food Research Institute']
# Stanford University
# Food Research Institute
# Stanford University
# ['Food Research Institute, Stanford University', 'Food Research Institute', 'Stanford University']
# Stanford University
# Food Research Institute
# 398
# Full  Stanford University
# Auth 0 0 Stanford University
# 398
# Harvard University
# ['Harvard University']
# 399
# Full  Harvard University
# Auth 0 0 Harvard University
# Harvard University
# ['Harvard University']
# 399
# Full  Harvard University
# Auth 1 0 Harvard University
# 399
# Harvard University
# ['Harvard University']
# 400
# Full  Harvard University
# Auth 0 0 Harvard University
# 400
# Michigan
# ['Michigan']
# Survey Research Center, University Of Michigan
# ['Michigan', 'Survey Research Center, University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# University Of Michigan
# ['Michigan', 'Survey Research Center, University Of Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 401
# Full  Survey Research Center, University Of Michigan United States (State)
# Auth 0 0 Survey Research Center, University Of Michigan United States (State)
# Auth 0 0 Survey Research Center
#
# Auth 0 1 University Of Michigan United States (State)
# University Of Michigan United States (State)
# 401
# California
# ['California']
# University Of California, Los Angeles
# ['California', 'University Of California, Los Angeles']
# California United States (State)
# UCLA
# University Of California
# ['California', 'University Of California, Los Angeles', 'University Of California']
# California United States (State)
# UCLA
# 402
# Full  University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State)
#
# Auth 0 1 Los Angeles
# Los Angeles
# 402
# University Of Arkansas
# ['University Of Arkansas']
# 403
# Full  University Of Arkansas
# Auth 0 0 University Of Arkansas
# 403
# Washington, Dc
# ['Washington, Dc']
# 404
# Full  Washington DC United States (City)
# Auth 0 0 Washington DC United States (City)
# 404
# University Of Wisconsin
# ['University Of Wisconsin']
# 405
# Full  University Of Wisconsin System
# Auth 0 0 University Of Wisconsin System
# 405
# University Of Tennessee
# ['University Of Tennessee']
# 406
# Full  University Of Tennessee
# Auth 0 0 University Of Tennessee
# 406
# Food Research Institute, Stanford University
# ['Food Research Institute, Stanford University']
# Food Research Institute
# ['Food Research Institute, Stanford University', 'Food Research Institute']
# Stanford University
# Food Research Institute
# Stanford University
# ['Food Research Institute, Stanford University', 'Food Research Institute', 'Stanford University']
# Stanford University
# Food Research Institute
# 407
# Full  Stanford University
# Auth 0 0 Stanford University
# 407
# Iowa State College
# ['Iowa State College']
# 408
# Full  Iowa State College
# Auth 0 0 Iowa State College
# 408
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 409
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 409
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 410
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 410
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 411
# Full  Princeton University
# Auth 0 0 Princeton University
# 411
# Iowa State College
# ['Iowa State College']
# 412
# Full  Iowa State College
# Auth 0 0 Iowa State College
# 412
# Massachusetts Institute Of Technology
# ['Massachusetts Institute Of Technology']
# 413
# Full  Massachusetts Institute Of Technology
# Auth 0 0 Massachusetts Institute Of Technology
# 413
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 414
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 414
# Duke University
# ['Duke University']
# 415
# Full  Duke University
# Auth 0 0 Duke University
# 415
# Berkeley
# ['Berkeley']
# California
# ['Berkeley', 'California']
# Berkeley California United States (City)
# California United States (State)
# University Of California (Berkeley)
# ['Berkeley', 'California', 'University Of California (Berkeley)']
# Berkeley California United States (City)
# California United States (State)
# University Of California
# ['Berkeley', 'California', 'University Of California (Berkeley)', 'University Of California']
# Berkeley California United States (City)
# California United States (State)
# 416
# Full  University Of California System (Berkeley California United States (City))
# Auth 0 0 University Of California System (Berkeley California United States (City))
# 416
# Columbia University
# ['Columbia University']
# 417
# Full  Columbia University
# Auth 0 0 Columbia University
# 417
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 418
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 418
# American University
# ['American University']
# 419
# Full  American University
# Auth 0 0 American University
# 419
# 420
# Full
# Auth 0 0
# 420
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 421
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 421
# University Of Wisconsin
# ['University Of Wisconsin']
# 422
# Full  University Of Wisconsin System
# Auth 0 0 University Of Wisconsin System
# 422
# Michigan
# ['Michigan']
# Michigan State College
# ['Michigan', 'Michigan State College']
# Michigan United States (State)
# Michigan State College
# 423
# Full  Michigan United States (State) State College
# Auth 0 0 Michigan United States (State) State College
# 423
# 424
# Full
# Auth 0 0
# 424
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 425
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 425
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 426
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 426
# Berkeley
# ['Berkeley']
# California
# ['Berkeley', 'California']
# Berkeley California United States (City)
# California United States (State)
# University Of California, Berkeley
# ['Berkeley', 'California', 'University Of California, Berkeley']
# Berkeley California United States (City)
# California United States (State)
# University Of California
# ['Berkeley', 'California', 'University Of California, Berkeley', 'University Of California']
# Berkeley California United States (City)
# California United States (State)
# 427
# Full  University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System
#
# Auth 0 1 Berkeley California United States (City)
# Berkeley California United States (City)
# 427
# Duke University
# ['Duke University']
# 428
# Full  Duke University
# Auth 0 0 Duke University
# 428
# University Of Florida
# ['University Of Florida']
# 429
# Full  University Of Florida
# Auth 0 0 University Of Florida
# 429
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 430
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 430
# Marquette University
# ['Marquette University']
# 431
# Full  Marquette University
# Auth 0 0 Marquette University
# 431
# Oxford
# ['Oxford']
# Oxford University
# ['Oxford', 'Oxford University']
# University Of Oxford
# University Of Oxford
# Elif
# Trinity College, Oxford
# ['Oxford', 'Oxford University', 'Trinity College, Oxford']
# University Of Oxford
# University Of Oxford
# Elif
# Trinity College
# ['Oxford', 'Oxford University', 'Trinity College, Oxford', 'Trinity College']
# University Of Oxford
# University Of Oxford
# Elif
# Trinity College, Oxford University
# ['Oxford', 'Oxford University', 'Trinity College, Oxford', 'Trinity College', 'Trinity College, Oxford University']
# University Of Oxford
# University Of Oxford
# Elif
# 432
# Full  Trinity College, University Of Oxford
# Auth 0 0 Trinity College, University Of Oxford
# Auth 0 0 Trinity College
#
# Auth 0 1 University Of Oxford
# University Of Oxford
# 432
# California
# ['California']
# University Of California, Los Angeles
# ['California', 'University Of California, Los Angeles']
# California United States (State)
# UCLA
# University Of California
# ['California', 'University Of California, Los Angeles', 'University Of California']
# California United States (State)
# UCLA
# 433
# Full  University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State), Los Angeles
# Auth 0 0 University Of California System United States (State)
#
# Auth 0 1 Los Angeles
# Los Angeles
# 433
# Oberlin College
# ['Oberlin College']
# 434
# Full  Oberlin College
# Auth 0 0 Oberlin College
# 434
# London
# ['London']
# London School Of Economics
# ['London', 'London School Of Economics']
# London United Kingdom (City)
# London School Of Economics & Political Sciences
# 435
# Full  London United Kingdom (City) School Of Economics And Political Science
# Auth 0 0 London United Kingdom (City) School Of Economics
# Auth 0 1 Political Science
# 435
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 436
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 436
# Full  University Of Michigan United States (State)
# Auth 1 0 University Of Michigan United States (State)
# 436
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 437
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 437
# Florida State University
# ['Florida State University']
# 438
# Full  Florida State University
# Auth 0 0 Florida State University
# 438
# Princeton
# ['Princeton']
# Princeton University
# ['Princeton', 'Princeton University']
# Princeton University
# Princeton University
# Elif
# 439
# Full  Princeton University
# Auth 0 0 Princeton University
# 439
# University Of Wisconsin
# ['University Of Wisconsin']
# 440
# Full  University Of Wisconsin System
# Auth 0 0 University Of Wisconsin System
# 440
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 441
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 441
# Johns Hopkins University
# ['Johns Hopkins University']
# 442
# Full  Johns Hopkins University
# Auth 0 0 Johns Hopkins University
# Johns Hopkins University
# ['Johns Hopkins University']
# 442
# Full  Johns Hopkins University
# Auth 1 0 Johns Hopkins University
# 442
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 443
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 443
# California
# ['California']
# University Of California, Los Angeles
# ...
# California
# ['Berkeley', 'California']
# Berkeley California United States (City)
# California United States (State)
# University Of California, Berkeley
# ['Berkeley', 'California', 'University Of California, Berkeley']
# Berkeley California United States (City)
# California United States (State)
# University Of California
# ['Berkeley', 'California', 'University Of California, Berkeley', 'University Of California']
# Berkeley California United States (City)
# California United States (State)
# 584
# Full  University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System
#
# Auth 0 1 Berkeley California United States (City)
# Berkeley California United States (City)
# 584
# Massachusetts Institute Of Technology
# ['Massachusetts Institute Of Technology']
# 585
# Full  Massachusetts Institute Of Technology
# Auth 0 0 Massachusetts Institute Of Technology
# 585
# Texas A And M College
# ['Texas A And M College']
# 586
# Full  Texas A & M University
# Auth 0 0 Texas A & M University
# 586
# Washington University
# ['Washington University']
# 587
# Full  Washington University In St Louis
# Auth 0 0 Washington University In St Louis
# 587
# Pennsylvania
# ['Pennsylvania']
# Pennsylvania State University
# ['Pennsylvania', 'Pennsylvania State University']
# Pittsburgh Pennslyvania United States (City)
# Pennsylvania State University
# 588
# Full  Pittsburgh Pennslyvania United States (City) State University
# Auth 0 0 Pittsburgh Pennslyvania United States (City) State University
# 588
# 589
# Full
# Auth 0 0
# 589
# Full
# Auth 1 0
# 589
# University Of Wisconsin
# ['University Of Wisconsin']
# 590
# Full  University Of Wisconsin System
# Auth 0 0 University Of Wisconsin System
# 590
# University Of Illinois
# ['University Of Illinois']
# 591
# Full  University Of Illinois System
# Auth 0 0 University Of Illinois System
# 591
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 592
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 592
# Vanderbilt University
# ['Vanderbilt University']
# 593
# Full  Vanderbilt University
# Auth 0 0 Vanderbilt University
# 593
# University Of Washington
# ['University Of Washington']
# 594
# Full  University Of Washington
# Auth 0 0 University Of Washington
# 594
# Manchester
# ['Manchester']
# University Of Manchester
# ['Manchester', 'University Of Manchester']
# Manchester United Kingdom(City)
# University Of Manchester
# 595
# Full  University Of Manchester United Kingdom(City)
# Auth 0 0 University Of Manchester United Kingdom(City)
# 595
# State College Of Washington
# ['State College Of Washington']
# 596
# Full  State College Of Washington
# Auth 0 0 State College Of Washington
# 596
# Yale University
# ['Yale University']
# 597
# Full  Yale University
# Auth 0 0 Yale University
# 597
# Columbia University
# ['Columbia University']
# 598
# Full  Columbia University
# Auth 0 0 Columbia University
# 598
# Amos Tuck School
# ['Amos Tuck School']
# 599
# Full  Dartmouth College
# Auth 0 0 Dartmouth College
# 599
# Massachusetts Institute Of Technology
# ['Massachusetts Institute Of Technology']
# 600
# Full  Massachusetts Institute Of Technology
# Auth 0 0 Massachusetts Institute Of Technology
# 600
# 601
# Full
# Auth 0 0
# 601
# 602
# Full
# Auth 0 0
# 602
# University Of Washington
# ['University Of Washington']
# 603
# Full  University Of Washington
# Auth 0 0 University Of Washington
# 603
# 604
# Full
# Auth 0 0
# 604
# Massachusetts Institute Of Technology
# ['Massachusetts Institute Of Technology']
# 605
# Full  Massachusetts Institute Of Technology
# Auth 0 0 Massachusetts Institute Of Technology
# 605
# Pennsylvania
# ['Pennsylvania']
# University Of Pennsylvania
# ['Pennsylvania', 'University Of Pennsylvania']
# Pittsburgh Pennslyvania United States (City)
# University Of Pennsylvania
# 606
# Full  University Of Pittsburgh Pennslyvania United States (City)
# Auth 0 0 University Of Pittsburgh Pennslyvania United States (City)
# 606
# Towa State College
# ['Towa State College']
# 607
# Full  Iowa State University
# Auth 0 0 Iowa State University
# 607
# Michigan
# ['Michigan']
# University Of Michigan
# ['Michigan', 'University Of Michigan']
# Michigan United States (State)
# University Of Michigan
# 608
# Full  University Of Michigan United States (State)
# Auth 0 0 University Of Michigan United States (State)
# 608
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 609
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 609
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 610
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 610
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 611
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 611
# Northwestern University
# ['Northwestern University']
# 612
# Full  Northwestern University
# Auth 0 0 Northwestern University
# 612
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 613
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 613
# 614
# Full
# Auth 0 0
# 614
# 615
# Full
# Auth 0 0
# 615
# 616
# Full
# Auth 0 0
# 616
# Roosevelt University
# ['Roosevelt University']
# 617
# Full  Roosevelt University
# Auth 0 0 Roosevelt University
# 617
# Massachusetts Institute Of Technology
# ['Massachusetts Institute Of Technology']
# 618
# Full  Massachusetts Institute Of Technology
# Auth 0 0 Massachusetts Institute Of Technology
# 618
# University Of Arkansas
# ['University Of Arkansas']
# 619
# Full  University Of Arkansas
# Auth 0 0 University Of Arkansas
# 619
# Federal Reserve Bai
# ['Federal Reserve Bai']
# 620
# Full  Federal Reserve Bank
# Auth 0 0 Federal Reserve Bank
# 620
# 621
# Full
# Auth 0 0
# 621
# Full
# Auth 1 0
# 621
# Oberlin College
# ['Oberlin College']
# 622
# Full  Oberlin College
# Auth 0 0 Oberlin College
# 622
# Berkeley
# ['Berkeley']
# California
# ['Berkeley', 'California']
# Berkeley California United States (City)
# California United States (State)
# University Of California, Berkeley
# ['Berkeley', 'California', 'University Of California, Berkeley']
# Berkeley California United States (City)
# California United States (State)
# University Of California
# ['Berkeley', 'California', 'University Of California, Berkeley', 'University Of California']
# Berkeley California United States (City)
# California United States (State)
# 623
# Full  University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System, Berkeley California United States (City)
# Auth 0 0 University Of California System
#
# Auth 0 1 Berkeley California United States (City)
# Berkeley California United States (City)
# 623
# Michigan
# ['Michigan']
# Michigan State University
# ['Michigan', 'Michigan State University']
# Michigan United States (State)
# Michigan State University
# 624
# Full  Michigan United States (State) State University
# Auth 0 0 Michigan United States (State) State University
# 624
# Rand Corporation
# ['Rand Corporation']
# 625
# Full  Rand Corporation
# Auth 0 0 Rand Corporation
# 625
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 626
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 626
# Yale University
# ['Yale University']
# 627
# Full  Yale University
# Auth 0 0 Yale University
# 627
# North Carolina State College
# ['North Carolina State College']
# 628
# Full  North Carolina State College
# Auth 0 0 North Carolina State College
# 628
# Yale University
# ['Yale University']
# 629
# Full  Yale University
# Auth 0 0 Yale University
# 629
# University Of Minnesota
# ['University Of Minnesota']
# 630
# Full  University Of Minnesota
# Auth 0 0 University Of Minnesota
# 630
# University Of Washington
# ['University Of Washington']
# 631
# Full  University Of Washington
# Auth 0 0 University Of Washington
# 631
# Massachusetts Institute Of Technology
# ['Massachusetts Institute Of Technology']
# 632
# Full  Massachusetts Institute Of Technology
# Auth 0 0 Massachusetts Institute Of Technology
# 632
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 633
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# 633
# University Of Washington
# ['University Of Washington']
# 634
# Full  University Of Washington
# Auth 0 0 University Of Washington
# University Of Washington
# ['University Of Washington']
# 634
# Full  University Of Washington
# Auth 1 0 University Of Washington
# 634
# Indiana University
# ['Indiana University']
# 635
# Full  Indiana University System
# Auth 0 0 Indiana University System
# 635
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 636
# Full  University Of Chicago Illinois United States (City)
# Auth 0 0 University Of Chicago Illinois United States (City)
# Chicago
# ['Chicago']
# University Of Chicago
# ['Chicago', 'University Of Chicago']
# Chicago Illinois United States (City)
# University Of Chicago
# 636
# Full  University Of Chicago Illinois United States (City)
# Auth 1 0 University Of Chicago Illinois United States (City)
# 636
# University Of Virginia
# ['University Of Virginia']
# 637
# Full  University Of Virginia
# Auth 0 0 University Of Virginia
# 637
# Birmingham
# ['Birmingham']
# Iowa State College
# ['Birmingham', 'Iowa State College']
# Birmingham United Kingdom (City)
# Iowa State College
# University Of Birmingham
# ['Birmingham', 'Iowa State College', 'University Of Birmingham']
# Birmingham United Kingdom (City)
# Iowa State College
# 638
# Full  University Of Birmingham United Kingdom (City) And Iowa State College
# Auth 0 0 University Of Birmingham United Kingdom (City)
# Auth 0 1 Iowa State College
# 638
# Ohio State University
# ['Ohio State University']
# University Of Virginia
# ['Ohio State University', 'University Of Virginia']
# Ohio State University
# University Of Virginia
# 639
# Full  Ohio State University And University Of Virginia
# Auth 0 0 Ohio State University
# Auth 0 1 University Of Virginia
# Ohio State University
# ['Ohio State University']
# University Of Virginia
# ['Ohio State University', 'University Of Virginia']
# Ohio State University
# University Of Virginia
# 639
# Full  Ohio State University And University Of Virginia
# Auth 1 0 Ohio State University
# Auth 1 1 University Of Virginia
# 639
# Depauw University
# ['Depauw University']
# 640
# Full  Depauw University
# Auth 0 0 Depauw University
# 640
# Chicago
# ['Chicago']
# Chicago, Illinoi
# ['Chicago', 'Chicago, Illinoi']
# Chicago Illinois United States (City)
# University Of Illinois Chicago
# Chicago, Illinois
# ['Chicago', 'Chicago, Illinoi', 'Chicago, Illinois']
# Chicago Illinois United States (City)
# University Of Illinois Chicago
# 641
# Full  Chicago Illinois United States (City), Illinois
# Auth 0 0 Chicago Illinois United States (City), Illinois
# Auth 0 0 Chicago Illinois United States (City)
#
# Auth 0 1 Illinois
# Illinois
# 641
# Columbia University
# ['Columbia University']
# 642
# Full  Columbia University
# Auth 0 0 Columbia University
# 642
# Duke University
# ['Duke University']
# 643
# Full  Duke University
# Auth 0 0 Duke University
# 643
# International Monetary Fund
# ['International Monetary Fund']
# 644
# Full  International Monetary Fund
# Auth 0 0 International Monetary Fund
# 644
# Chicago
# ['Chicago']
# Chicago, Illinoi
# ['Chicago', 'Chicago, Illinoi']
# Chicago Illinois United States (City)
# University Of Illinois Chicago
# 645
# Full  Chicago Illinois United States (City), Illinoi
# Auth 0 0 Chicago Illinois United States (City), Illinoi
# Auth 0 0 Chicago Illinois United States (City)
#
# Auth 0 1 Illinoi
# Illinoi
# Chicago
# ['Chicago']
# Chicago, Illinoi
# ['Chicago', 'Chicago, Illinoi']
# Chicago Illinois United States (City)
# University Of Illinois Chicago
# 645
# Full  Chicago Illinois United States (City), Illinoi
# Auth 1 0 Chicago Illinois United States (City), Illinoi
# Auth 1 0 Chicago Illinois United States (City)
#
# Auth 1 1 Illinoi
# Illinoi
# Chicago
# ['Chicago']
# Chicago, Illinoi
# ['Chicago', 'Chicago, Illinoi']
# Chicago Illinois United States (City)
# University Of Illinois Chicago
# 645
# Full  Chicago Illinois United States (City), Illinoi
# Auth 2 0 Chicago Illinois United States (City), Illinoi
# Auth 2 0 Chicago Illinois United States (City)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2_author_affs_consolidated_2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 18>()
#      82             testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2']  = auths_affs_split_comma[1].strip().rstrip(',')
#      83         print('Auth', str(auth_no), str(affcomma) , testdata.loc[i,str(auth_no)+'_author_affs_consolidated_'+str(affcomma)])
# ---> 84         print(testdata.loc[i,str(auth_no)+'_author_affs_consolidated_2'])
#      85 if len(auths_affs_split_comma) == 3:
#      86     for affcomma in range(len(auths_affs_split_comma)):
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:3616, in DataFrame._get_value(self, index, col, takeable)
#    3613     series = self._ixs(col, axis=1)
#    3614     return series._values[index]
# -> 3616 series = self._get_item_cache(col)
#    3617 engine = self.index._engine
#    3619 if not isinstance(self.index, MultiIndex):
#    3620     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3621     #  results if our categories are integers that dont match our codes
#    3622     # IntervalIndex: IntervalTree has no get_loc
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:3939, in DataFrame._get_item_cache(self, item)
#    3934 res = cache.get(item)
#    3935 if res is None:
#    3936     # All places that call _get_item_cache have unique columns,
#    3937     #  pending resolution of GH#33047
# -> 3939     loc = self.columns.get_loc(item)
#    3940     res = self._ixs(loc, axis=1)
#    3942     cache[item] = res
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: '2_author_affs_consolidated_2'

# %%
#Checking the newly created column names
print(testdata.columns.values)
# Out:
# ['Journal_Name' 'Authors_count' 'Authors_list' 'Article_ID' 'content_type'
#  'stable_url' 'Ref_type' 'ref_string' 'ref_string_clean1' 'year'
#  '0_author' '0_author_affs' '1_author' '1_author_affs' '2_author'
#  '2_author_affs' '3_author' '3_author_affs' '4_author' '4_author_affs'
#  '5_author' '5_author_affs' '0_author_affs_consolidated'
#  '1_author_affs_consolidated' '2_author_affs_consolidated'
#  '3_author_affs_consolidated' '4_author_affs_consolidated'
#  '5_author_affs_consolidated' '0_author_affs_consolidated_0'
#  '0_author_affs_consolidated_1' '0_author_affs_consolidated_2'
#  '1_author_affs_consolidated_1' '1_author_affs_consolidated_2'
#  '1_author_affs_consolidated_0' '2_author_affs_consolidated_0'
#  '3_author_affs_consolidated_0' '0_author_affs_consolidated_3'
#  '2_author_affs_consolidated_1' '2_author_affs_consolidated_2'
#  '1_author_affs_consolidated_3' '2_author_affs_consolidated_3'
#  '3_author_affs_consolidated_1' '4_author_affs_consolidated_0'
#  '0_author_affs_consolidated_4' '3_author_affs_consolidated_2'
#  '3_author_affs_consolidated_3' '5_author_affs_consolidated_0']

# %%
# Only keeping the desired columns
testdata = testdata[['Journal_Name' ,'Authors_count', 'Authors_list', 'Article_ID', 'content_type',
 'stable_url', 'Ref_type' ,'ref_string', 'ref_string_clean1', 'year',
 '0_author_affs', 
 '0_author_affs_consolidated',
 '0_author_affs_consolidated_0',
 '0_author_affs_consolidated_1', 
 '0_author_affs_consolidated_2', 
 '1_author_affs', 
 '1_author_affs_consolidated',
 '1_author_affs_consolidated_0',
 '1_author_affs_consolidated_1',
  '1_author_affs_consolidated_2',
 '2_author_affs',
 '2_author_affs_consolidated',
 '2_author_affs_consolidated_0',
 '2_author_affs_consolidated_1', 
 '2_author_affs_consolidated_2' ,
 '3_author_affs',
 '3_author_affs_consolidated', 
 '3_author_affs_consolidated_0',
 '3_author_affs_consolidated_1',
 '4_author_affs',
 '4_author_affs_consolidated',
 '4_author_affs_consolidated_0',
 '5_author_affs', 
 '5_author_affs_consolidated']]

# %%
# Excel output to get an overview of the data
#This Should be changed to output to your local storage
testdata.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/3_consolidation/Files/JPE_Affiliations.xlsx')
