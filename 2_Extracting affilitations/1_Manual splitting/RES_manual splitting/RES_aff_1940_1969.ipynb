# %%
# For JPE_ref_output_2001_2010.json
import json
import re
import pandas as pd
import string
import openpyxl
from rapidfuzz import fuzz

# Import JSON file
f = open('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/RES/affs/RES_aff_output_1960_1969.json')
json_data = json.load(f)

# Def regex search
def find_reference(word):
    return re.compile(r'\b({0})\b'.format(word)).search

# Def character search
def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)

# Define Journal and Dataframe
Journal_Name = 'RES'
Reference_Data_List = []

# Extract Json Data into dataframe
for key1, value1 in json_data.items():
    Article_ID = key1
    content_type = value1["content_type"]
    author_list = value1["authors"]
    authorscount = len(author_list)
    if len(author_list) == 1:
        author_1 = author_list[0]
        author_2 = ''
        author_3 = ''
        author_4 = ''
        author_5 = ''
        author_6 = ''
    elif len(author_list) == 2:
        author_1 = author_list[0]
        author_2 = author_list[1]
        author_3 = ''
        author_4 = ''
        author_5 = ''
        author_6 = ''
    elif len(author_list) == 3:
        author_1 = author_list[0]
        author_2 = author_list[1]
        author_3 = author_list[2]
        author_4 = ''
        author_5 = ''
        author_6 = ''
    elif len(author_list) == 4:
        author_1 = author_list[0]
        author_2 = author_list[1]
        author_3 = author_list[2]
        author_4 = author_list[3]
        author_5 = ''
        author_6 = ''
    elif len(author_list) == 5:
        author_1 = author_list[0]
        author_2 = author_list[1]
        author_3 = author_list[2]
        author_4 = author_list[3]
        author_5 = author_list[4]
        author_6 = ''
    else:
        author_1 = author_list[0]
        author_2 = author_list[1]
        author_3 = author_list[2]
        author_4 = author_list[3]
        author_5 = author_list[4]
        author_6 = author_list[5]

    author_1 = author_1.strip().upper()
    author_2 = author_2.strip().upper()
    author_3 = author_3.strip().upper()
    author_4 = author_4.strip().upper()
    author_5 = author_5.strip().upper()
    author_6 = author_6.strip().upper()

    #print(author_list)
    if len(author_list) > 1:
        authors = ",".join(author_list)
    else:
        authors = author_list[0]
        stable_url = value1["stable_url"]
    for key2 in value1["affiliations"]:
        Ref_type = key2
        if key2 == "found":
            ref_string = value1["affiliations"][key2]
            ref_string = ref_string.upper()

            print(author_list)
            for i in author_list:
                #auth = i
                #s = 'K. R. MACCRIMMON'
            #s = 'a'
            #a = re.findall(r'.*\sK. R. MACCRIMMON',string2)
                i = i.upper().strip()
                pattern = re.compile(r".*"+i+"")
                reference_string_list = re.findall(pattern,ref_string)
                print(i)
                print(reference_string_list)
                #print(ref_string)
            # #reference_string_list = ref_string.split("\n\n")
            # #ref_string_1 = ref_string.upper()
            # ref_string_1 = re.sub(r"[.]","",ref_string)
            # #reference_string_list = re.findall('\w+\s[\w.-]+\s*\w*\n',ref_string_1)
            # reference_string_list = re.findall('.+',ref_string_1)
            # #reference_string_list = reference_string_list1[1:3095]

            # #Removing the text infront of author and aff
            # n = 0
            # while fuzz.ratio(author_1,reference_string_list[0]) < 30:
            #     reference_string_list = reference_string_list[1:]
            #     n = n+1
            #     if len(reference_string_list) == 0:
            #         break
            # #Remving and inbetween references
            # for i in reference_string_list:
            #     if i == 'and':
            #         reference_string_list.remove(i)

            #     #auth = re.findall('\sand\s',i)
            # if len(reference_string_list) >= 2:
            #     if re.findall(' and ',reference_string_list[0]):
            #         x = re.split(' and', reference_string_list[0])
            #         reference_string_list[0] = x[0]
            #         if len(x) == 2:
            #             reference_string_list.append(x[1])


            ref_length = len(reference_string_list)

            if len(reference_string_list) == 1:
                Author1 = reference_string_list[0]
                Affilliation1 = ''
                Author2 = ''
                Affilliation2 = ''
                Author3 = ''
                Affilliation3 = ''
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 2:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = ''
                Affilliation2 = ''
                Author3 = ''
                Affilliation3 = ''
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 3:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = ''
                Author3 = ''
                Affilliation3 = ''
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 4:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]
                Author3 = ''
                Affilliation3 = ''
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 5:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]  
                Affilliation3 = ''
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = '' 
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 6:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]
                Affilliation3 = reference_string_list[5]     
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = '' 
                Author6 = ''
                Affilliation6 = ''   
            elif len(reference_string_list) == 7:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]
                Affilliation3 = reference_string_list[5] 
                Author4 = reference_string_list[6]
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 8:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]
                Affilliation3 = reference_string_list[5] 
                Author4 = reference_string_list[6]
                Affilliation4 = reference_string_list[7]
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 9:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]
                Affilliation3 = reference_string_list[5] 
                Author4 = reference_string_list[6]
                Affilliation4 = reference_string_list[7]
                Author5 = reference_string_list[8]
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 10:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]
                Affilliation3 = reference_string_list[5] 
                Author4 = reference_string_list[6]
                Affilliation4 = reference_string_list[7]
                Author5 = reference_string_list[8]
                Affilliation5 = reference_string_list[9]
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 11:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]
                Affilliation3 = reference_string_list[5] 
                Author4 = reference_string_list[6]
                Affilliation4 = reference_string_list[7]
                Author5 = reference_string_list[8]
                Affilliation5 = reference_string_list[9]
                Author6 = reference_string_list[10]
                Affilliation6 = ''
            else:
                Author1 = ''
                Affilliation1 = ''
                Author2 = ''
                Affilliation2 = ''
                Author3 = ''
                Affilliation3 = ''
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                # Author1 = reference_string_list[0]
                # Affilliation1 = reference_string_list[1]
                # Author2 = reference_string_list[2]
                # Affilliation2 = reference_string_list[3]   
                # Author3 = reference_string_list[4]
                # Affilliation3 = reference_string_list[5] 
                # Author4 = reference_string_list[6]
                # Affilliation4 = reference_string_list[7]
                # Author5 = reference_string_list[8]
                # Affilliation5 = reference_string_list[9]
                # Author6 = reference_string_list[10]
                #Affilliation6 = reference_string_list[11]

            Author1 = Author1.strip()
            Affilliation1 = Affilliation1.strip()
            Author2 = Author2.strip()
            Affilliation2 = Affilliation2.strip() 
            Author3 = Author3.strip()
            Affilliation3 = Affilliation3.strip()
            Author4 = Author4.strip()
            Affilliation4 = Affilliation4.strip()
            Author5 = Author5.strip()
            Affilliation5 = Affilliation5.strip()
            Author6 = Author6.strip()
            Affilliation6 = Affilliation6.strip()
# for i in range(1,7):
#     if author_(i) == 0
#     else: 
#         print(no)

    

    a1fuzz = fuzz.ratio(author_1,Author1)
    if author_1 == Author1 == "":
        a1 = 'Empty' 
    elif author_1 == Author1:
        a1 = 'True'
    else:
        a1 = 'False'
    if author_2 == Author2 == "":
        a2 = 'Empty' 
    elif author_2 == Author2:
        a2 = 'True'
    else:
        a2 = 'False'
    if author_3 == Author3 == "":
        a3 = 'Empty' 
    elif author_3 == Author3:
        a3 = 'True'
    else:
        a3 = 'False'
    if author_4 == Author4 == "":
        a4 = 'Empty' 
    elif author_4 == Author4:
        a4 = 'True'
    else:
        a4 = 'False'
    if author_5 == Author5 == "":
        a5 = 'Empty' 
    elif author_5 == Author5:
        a5 = 'True'
    else:
        a5 = 'False'
    if author_6 == Author6 == "":
        a6 = 'Empty' 
    elif author_6 == Author6:
        a6 = 'True'
    else:
        a6 = 'False'
                
    #print(Author1)
    Reference_Data_List.append({'Journal_Name' : Journal_Name,'Author1':Author1, 'Affilliation1':Affilliation1, 'Author2':Author2,'Affilliation2':Affilliation2,
     
    'authorscount':authorscount,
    'Authors' : authors, 'a1fuzz':a1fuzz,
    'author_1':author_1, 'Author1':Author1,
    'author_2':author_2 , 'author_3':author_3, 'author_4':author_4, 'author_5':author_5 , 'author_6':author_6,
    'Article_ID' : Article_ID, 'content_type' : content_type,
    #'stable_url' : stable_url, 
    'Ref_type': Ref_type, 
     'Author3':Author3,'Affilliation3':Affilliation3,
    'Author4':Author4, 'Affilliation4':Affilliation4, 'Author5':Author5, 'Affilliation5':Affilliation5, 'Author6':Author6, 'Affilliation6':Affilliation6, 
    'ref_length':ref_length, 'ref_string':ref_string,
    'a1':a1,'a2':a2,'a3':a3,'a4':a4,'a5':a5,'a6':a6 })

Reference_Data = pd.DataFrame.from_records(Reference_Data_List)     
Reference_Data.to_excel('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/RES/JPE_affiliation_output_2000_2009_1.xlsx')
#Reference_Data.to_excel('/Users/danaebouwer/Documents/Work/Matthew sheets/drive-download-20220901T140508Z-001/JPE/JPE_ref_output_2001_2010/JPE_ref_output_2001_2010.xlsx')
# Out:
# ['J. W. Friedman']
# J. W. FRIEDMAN
# ['UNIVERSITY OF ROCHESTER J. W. FRIEDMAN']
# ['A. C. Hoggatt']
# A. C. HOGGATT
# ['UNIVERSITY OF CALIFORNIA, BERKELEY A. C. HOGGATT']
# ['K. R. MacCrimmon', ' M. Toda']
# K. R. MACCRIMMON
# ['CARNEGIE-MELLON UNIVERSITY K. R. MACCRIMMON']
# M. TODA
# []
# ['Roger Sherman']
# ROGER SHERMAN
# ['UNIVERSITY OF BRISTOL AND ROGER SHERMAN']
# ['John A. Carlson', " Terrence B. O'Keefe"]
# JOHN A. CARLSON
# ['PURDUE UNIVERSITY JOHN A. CARLSON']
# TERRENCE B. O'KEEFE
# ["TERRENCE B. O'KEEFE"]
# ['L. L. Cummings', ' D. L. Harnett']
# L. L. CUMMINGS
# ['UNIVERSITY OF WISCONSIN L. L. CUMMINGS']
# D. L. HARNETT
# []
# ['John E. Floyd']
# JOHN E. FLOYD
# []
# ['J. Hadar', ' C. Hillinger']
# J. HADAR
# ['CASE WESTERN RESERVE J. HADAR']
# C. HILLINGER
# ['UNIVERSITY, CLEVELAND C. HILLINGER']
# ['H. Atsumi']
# H. ATSUMI
# []
# ['V. K. Chetty', ' U. Sankar']
# V. K. CHETTY
# []
# U. SANKAR
# ['UNIVERSITY OF WISCONSIN, MILWAUKEE U. SANKAR']
# ['P. S. Dasgupta']
# P. S. DASGUPTA
# ['TRINITY HALL, CAMBRIDGE P. S. DASGUPTA']
# ['M. Dutta', ' V. Su']
# M. DUTTA
# []
# V. SU
# []
# ['G. Hanoch', ' H. Levy']
# G. HANOCH
# ['THE HEBREW UNIVERSITY, G. HANOCH']
# H. LEVY
# ['JERUSALEM H. LEVY']
# ['G. M. Heal']
# G. M. HEAL
# ["CHRIST'S COLLEGE, CAMBRIDGE G. M. HEAL"]
# ['D. Levhari', ' E. Sheshinski']
# D. LEVHARI
# ['THE HEBREW UNIVERSITY, JERUSALEM D. LEVHARI']
# E. SHESHINSKI
# ['HARVARD UNIVERSITY E. SHESHINSKI', 'SEE SHESHINSKI']
# ['Amartya Sen']
# AMARTYA SEN
# ['HARVARD UNIVERSITY AND AMARTYA SEN']
# ['R. Britto']
# R. BRITTO
# ['UNIVERSITY OF CALIFORNIA, R. BRITTO']
# ['A. B. Atkinson']
# A. B. ATKINSON
# ["ST JOHN'S COLLEGE, CAMBRIDGE A. B. ATKINSON"]
# ['D. Levhari', ' T. N. Srinivasan']
# D. LEVHARI
# ['THE HEBREW UNIVERSITY, JERUSALEM D. LEVHARI']
# T. N. SRINIVASAN
# ['INDIAN STATISTICAL INSTITUTE T. N. SRINIVASAN']
# ['Jerome L. Stein', ' Keizo Nagatani']
# JEROME L. STEIN
# ['BROWN UNIVERSITY JEROME L. STEIN']
# KEIZO NAGATANI
# ['UNIVERSITY OF BRITISH COLUMBIA KKEIZO NAGATANI']
# ['S. Rosen']
# S. ROSEN
# ['UNIVERSITY OF ROCHESTER AND S. ROSEN']
# ['R. D. Portes']
# R. D. PORTES
# []
# ['P. J. Dhrymes']
# P. J. DHRYMES
# ['UNIVERSITY OF PENNSYLVANIA P. J. DHRYMES']
# ['A. B. Treadway']
# A. B. TREADWAY
# ['NORTHWESTERN UNIVERSITY A. B. TREADWAY']
# ['A. Zellner', ' N. S. Revankar']
# A. ZELLNER
# ['UNIVERSITY OF CHICAGO A. ZELLNER']
# N. S. REVANKAR
# ['STATE UNIVERSITY OF NEW YORK AT BUFFALO N. S. REVANKAR']
# ['A. S. Goldberger']
# A. S. GOLDBERGER
# ['UNIVERSITY OF WISCONSIN AND A. S. GOLDBERGER']
# ['T. Ichishi']
# T. ICHISHI
# []
# ['D. Mario Nuti']
# D. MARIO NUTI
# []
# ['Joan Robinson']
# JOAN ROBINSON
# ['CAMBRIDGE JOAN ROBINSON']
# ['K. Borch']
# K. BORCH
# []
# ['M. S. Feldstein']
# M. S. FELDSTEIN
# ['HARVARD UNIVERSITY M. S. FELDSTEIN']
# ['James Tobin']
# JAMES TOBIN
# ['YALE UNIVERSITY JAMES TOBIN']
# ['K. Shell', ' M. Sidrauski', ' J. E. Stiglitz']
# K. SHELL
# []
# M. SIDRAUSKI
# ['MASSACHUSETTS INSTITUTE OF TECHNOLOGY M. SIDRAUSKI']
# J. E. STIGLITZ
# []
# ['J. N. Bhagwati', ' T. N. Srinivasan']
# J. N. BHAGWATI
# ['MASSACHUSETTS INSTITUTE OF TECHNOLOGY J. N. BHAGWATI']
# T. N. SRINIVASAN
# ['INDIAN STATISTICAL INSTITUTE T. N. SRINIVASAN']
# ['M. Bruno']
# M. BRUNO
# ['HEBREW UNIVERSITY, JERUSALEM M. BRUNO']
# ['J. S. Flemming']
# J. S. FLEMMING
# ['NUFFIELD COLLEGE, OXFORD J. S. FLEMMING']
# ['J. A. Mirrlees']
# J. A. MIRRLEES
# ['NUFFIELD COLLEGE, OXFORD J. A. MIRRLEES']
# ['P. S. Dasgupta']
# P. S. DASGUPTA
# ['CARNEGIE-MELLON UNIVERSITY, PITTSBURGH P. S. DASGUPTA']
# ['Ken-Ichi Inada']
# KEN-ICHI INADA
# []
# ['Ken-Ichi Inada']
# KEN-ICHI INADA
# []
# ['A. P. Barten', ' T. Kloek', ' F. B. Lempers']
# A. P. BARTEN
# ['UNIVERSITY OF LOUVAIN A. P. BARTEN']
# T. KLOEK
# ['NETHERLANDS SCHOOL OF ECONOMICS T. KLOEK']
# F. B. LEMPERS
# ['NETHERLANDS SCHOOL OF ECONOMICS F. B. LEMPERS']
# ['C. Hillinger']
# C. HILLINGER
# ['CASE WESTERN RESERVE UNIVERSITY, C. HILLINGER']
# ['Yasu Hosomatsu']
# YASU HOSOMATSU
# ['WAYNE STATE UNIVERSITY YASU HOSOMATSU']
# ['P. J. Kalman']
# P. J. KALMAN
# ['STATE UNIVERSITY OF NEW YORK AT STONY BROOK P. J. KALMAN']
# ['James R. Melvin']
# JAMES R. MELVIN
# ['UNIVERSITY OF WESTERN ONTARIO JAMES R. MELVIN']
# ['T. Negishi']
# T. NEGISHI
# []
# ['W. M. Gorman']
# W. M. GORMAN
# ['LONDON SCHOOL OF ECONOMICS W. M. GORMAN']
# ['F. M. Fisher']
# F. M. FISHER
# ['MASSACHUSETTS INSTITUTE OF TECHNOLOGY F. M. FISHER']
# ['B. P. Stigum']
# B. P. STIGUM
# []
# ['F. M. Fisher']
# F. M. FISHER
# ['MASSACHUSETTS INSTITUTE OF TECHNOLOGY F. M. FISHER']
# ['J. K. Whitaker']
# J. K. WHITAKER
# ['BRISTOL UNIVERSITY AND J. K. WHITAKER']
# ['W. Hildenbrand']
# W. HILDENBRAND
# ['STUDIENGRUPPE FÜR SYSTEMFORSCHUNG, HEIDELBERG, GERMANY. W. HILDENBRAND']
# ['A. Douglas']
# A. DOUGLAS
# ['UNIVERSITY OF CALIFORNIA, A. DOUGLAS']
# ['Sanjit Bose']
# SANJIT BOSE
# ['PROJECT FOR QUANTITATIVE RESEARCH SANJIT BOSE']
# ['Jagdish N. Bhagwati']
# JAGDISH N. BHAGWATI
# ['MASSACHUSETTS INSTITUTE OF TECHNOLOGY JAGDISH N. BHAGWATI']
# ['M. L. Balinski', ' W. J. Baumol']
# M. L. BALINSKI
# ['CITY UNIVERSITY OF NEW YORK M. L. BALINSKI']
# W. J. BAUMOL
# ['PRINCETON UNIVERSITY W. J. BAUMOL']
# ['J. W. Friedman']
# J. W. FRIEDMAN
# ['YALE UNIVERSITY J. W. FRIEDMAN']
# ['M. I. Nadiri']
# M. I. NADIRI
# ['NORTHWESTERN UNIVERSITY M. I. NADIRI']
# ['B. Näslund']
# B. NÄSLUND
# []
# ['L. G. Telser', ' R. L. Graves']
# L. G. TELSER
# ['UNIVERSITY OF CHICAGO L. G. TELSER']
# R. L. GRAVES
# ['R. L. GRAVES']
# ['E. Glustoff']
# E. GLUSTOFF
# []
# ['K. Inada']
# K. INADA
# ['TOKYO METROPOLITAN UNIVERSITY K. INADA']
# ['A. G. Hines']
# A. G. HINES
# []
# ['E. P. Howrey', ' R. E. Quandt']
# E. P. HOWREY
# ['PRINCETON UNIVERSITY E. P. HOWREY']
# R. E. QUANDT
# ['R. E. QUANDT']
# ['K. Kubota']
# K. KUBOTA
# []
# ['J. A. Carlson']
# J. A. CARLSON
# ['PURDUE UNIVERSITY J. A. CARLSON']
# ['Richard Zeckhauser']
# RICHARD ZECKHAUSER
# ['LONDON SCHOOL OF ECONOMICS, VISITOR RICHARD ZECKHAUSER']
# ['R. Sato', ' M. Beckmann']
# R. SATO
# ['BROWN UNIVERSITY R. SATO']
# M. BECKMANN
# ['M. BECKMANN']
# ['Christopher Bliss']
# CHRISTOPHER BLISS
# []
# ['O. Eckstein']
# O. ECKSTEIN
# ['HARVARD UNIVERSITY O. ECKSTEIN']
# ['S. M. Goldman']
# S. M. GOLDMAN
# ['UNIVERSITY OF CALIFORNIA, BERKELEY S. M. GOLDMAN']
# ['M. Kurz']
# M. KURZ
# []
# ['F. H. Hahn']
# F. H. HAHN
# ['LONDON SCHOOL OF ECONOMICS. F. H. HAHN']
# ['E. S. Phelps', ' R. A. Pollak']
# E. S. PHELPS
# ['UNIVERSITY OF PENNSYLVANIA E. S. PHELPS']
# R. A. POLLAK
# ['R. A. POLLAK']
# ['R. A. Pollak']
# R. A. POLLAK
# ['UNIVERSITY OF PENNSYLVANIA R. A. POLLAK']
# ['L. L. Wegge']
# L. L. WEGGE
# ['UNIVERSITY OF CALIFORNIA, L. L. WEGGE']
# ['Y. Mundlak']
# Y. MUNDLAK
# ['HEBREW UNIVERSITY, JERUSALEM Y. MUNDLAK']
# ['Prasanta K. Pattanaik']
# PRASANTA K. PATTANAIK
# ['DELHI SCHOOL OF ECONOMICS PRASANTA K. PATTANAIK']
# ['J. P. Quirk']
# J. P. QUIRK
# ['UNIVERSITY OF KANSAS J. P. QUIRK']
# ['A. K. Dixit']
# A. K. DIXIT
# []
# ['R. E. Hall']
# R. E. HALL
# ['MASSACHUSETTS INSTITUTE OF TECHNOLOGY R. E. HALL']
# ['J. P. Gould']
# J. P. GOULD
# []
# ['R. Sato', ' M. J. Beckmann']
# R. SATO
# []
# M. J. BECKMANN
# []
# ['C. W. J. Granger', ' H. J. B. Rees']
# C. W. J. GRANGER
# ['UNIVERSITY OF NOTTINGHAM C. W. J. GRANGER']
# H. J. B. REES
# []
# ['Y. Haitovsky']
# Y. HAITOVSKY
# ['TECHNION-ISRAEL INSTITUTE Y. HAITOVSKY']
# ['S. Clemhout']
# S. CLEMHOUT
# ['UNIVERSITY OF CALIFORNIA, BERKELEY S. CLEMHOUT']
# ['E. Kuh']
# E. KUH
# []
# ['F. Rushdy', ' P. J. Lund']
# F. RUSHDY
# ['UNIVERSITY OF MANCHESTER F. RUSHDY']
# P. J. LUND
# ['P. J. LUND']
# ['M. S. Feldstein']
# M. S. FELDSTEIN
# ['NUFFIELD COLLEGE, OXFORD AND HARVARD UNIVERSITY M. S. FELDSTEIN']
# ['H. A. John Green']
# H. A. JOHN GREEN
# []
# ['P. J. Dhrymes']
# P. J. DHRYMES
# ['UNIVERSITY OF PENNSYLVANIA P. J. DHRYMES']
# ['R. Sato', ' K. Nagatani']
# R. SATO
# ['BROWN UNIVERSITY R. SATO']
# K. NAGATANI
# ['K. NAGATANI']
# ['J. J. McCall']
# J. J. MCCALL
# []
# ['R. J. Ruffin']
# R. J. RUFFIN
# ['WASHINGTON STATE UNIVERSITY R. J. RUFFIN']
# ['R. Sato']
# R. SATO
# []
# ['G. R. Blakley', ' W. F. Gossling']
# G. R. BLAKLEY
# ['STATE UNIVERSITY OF NEW YORK AT BUFFALO G. R. BLAKLEY']
# W. F. GOSSLING
# []
# ['M. S. Ramanujam']
# M. S. RAMANUJAM
# ['DELHI SCHOOL OF ECONOMICS M. S. RAMANUJAM']
# ['D. W. Jorgenson', ' Z. Griliches']
# D. W. JORGENSON
# ['UNIVERSITY OF CALIFORNIA, BERKELEY D. W. JORGENSON']
# Z. GRILICHES
# ['UNIVERSITY OF CHICAGO Z. GRILICHES']
# ['Allan Hynes']
# ALLAN HYNES
# ['UNIVERSITY OF WASHINGTON. ALLAN HYNES']
# ['K. Hamada']
# K. HAMADA
# ['UNIVERSITY OF TOKYO K. HAMADA']
# ['P. Bohm']
# P. BOHM
# []
# ['Takashi Negishi']
# TAKASHI NEGISHI
# ['UNIVERSITY OF TOKYO TAKASHI NEGISHI']
# ['M. McManus']
# M. MCMANUS
# ['UNIVERSITY OF BIRMINGHAM M. MCMANUS']
# ['O. A. Davis', ' A. B. Whinston']
# O. A. DAVIS
# ['CARNEGIE INSTITUTE OF TECHNOLOGY O. A. DAVIS']
# A. B. WHINSTON
# ['PURDUE UNIVERSITY A. B. WHINSTON']
# ['H. Rose']
# H. ROSE
# []
# ['R. E. Lucas', ' Jr.']
# R. E. LUCAS
# ['CARNEGIE INSTITUTE OF TECHNOLOGY. R. E. LUCAS']
# JR.
# ['CARNEGIE INSTITUTE OF TECHNOLOGY. R. E. LUCAS, JR.']
# ['J. Hirshleifer']
# J. HIRSHLEIFER
# ['UNIVERSITY OF CALIFORNIA, LOS ANGELES J. HIRSHLEIFER']
# ['K. Sato']
# K. SATO
# []
# ['A. Nataf']
# A. NATAF
# ['FACULTÉ DES SCIENCES DE CAEN A. NATAF']
# ['J. E. Stiglitz']
# J. E. STIGLITZ
# []
# ['E. Sheshinski']
# E. SHESHINSKI
# ['MASSACHUSETTS INSTITUTE OF TECHNOLOGY E. SHESHINSKI']
# ['David Gale']
# DAVID GALE
# ['UNIVERSITY OF CALIFORNIA, BERKELEY DAVID GALE']
# ['D. Gale']
# D. GALE
# []
# ['D. McFadden']
# D. MCFADDEN
# ['UNIVERSITY OF CHICAGO. D. MCFADDEN']
# ['R. Radner']
# R. RADNER
# ['UNIVERSITY OF CALIFORNIA, BERKELEY. R. RADNER']
# ['S. G. Winter', ' Jr.']
# S. G. WINTER
# ['THE RAND CORPORATION, S. G. WINTER']
# JR.
# ['THE RAND CORPORATION, S. G. WINTER, JR.']
# ['J. Tsukui']
# J. TSUKUI
# ['TOKYO COLLEGE OF ECONOMICS J. TSUKUI']
# ['J. A. Mirrlees']
# J. A. MIRRLEES
# ['TRINITY COLLEGE J. A. MIRRLEES']
# ['L. Johansen']
# L. JOHANSEN
# ['UNIVERSITY OF OSLO L. JOHANSEN', '[8] L. JOHANSEN']
# ['C. C. von Weizsäcker']
# C. C. VON WEIZSÄCKER
# []
# ['R. M. Solow', ' J. Tobin', ' C. C. von Weizsacker', ' M. Yaari']
# R. M. SOLOW
# ['ERRATA TO ** NEOCLASSICAL GROWTH WITH FIXED FACTOR PROPORTIONS " BY R. M. SOLOW']
# J. TOBIN
# ['J. TOBIN']
# C. C. VON WEIZSACKER
# []
# M. YAARI
# ['J. TOBIN, C. C. VON WEIZSÜCKER AND M. YAARI']
# ['Paul A. Samuelson', ' Franco Modigliani']
# PAUL A. SAMUELSON
# []
# FRANCO MODIGLIANI
# []
# ['Luigi L. Pasinetti']
# LUIGI L. PASINETTI
# []
# ['Joan Robinson']
# JOAN ROBINSON
# ['CAMBRIDGE JOAN ROBINSON']
# ['Nicholas Kaldor']
# NICHOLAS KALDOR
# ["KING'S COLLEGE, CAMBRIDGE NICHOLAS KALDOR"]
# ['P. Samuelson', ' F. Modigliani']
# P. SAMUELSON
# ['MASSACHUSETTS INSTITUTE OF P. SAMUELSON']
# F. MODIGLIANI
# ['TECHNOLOGY F. MODIGLIANI']
# ['K. Sato']
# K. SATO
# []
# ['Michael K. Evans']
# MICHAEL K. EVANS
# ['UNIVERSITY OF PENNSYLVANIA MICHAEL K. EVANS']
# ['Amartya K. Sen']
# AMARTYA K. SEN
# ['DELHI SCHOOL OF ECONOMICS AMARTYA K. SEN']
# ['R. J. Ball', ' E. B. A. St Cyr']
# R. J. BALL
# ['LONDON GRADUATE SCHOOL OF R. J. BALL']
# E. B. A. ST CYR
# []
# ['John Vanderkamp']
# JOHN VANDERKAMP
# ['UNIVERSITY OF BRITISH COLUMBIA JOHN VANDERKAMP']
# ['G. C. Harcourt']
# G. C. HARCOURT
# ['TRINITY HALL, CAMBRIDGE G. C. HARCOURT']
# ['D. V. T. Bear']
# D. V. T. BEAR
# ['UNIVERSITY OF CALIFORNIA, SAN DIEGO D. V. T. BEAR']
# ['C. C. von Weizsäcker']
# C. C. VON WEIZSÄCKER
# []
# ['W. M. Corden']
# W. M. CORDEN
# ['AUSTRALIAN NATIONAL UNIVERSITY, W. M. CORDEN']
# ['K. Sato']
# K. SATO
# ['UNITED NATIONS, NEW YORK K. SATO']
# ['David Levhari']
# DAVID LEVHARI
# []
# ['E. S. Phelps']
# E. S. PHELPS
# []
# ['D. J. Horwell']
# D. J. HORWELL
# ['UNIVERSITY OF SOUTHAMPTON. D. J. HORWELL']
# ['Harry G. Johnson']
# HARRY G. JOHNSON
# []
# ['E. Kleiman', ' T. Ophir']
# E. KLEIMAN
# []
# T. OPHIR
# []
# ['J. K. Whitaker']
# J. K. WHITAKER
# ['UNIVERSITY OF BRISTOL. J. K. WHITAKER']
# ['Ken-ichi Inada']
# KEN-ICHI INADA
# []
# ['David Levhari']
# DAVID LEVHARI
# []
# ['P. K. Bardhan']
# P. K. BARDHAN
# ['PEMBROKE COLLEGE, CAMBRIDGE. P. K. BARDHAN']
# ['Nissan Livitan']
# NISSAN LIVITAN
# []
# ['Josef Hadar']
# JOSEF HADAR
# []
# ['J. E. Meade']
# J. E. MEADE
# ['CAMBRIDGE. J. E. MEADE']
# ['Franklin M. Fisher']
# FRANKLIN M. FISHER
# ['M. I. T. FRANKLIN M. FISHER']
# ['Peter A. Diamond']
# PETER A. DIAMOND
# ['UNIVERSITY OF CALIFORNIA, BERKELEY, CALIFORNIA. PETER A. DIAMOND']
# ['James Quirk', ' Richard Ruppert']
# JAMES QUIRK
# ['PURDUE UNIVERSITY. JAMES QUIRK']
# RICHARD RUPPERT
# ['UNIVERSITY OF CALIFORNIA, SANTA BARBARA. RICHARD RUPPERT']
# ['Jürg Niehans']
# JÜRG NIEHANS
# ['UNIVERSITY OF ZÜRICH JÜRG NIEHANS']
# ['F. H. Hahn']
# F. H. HAHN
# ['CHURCHILL COLLEGE, F. H. HAHN']
# ['F. P. R. Brechling']
# F. P. R. BRECHLING
# []
# ['W. M. Gorman']
# W. M. GORMAN
# ['NUFFIELD COLLEGE, OXFORD. W. M. GORMAN']
# ['P. E. Hart']
# P. E. HART
# ['UNIVERSITY OF BRISTOL. P. E. HART']
# ['David Cass']
# DAVID CASS
# ['YALE UNIVERSITY. DAVID CASS']
# ['P. K. Bardhan']
# P. K. BARDHAN
# ['PEMBROKE COLLEGE, CAMBRIDGE. P. K. BARDHAN', '[2] P. K. BARDHAN']
# ['Charles R. Frank', ' Jr.']
# CHARLES R. FRANK
# ['CHARLES R. FRANK']
# JR.
# ['CHARLES R. FRANK, JR.', '[4] FRANK, JR.']
# ['Akira Takayama']
# AKIRA TAKAYAMA
# ['UNIVERSITY OF MANCHESTER. AKIRA TAKAYAMA']
# ['Otto Eckstein']
# OTTO ECKSTEIN
# ['THE ARTICLE, * THEORY OF WAGE-PRICE PROCESS IN MODERN INDUSTRY ", BY OTTO ECKSTEIN']
# ['Carl Christian von Weizsäcker']
# CARL CHRISTIAN VON WEIZSÄCKER
# []
# ['J. M. Samuels']
# J. M. SAMUELS
# []
# ['Jerome L. Stein']
# JEROME L. STEIN
# ['BROWN UNIVERSITY. JEROME L. STEIN']
# ['Hiroshi Atsumi']
# HIROSHI ATSUMI
# []
# ['Menahem E. Yaari']
# MENAHEM E. YAARI
# ['YALE UNIVERSITY. MENAHEM E. YAARI']
# ['Ken-Ichi Inada']
# KEN-ICHI INADA
# []
# ['Peter A. Diamond']
# PETER A. DIAMOND
# ['UNIVERSITY OF CALIFORNIA, BERKELEY. PETER A. DIAMOND']
# ['Dan Usher']
# DAN USHER
# ['NUFFIELD COLLEGE, OXFORD. DAN USHER']
# ['Otto A. Davis', ' Andrew B. Whinston']
# OTTO A. DAVIS
# []
# ANDREW B. WHINSTON
# ['UNIVERSITY OF VIRGINIA. ANDREW B. WHINSTON']
# ['S. K. Bhattacharyya']
# S. K. BHATTACHARYYA
# ['LONDON SCHOOL OF ECONOMICS AND CALCUTTA UNIVERSITY. S. K. BHATTACHARYYA']
# ['Karl Vind']
# KARL VIND
# ['KARL VIND']
# ['Henry Y. Wan', ' Jr.']
# HENRY Y. WAN
# ['HENRY Y. WAN']
# JR.
# ['HENRY Y. WAN, JR.']
# ['Pan A. Yotopoulos']
# PAN A. YOTOPOULOS
# []
# ['I. A. McDougall']
# I. A. MCDOUGALL
# []
# ['A. G. Hines']
# A. G. HINES
# ['LONDON. A. G. HINES']
# ['Sara Behman']
# SARA BEHMAN
# ['UNIVERSITY OF CALIFORNIA, BERKELEY. SARA BEHMAN']
# ['Otto Eckstein']
# OTTO ECKSTEIN
# []
# ['G. L. Perry']
# G. L. PERRY
# ['UNIVERSITY OF MINESOTA. G. L. PERRY']
# ['M. W. Reder']
# M. W. REDER
# ['STANFORD UNIVERSITY. M. W. REDER', '[1] M. W. REDER', '[2] M. W. REDER']
# ['D. Smyth']
# D. SMYTH
# ['D. SMYTH']
# ['Paul A. Samuelson']
# PAUL A. SAMUELSON
# ['PAUL A. SAMUELSON']
# ['Douglas Dosser']
# DOUGLAS DOSSER
# []
# ['David Smyth']
# DAVID SMYTH
# []
# ['S. Chakravarty']
# S. CHAKRAVARTY
# ['DELHI UNIVERSITY. S. CHAKRAVARTY']
# ['Akira Takayama']
# AKIRA TAKAYAMA
# ['TOKYO, JAPAN. AKIRA TAKAYAMA']
# ['K. J. Arrow']
# K. J. ARROW
# ['K. J. ARROW']
# ['Akihiro Amano']
# AKIHIRO AMANO
# []
# ['Perry P. Chang']
# PERRY P. CHANG
# ['PERRY P. CHANG']
# ['Luigi L. Pasinetti']
# LUIGI L. PASINETTI
# ['LUIGI L. PASINETTI']
# ['Ajit Dasgupta']
# AJIT DASGUPTA
# ['AJIT DASGUPTA']
# ['José Encarnación', ' Jr']
# JOSÉ ENCARNACIÓN
# ['JOSÉ ENCARNACIÓN']
# JR
# ['JOSÉ ENCARNACIÓN, JR']
# ['D. Calvin Gogerty', ' Gordon C. Winston']
# D. CALVIN GOGERTY
# ['D. CALVIN GOGERTY']
# GORDON C. WINSTON
# ['GORDON C. WINSTON']
# ['Ken-Ichi Inada']
# KEN-ICHI INADA
# []
# ['K. Okuguchi']
# K. OKUGUCHI
# []
# ['Takashi Negishi']
# TAKASHI NEGISHI
# []
# ['Ilari Tyrni']
# ILARI TYRNI
# ['ILARI TYRNI']
# ['Amartya Kumar Sen']
# AMARTYA KUMAR SEN
# ['AMARTYA KUMAR SEN']
# ['J. K. Whitaker']
# J. K. WHITAKER
# ['UNIVERSITY OF BRISTOL. J. K. WHITAKER']
# ['Hirofumi Uzawa']
# HIROFUMI UZAWA
# ['HIROFUMI UZAWA']
# ['H. Nikaido']
# H. NIKAIDO
# ['OSAKA. H. NIKAIDO']
# ['Ken-Ichi Inada']
# KEN-ICHI INADA
# []
# ['E. H. Chamberlin']
# E. H. CHAMBERLIN
# ['E. H. CHAMBERLIN']
# ['W. M. Gorman']
# W. M. GORMAN
# ['W. M. GORMAN']
# ['Kelvin J. Lancaster']
# KELVIN J. LANCASTER
# []
# ['P. N. Mathur']
# P. N. MATHUR
# ['POONA. P. N. MATHUR']
# ['V. Mukerji']
# V. MUKERJI
# ['POONA. V. MUKERJI']
# ['R. G. Penner']
# R. G. PENNER
# ['ROCHESTER, NEW YORK. R. G. PENNER']
# ['Jaroslav Vanek']
# JAROSLAV VANEK
# ['CAMBRIDGE, MASS. JAROSLAV VANEK']
# ['J. E. Meade']
# J. E. MEADE
# ['CAMBRIDGE. J. E. MEADE']
# ['Joan Robinson']
# JOAN ROBINSON
# ['CAMBRIDGE. JOAN ROBINSON']
# ['Lionel W. McKenzie']
# LIONEL W. MCKENZIE
# []
# ['Gerard Debreu']
# GERARD DEBREU
# ['NEW HAVEN, CONN., AND BERKELEY, CALIF. GERARD DEBREU']
# ['R. J. Ball', ' Pamela S. Drake']
# R. J. BALL
# ['MANCHESTER. R. J. BALL']
# PAMELA S. DRAKE
# ['PAMELA S. DRAKE']
# ['Graham Pyatt']
# GRAHAM PYATT
# ['CAMBRIDGE. GRAHAM PYATT']
# ['Tony Lancaster']
# TONY LANCASTER
# ['CAMBRIDGE. TONY LANCASTER']
# ['Emanuel M. Drandakis']
# EMANUEL M. DRANDAKIS
# ['EMANUEL M. DRANDAKIS']
# ['Trout Rader']
# TROUT RADER
# ['NEW HAVEN, CONNECTICUT, AND COLUMBIA, MISSOURI. TROUT RADER']
# ['V. Mukerji']
# V. MUKERJI
# ['[2] V. MUKERJI']
# ['Daniel McFadden']
# DANIEL MCFADDEN
# ['PITTSBURGH. DANIEL MCFADDEN']
# ['Daniel Orr']
# DANIEL ORR
# ['CHICAGO. DANIEL ORR']
# ['Herbert A. Simon', ' Ferdinand K. Levy']
# HERBERT A. SIMON
# []
# FERDINAND K. LEVY
# []
# ['Akira Takayama']
# AKIRA TAKAYAMA
# ['TOKYO. AKIRA TAKAYAMA']
# ['H. Uzawa']
# H. UZAWA
# ['STANFORD. H. UZAWA']
# ['Ken-Ichi Inada']
# KEN-ICHI INADA
# ['TOKYO. KEN-ICHI INADA']
# ['Ira Horowitz']
# IRA HOROWITZ
# []
# ['F. R. Oliver']
# F. R. OLIVER
# ['EXETER. F. R. OLIVER', '[5] F. R. OLIVER']
# ['M. McManus']
# M. MCMANUS
# ['BIRMINGHAM. M. MCMANUS']
# ['Dale W. Jorgenson']
# DALE W. JORGENSON
# ['BERKELEY. DALE W. JORGENSON']
# ['A. A. Walters']
# A. A. WALTERS
# ['BIRMINGHAM. A. A. WALTERS']
# ['Ryuzo Sato']
# RYUZO SATO
# []
# ['Vernon L. Smith']
# VERNON L. SMITH
# []
# ['Stanley Reiter']
# STANLEY REITER
# ['LAFAYETTE, INDIANA. STANLEY REITER']
# ['Ashok Guha']
# ASHOK GUHA
# ['CAMBRIDGE, MASS. ASHOK GUHA']
# ['N. F. Laing']
# N. F. LAING
# []
# ['W. M. Gorman']
# W. M. GORMAN
# ['OXFORD. W. M. GORMAN']
# ['George J. Stigler']
# GEORGE J. STIGLER
# ['CHICAGO. GEORGE J. STIGLER']
# ['Milton Friedman']
# MILTON FRIEDMAN
# ['CHICAGO. MILTON FRIEDMAN']
# ['G. C. Archibald']
# G. C. ARCHIBALD
# ['BERKELEY. G. C. ARCHIBALD']
# ['Luigi L. Pasinetti']
# LUIGI L. PASINETTI
# ['CAMBRIDGE. LUIGI L. PASINETTI']
# ['J. M. Montias']
# J. M. MONTIAS
# ['NEW HAVEN. J. M. MONTIAS']
# ['Hirofumi Uzawa']
# HIROFUMI UZAWA
# ['STANFORD HIROFUMI UZAWA']
# ['G. H. Borts', ' E. J. Mishan']
# G. H. BORTS
# []
# E. J. MISHAN
# []
# ['Hukukane Nikaidô']
# HUKUKANE NIKAIDÔ
# []
# ['J. Wise']
# J. WISE
# []
# ['Anne O. Krueger']
# ANNE O. KRUEGER
# ['MINNEAPOLIS. ANNE O. KRUEGER']
# ['F. H. Hahn']
# F. H. HAHN
# ['CAMBRIDGE. F. H. HAHN']
# ['Robert L. Bishop']
# ROBERT L. BISHOP
# ['CAMBRIDGE, MASS. ROBERT L. BISHOP']
# ['M. McManus']
# M. MCMANUS
# ['BIRMINGHAM. M. MCMANUS']
# ['Kenneth J. Arrow']
# KENNETH J. ARROW
# []
# ['Nicholas Kaldor', ' James A. Mirrlees']
# NICHOLAS KALDOR
# ['CAMBRIDGE. NICHOLAS KALDOR']
# JAMES A. MIRRLEES
# []
# ['Paul A. Samuelson']
# PAUL A. SAMUELSON
# ['CAMBRIDGE, MASS. PAUL A. SAMUELSON']
# ['Robert M. Solow']
# ROBERT M. SOLOW
# ['CAMBRIDGE, MASS . AND WASHINGTON, D.C. ROBERT M. SOLOW']
# ['Joan Robinson']
# JOAN ROBINSON
# ['CAMBRIDGE. JOAN ROBINSON', '! SEE JOAN ROBINSON']
# ['J. E. Meade']
# J. E. MEADE
# ['CAMBRIDGE. J. E. MEADE']
# ['D. G. Champernowne']
# D. G. CHAMPERNOWNE
# ['CAMBRIDGE. D. G. CHAMPERNOWNE']
# ['J. Black']
# J. BLACK
# ['OXFORD J. BLACK']
# ['Richard Stone', ' J. A. C. Brown']
# RICHARD STONE
# []
# J. A. C. BROWN
# ['J. A. C. BROWN']
# ['Ronald Findlay']
# RONALD FINDLAY
# ['RANGOON. RONALD FINDLAY']
# ['Kelvin Lancaster']
# KELVIN LANCASTER
# ['LONDON. KELVIN LANCASTER']
# ['P. H. Pearse']
# P. H. PEARSE
# ['EDINBURGH. P. H. PEARSE']
# ['James P. Quirk', ' Rubin Saposnik']
# JAMES P. QUIRK
# []
# RUBIN SAPOSNIK
# ['RUBIN SAPOSNIK']
# ['P. E. Hart']
# P. E. HART
# ['BRISTOL. P. E. HART']
# ['C. E. Ferguson']
# C. E. FERGUSON
# ['DURHAM, N. CAROLINA. C. E. FERGUSON']
# ['G. C. Archibald']
# G. C. ARCHIBALD
# ['LONDON. G. C. ARCHIBALD']
# ['J. Johnston']
# J. JOHNSTON
# ['MANCHESTER. J. JOHNSTON']
# ['Hirofumi Uzawa']
# HIROFUMI UZAWA
# ['STANFORD. HIROFUMI UZAWA']
# ['Robert M. Solow']
# ROBERT M. SOLOW
# []
# ['Peter Newman', ' J. N. Wolfe']
# PETER NEWMAN
# ['ANN ARBOR PETER NEWMAN']
# J. N. WOLFE
# ['1 FOR AN ACCOUNT OF THE STOCHASTIC APPROACH TO THE LIFE HISTORY OF THE INDIVIDUAL FIRM, SEE J. N. WOLFE']
# ['F. H. Hahn']
# F. H. HAHN
# ['CAMBRIDGE. F. H. HAHN']
# ['H. A. John Green']
# H. A. JOHN GREEN
# ['TORONTO. H. A. JOHN GREEN']
# ['J. Parry Lewis']
# J. PARRY LEWIS
# ['MANCHESTER. J. PARRY LEWIS']
# ['E. Malinvaud']
# E. MALINVAUD
# ['PARIS. E. MALINVAUD']
# ['Ronald W. Jones']
# RONALD W. JONES
# []
# ['Kenneth J. Arrow']
# KENNETH J. ARROW
# ['STANFORD, CALIFORNIA. KENNETH J. ARROW']
# ['Lucien Foldes']
# LUCIEN FOLDES
# ['LONDON. LUCIEN FOLDES']
# ['Takashi Negishi']
# TAKASHI NEGISHI
# []
# ['A. B. Araoz', ' H. B. Malmgren']
# A. B. ARAOZ
# []
# H. B. MALMGREN
# ['H. B. MALMGREN']
# ['J. R. Hicks']
# J. R. HICKS
# ['OXFORD. J. R. HICKS']
# ['M. Morishima']
# M. MORISHIMA
# ['OSAKA, JAPAN. M. MORISHIMA']
# ['Roy Radner']
# ROY RADNER
# []
# ['Dale W. Jorgenson']
# DALE W. JORGENSON
# ['BERKELEY, CALIFORNIA. DALE W. JORGENSON']
# ['H. Uzawa']
# H. UZAWA
# ['UNIVERSITY OF CALIFORNIA, BERKELEY, AND STANFORD UNIVERSITY. H. UZAWA']
# ['Franklin M. Fisher']
# FRANKLIN M. FISHER
# ['CAMBRIDGE, MASS. FRANKLIN M. FISHER']
# ['M. McManus', ' Richard E. Quandt']
# M. MCMANUS
# ['BIRMINGHAM. M. MCMANUS']
# RICHARD E. QUANDT
# ['PRINCETON. RICHARD E. QUANDT']
# ['Hirofumi Uzawa']
# HIROFUMI UZAWA
# []
# ['Peter Newman']
# PETER NEWMAN
# ['MONA, JAMAICA. PETER NEWMAN']
# ['W. M. Corden']
# W. M. CORDEN
# ['MELBOURNE. W. M. CORDEN']
# ['Zivia S. Wurtele']
# ZIVIA S. WURTELE
# ['CALIFORNIA. ZIVIA S. WURTELE']
# ['W. J. Baumol']
# W. J. BAUMOL
# ['PRINCETON. W. J. BAUMOL']
# ['R. W. Clower', ' M. L. Burstein']
# R. W. CLOWER
# ['NORTHWESTERN. R. W. CLOWER', '1957), AND PARTICULARLY PP. 36, 76, 128-34, 160-63, 166-171; ALSO R. W. CLOWER']
# M. L. BURSTEIN
# ['M. L. BURSTEIN']
# ['F. H. Hahn']
# F. H. HAHN
# ['CAMBRIDGE F. H. HAHN']
# ['R. J. Ball', ' Ronald Bodkin']
# R. J. BALL
# ['PENNSYLVANIA R. J. BALL']
# RONALD BODKIN
# ['RONALD BODKIN']
# ['G. C. Archibald', ' R. C. Lipsey']
# G. C. ARCHIBALD
# ['LONDON. G. C. ARCHIBALD']
# R. C. LIPSEY
# []
# ['Peter Robson']
# PETER ROBSON
# ['CAMBRIDGE. PETER ROBSON']
# ['A. Rubner']
# A. RUBNER
# ['A. RUBNER']
# ['Leland L. Johnson']
# LELAND L. JOHNSON
# []
# ['Marcel K. Richter']
# MARCEL K. RICHTER
# ['UNIVERSITY OF MINNESOTA. MARCEL K. RICHTER']
# ['Ronald Findlay']
# RONALD FINDLAY
# []
# ['Nicholas Kaldor']
# NICHOLAS KALDOR
# ['CAMBRIDGE. NICHOLAS KALDOR']
# ['H. Uzawa']
# H. UZAWA
# []
# ['Michio Morishima']
# MICHIO MORISHIMA
# ['OSAKA. MICHIO MORISHIMA']
# ['Peter Newman']
# PETER NEWMAN
# ['JAMAICA. PETER NEWMAN']
# ['G. C. Archibald']
# G. C. ARCHIBALD
# ['LONDON. G. C. ARCHIBALD']
# ['Peter Newman']
# PETER NEWMAN
# ['JAMAICA. PETER NEWMAN']
# ['Luigi L. Pasinetti']
# LUIGI L. PASINETTI
# ['HARVARD UNIVERSITY AND CAMBRIDGE UNIVERSITY. LUIGI L. PASINETTI']
# ['Bjorn Thalberg']
# BJORN THALBERG
# ['OSLO. BJORN THALBERG']
# ['Hiroshi Atsumi']
# HIROSHI ATSUMI
# []
# ['James Tobin']
# JAMES TOBIN
# ['NEW HAVEN, CONNECTICUT. JAMES TOBIN']
# ['Nicholas Kaldor']
# NICHOLAS KALDOR
# ['CAMBRIDGE. NICHOLAS KALDOR']
# ['H. Myint']
# H. MYINT
# ['OXFORD AND RANGOON. H. MYINT']
# ['R. D. Theocharis']
# R. D. THEOCHARIS
# []
# ['Hans Jurgen Jaksch']
# HANS JURGEN JAKSCH
# ['FRANKFVRT AM MAIN. HANS JURGEN JAKSCH']

# %%
Reference_Data
# Out:
#     Journal_Name                                           Author1  \
# 0            RES            UNIVERSITY OF ROCHESTER J. W. FRIEDMAN
# 1            RES  UNIVERSITY OF CALIFORNIA, BERKELEY A. C. HOGGATT
# 2            RES
# 3            RES           UNIVERSITY OF BRISTOL AND ROGER SHERMAN
# 4            RES                               TERRENCE B. O'KEEFE
# ..           ...                                               ...
# 313          RES               NEW HAVEN, CONNECTICUT. JAMES TOBIN
# 314          RES                        CAMBRIDGE. NICHOLAS KALDOR
# 315          RES                      OXFORD AND RANGOON. H. MYINT
# 316          RES
# 317          RES             FRANKFVRT AM MAIN. HANS JURGEN JAKSCH
#
#     Affilliation1 Author2 Affilliation2  authorscount  \
# 0                                                   1
# 1                                                   1
# 2                                                   2
# 3                                                   1
# 4                                                   2
# ..            ...     ...           ...           ...
# 313                                                 1
# 314                                                 1
# 315                                                 1
# 316                                                 1
# 317                                                 1
#
#                                   Authors     a1fuzz            author_1  \
# 0                          J. W. Friedman  53.846154      J. W. FRIEDMAN
# 1                           A. C. Hoggatt  42.622951       A. C. HOGGATT
# 2               K. R. MacCrimmon, M. Toda   0.000000    K. R. MACCRIMMON
# 3                           Roger Sherman  50.000000       ROGER SHERMAN
# 4    John A. Carlson, Terrence B. O'Keefe  29.411765     JOHN A. CARLSON
# ..                                    ...        ...                 ...
# 313                           James Tobin  47.826087         JAMES TOBIN
# 314                       Nicholas Kaldor  73.170732     NICHOLAS KALDOR
# 315                              H. Myint  44.444444            H. MYINT
# 316                      R. D. Theocharis   0.000000    R. D. THEOCHARIS
# 317                    Hans Jurgen Jaksch  65.454545  HANS JURGEN JAKSCH
#
#                 author_2  ... Author6 Affilliation6 ref_length  \
# 0                         ...                                1
# 1                         ...                                1
# 2                M. TODA  ...                                0
# 3                         ...                                1
# 4    TERRENCE B. O'KEEFE  ...                                1
# ..                   ...  ...     ...           ...        ...
# 313                       ...                                1
# 314                       ...                                1
# 315                       ...                                1
# 316                       ...                                0
# 317                       ...                                1
#
#                                             ref_string     a1     a2     a3  \
# 0    414 REVIEW OF ECONOMIC STUDIES\n\nTHE ADVANTAG...  False  Empty  Empty
# 1    BEHAVIOUR OF ROBOTS IN BIFURCATED DUOPOLY GAME...  False  Empty  Empty
# 2    450 REVIEW OF ECONOMIC STUDIES\n\nINDIFFERENCE...  False  False  Empty
# 3    464 REVIEW OF ECONOMIC STUDIES\n\nOBSERVE NO M...  False  Empty  Empty
# 4    484 REVIEW OF ECONOMIC STUDIES\n\nAS IN ANY EX...  False  False  Empty
# ..                                                 ...    ...    ...    ...
# 313  120 REVIEW OF ECONOMIC STUDIES\n\nMEANWHILE, H...  False  Empty  Empty
# 314  A REJOINDER TO MR. ATSUMI AND PROFESSOR TOBIN ...  False  Empty  Empty
# 315  132 REVIEW OF ECONOMIC STUDIES\n\nQUITE HAVE T...  False  Empty  Empty
# 316  134 REVIEW OF ECONOMIC STUDIES\n\n9\n(0) A5, G...  False  Empty  Empty
# 317  138 REVIEW OF ECONOMIC STUDIES\n\nALSO, NOTE T...  False  Empty  Empty
#
#         a4     a5     a6
# 0    Empty  Empty  Empty
# 1    Empty  Empty  Empty
# 2    Empty  Empty  Empty
# 3    Empty  Empty  Empty
# 4    Empty  Empty  Empty
# ..     ...    ...    ...
# 313  Empty  Empty  Empty
# 314  Empty  Empty  Empty
# 315  Empty  Empty  Empty
# 316  Empty  Empty  Empty
# 317  Empty  Empty  Empty
#
# [318 rows x 33 columns]

# %%
True_count = 0
False_count = 0
for item in Reference_Data['a1fuzz'][1:len(Reference_Data)]:
    if item >50:
        True_count += 1
    else:
        False_count +=1
print(True_count)
print(False_count)
print(True_count/(True_count+False_count))
# Out:
# 126
# 191
# 0.39747634069400634

# %%
list = ['1','2','3','4']
list.remove('2')
list
# Out:
# ['1', '3', '4']

# %%
string = ("""JAN POTTERS and tim cook
Tilburg University, The Netherlands

and

SIGRID SUETENS and matt
Tilburg University, The Netherlands
""")

list = re.findall('.+',string)
for i in list:
    if i == 'and':
        list.remove(i)

for i in list:
    #auth = re.findall('\sand\s',i)
    if len(re.split(' and',i)) == 2:
        list[0] = re.split(' and',i)[0]
        list.append(re.split(' and',i)[1])

    
print(list)
len(list)
    
#list[0]
# Out:
# ['SIGRID SUETENS', 'Tilburg University, The Netherlands', 'SIGRID SUETENS and matt', 'Tilburg University, The Netherlands', ' tim cook', ' matt']
# 6
