# %% [markdown]
# # Using rapidfuzz to extract affiliatuons from JPE

# %% [markdown]
# First the JSON output file from tezseract is read in and made into a useable dataframe

# %%
#Importing the libraries
import json
import pandas as pd
from rapidfuzz import process
import requests

# Load input files from github
tesseract_input = requests.get('https://raw.githubusercontent.com/Matt970204/Affiliations_V2/main/1_Input%20files%20and%20processing%20input%20files/1_1_Input%20files/Tesseract%20affiliation%20output/JPE/JPE_affiliation_output_1940_2010.json')
json_data = tesseract_input.json()

# Import local JSON file
#f = open('/Users/MattJohnson/Desktop/Affiliations/1_Input files and processing input files/1_1_Input files/Tesseract affiliation output/JPE/JPE_affiliation_output_1940_2010.json')
#json_data = json.load(f)

# Define Journal and Dataframe
Journal_Name = 'JPE'
Reference_Data_List = []

# Extract Json Data into dataframe
for key1, value1 in json_data.items():
    Article_ID = key1
    content_type = value1["content_type"]
    author_list = value1["authors"]
    authorsNo = len(author_list)
    stable_url = value1["stable_url"]
    for key2 in value1["affiliations"]:
        Ref_type = key2
        if key2 == "found":
            ref_string = value1["affiliations"][key2]

    Reference_Data_List.append({'Journal_Name' : Journal_Name,
    'Authors_count' : authorsNo, 
    'Article_ID' : Article_ID, 'content_type' : content_type,
    'stable_url' : stable_url, 
    'Ref_type': Ref_type,  'ref_string':ref_string })

JPE_aff_ref_output_1940_2010 = pd.DataFrame.from_records(Reference_Data_List)     
JPE_aff_ref_output_1940_2010.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/Working files/JPE_aff_ref_output_1940_2010.xlsx')

# %% [markdown]
# Next the Unique list of universities is read in, this is used as a database to check the affiliton string against using rapidfuzz.

# %%
# Load in the list of unique Universites from github stored in 2_fuzzy matching
#affs = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/main/2_Extracting%20affilitations/2_Fuzzy%20matching/University%20list/Unique%20Universities.xlsx")

# Local store
affs = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/University list/Unique Universities.xlsx')
print(affs.shape)

#testdata = JPE_1940_2010.loc[0:20].reset_index(drop = True)
testdata = JPE_aff_ref_output_1940_2010

for i in range(len(affs)):
    #Replaceing title case and stripping leading space
    affs.iat[i,0] = affs.iat[i,0].strip().title()
Affiliation_choices = affs['Affilliation'].values.tolist()

for i in range(len(testdata)):
    #Replaceing title case and stripping leading space
    testdata.iat[i,6] = testdata.iat[i,6].strip().title()
# Out:
# (849, 14)

# %%
process.extract(" Johannes Hórner Yale University Andrzej Skrzypacz Stanford University" ,Affiliation_choices, limit= 10, score_cutoff= 90)
Affiliation_choices[0]
# Out:
# 'Yale University'

# %% [markdown]
# Next the test data is split line by line and parsed through the fuzzy matching library rapid fuzz.  Using the process.extract function a list of variables from a data frame being the unique universities is checked to see if there is a match in the input line from tesseract.

# %%
# For loop to iterate through lines in the input data and check to see if this exists in the created data base. 
# If it exists it is appended to a dataframe as the next affiliton for that paper
for i in range(len(testdata)):
    split = testdata.iat[i,6].split('\n\n')
    split_len = len(testdata.iat[i,6].split('\n\n'))
    affiliations = []
    count_no_aff = 0
    for j in range(split_len):
        #print(i)
        if len(process.extract(split[j],Affiliation_choices, limit= 10, score_cutoff= 90)) > 0:
            affiliations = affiliations + process.extract(split[j],Affiliation_choices, limit= 10, score_cutoff= 90)
        if len(process.extract(split[j],Affiliation_choices, limit= 10, score_cutoff= 90)) == 0:
            count_no_aff = count_no_aff+1

        if count_no_aff == 8:
            break
        if j == split_len:
            break

    print("Length = " , len(affiliations), ", Number = ",i)
    if len(affiliations) == 0:
        testdata.loc[i,['Missing aff']] = "Missing"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 1:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 2:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 3:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 4:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 5:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
        print(affiliations)
    elif len(affiliations) == 6:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['aff6']] = affiliations[5][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 7:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['aff6']] = affiliations[5][0]
        testdata.loc[i,['aff7']] = affiliations[6][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 8:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['aff6']] = affiliations[5][0]
        testdata.loc[i,['aff7']] = affiliations[6][0]
        testdata.loc[i,['aff8']] = affiliations[7][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 9:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['aff6']] = affiliations[5][0]
        testdata.loc[i,['aff7']] = affiliations[6][0]
        testdata.loc[i,['aff8']] = affiliations[7][0]
        testdata.loc[i,['aff9']] = affiliations[8][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 10:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['aff6']] = affiliations[5][0]
        testdata.loc[i,['aff7']] = affiliations[6][0]
        testdata.loc[i,['aff8']] = affiliations[7][0]
        testdata.loc[i,['aff9']] = affiliations[8][0]
        testdata.loc[i,['aff10']] = affiliations[9][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 11:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['aff6']] = affiliations[5][0]
        testdata.loc[i,['aff7']] = affiliations[6][0]
        testdata.loc[i,['aff8']] = affiliations[7][0]
        testdata.loc[i,['aff9']] = affiliations[8][0]
        testdata.loc[i,['aff10']] = affiliations[9][0]
        testdata.loc[i,['aff11']] = affiliations[10][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 12:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['aff6']] = affiliations[5][0]
        testdata.loc[i,['aff7']] = affiliations[6][0]
        testdata.loc[i,['aff8']] = affiliations[7][0]
        testdata.loc[i,['aff9']] = affiliations[8][0]
        testdata.loc[i,['aff10']] = affiliations[9][0]
        testdata.loc[i,['aff11']] = affiliations[10][0]
        testdata.loc[i,['aff12']] = affiliations[11][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    else: 
        testdata.loc[i,['Missing aff']] = "More than 12"
# Out:
# Length =  2 , Number =  0
# Length =  4 , Number =  1
# Length =  2 , Number =  2
# Length =  3 , Number =  3
# Length =  1 , Number =  4
# Length =  4 , Number =  5
# Length =  3 , Number =  6
# Length =  0 , Number =  7
# Length =  3 , Number =  8
# Length =  3 , Number =  9
# Length =  2 , Number =  10
# Length =  2 , Number =  11
# Length =  4 , Number =  12
# Length =  3 , Number =  13
# Length =  4 , Number =  14
# Length =  0 , Number =  15
# Length =  2 , Number =  16
# Length =  4 , Number =  17
# Length =  3 , Number =  18
# Length =  2 , Number =  19
# Length =  6 , Number =  20
# Length =  2 , Number =  21
# Length =  3 , Number =  22
# Length =  0 , Number =  23
# Length =  4 , Number =  24
# Length =  3 , Number =  25
# Length =  1 , Number =  26
# Length =  1 , Number =  27
# Length =  4 , Number =  28
# Length =  4 , Number =  29
# Length =  0 , Number =  30
# Length =  1 , Number =  31
# Length =  10 , Number =  32
# Length =  5 , Number =  33
# [('National Bureau Of Economic Research', 90.0, 531), ('Innocenzo Gasparini Institute For Economic Research', 90.0, 592), ('National Bureau Of Economic Research', 90.0, 531), ('Harvard University', 90.0, 695), ('London Business School', 90.0, 242)]
# Length =  3 , Number =  34
# Length =  2 , Number =  35
# Length =  1 , Number =  36
# Length =  0 , Number =  37
# Length =  7 , Number =  38
# Length =  7 , Number =  39
# Length =  10 , Number =  40
# Length =  3 , Number =  41
# Length =  5 , Number =  42
# [('National Bureau Of Economic Research', 90.0, 531), ('Massachusetts Institute Of Technology', 90.0, 549), ('Stanford University', 90.0, 8), ('National Bureau Of Economic Research', 90.0, 531), ('Massachusetts Institute Of Technology', 100.0, 549)]
# Length =  7 , Number =  43
# Length =  6 , Number =  44
# Length =  6 , Number =  45
# Length =  3 , Number =  46
# Length =  7 , Number =  47
# Length =  2 , Number =  48
# Length =  2 , Number =  49
# Length =  1 , Number =  50
# Length =  4 , Number =  51
# Length =  3 , Number =  52
# Length =  4 , Number =  53
# Length =  3 , Number =  54
# Length =  2 , Number =  55
# Length =  4 , Number =  56
# Length =  5 , Number =  57
# [('National Bureau Of Economic Research', 90.0, 531), ('Harvard University', 90.0, 695), ('Hoover Institution', 90.0, 103), ('University Of Chicago', 90.0, 222), ('National Bureau Of Economic Research', 90.0, 531)]
# Length =  3 , Number =  58
# Length =  3 , Number =  59
# Length =  3 , Number =  60
# Length =  3 , Number =  61
# Length =  4 , Number =  62
# Length =  5 , Number =  63
# [('Boston University', 90.0, 66), ('National Bureau Of Economic Research', 90.0, 531), ('Wellesley College', 90.0, 91), ('National Bureau Of Economic Research', 90.0, 531), ('Federal Reserve Bank Of New York', 100.0, 473)]
# Length =  1 , Number =  64
# Length =  3 , Number =  65
# Length =  1 , Number =  66
# Length =  2 , Number =  67
# Length =  4 , Number =  68
# Length =  2 , Number =  69
# Length =  2 , Number =  70
# Length =  6 , Number =  71
# Length =  4 , Number =  72
# Length =  2 , Number =  73
# Length =  4 , Number =  74
# Length =  5 , Number =  75
# [('Cornell University', 90.0, 98), ('Santa Fe Institute', 90.0, 112), ('University Of Missouri', 90.0, 261), ('University Of Wisconsin', 90.0, 296), ('University Of Wisconsin', 100.0, 296)]
# Length =  1 , Number =  76
# Length =  4 , Number =  77
# Length =  6 , Number =  78
# Length =  3 , Number =  79
# Length =  7 , Number =  80
# Length =  3 , Number =  81
# Length =  2 , Number =  82
# Length =  2 , Number =  83
# Length =  0 , Number =  84
# Length =  3 , Number =  85
# Length =  6 , Number =  86
# Length =  1 , Number =  87
# Length =  1 , Number =  88
# Length =  5 , Number =  89
# [('Hebrew University', 90.0, 75), ('University Of Warwick', 90.0, 235), ('Tel–Aviv University', 91.89189189189189, 151), ('University Of Warwick', 100.0, 235), ('Warwick University', 95.0, 126)]
# Length =  6 , Number =  90
# Length =  2 , Number =  91
# Length =  3 , Number =  92
# Length =  5 , Number =  93
# [('European University Institute', 100.0, 419), ('University College London', 100.0, 341), ('University College', 95.0, 635), ('University College London', 100.0, 341), ('University College', 95.0, 635)]
# Length =  4 , Number =  94
# Length =  1 , Number =  95
# Length =  3 , Number =  96
# Length =  2 , Number =  97
# Length =  2 , Number =  98
# Length =  4 , Number =  99
# Length =  2 , Number =  100
# Length =  4 , Number =  101
# Length =  5 , Number =  102
# [('University Of Minnesota', 90.0, 289), ('National Bureau Of Economic Research', 90.0, 531), ('Federal Reserve Board', 100.0, 204), ('Federal Reserve Board Of Governors', 90.0, 515), ('Social Security Administration', 100.0, 443)]
# Length =  5 , Number =  103
# [('National Bureau Of Economic Research', 90.0, 531), ('Massachusetts Institute Of Technology', 90.0, 549), ('Massachusetts Institute Of Technology', 100.0, 549), ('National Bureau Of Economic Research', 90.0, 531), ('Massachusetts Institute Of Technology', 90.0, 549)]
# Length =  1 , Number =  104
# Length =  5 , Number =  105
# [('University Of California, Irvine', 90.0, 485), ('National Bureau Of Economic Research', 90.0, 531), ('New York Citt-Rand Institute', 90.0, 399), ('Rand Corporation', 90.0, 798), ('Brandeis University', 90.0, 811)]
# Length =  6 , Number =  106
# Length =  4 , Number =  107
# Length =  3 , Number =  108
# Length =  2 , Number =  109
# Length =  2 , Number =  110
# Length =  6 , Number =  111
# Length =  6 , Number =  112
# Length =  5 , Number =  113
# [('University College London', 90.0, 341), ('National Bureau Of Economic Research', 90.0, 531), ('University College', 90.0, 635), ('University College London', 90.0, 341), ('University College', 90.0, 635)]
# Length =  1 , Number =  114
# Length =  4 , Number =  115
# Length =  2 , Number =  116
# Length =  4 , Number =  117
# Length =  4 , Number =  118
# Length =  4 , Number =  119
# Length =  4 , Number =  120
# Length =  2 , Number =  121
# Length =  5 , Number =  122
# [('Oxford University', 100.0, 4), ('University Of Oxford', 95.0, 793), ('Oxford', 90.0, 3), ('Northwestern University', 100.0, 277), ('Northeastern University', 95.65217391304348, 276)]
# Length =  6 , Number =  123
# Length =  7 , Number =  124
# Length =  7 , Number =  125
# Length =  3 , Number =  126
# Length =  3 , Number =  127
# Length =  1 , Number =  128
# Length =  1 , Number =  129
# Length =  4 , Number =  130
# Length =  2 , Number =  131
# Length =  2 , Number =  132
# Length =  3 , Number =  133
# Length =  3 , Number =  134
# Length =  2 , Number =  135
# Length =  6 , Number =  136
# Length =  3 , Number =  137
# Length =  1 , Number =  138
# Length =  6 , Number =  139
# Length =  7 , Number =  140
# Length =  2 , Number =  141
# Length =  3 , Number =  142
# Length =  3 , Number =  143
# Length =  4 , Number =  144
# Length =  1 , Number =  145
# Length =  3 , Number =  146
# Length =  3 , Number =  147
# Length =  4 , Number =  148
# Length =  2 , Number =  149
# Length =  4 , Number =  150
# Length =  5 , Number =  151
# [('National Taiwan University', 100.0, 356), ('National University', 95.0, 143), ('University Of Paris', 90.0, 163), ('University Of California, Irvine', 90.0, 485), ('National Bureau Of Economic Research', 90.0, 531)]
# Length =  1 , Number =  152
# Length =  3 , Number =  153
# Length =  3 , Number =  154
# Length =  3 , Number =  155
# Length =  3 , Number =  156
# Length =  1 , Number =  157
# Length =  1 , Number =  158
# Length =  3 , Number =  159
# Length =  1 , Number =  160
# Length =  3 , Number =  161
# Length =  3 , Number =  162
# Length =  1 , Number =  163
# Length =  2 , Number =  164
# Length =  3 , Number =  165
# Length =  3 , Number =  166
# Length =  4 , Number =  167
# Length =  3 , Number =  168
# Length =  5 , Number =  169
# [('Paris School Of Economics', 90.0, 335), ('Federal Reserve Bank Of Boston', 90.0, 436), ('National Bureau Of Economic Research', 90.0, 531), ('National Bureau Of Economic Research', 90.0, 531), ('Harvard University', 90.0, 695)]
# Length =  2 , Number =  170
# Length =  3 , Number =  171
# Length =  2 , Number =  172
# Length =  1 , Number =  173
# Length =  3 , Number =  174
# Length =  4 , Number =  175
# Length =  6 , Number =  176
# Length =  1 , Number =  177
# Length =  2 , Number =  178
# Length =  2 , Number =  179
# Length =  3 , Number =  180
# Length =  2 , Number =  181
# Length =  6 , Number =  182
# Length =  2 , Number =  183
# Length =  1 , Number =  184
# Length =  1 , Number =  185
# Length =  0 , Number =  186
# Length =  2 , Number =  187
# Length =  1 , Number =  188
# Length =  4 , Number =  189
# Length =  3 , Number =  190
# Length =  2 , Number =  191
# Length =  3 , Number =  192
# Length =  3 , Number =  193
# Length =  3 , Number =  194
# Length =  1 , Number =  195
# Length =  2 , Number =  196
# Length =  3 , Number =  197
# Length =  4 , Number =  198
# Length =  3 , Number =  199
# Length =  2 , Number =  200
# Length =  5 , Number =  201
# [('Duke University', 100.0, 18), ('Drake University', 90.32258064516128, 786), ('Federal Reserve Bank Of Richmond', 100.0, 474), ('Princeton University', 90.0, 178), ('National Bureau Of Economic Research', 90.0, 531)]
# Length =  4 , Number =  202
# Length =  5 , Number =  203
# [('Northwestern University', 90.0, 277), ('National Bureau Of Economic Research', 90.0, 531), ('National Bureau Of Economic Research', 90.0, 531), ('Northwestern University', 90.0, 277), ('National Bureau Of Economic Research', 90.0, 531)]
# Length =  2 , Number =  204
# Length =  2 , Number =  205
# Length =  1 , Number =  206
# Length =  3 , Number =  207
# Length =  2 , Number =  208
# Length =  2 , Number =  209
# Length =  2 , Number =  210
# Length =  2 , Number =  211
# Length =  3 , Number =  212
# Length =  2 , Number =  213
# Length =  3 , Number =  214
# Length =  2 , Number =  215
# Length =  4 , Number =  216
# Length =  0 , Number =  217
# Length =  2 , Number =  218
# Length =  3 , Number =  219
# Length =  3 , Number =  220
# Length =  2 , Number =  221
# Length =  8 , Number =  222
# Length =  5 , Number =  223
# [('Federal Reserve Bank Of Minneapolis', 90.0, 523), ('National Bureau Of Economic Research', 90.0, 531), ('University Of California, Los Angeles', 90.0, 550), ('National Bureau Of Economic Research', 90.0, 531), ('University Of California, Los Angeles', 90.0, 550)]
# Length =  2 , Number =  224
# Length =  4 , Number =  225
# Length =  3 , Number =  226
# Length =  4 , Number =  227
# Length =  4 , Number =  228
# Length =  3 , Number =  229
# Length =  1 , Number =  230
# Length =  3 , Number =  231
# Length =  2 , Number =  232
# Length =  4 , Number =  233
# Length =  1 , Number =  234
# Length =  2 , Number =  235
# Length =  1 , Number =  236
# Length =  2 , Number =  237
# Length =  2 , Number =  238
# Length =  2 , Number =  239
# Length =  4 , Number =  240
# Length =  3 , Number =  241
# Length =  1 , Number =  242
# Length =  1 , Number =  243
# Length =  2 , Number =  244
# Length =  1 , Number =  245
# Length =  2 , Number =  246
# Length =  2 , Number =  247
# Length =  1 , Number =  248
# Length =  2 , Number =  249
# Length =  3 , Number =  250
# Length =  13 , Number =  251
# Length =  2 , Number =  252
# Length =  7 , Number =  253
# Length =  4 , Number =  254
# Length =  2 , Number =  255
# Length =  2 , Number =  256
# Length =  5 , Number =  257
# [('University Of Minnesota', 90.0, 289), ('Federal Reserve Bank Of Minneapolis', 90.0, 523), ('National Bureau Of Economic Research', 90.0, 531), ('Stanford University', 90.0, 8), ('National Bureau Of Economic Research', 90.0, 531)]
# Length =  4 , Number =  258
# Length =  6 , Number =  259
# Length =  2 , Number =  260
# Length =  2 , Number =  261
# Length =  4 , Number =  262
# Length =  1 , Number =  263
# Length =  3 , Number =  264
# Length =  2 , Number =  265
# Length =  4 , Number =  266
# Length =  1 , Number =  267
# Length =  3 , Number =  268
# Length =  1 , Number =  269
# Length =  2 , Number =  270
# Length =  8 , Number =  271
# Length =  4 , Number =  272
# Length =  1 , Number =  273
# Length =  2 , Number =  274
# Length =  1 , Number =  275
# Length =  1 , Number =  276
# Length =  2 , Number =  277
# Length =  2 , Number =  278
# Length =  6 , Number =  279
# Length =  4 , Number =  280
# Length =  3 , Number =  281
# Length =  1 , Number =  282
# Length =  6 , Number =  283
# Length =  2 , Number =  284
# Length =  1 , Number =  285
# Length =  1 , Number =  286
# Length =  2 , Number =  287
# Length =  1 , Number =  288
# Length =  3 , Number =  289
# Length =  2 , Number =  290
# Length =  1 , Number =  291
# Length =  4 , Number =  292
# Length =  4 , Number =  293
# Length =  3 , Number =  294
# Length =  0 , Number =  295
# Length =  1 , Number =  296
# Length =  2 , Number =  297
# Length =  3 , Number =  298
# Length =  0 , Number =  299
# Length =  4 , Number =  300
# Length =  1 , Number =  301
# Length =  3 , Number =  302
# Length =  4 , Number =  303
# Length =  1 , Number =  304
# Length =  4 , Number =  305
# Length =  1 , Number =  306
# Length =  5 , Number =  307
# [('Princeton University', 100.0, 178), ('New York University', 100.0, 145), ('City University Of New York', 95.0, 370), ('State University Of New York', 95.0, 407), ('York University', 95.0, 829)]
# Length =  1 , Number =  308
# Length =  4 , Number =  309
# Length =  0 , Number =  310
# Length =  3 , Number =  311
# Length =  0 , Number =  312
# Length =  5 , Number =  313
# [('Duke University', 90.0, 18), ('National Bureau Of Economic Research', 90.0, 531), ('University Of Pennsylvania', 100.0, 364), ('University Of Toronto', 90.0, 232), ('National Bureau Of Economic Research', 90.0, 531)]
# Length =  2 , Number =  314
# Length =  17 , Number =  315
# Length =  3 , Number =  316
# Length =  3 , Number =  317
# Length =  1 , Number =  318
# Length =  5 , Number =  319
# [('Cornell University', 100.0, 98), ('Cornell University', 90.0, 98), ('National Bureau Of Economic Research', 90.0, 531), ('Cornell University', 90.0, 98), ('Cornell University', 100.0, 98)]
# Length =  2 , Number =  320
# Length =  2 , Number =  321
# Length =  1 , Number =  322
# Length =  1 , Number =  323
# Length =  3 , Number =  324
# Length =  2 , Number =  325
# Length =  2 , Number =  326
# Length =  3 , Number =  327
# Length =  3 , Number =  328
# Length =  3 , Number =  329
# Length =  4 , Number =  330
# Length =  3 , Number =  331
# Length =  4 , Number =  332
# Length =  1 , Number =  333
# Length =  2 , Number =  334
# Length =  2 , Number =  335
# Length =  5 , Number =  336
# [('University Of California, Los Angeles', 90.0, 550), ('National Bureau Of Economic Research', 90.0, 531), ('New York University', 90.0, 145), ('Federal Reserve Bank Of Minneapolis', 90.0, 523), ('York University', 90.0, 829)]
# Length =  0 , Number =  337
# Length =  1 , Number =  338
# Length =  5 , Number =  339
# [('Federal Reserve Board Of Governors', 95.0, 515), ('Board Of Governors Of The Federal Reserve System', 95.0, 585), ('University Of Minnesota', 90.0, 289), ('Federal Reserve Bank Of Chicago', 90.0, 453), ('National Bureau Of Economic Research', 90.0, 531)]
# Length =  2 , Number =  340
# Length =  2 , Number =  341
# Length =  3 , Number =  342
# Length =  3 , Number =  343
# Length =  4 , Number =  344
# Length =  3 , Number =  345
# Length =  2 , Number =  346
# Length =  3 , Number =  347
# Length =  1 , Number =  348
# Length =  1 , Number =  349
# Length =  1 , Number =  350
# Length =  1 , Number =  351
# Length =  5 , Number =  352
# [('National Bureau Of Economic Research', 90.0, 531), ('Massachusetts Institute Of Technology', 90.0, 549), ('University Of California, Los Angeles', 100.0, 550), ('Northwestern University', 100.0, 277), ('Northeastern University', 95.65217391304348, 276)]
# Length =  4 , Number =  353
# Length =  3 , Number =  354
# Length =  2 , Number =  355
# Length =  1 , Number =  356
# Length =  2 , Number =  357
# Length =  1 , Number =  358
# Length =  1 , Number =  359
# Length =  4 , Number =  360
# Length =  3 , Number =  361
# Length =  2 , Number =  362
# Length =  2 , Number =  363
# Length =  2 , Number =  364
# Length =  5 , Number =  365
# [('University Of Essex', 100.0, 158), ('University Of Sussex', 92.3076923076923, 193), ('Tinbergen Institute', 90.0, 152), ('Erasmus University Rotterdam', 90.0, 387), ('Erasmus University Rotterdam', 90.0, 387)]
# Length =  2 , Number =  366
# Length =  4 , Number =  367
# Length =  2 , Number =  368
# Length =  4 , Number =  369
# Length =  1 , Number =  370
# Length =  1 , Number =  371
# Length =  2 , Number =  372
# Length =  2 , Number =  373
# Length =  4 , Number =  374
# Length =  6 , Number =  375
# Length =  1 , Number =  376
# Length =  1 , Number =  377
# Length =  3 , Number =  378
# Length =  1 , Number =  379
# Length =  1 , Number =  380
# Length =  5 , Number =  381
# [('Federal Reserve Bank Of Minneapolis', 90.0, 523), ('National Bureau Of Economic Research', 90.0, 531), ('University Of California, Los Angeles', 90.0, 550), ('University Of Minnesota', 90.0, 289), ('National Bureau Of Economic Research', 90.0, 531)]
# Length =  1 , Number =  382
# Length =  2 , Number =  383
# Length =  2 , Number =  384
# Length =  2 , Number =  385
# Length =  4 , Number =  386
# Length =  4 , Number =  387
# Length =  5 , Number =  388
# [('University Of California, Los Angeles', 97.2972972972973, 550), ('Northwestern University', 90.0, 277), ('Federal Reserve Bank Of Chicago', 90.0, 453), ('National Bureau Of Economic Research', 90.0, 531), ('Center For Economic Policy Research', 95.0, 784)]
# Length =  2 , Number =  389
# Length =  2 , Number =  390
# Length =  2 , Number =  391
# Length =  3 , Number =  392
# Length =  4 , Number =  393
# Length =  4 , Number =  394
# Length =  2 , Number =  395
# Length =  3 , Number =  396
# Length =  1 , Number =  397
# Length =  2 , Number =  398
# Length =  3 , Number =  399
# Length =  0 , Number =  400
# Length =  0 , Number =  401
# Length =  2 , Number =  402
# Length =  2 , Number =  403
# Length =  3 , Number =  404
# Length =  9 , Number =  405
# Length =  1 , Number =  406
# Length =  3 , Number =  407
# Length =  1 , Number =  408
# Length =  3 , Number =  409
# Length =  2 , Number =  410
# Length =  4 , Number =  411
# Length =  3 , Number =  412
# Length =  2 , Number =  413
# Length =  2 , Number =  414
# Length =  4 , Number =  415
# Length =  2 , Number =  416
# Length =  4 , Number =  417
# Length =  2 , Number =  418
# Length =  3 , Number =  419
# Length =  2 , Number =  420
# Length =  3 , Number =  421
# Length =  4 , Number =  422
# Length =  3 , Number =  423
# Length =  2 , Number =  424
# Length =  4 , Number =  425
# Length =  1 , Number =  426
# Length =  2 , Number =  427
# Length =  1 , Number =  428
# Length =  6 , Number =  429
# Length =  1 , Number =  430
# Length =  2 , Number =  431
# Length =  5 , Number =  432
# [('New York University', 90.0, 145), ('National Bureau Of Economic Research', 90.0, 531), ('York University', 90.0, 829), ('National Bureau Of Economic Research', 90.0, 531), ('University Of Southern California', 90.0, 509)]
# Length =  3 , Number =  433
# Length =  1 , Number =  434
# Length =  6 , Number =  435
# Length =  3 , Number =  436
# Length =  2 , Number =  437
# Length =  2 , Number =  438
# Length =  4 , Number =  439
# Length =  3 , Number =  440
# Length =  9 , Number =  441
# Length =  3 , Number =  442
# Length =  5 , Number =  443
# [('University Of Oslo', 90.0, 121), ('Carnegie Mellon University', 100.0, 350), ('Cabnegie-Mellon University', 96.15384615384616, 349), ('University Of Pennsylvania', 90.0, 364), ('National Bureau Of Economic Research', 90.0, 531)]
# Length =  2 , Number =  444
# Length =  3 , Number =  445
# Length =  3 , Number =  446
# Length =  1 , Number =  447
# Length =  2 , Number =  448
# Length =  6 , Number =  449
# Length =  6 , Number =  450
# Length =  5 , Number =  451
# [('Dartmouth College', 100.0, 70), ('Yale University', 100.0, 0), ('Columbia University', 100.0, 6), ('Harvard University', 100.0, 695), ('Harvard', 90.0, 2)]
# Length =  5 , Number =  452
# [('Columbia University', 90.0, 6), ('National Bureau Of Economic Research', 90.0, 531), ('Brookings Institution', 90.0, 201), ('International Monetary Fund', 90.0, 372), ('National Bureau Of Economic Research', 90.0, 531)]
# Length =  1 , Number =  453
# Length =  1 , Number =  454
# Length =  4 , Number =  455
# Length =  2 , Number =  456
# Length =  2 , Number =  457
# Length =  2 , Number =  458
# Length =  2 , Number =  459
# Length =  4 , Number =  460
# Length =  2 , Number =  461
# Length =  4 , Number =  462
# Length =  2 , Number =  463
# Length =  4 , Number =  464
# Length =  1 , Number =  465
# Length =  6 , Number =  466
# Length =  2 , Number =  467
# Length =  4 , Number =  468
# Length =  4 , Number =  469
# Length =  1 , Number =  470
# Length =  1 , Number =  471
# Length =  2 , Number =  472
# Length =  3 , Number =  473
# Length =  1 , Number =  474
# Length =  1 , Number =  475
# Length =  3 , Number =  476
# Length =  1 , Number =  477
# Length =  2 , Number =  478
# Length =  3 , Number =  479
# Length =  1 , Number =  480
# Length =  1 , Number =  481
# Length =  1 , Number =  482
# Length =  2 , Number =  483
# Length =  2 , Number =  484
# Length =  3 , Number =  485
# Length =  1 , Number =  486
# Length =  0 , Number =  487
# Length =  4 , Number =  488
# Length =  3 , Number =  489
# Length =  3 , Number =  490
# Length =  3 , Number =  491
# Length =  2 , Number =  492
# Length =  3 , Number =  493
# Length =  2 , Number =  494
# Length =  2 , Number =  495
# Length =  4 , Number =  496
# Length =  6 , Number =  497
# Length =  2 , Number =  498
# Length =  3 , Number =  499
# Length =  2 , Number =  500
# Length =  7 , Number =  501
# Length =  2 , Number =  502
# Length =  4 , Number =  503
# Length =  4 , Number =  504
# Length =  2 , Number =  505
# Length =  2 , Number =  506
# Length =  1 , Number =  507
# Length =  2 , Number =  508
# Length =  2 , Number =  509
# Length =  3 , Number =  510
# Length =  4 , Number =  511
# Length =  3 , Number =  512
# Length =  1 , Number =  513
# Length =  2 , Number =  514
# Length =  0 , Number =  515
# Length =  2 , Number =  516
# Length =  1 , Number =  517
# Length =  3 , Number =  518
# Length =  4 , Number =  519
# Length =  1 , Number =  520
# Length =  1 , Number =  521
# Length =  1 , Number =  522
# Length =  4 , Number =  523
# Length =  1 , Number =  524
# Length =  1 , Number =  525
# Length =  4 , Number =  526
# Length =  2 , Number =  527
# Length =  2 , Number =  528
# Length =  2 , Number =  529
# Length =  2 , Number =  530
# Length =  1 , Number =  531
# Length =  2 , Number =  532
# Length =  2 , Number =  533
# Length =  1 , Number =  534
# Length =  2 , Number =  535
# Length =  5 , Number =  536
# [('University College London', 90.0, 341), ('National Bureau Of Economic Research', 90.0, 531), ('University College', 90.0, 635), ('University College London', 90.0, 341), ('University College', 90.0, 635)]
# Length =  5 , Number =  537
# [('Duke University', 100.0, 18), ('Drake University', 90.32258064516128, 786), ('University Of Chicago', 90.0, 222), ('National Bureau Of Economic Research', 90.0, 531), ('University Of Pennsylvania', 100.0, 364)]
# Length =  2 , Number =  538
# Length =  1 , Number =  539
# Length =  3 , Number =  540
# Length =  3 , Number =  541
# Length =  1 , Number =  542
# Length =  5 , Number =  543
# [('University Of Illinois', 90.0, 256), ('National Bureau Of Economic Research', 90.0, 531), ('University Of Chicago', 90.0, 222), ('American Bar Foundation', 90.0, 269), ('National Bureau Of Economic Research', 90.0, 531)]
# Length =  2 , Number =  544
# Length =  6 , Number =  545
# Length =  2 , Number =  546
# Length =  1 , Number =  547
# Length =  4 , Number =  548
# Length =  1 , Number =  549
# Length =  3 , Number =  550
# Length =  0 , Number =  551
# Length =  3 , Number =  552
# Length =  1 , Number =  553
# Length =  4 , Number =  554
# Length =  2 , Number =  555
# Length =  1 , Number =  556
# Length =  2 , Number =  557
# Length =  4 , Number =  558
# Length =  1 , Number =  559
# Length =  6 , Number =  560
# Length =  2 , Number =  561
# Length =  1 , Number =  562
# Length =  6 , Number =  563
# Length =  4 , Number =  564
# Length =  2 , Number =  565
# Length =  3 , Number =  566
# Length =  1 , Number =  567
# Length =  2 , Number =  568
# Length =  8 , Number =  569
# Length =  4 , Number =  570
# Length =  7 , Number =  571
# Length =  2 , Number =  572
# Length =  1 , Number =  573
# Length =  5 , Number =  574
# [('New York University', 100.0, 145), ('City University Of New York', 95.0, 370), ('State University Of New York', 95.0, 407), ('York University', 95.0, 829), ('Brown University', 93.75, 37)]
# Length =  1 , Number =  575
# Length =  4 , Number =  576
# Length =  2 , Number =  577
# Length =  1 , Number =  578
# Length =  5 , Number =  579
# [('University Of Essex', 100.0, 158), ('University Of Sussex', 92.3076923076923, 193), ('Indiana University', 90.0, 792), ("Queen'S University", 90.0, 814), ('University Of Pennsylvania', 100.0, 364)]
# Length =  2 , Number =  580
# Length =  4 , Number =  581
# Length =  4 , Number =  582
# Length =  2 , Number =  583
# Length =  1 , Number =  584
# Length =  2 , Number =  585
# Length =  3 , Number =  586
# Length =  2 , Number =  587
# Length =  3 , Number =  588
# Length =  1 , Number =  589
# Length =  3 , Number =  590
# Length =  3 , Number =  591
# Length =  12 , Number =  592
# Length =  12 , Number =  593
# Length =  0 , Number =  594
# Length =  13 , Number =  595
# Length =  1 , Number =  596
# Length =  2 , Number =  597
# Length =  1 , Number =  598
# Length =  2 , Number =  599
# Length =  2 , Number =  600
# Length =  2 , Number =  601
# Length =  2 , Number =  602
# Length =  2 , Number =  603
# Length =  3 , Number =  604
# Length =  4 , Number =  605
# Length =  0 , Number =  606
# Length =  1 , Number =  607
# Length =  2 , Number =  608
# Length =  2 , Number =  609
# Length =  5 , Number =  610
# [('University Of Houston', 100.0, 696), ('University Of Houston–Downtown', 95.0, 698), ('University Of Houston–Victoria', 95.0, 699), ('University Of Aston', 90.0, 156), ('University Of Houston–Clear Lake', 90.0, 697)]
# Length =  6 , Number =  611
# Length =  3 , Number =  612
# Length =  3 , Number =  613
# Length =  2 , Number =  614
# Length =  2 , Number =  615
# Length =  2 , Number =  616
# Length =  1 , Number =  617
# Length =  3 , Number =  618
# Length =  1 , Number =  619
# Length =  2 , Number =  620
# Length =  5 , Number =  621
# [('U.S. Department Of The Treasury', 95.0, 462), ('Resources For The Future', 100.0, 306), ('World Bank', 90.0, 10), ('University Of Maryland', 90.0, 772), ('Resources For The Future', 100.0, 306)]
# Length =  1 , Number =  622
# Length =  1 , Number =  623
# Length =  3 , Number =  624
# Length =  1 , Number =  625
# Length =  2 , Number =  626
# Length =  4 , Number =  627
# Length =  4 , Number =  628
# Length =  4 , Number =  629
# Length =  2 , Number =  630
# Length =  3 , Number =  631
# Length =  2 , Number =  632
# Length =  2 , Number =  633
# Length =  2 , Number =  634
# Length =  2 , Number =  635
# Length =  5 , Number =  636
# [('Oxford University', 90.0, 4), ('Katholieke Universiteit Leuven', 90.0, 422), ('Oxford University', 100.0, 4), ('University Of Oxford', 95.0, 793), ('Oxford', 90.0, 3)]
# Length =  3 , Number =  637
# Length =  4 , Number =  638
# Length =  4 , Number =  639
# Length =  1 , Number =  640
# Length =  1 , Number =  641
# Length =  1 , Number =  642
# Length =  1 , Number =  643
# Length =  1 , Number =  644
# Length =  1 , Number =  645
# Length =  1 , Number =  646
# Length =  1 , Number =  647
# Length =  5 , Number =  648
# [('Washington University', 100.0, 238), ('University Of Washington', 95.0, 326), ('Washington State University', 95.0, 385), ('George Washington University', 95.0, 388), ('Washington University In St. Louis', 90.0, 521)]
# Length =  2 , Number =  649
# Length =  2 , Number =  650
# Length =  1 , Number =  651
# Length =  4 , Number =  652
# Length =  1 , Number =  653
# Length =  1 , Number =  654
# Length =  1 , Number =  655
# Length =  1 , Number =  656
# Length =  1 , Number =  657
# Length =  5 , Number =  658
# [('University Of Pennsylvania', 96.15384615384616, 364), ('New York University', 100.0, 145), ('City University Of New York', 95.0, 370), ('State University Of New York', 95.0, 407), ('York University', 95.0, 829)]
# Length =  2 , Number =  659
# Length =  2 , Number =  660
# Length =  3 , Number =  661
# Length =  3 , Number =  662
# Length =  1 , Number =  663
# Length =  2 , Number =  664
# Length =  1 , Number =  665
# Length =  1 , Number =  666
# Length =  2 , Number =  667
# Length =  1 , Number =  668
# Length =  1 , Number =  669
# Length =  2 , Number =  670
# Length =  1 , Number =  671
# Length =  3 , Number =  672
# Length =  2 , Number =  673
# Length =  2 , Number =  674
# Length =  2 , Number =  675
# Length =  1 , Number =  676
# Length =  4 , Number =  677
# Length =  1 , Number =  678
# Length =  2 , Number =  679
# Length =  4 , Number =  680
# Length =  1 , Number =  681
# Length =  1 , Number =  682
# Length =  5 , Number =  683
# [('Federal Reserve Board Of Governors', 100.0, 515), ('Board Of Governors Of The Federal Reserve System', 95.0, 585), ('Federal Reserve Board', 90.0, 204), ('George Washington University', 100.0, 388), ('Washington University', 95.0, 238)]
# Length =  1 , Number =  684
# Length =  2 , Number =  685
# Length =  3 , Number =  686
# Length =  2 , Number =  687
# Length =  1 , Number =  688
# Length =  1 , Number =  689
# Length =  2 , Number =  690
# Length =  3 , Number =  691
# Length =  2 , Number =  692
# Length =  4 , Number =  693
# Length =  4 , Number =  694
# Length =  2 , Number =  695
# Length =  2 , Number =  696
# Length =  1 , Number =  697
# Length =  2 , Number =  698
# Length =  6 , Number =  699
# Length =  1 , Number =  700
# Length =  4 , Number =  701
# Length =  1 , Number =  702
# Length =  4 , Number =  703
# Length =  4 , Number =  704
# Length =  2 , Number =  705
# Length =  1 , Number =  706
# Length =  4 , Number =  707
# Length =  2 , Number =  708
# Length =  5 , Number =  709
# [('National Bureau Of Economic Research', 90.0, 531), ('Harvard University', 90.0, 695), ('University Of Chicago', 90.0, 222), ('Federal Reserve Bank Of Chicago', 90.0, 453), ('National Bureau Of Economic Research', 90.0, 531)]
# Length =  2 , Number =  710
# Length =  2 , Number =  711
# Length =  2 , Number =  712
# Length =  2 , Number =  713
# Length =  4 , Number =  714
# Length =  4 , Number =  715
# Length =  3 , Number =  716
# Length =  1 , Number =  717
# Length =  1 , Number =  718
# Length =  3 , Number =  719
# Length =  2 , Number =  720
# Length =  4 , Number =  721
# Length =  2 , Number =  722
# Length =  2 , Number =  723
# Length =  3 , Number =  724
# Length =  2 , Number =  725
# Length =  3 , Number =  726
# Length =  1 , Number =  727
# Length =  1 , Number =  728
# Length =  1 , Number =  729
# Length =  2 , Number =  730
# Length =  4 , Number =  731
# Length =  4 , Number =  732
# Length =  3 , Number =  733
# Length =  1 , Number =  734
# Length =  1 , Number =  735
# Length =  2 , Number =  736
# Length =  2 , Number =  737
# Length =  1 , Number =  738
# Length =  3 , Number =  739
# Length =  6 , Number =  740
# Length =  2 , Number =  741
# Length =  1 , Number =  742
# Length =  3 , Number =  743
# Length =  2 , Number =  744
# Length =  3 , Number =  745
# Length =  1 , Number =  746
# Length =  1 , Number =  747
# Length =  3 , Number =  748
# Length =  1 , Number =  749
# Length =  10 , Number =  750
# Length =  3 , Number =  751
# Length =  1 , Number =  752
# Length =  2 , Number =  753
# Length =  3 , Number =  754
# Length =  4 , Number =  755
# Length =  4 , Number =  756
# Length =  3 , Number =  757
# Length =  1 , Number =  758
# Length =  2 , Number =  759
# Length =  3 , Number =  760
# Length =  2 , Number =  761
# Length =  3 , Number =  762
# Length =  3 , Number =  763
# Length =  1 , Number =  764
# Length =  3 , Number =  765
# Length =  2 , Number =  766
# Length =  2 , Number =  767
# Length =  5 , Number =  768
# [('Stockholm School Of Economics', 90.0, 426), ('Center For Economic Policy Research', 90.0, 784), ('University College London', 90.0, 341), ('University College', 90.0, 635), ('Center For Economic Policy Research', 90.0, 784)]
# Length =  1 , Number =  769
# Length =  0 , Number =  770
# Length =  6 , Number =  771
# Length =  3 , Number =  772
# Length =  1 , Number =  773
# Length =  1 , Number =  774
# Length =  2 , Number =  775
# Length =  1 , Number =  776
# Length =  4 , Number =  777
# Length =  7 , Number =  778
# Length =  4 , Number =  779
# Length =  1 , Number =  780
# Length =  2 , Number =  781
# Length =  2 , Number =  782
# Length =  5 , Number =  783
# [('Oxford', 90.0, 3), ('Nuffield College', 90.0, 47), ('Nuffield College', 90.0, 619), ('Oxford', 90.0, 3), ('Keble College', 90.0, 610)]
# Length =  4 , Number =  784
# Length =  2 , Number =  785
# Length =  1 , Number =  786
# Length =  2 , Number =  787
# Length =  2 , Number =  788
# Length =  2 , Number =  789
# Length =  6 , Number =  790
# Length =  2 , Number =  791
# Length =  3 , Number =  792
# Length =  2 , Number =  793
# Length =  3 , Number =  794
# Length =  3 , Number =  795
# Length =  3 , Number =  796
# Length =  1 , Number =  797
# Length =  5 , Number =  798
# [('University Of Rochester', 90.0, 290), ('University Of Pennsylvania', 90.0, 364), ('University Of Minnesota', 90.0, 289), ('University Of Pennsylvania', 90.0, 364), ('Federal Reserve Bank Of Minneapolis', 90.0, 523)]
# Length =  3 , Number =  799
# Length =  5 , Number =  800
# [('University Of Pennsylvania', 100.0, 364), ('New York University', 100.0, 145), ('City University Of New York', 95.0, 370), ('State University Of New York', 95.0, 407), ('York University', 95.0, 829)]
# Length =  5 , Number =  801
# [('Oxford', 90.0, 3), ('Oxford University', 90.0, 4), ('Nuffield College', 90.0, 47), ('Nuffield College', 90.0, 619), ('Oxford University', 90.0, 4)]
# Length =  4 , Number =  802
# Length =  3 , Number =  803
# Length =  1 , Number =  804
# Length =  4 , Number =  805
# Length =  1 , Number =  806
# Length =  3 , Number =  807
# Length =  3 , Number =  808
# Length =  4 , Number =  809
# Length =  2 , Number =  810
# Length =  2 , Number =  811
# Length =  0 , Number =  812
# Length =  1 , Number =  813
# Length =  4 , Number =  814
# Length =  3 , Number =  815
# Length =  3 , Number =  816
# Length =  1 , Number =  817
# Length =  2 , Number =  818
# Length =  4 , Number =  819
# Length =  1 , Number =  820
# Length =  4 , Number =  821
# Length =  0 , Number =  822
# Length =  3 , Number =  823
# Length =  0 , Number =  824
# Length =  1 , Number =  825
# Length =  4 , Number =  826
# Length =  4 , Number =  827
# Length =  1 , Number =  828
# Length =  2 , Number =  829
# Length =  1 , Number =  830
# Length =  3 , Number =  831
# Length =  2 , Number =  832
# Length =  2 , Number =  833
# Length =  2 , Number =  834
# Length =  3 , Number =  835
# Length =  2 , Number =  836
# Length =  2 , Number =  837
# Length =  1 , Number =  838
# Length =  1 , Number =  839
# Length =  2 , Number =  840
# Length =  1 , Number =  841
# Length =  1 , Number =  842
# Length =  1 , Number =  843
# Length =  1 , Number =  844
# Length =  2 , Number =  845
# Length =  4 , Number =  846
# Length =  3 , Number =  847
# Length =  3 , Number =  848
# Length =  1 , Number =  849
# Length =  2 , Number =  850
# Length =  1 , Number =  851
# Length =  1 , Number =  852
# Length =  3 , Number =  853
# Length =  1 , Number =  854
# Length =  3 , Number =  855
# Length =  4 , Number =  856
# Length =  2 , Number =  857
# Length =  2 , Number =  858
# Length =  2 , Number =  859
# Length =  4 , Number =  860
# Length =  2 , Number =  861
# Length =  3 , Number =  862
# Length =  1 , Number =  863
# Length =  3 , Number =  864
# Length =  1 , Number =  865
# Length =  5 , Number =  866
# [('Tilburg University', 90.0, 115), ('Tel–Aviv University', 90.0, 151), ('University Of Chicago', 100.0, 222), ('Tel–Aviv University', 100.0, 151), ('Telaviv University', 97.2972972972973, 824)]
# Length =  2 , Number =  867
# Length =  1 , Number =  868
# Length =  1 , Number =  869
# Length =  2 , Number =  870
# Length =  2 , Number =  871
# Length =  1 , Number =  872
# Length =  1 , Number =  873
# Length =  1 , Number =  874
# Length =  1 , Number =  875
# Length =  1 , Number =  876
# Length =  1 , Number =  877
# Length =  1 , Number =  878
# Length =  1 , Number =  879
# Length =  2 , Number =  880
# Length =  1 , Number =  881
# Length =  3 , Number =  882
# Length =  2 , Number =  883
# Length =  2 , Number =  884
# Length =  3 , Number =  885
# Length =  0 , Number =  886
# Length =  1 , Number =  887
# Length =  1 , Number =  888
# Length =  1 , Number =  889
# Length =  1 , Number =  890
# Length =  3 , Number =  891
# Length =  3 , Number =  892
# Length =  1 , Number =  893
# Length =  1 , Number =  894
# Length =  4 , Number =  895
# Length =  2 , Number =  896
# Length =  2 , Number =  897
# Length =  4 , Number =  898
# Length =  2 , Number =  899
# Length =  2 , Number =  900
# Length =  1 , Number =  901
# Length =  2 , Number =  902
# Length =  2 , Number =  903
# Length =  1 , Number =  904
# Length =  1 , Number =  905
# Length =  1 , Number =  906
# Length =  6 , Number =  907
# Length =  3 , Number =  908
# Length =  1 , Number =  909
# Length =  2 , Number =  910
# Length =  1 , Number =  911
# Length =  1 , Number =  912
# Length =  4 , Number =  913
# Length =  3 , Number =  914
# Length =  1 , Number =  915
# Length =  3 , Number =  916
# Length =  2 , Number =  917
# Length =  0 , Number =  918
# Length =  3 , Number =  919
# Length =  2 , Number =  920
# Length =  2 , Number =  921
# Length =  1 , Number =  922
# Length =  1 , Number =  923
# Length =  1 , Number =  924
# Length =  2 , Number =  925
# Length =  2 , Number =  926
# Length =  6 , Number =  927
# Length =  2 , Number =  928
# Length =  2 , Number =  929
# Length =  1 , Number =  930
# Length =  1 , Number =  931
# Length =  6 , Number =  932
# Length =  2 , Number =  933
# Length =  2 , Number =  934
# Length =  8 , Number =  935
# Length =  4 , Number =  936
# Length =  1 , Number =  937
# Length =  2 , Number =  938
# Length =  2 , Number =  939
# Length =  1 , Number =  940
# Length =  2 , Number =  941
# Length =  2 , Number =  942
# Length =  1 , Number =  943
# Length =  1 , Number =  944
# Length =  1 , Number =  945
# Length =  1 , Number =  946
# Length =  2 , Number =  947
# Length =  1 , Number =  948
# Length =  1 , Number =  949
# Length =  2 , Number =  950
# Length =  1 , Number =  951
# Length =  2 , Number =  952
# Length =  2 , Number =  953
# Length =  1 , Number =  954
# Length =  1 , Number =  955
# Length =  4 , Number =  956
# Length =  3 , Number =  957
# Length =  4 , Number =  958
# Length =  2 , Number =  959
# Length =  1 , Number =  960
# Length =  2 , Number =  961
# Length =  6 , Number =  962
# Length =  3 , Number =  963
# Length =  1 , Number =  964
# Length =  1 , Number =  965
# Length =  1 , Number =  966
# Length =  1 , Number =  967
# Length =  2 , Number =  968
# Length =  1 , Number =  969
# Length =  1 , Number =  970
# Length =  3 , Number =  971
# Length =  2 , Number =  972
# Length =  2 , Number =  973
# Length =  1 , Number =  974
# Length =  2 , Number =  975
# Length =  3 , Number =  976
# Length =  1 , Number =  977
# Length =  1 , Number =  978
# Length =  1 , Number =  979
# Length =  1 , Number =  980
# Length =  1 , Number =  981
# Length =  1 , Number =  982
# Length =  1 , Number =  983
# Length =  1 , Number =  984
# Length =  1 , Number =  985
# Length =  1 , Number =  986
# Length =  1 , Number =  987
# Length =  1 , Number =  988
# Length =  2 , Number =  989
# Length =  2 , Number =  990
# Length =  3 , Number =  991
# Length =  1 , Number =  992
# Length =  1 , Number =  993
# Length =  2 , Number =  994
# Length =  1 , Number =  995
# Length =  1 , Number =  996
# Length =  4 , Number =  997
# Length =  1 , Number =  998
# Length =  1 , Number =  999
# Length =  1 , Number =  1000
# Length =  2 , Number =  1001
# Length =  8 , Number =  1002
# Length =  1 , Number =  1003
# Length =  2 , Number =  1004
# Length =  4 , Number =  1005
# Length =  1 , Number =  1006
# Length =  1 , Number =  1007
# Length =  1 , Number =  1008
# Length =  5 , Number =  1009
# [('University Of Pennsylvania', 100.0, 364), ('New York University', 100.0, 145), ('City University Of New York', 95.0, 370), ('State University Of New York', 95.0, 407), ('York University', 95.0, 829)]
# Length =  8 , Number =  1010
# Length =  4 , Number =  1011
# Length =  1 , Number =  1012
# Length =  1 , Number =  1013
# Length =  2 , Number =  1014
# Length =  2 , Number =  1015
# Length =  1 , Number =  1016
# Length =  1 , Number =  1017
# Length =  2 , Number =  1018
# Length =  2 , Number =  1019
# Length =  1 , Number =  1020
# Length =  1 , Number =  1021
# Length =  2 , Number =  1022
# Length =  2 , Number =  1023
# Length =  3 , Number =  1024
# Length =  9 , Number =  1025
# Length =  2 , Number =  1026
# Length =  3 , Number =  1027
# Length =  2 , Number =  1028
# Length =  4 , Number =  1029
# Length =  4 , Number =  1030
# Length =  3 , Number =  1031
# Length =  2 , Number =  1032
# Length =  1 , Number =  1033
# Length =  4 , Number =  1034
# Length =  1 , Number =  1035
# Length =  1 , Number =  1036
# Length =  6 , Number =  1037
# Length =  1 , Number =  1038
# Length =  2 , Number =  1039
# Length =  1 , Number =  1040
# Length =  1 , Number =  1041
# Length =  8 , Number =  1042
# Length =  1 , Number =  1043
# Length =  3 , Number =  1044
# Length =  1 , Number =  1045
# Length =  6 , Number =  1046
# Length =  1 , Number =  1047
# Length =  1 , Number =  1048
# Length =  0 , Number =  1049
# Length =  4 , Number =  1050
# Length =  3 , Number =  1051
# Length =  2 , Number =  1052
# Length =  1 , Number =  1053
# Length =  1 , Number =  1054
# Length =  2 , Number =  1055
# Length =  3 , Number =  1056
# Length =  0 , Number =  1057
# Length =  4 , Number =  1058
# Length =  1 , Number =  1059
# Length =  1 , Number =  1060
# Length =  1 , Number =  1061
# Length =  9 , Number =  1062
# Length =  3 , Number =  1063
# Length =  3 , Number =  1064
# Length =  3 , Number =  1065
# Length =  1 , Number =  1066
# Length =  2 , Number =  1067
# Length =  1 , Number =  1068
# Length =  1 , Number =  1069
# Length =  2 , Number =  1070
# Length =  2 , Number =  1071
# Length =  1 , Number =  1072
# Length =  4 , Number =  1073
# Length =  1 , Number =  1074
# Length =  1 , Number =  1075
# Length =  1 , Number =  1076
# Length =  3 , Number =  1077
# Length =  5 , Number =  1078
# [('New York University', 90.0, 145), ('York University', 90.0, 829), ('Stanford University', 90.0, 8), ('University Of Pennsylvania', 90.0, 364), ('Federal Reserve Bank Of Minneapolis', 90.0, 523)]
# Length =  3 , Number =  1079
# Length =  4 , Number =  1080
# Length =  6 , Number =  1081
# Length =  1 , Number =  1082
# Length =  1 , Number =  1083
# Length =  1 , Number =  1084
# Length =  2 , Number =  1085
# Length =  1 , Number =  1086
# Length =  1 , Number =  1087
# Length =  1 , Number =  1088
# Length =  1 , Number =  1089
# Length =  1 , Number =  1090
# Length =  3 , Number =  1091
# Length =  2 , Number =  1092
# Length =  1 , Number =  1093
# Length =  2 , Number =  1094
# Length =  1 , Number =  1095
# Length =  2 , Number =  1096
# Length =  3 , Number =  1097
# Length =  2 , Number =  1098
# Length =  1 , Number =  1099
# Length =  1 , Number =  1100
# Length =  2 , Number =  1101
# Length =  1 , Number =  1102
# Length =  1 , Number =  1103
# Length =  2 , Number =  1104
# Length =  1 , Number =  1105
# Length =  1 , Number =  1106
# Length =  1 , Number =  1107
# Length =  1 , Number =  1108
# Length =  2 , Number =  1109
# Length =  1 , Number =  1110
# Length =  1 , Number =  1111
# Length =  1 , Number =  1112
# Length =  1 , Number =  1113
# Length =  2 , Number =  1114
# Length =  2 , Number =  1115
# Length =  4 , Number =  1116
# Length =  3 , Number =  1117
# Length =  3 , Number =  1118
# Length =  1 , Number =  1119
# Length =  1 , Number =  1120
# Length =  4 , Number =  1121
# Length =  3 , Number =  1122
# Length =  1 , Number =  1123
# Length =  1 , Number =  1124
# Length =  1 , Number =  1125
# Length =  1 , Number =  1126
# Length =  1 , Number =  1127
# Length =  1 , Number =  1128
# Length =  1 , Number =  1129
# Length =  2 , Number =  1130
# Length =  0 , Number =  1131
# Length =  1 , Number =  1132
# Length =  1 , Number =  1133
# Length =  0 , Number =  1134
# Length =  1 , Number =  1135
# Length =  1 , Number =  1136
# Length =  2 , Number =  1137
# Length =  1 , Number =  1138
# Length =  1 , Number =  1139
# Length =  1 , Number =  1140
# Length =  2 , Number =  1141
# Length =  1 , Number =  1142
# Length =  1 , Number =  1143
# Length =  3 , Number =  1144
# Length =  3 , Number =  1145
# Length =  3 , Number =  1146
# Length =  2 , Number =  1147
# Length =  1 , Number =  1148
# Length =  1 , Number =  1149
# Length =  2 , Number =  1150
# Length =  3 , Number =  1151
# Length =  2 , Number =  1152
# Length =  3 , Number =  1153
# Length =  3 , Number =  1154
# Length =  1 , Number =  1155
# Length =  1 , Number =  1156
# Length =  4 , Number =  1157
# Length =  3 , Number =  1158
# Length =  1 , Number =  1159
# Length =  0 , Number =  1160
# Length =  4 , Number =  1161
# Length =  3 , Number =  1162
# Length =  1 , Number =  1163
# Length =  7 , Number =  1164
# Length =  1 , Number =  1165
# Length =  2 , Number =  1166
# Length =  2 , Number =  1167
# Length =  2 , Number =  1168
# Length =  5 , Number =  1169
# [('New York University', 100.0, 145), ('City University Of New York', 95.0, 370), ('State University Of New York', 95.0, 407), ('York University', 95.0, 829), ('Brown University', 100.0, 37)]
# Length =  3 , Number =  1170
# Length =  2 , Number =  1171
# Length =  2 , Number =  1172
# Length =  2 , Number =  1173
# Length =  3 , Number =  1174
# Length =  2 , Number =  1175
# Length =  1 , Number =  1176
# Length =  3 , Number =  1177
# Length =  3 , Number =  1178
# Length =  2 , Number =  1179
# Length =  2 , Number =  1180
# Length =  1 , Number =  1181
# Length =  3 , Number =  1182
# Length =  2 , Number =  1183
# Length =  1 , Number =  1184
# Length =  1 , Number =  1185
# Length =  1 , Number =  1186
# Length =  1 , Number =  1187
# Length =  2 , Number =  1188
# Length =  1 , Number =  1189
# Length =  1 , Number =  1190
# Length =  1 , Number =  1191
# Length =  2 , Number =  1192
# Length =  1 , Number =  1193
# Length =  2 , Number =  1194
# Length =  2 , Number =  1195
# Length =  2 , Number =  1196
# Length =  4 , Number =  1197
# Length =  2 , Number =  1198
# Length =  1 , Number =  1199
# Length =  2 , Number =  1200
# Length =  1 , Number =  1201
# Length =  3 , Number =  1202
# Length =  2 , Number =  1203
# Length =  4 , Number =  1204
# Length =  1 , Number =  1205
# Length =  2 , Number =  1206
# Length =  1 , Number =  1207
# Length =  1 , Number =  1208
# Length =  1 , Number =  1209
# Length =  3 , Number =  1210
# Length =  1 , Number =  1211
# Length =  1 , Number =  1212
# Length =  2 , Number =  1213
# Length =  1 , Number =  1214
# Length =  1 , Number =  1215
# Length =  4 , Number =  1216
# Length =  1 , Number =  1217
# Length =  1 , Number =  1218
# Length =  1 , Number =  1219
# Length =  1 , Number =  1220
# Length =  2 , Number =  1221
# Length =  1 , Number =  1222
# Length =  2 , Number =  1223
# Length =  3 , Number =  1224
# Length =  2 , Number =  1225
# Length =  2 , Number =  1226
# Length =  2 , Number =  1227
# Length =  2 , Number =  1228
# Length =  4 , Number =  1229
# Length =  1 , Number =  1230
# Length =  4 , Number =  1231
# Length =  3 , Number =  1232
# Length =  5 , Number =  1233
# [('University Of Minnesota', 100.0, 289), ('Governors University Of Minnesota', 95.0, 501), ('Harvard', 90.0, 2), ('Bar Ilan University', 90.0, 129), ('Harvard University', 90.0, 695)]
# Length =  2 , Number =  1234
# Length =  1 , Number =  1235
# Length =  2 , Number =  1236
# Length =  1 , Number =  1237
# Length =  4 , Number =  1238
# Length =  1 , Number =  1239
# Length =  1 , Number =  1240
# Length =  4 , Number =  1241
# Length =  0 , Number =  1242
# Length =  2 , Number =  1243
# Length =  1 , Number =  1244
# Length =  1 , Number =  1245
# Length =  1 , Number =  1246
# Length =  1 , Number =  1247
# Length =  2 , Number =  1248
# Length =  0 , Number =  1249
# Length =  1 , Number =  1250
# Length =  1 , Number =  1251
# Length =  1 , Number =  1252
# Length =  2 , Number =  1253
# Length =  2 , Number =  1254
# Length =  2 , Number =  1255
# Length =  2 , Number =  1256
# Length =  1 , Number =  1257
# Length =  2 , Number =  1258
# Length =  1 , Number =  1259
# Length =  2 , Number =  1260
# Length =  2 , Number =  1261
# Length =  1 , Number =  1262
# Length =  2 , Number =  1263
# Length =  3 , Number =  1264
# Length =  1 , Number =  1265
# Length =  1 , Number =  1266
# Length =  2 , Number =  1267
# Length =  2 , Number =  1268
# Length =  2 , Number =  1269
# Length =  1 , Number =  1270
# Length =  0 , Number =  1271
# Length =  2 , Number =  1272
# Length =  2 , Number =  1273
# Length =  2 , Number =  1274
# Length =  2 , Number =  1275
# Length =  0 , Number =  1276
# Length =  2 , Number =  1277
# Length =  1 , Number =  1278
# Length =  1 , Number =  1279
# Length =  3 , Number =  1280
# Length =  1 , Number =  1281
# Length =  2 , Number =  1282
# Length =  2 , Number =  1283
# Length =  1 , Number =  1284
# Length =  1 , Number =  1285
# Length =  2 , Number =  1286
# Length =  1 , Number =  1287
# Length =  2 , Number =  1288
# Length =  1 , Number =  1289
# Length =  1 , Number =  1290
# Length =  2 , Number =  1291
# Length =  0 , Number =  1292
# Length =  1 , Number =  1293
# Length =  1 , Number =  1294
# Length =  1 , Number =  1295
# Length =  1 , Number =  1296
# Length =  2 , Number =  1297
# Length =  1 , Number =  1298
# ...
# Length =  11 , Number =  3782
# Length =  2 , Number =  3783
# Length =  2 , Number =  3784
# Length =  5 , Number =  3785
# [('Carnegie Institute Of Technology', 95.0, 469), ('Mines Paristech', 90.0, 25), ('Jesus College', 90.0, 609), ('Hughes Hall', 90.0, 665), ('Jesus College', 90.0, 666)]
# Length =  1 , Number =  3786
# Length =  1 , Number =  3787
# Length =  1 , Number =  3788
# Length =  1 , Number =  3789
# Length =  4 , Number =  3790
# Length =  1 , Number =  3791
# Length =  0 , Number =  3792
# Length =  0 , Number =  3793
# Length =  1 , Number =  3794
# Length =  1 , Number =  3795
# Length =  0 , Number =  3796
# Length =  4 , Number =  3797
# Length =  1 , Number =  3798
# Length =  9 , Number =  3799
# Length =  1 , Number =  3800
# Length =  1 , Number =  3801
# Length =  1 , Number =  3802
# Length =  4 , Number =  3803
# Length =  2 , Number =  3804
# Length =  2 , Number =  3805
# Length =  1 , Number =  3806
# Length =  2 , Number =  3807
# Length =  1 , Number =  3808
# Length =  3 , Number =  3809
# Length =  6 , Number =  3810
# Length =  0 , Number =  3811
# Length =  0 , Number =  3812
# Length =  1 , Number =  3813
# Length =  0 , Number =  3814
# Length =  2 , Number =  3815
# Length =  2 , Number =  3816
# Length =  1 , Number =  3817
# Length =  1 , Number =  3818
# Length =  1 , Number =  3819
# Length =  1 , Number =  3820
# Length =  4 , Number =  3821
# Length =  1 , Number =  3822
# Length =  2 , Number =  3823
# Length =  1 , Number =  3824
# Length =  1 , Number =  3825
# Length =  1 , Number =  3826
# Length =  13 , Number =  3827
# Length =  2 , Number =  3828
# Length =  1 , Number =  3829
# Length =  11 , Number =  3830
# Length =  11 , Number =  3831
# Length =  4 , Number =  3832
# Length =  1 , Number =  3833
# Length =  1 , Number =  3834
# Length =  0 , Number =  3835
# Length =  0 , Number =  3836
# Length =  1 , Number =  3837
# Length =  0 , Number =  3838
# Length =  4 , Number =  3839
# Length =  0 , Number =  3840
# Length =  1 , Number =  3841
# Length =  0 , Number =  3842
# Length =  1 , Number =  3843
# Length =  2 , Number =  3844
# Length =  1 , Number =  3845
# Length =  1 , Number =  3846
# Length =  1 , Number =  3847
# Length =  1 , Number =  3848
# Length =  2 , Number =  3849
# Length =  1 , Number =  3850
# Length =  0 , Number =  3851
# Length =  1 , Number =  3852
# Length =  1 , Number =  3853
# Length =  1 , Number =  3854
# Length =  1 , Number =  3855
# Length =  4 , Number =  3856
# Length =  4 , Number =  3857
# Length =  1 , Number =  3858
# Length =  1 , Number =  3859
# Length =  11 , Number =  3860
# Length =  1 , Number =  3861
# Length =  1 , Number =  3862
# Length =  1 , Number =  3863
# Length =  1 , Number =  3864
# Length =  1 , Number =  3865
# Length =  1 , Number =  3866
# Length =  2 , Number =  3867
# Length =  1 , Number =  3868
# Length =  1 , Number =  3869
# Length =  1 , Number =  3870
# Length =  4 , Number =  3871
# Length =  1 , Number =  3872
# Length =  3 , Number =  3873
# Length =  1 , Number =  3874
# Length =  1 , Number =  3875
# Length =  1 , Number =  3876
# Length =  3 , Number =  3877
# Length =  0 , Number =  3878
# Length =  1 , Number =  3879
# Length =  2 , Number =  3880
# Length =  2 , Number =  3881
# Length =  1 , Number =  3882
# Length =  2 , Number =  3883
# Length =  1 , Number =  3884
# Length =  1 , Number =  3885
# Length =  0 , Number =  3886
# Length =  1 , Number =  3887
# Length =  1 , Number =  3888
# Length =  3 , Number =  3889
# Length =  1 , Number =  3890
# Length =  2 , Number =  3891
# Length =  1 , Number =  3892
# Length =  1 , Number =  3893
# Length =  1 , Number =  3894
# Length =  2 , Number =  3895
# Length =  1 , Number =  3896
# Length =  1 , Number =  3897
# Length =  1 , Number =  3898
# Length =  2 , Number =  3899
# Length =  4 , Number =  3900
# Length =  0 , Number =  3901
# Length =  2 , Number =  3902
# Length =  1 , Number =  3903
# Length =  1 , Number =  3904
# Length =  2 , Number =  3905
# Length =  3 , Number =  3906
# Length =  2 , Number =  3907
# Length =  1 , Number =  3908
# Length =  1 , Number =  3909
# Length =  1 , Number =  3910
# Length =  2 , Number =  3911
# Length =  1 , Number =  3912
# Length =  0 , Number =  3913
# Length =  0 , Number =  3914
# Length =  2 , Number =  3915
# Length =  1 , Number =  3916
# Length =  1 , Number =  3917
# Length =  2 , Number =  3918
# Length =  1 , Number =  3919
# Length =  1 , Number =  3920
# Length =  0 , Number =  3921
# Length =  1 , Number =  3922
# Length =  1 , Number =  3923
# Length =  2 , Number =  3924
# Length =  12 , Number =  3925
# Length =  1 , Number =  3926
# Length =  1 , Number =  3927
# Length =  1 , Number =  3928
# Length =  1 , Number =  3929
# Length =  2 , Number =  3930
# Length =  1 , Number =  3931
# Length =  2 , Number =  3932
# Length =  1 , Number =  3933
# Length =  1 , Number =  3934
# Length =  1 , Number =  3935
# Length =  1 , Number =  3936
# Length =  2 , Number =  3937
# Length =  0 , Number =  3938
# Length =  1 , Number =  3939
# Length =  1 , Number =  3940
# Length =  1 , Number =  3941
# Length =  1 , Number =  3942
# Length =  4 , Number =  3943
# Length =  1 , Number =  3944
# Length =  2 , Number =  3945
# Length =  2 , Number =  3946
# Length =  2 , Number =  3947
# Length =  2 , Number =  3948
# Length =  4 , Number =  3949
# Length =  1 , Number =  3950
# Length =  1 , Number =  3951
# Length =  1 , Number =  3952
# Length =  1 , Number =  3953
# Length =  1 , Number =  3954
# Length =  4 , Number =  3955
# Length =  0 , Number =  3956
# Length =  0 , Number =  3957
# Length =  2 , Number =  3958
# Length =  1 , Number =  3959
# Length =  3 , Number =  3960
# Length =  1 , Number =  3961
# Length =  1 , Number =  3962
# Length =  1 , Number =  3963
# Length =  1 , Number =  3964
# Length =  0 , Number =  3965
# Length =  4 , Number =  3966
# Length =  2 , Number =  3967
# Length =  1 , Number =  3968
# Length =  1 , Number =  3969
# Length =  1 , Number =  3970
# Length =  0 , Number =  3971
# Length =  1 , Number =  3972
# Length =  0 , Number =  3973
# Length =  0 , Number =  3974
# Length =  1 , Number =  3975
# Length =  0 , Number =  3976
# Length =  0 , Number =  3977
# Length =  1 , Number =  3978
# Length =  0 , Number =  3979
# Length =  1 , Number =  3980
# Length =  0 , Number =  3981
# Length =  0 , Number =  3982
# Length =  0 , Number =  3983
# Length =  0 , Number =  3984
# Length =  0 , Number =  3985
# Length =  0 , Number =  3986
# Length =  0 , Number =  3987
# Length =  0 , Number =  3988
# Length =  0 , Number =  3989
# Length =  0 , Number =  3990
# Length =  0 , Number =  3991
# Length =  0 , Number =  3992
# Length =  0 , Number =  3993
# Length =  0 , Number =  3994
# Length =  0 , Number =  3995
# Length =  0 , Number =  3996
# Length =  0 , Number =  3997
# Length =  1 , Number =  3998
# Length =  0 , Number =  3999
# Length =  0 , Number =  4000
# Length =  1 , Number =  4001
# Length =  0 , Number =  4002
# Length =  0 , Number =  4003
# Length =  0 , Number =  4004
# Length =  0 , Number =  4005
# Length =  0 , Number =  4006
# Length =  0 , Number =  4007
# Length =  0 , Number =  4008
# Length =  1 , Number =  4009
# Length =  0 , Number =  4010
# Length =  0 , Number =  4011
# Length =  0 , Number =  4012
# Length =  0 , Number =  4013
# Length =  3 , Number =  4014
# Length =  0 , Number =  4015
# Length =  0 , Number =  4016
# Length =  2 , Number =  4017
# Length =  0 , Number =  4018
# Length =  0 , Number =  4019
# Length =  3 , Number =  4020
# Length =  0 , Number =  4021
# Length =  1 , Number =  4022
# Length =  1 , Number =  4023
# Length =  0 , Number =  4024
# Length =  0 , Number =  4025
# Length =  0 , Number =  4026
# Length =  0 , Number =  4027
# Length =  3 , Number =  4028
# Length =  1 , Number =  4029
# Length =  1 , Number =  4030
# Length =  0 , Number =  4031
# Length =  0 , Number =  4032
# Length =  1 , Number =  4033
# Length =  1 , Number =  4034
# Length =  2 , Number =  4035
# Length =  1 , Number =  4036
# Length =  1 , Number =  4037
# Length =  0 , Number =  4038
# Length =  0 , Number =  4039
# Length =  0 , Number =  4040
# Length =  0 , Number =  4041
# Length =  1 , Number =  4042
# Length =  0 , Number =  4043
# Length =  0 , Number =  4044
# Length =  0 , Number =  4045
# Length =  0 , Number =  4046
# Length =  0 , Number =  4047
# Length =  0 , Number =  4048
# Length =  3 , Number =  4049
# Length =  0 , Number =  4050
# Length =  0 , Number =  4051
# Length =  0 , Number =  4052
# Length =  0 , Number =  4053
# Length =  0 , Number =  4054
# Length =  0 , Number =  4055
# Length =  0 , Number =  4056
# Length =  1 , Number =  4057
# Length =  0 , Number =  4058
# Length =  0 , Number =  4059
# Length =  0 , Number =  4060
# Length =  0 , Number =  4061
# Length =  0 , Number =  4062
# Length =  1 , Number =  4063
# Length =  0 , Number =  4064
# Length =  0 , Number =  4065
# Length =  0 , Number =  4066
# Length =  0 , Number =  4067
# Length =  2 , Number =  4068
# Length =  1 , Number =  4069
# Length =  1 , Number =  4070
# Length =  0 , Number =  4071
# Length =  0 , Number =  4072
# Length =  1 , Number =  4073
# Length =  0 , Number =  4074
# Length =  0 , Number =  4075
# Length =  0 , Number =  4076
# Length =  0 , Number =  4077
# Length =  0 , Number =  4078
# Length =  0 , Number =  4079
# Length =  0 , Number =  4080
# Length =  0 , Number =  4081
# Length =  0 , Number =  4082
# Length =  1 , Number =  4083
# Length =  0 , Number =  4084
# Length =  0 , Number =  4085
# Length =  1 , Number =  4086
# Length =  1 , Number =  4087
# Length =  1 , Number =  4088
# Length =  3 , Number =  4089
# Length =  1 , Number =  4090
# Length =  0 , Number =  4091
# Length =  10 , Number =  4092
# Length =  0 , Number =  4093
# Length =  0 , Number =  4094
# Length =  0 , Number =  4095
# Length =  0 , Number =  4096
# Length =  0 , Number =  4097
# Length =  0 , Number =  4098
# Length =  3 , Number =  4099
# Length =  6 , Number =  4100
# Length =  0 , Number =  4101
# Length =  0 , Number =  4102
# Length =  0 , Number =  4103
# Length =  1 , Number =  4104
# Length =  1 , Number =  4105
# Length =  0 , Number =  4106
# Length =  0 , Number =  4107
# Length =  0 , Number =  4108
# Length =  0 , Number =  4109
# Length =  0 , Number =  4110
# Length =  0 , Number =  4111
# Length =  0 , Number =  4112
# Length =  3 , Number =  4113
# Length =  3 , Number =  4114
# Length =  3 , Number =  4115
# Length =  3 , Number =  4116
# Length =  0 , Number =  4117
# Length =  1 , Number =  4118
# Length =  1 , Number =  4119
# Length =  0 , Number =  4120
# Length =  0 , Number =  4121
# Length =  0 , Number =  4122
# Length =  0 , Number =  4123
# Length =  1 , Number =  4124
# Length =  0 , Number =  4125
# Length =  0 , Number =  4126
# Length =  0 , Number =  4127
# Length =  0 , Number =  4128
# Length =  3 , Number =  4129
# Length =  3 , Number =  4130
# Length =  3 , Number =  4131
# Length =  1 , Number =  4132
# Length =  1 , Number =  4133
# Length =  0 , Number =  4134
# Length =  0 , Number =  4135
# Length =  0 , Number =  4136
# Length =  0 , Number =  4137
# Length =  1 , Number =  4138
# Length =  0 , Number =  4139
# Length =  0 , Number =  4140
# Length =  0 , Number =  4141
# Length =  0 , Number =  4142
# Length =  4 , Number =  4143
# Length =  0 , Number =  4144
# Length =  1 , Number =  4145
# Length =  0 , Number =  4146
# Length =  1 , Number =  4147
# Length =  0 , Number =  4148
# Length =  0 , Number =  4149
# Length =  0 , Number =  4150
# Length =  0 , Number =  4151
# Length =  0 , Number =  4152
# Length =  0 , Number =  4153
# Length =  0 , Number =  4154
# Length =  0 , Number =  4155
# Length =  0 , Number =  4156
# Length =  1 , Number =  4157
# Length =  0 , Number =  4158
# Length =  0 , Number =  4159
# Length =  1 , Number =  4160
# Length =  1 , Number =  4161
# Length =  1 , Number =  4162
# Length =  1 , Number =  4163
# Length =  1 , Number =  4164
# Length =  0 , Number =  4165
# Length =  1 , Number =  4166
# Length =  0 , Number =  4167
# Length =  0 , Number =  4168
# Length =  0 , Number =  4169
# Length =  3 , Number =  4170
# Length =  0 , Number =  4171
# Length =  0 , Number =  4172
# Length =  0 , Number =  4173
# Length =  0 , Number =  4174
# Length =  1 , Number =  4175
# Length =  0 , Number =  4176
# Length =  1 , Number =  4177
# Length =  0 , Number =  4178
# Length =  0 , Number =  4179
# Length =  0 , Number =  4180
# Length =  0 , Number =  4181
# Length =  1 , Number =  4182
# Length =  0 , Number =  4183
# Length =  0 , Number =  4184
# Length =  0 , Number =  4185
# Length =  0 , Number =  4186
# Length =  0 , Number =  4187
# Length =  3 , Number =  4188
# Length =  3 , Number =  4189
# Length =  0 , Number =  4190
# Length =  0 , Number =  4191
# Length =  0 , Number =  4192
# Length =  0 , Number =  4193
# Length =  1 , Number =  4194
# Length =  0 , Number =  4195
# Length =  0 , Number =  4196
# Length =  0 , Number =  4197
# Length =  0 , Number =  4198
# Length =  0 , Number =  4199
# Length =  0 , Number =  4200
# Length =  0 , Number =  4201
# Length =  0 , Number =  4202
# Length =  3 , Number =  4203
# Length =  3 , Number =  4204
# Length =  3 , Number =  4205
# Length =  0 , Number =  4206
# Length =  0 , Number =  4207
# Length =  0 , Number =  4208
# Length =  0 , Number =  4209
# Length =  0 , Number =  4210
# Length =  1 , Number =  4211
# Length =  0 , Number =  4212
# Length =  0 , Number =  4213
# Length =  0 , Number =  4214
# Length =  1 , Number =  4215
# Length =  0 , Number =  4216
# Length =  1 , Number =  4217
# Length =  1 , Number =  4218
# Length =  1 , Number =  4219
# Length =  1 , Number =  4220
# Length =  0 , Number =  4221
# Length =  1 , Number =  4222
# Length =  1 , Number =  4223
# Length =  0 , Number =  4224
# Length =  0 , Number =  4225
# Length =  0 , Number =  4226
# Length =  1 , Number =  4227
# Length =  1 , Number =  4228
# Length =  1 , Number =  4229
# Length =  0 , Number =  4230
# Length =  1 , Number =  4231
# Length =  1 , Number =  4232
# Length =  2 , Number =  4233
# Length =  0 , Number =  4234
# Length =  1 , Number =  4235
# Length =  1 , Number =  4236
# Length =  1 , Number =  4237
# Length =  0 , Number =  4238
# Length =  2 , Number =  4239
# Length =  0 , Number =  4240
# Length =  1 , Number =  4241
# Length =  0 , Number =  4242
# Length =  1 , Number =  4243
# Length =  2 , Number =  4244
# Length =  1 , Number =  4245
# Length =  1 , Number =  4246
# Length =  1 , Number =  4247
# Length =  1 , Number =  4248
# Length =  1 , Number =  4249
# Length =  2 , Number =  4250
# Length =  1 , Number =  4251
# Length =  0 , Number =  4252
# Length =  1 , Number =  4253
# Length =  0 , Number =  4254
# Length =  2 , Number =  4255
# Length =  0 , Number =  4256
# Length =  0 , Number =  4257
# Length =  1 , Number =  4258
# Length =  0 , Number =  4259
# Length =  0 , Number =  4260
# Length =  0 , Number =  4261
# Length =  1 , Number =  4262
# Length =  7 , Number =  4263
# Length =  0 , Number =  4264
# Length =  1 , Number =  4265
# Length =  1 , Number =  4266
# Length =  1 , Number =  4267
# Length =  1 , Number =  4268
# Length =  3 , Number =  4269
# Length =  0 , Number =  4270
# Length =  1 , Number =  4271
# Length =  1 , Number =  4272
# Length =  1 , Number =  4273
# Length =  1 , Number =  4274
# Length =  1 , Number =  4275
# Length =  1 , Number =  4276
# Length =  1 , Number =  4277
# Length =  1 , Number =  4278
# Length =  0 , Number =  4279
# Length =  1 , Number =  4280
# Length =  0 , Number =  4281
# Length =  1 , Number =  4282
# Length =  1 , Number =  4283
# Length =  0 , Number =  4284
# Length =  1 , Number =  4285
# Length =  1 , Number =  4286
# Length =  2 , Number =  4287
# Length =  1 , Number =  4288
# Length =  1 , Number =  4289
# Length =  2 , Number =  4290
# Length =  2 , Number =  4291
# Length =  2 , Number =  4292
# Length =  0 , Number =  4293
# Length =  0 , Number =  4294
# Length =  0 , Number =  4295
# Length =  1 , Number =  4296
# Length =  1 , Number =  4297
# Length =  1 , Number =  4298
# Length =  1 , Number =  4299
# Length =  1 , Number =  4300
# Length =  2 , Number =  4301
# Length =  2 , Number =  4302
# Length =  1 , Number =  4303
# Length =  1 , Number =  4304
# Length =  1 , Number =  4305
# Length =  1 , Number =  4306
# Length =  0 , Number =  4307
# Length =  1 , Number =  4308
# Length =  0 , Number =  4309
# Length =  0 , Number =  4310
# Length =  1 , Number =  4311
# Length =  1 , Number =  4312
# Length =  0 , Number =  4313
# Length =  0 , Number =  4314
# Length =  7 , Number =  4315
# Length =  1 , Number =  4316
# Length =  1 , Number =  4317
# Length =  1 , Number =  4318
# Length =  4 , Number =  4319
# Length =  0 , Number =  4320
# Length =  1 , Number =  4321
# Length =  1 , Number =  4322
# Length =  0 , Number =  4323
# Length =  0 , Number =  4324
# Length =  1 , Number =  4325
# Length =  0 , Number =  4326

# %%
testdata.loc[1,['aff1']]
# Out:
# aff1    National Bureau Of Economic Research
# Name: 1, dtype: object

# %%
list(testdata.columns.values)
testdata = testdata[['Journal_Name',
 'Authors_count',
 'Article_ID',
 'content_type',
 'stable_url',
 'Ref_type',
 'ref_string',
 'Missing aff',
 'No of Affs',
 'aff1',
 'aff2',
 'aff3',
 'aff4',
 'aff5',
 'aff6',
 'aff7',
 'aff8',
 'aff9',
 'aff10',
 'aff11',
 'aff12']]
list(testdata.columns.values)
# Out:
# ['Journal_Name',
#  'Authors_count',
#  'Article_ID',
#  'content_type',
#  'stable_url',
#  'Ref_type',
#  'ref_string',
#  'Missing aff',
#  'No of Affs',
#  'aff1',
#  'aff2',
#  'aff3',
#  'aff4',
#  'aff5',
#  'aff6',
#  'aff7',
#  'aff8',
#  'aff9',
#  'aff10',
#  'aff11',
#  'aff12']

# %%
print(testdata.iat[1,9])
print(testdata.iat[1,20])
# Out:
# National Bureau Of Economic Research
# nan

# %%
import numpy as np
testdata = testdata.replace(np.nan, '', regex=True)
for i in range(len(testdata)):
    for j in range(9,20):
    #Replaceing title case and stripping leading space
        testdata.iat[i,j] = testdata.iat[i,j].strip().title()
        testdata.iat[i,j] = testdata.iat[i,j].rstrip(',')

# Columbia
# Columbia University
        if testdata.iat[i,j] == 'Columbia':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Columbia", "Columbia University")

        if testdata.iat[i,j] == 'Columbia Business School':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Columbia Business School", "Columbia University")

        if testdata.iat[i,j] == 'Columbia Graduate School Of Business':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Columbia Graduate School Of Business", "Columbia University")
    
# Harvard
#Harvard University
        if testdata.iat[i,j] == 'Harvard':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Harvard", "Harvard University")

        if testdata.iat[i,j] == 'Harvard Business School':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Harvard Business School", "Harvard University")

        if testdata.iat[i,j] == 'Harvard Graduate School of Design':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Harvard Graduate School of Design", "Harvard University")

        if testdata.iat[i,j] == 'Harvard Law School':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Harvard Law School", "Harvard University")

        if testdata.iat[i,j] == 'Harvard Divinity School':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Harvard Divinity School", "Harvard University")

        if testdata.iat[i,j] == 'Harvard Medical School':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Harvard Medical School", "Harvard University")

        if testdata.iat[i,j] == 'John F. Kennedy School of Government':
            testdata.iat[i,j] = testdata.iat[i,j].replace("John F. Kennedy School of Government", "Harvard University")

        if testdata.iat[i,j] == 'Harvard T.H. Chan School of Public Health':
            testdata.iat[i,j] = testdata.iat[i,j].replace('Harvard T.H. Chan School of Public Health', "Harvard University")

        if testdata.iat[i,j] == 'Harvard John A. Paulson School of Engineering and Applied Sciences':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Harvard John A. Paulson School of Engineering and Applied Sciences", "Harvard University")

        if testdata.iat[i,j] == 'Harvard Kenneth C. Griffin Graduate School of Arts and Sciences':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Harvard Kenneth C. Griffin Graduate School of Arts and Sciences", "Harvard University")

        if testdata.iat[i,j] == 'Harvard Division of Continuing Education':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Harvard Division of Continuing Education", "Harvard University")



# Oxford
# Base Oxford spelling
# University Of Oxford
        if testdata.iat[i,j] == 'Oxford':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Oxford", "University Of Oxford")

        if testdata.iat[i,j] == 'Oxford University':
            testdata.iat[i,j] = testdata.iat[i,j].replace('Oxford University', "University Of Oxford")

        if testdata.iat[i,j] == 'Christ Church':
            testdata.iat[i,j] = testdata.iat[i,j].replace('Christ Church', "University Of Oxford")

        if testdata.iat[i,j] == 'Nuffield College, Oxford':
            testdata.iat[i,j] = testdata.iat[i,j].replace('Nuffield College', "University Of Oxford")

        if testdata.iat[i,j] == 'Trinity College, Oxford':
            testdata.iat[i,j] = testdata.iat[i,j].replace('Trinity College', "University Of Oxford")   
        
        if testdata.iat[i,j] == 'All Souls College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("All Souls College", "University Of Oxford")   

        if testdata.iat[i,j] == 'Balliol College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Balliol College", "University Of Oxford")

        if testdata.iat[i,j] == 'Brasenose College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Brasenose College", "University Of Oxford")

        if testdata.iat[i,j] == 'Corpus Christi College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Corpus Christi College", "University Of Oxford")

        if testdata.iat[i,j] == 'Exeter College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Exeter College", "University Of Oxford")

        if testdata.iat[i,j] == 'Green Templeton College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Green Templeton College", "University Of Oxford")

        if testdata.iat[i,j] == 'Harris Manchester College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Harris Manchester College", "University Of Oxford")

        if testdata.iat[i,j] == 'Hertford College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Hertford College", "University Of Oxford")

        if testdata.iat[i,j] == 'Jesus College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Jesus College", "University Of Oxford")

        if testdata.iat[i,j] == 'Keble College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Keble College", "University Of Oxford")

        if testdata.iat[i,j] == 'Kellogg College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Kellogg College", "University Of Oxford")

        if testdata.iat[i,j] == 'Lady Margaret Hall':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Lady Margaret Hall", "University Of Oxford")

        if testdata.iat[i,j] == 'Linacre College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Linacre College", "University Of Oxford")

        if testdata.iat[i,j] == 'Lincoln College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Lincoln College", "University Of Oxford")

        if testdata.iat[i,j] == 'Magdalen College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Magdalen College", "University Of Oxford")

        if testdata.iat[i,j] == 'Mansfield College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Mansfield College", "University Of Oxford")

        if testdata.iat[i,j] == 'Merton College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Merton College", "University Of Oxford")

        if testdata.iat[i,j] == 'New College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("New College", "University Of Oxford")

        if testdata.iat[i,j] == 'Oriel College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Oriel College", "University Of Oxford")

        if testdata.iat[i,j] == 'Pembroke College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Pembroke College", "University Of Oxford")

        if testdata.iat[i,j] == 'Reuben College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Reuben College", "University Of Oxford")

        if testdata.iat[i,j] == 'Somerville College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Somerville College", "University Of Oxford")

        if testdata.iat[i,j] == "St Anne's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("St Anne's College", "University Of Oxford")

        if testdata.iat[i,j] == "St Antony's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("St Antony's College", "University Of Oxford")

        if testdata.iat[i,j] == "St Catherine's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("St Catherine's College", "University Of Oxford")

        if testdata.iat[i,j] == 'St Cross College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("St Cross College", "University Of Oxford")

        if testdata.iat[i,j] == 'St Edmund Hall':
            testdata.iat[i,j] = testdata.iat[i,j].replace("St Edmund Hall", "University Of Oxford")

        if testdata.iat[i,j] == "St Hilda's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("St Hilda's College", "University Of Oxford")

        if testdata.iat[i,j] == "St Hugh's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("St Hugh's College", "University Of Oxford")

        if testdata.iat[i,j] == "St John's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("St John's College", "University Of Oxford")

        if testdata.iat[i,j] == "St Peter's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("St Peter's College", "University Of Oxford")  

        if testdata.iat[i,j] == "The Queen's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("The Queen's College", "University Of Oxford")  

        if testdata.iat[i,j] == 'University College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("University College", "University Of Oxford")  

        if testdata.iat[i,j] == 'Wadham College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Wadham College", "University Of Oxford")  

        if testdata.iat[i,j] == 'Wolfson College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Wolfson College", "University Of Oxford")  

        if testdata.iat[i,j] == 'Worcester College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Worcester College", "University Of Oxford")  

# Yale
# Base Yale spelling
# Yale University
        if testdata.iat[i,j] == 'Yale':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Yale", "Yale University")

        if testdata.iat[i,j] == 'Berkeley College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Berkeley College", "Yale University")

        if testdata.iat[i,j] == 'Branford College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Branford College", "Yale University")

        if testdata.iat[i,j] == 'Davenport College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Davenport College", "Yale University")

        if testdata.iat[i,j] == 'Ezra Stiles College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Ezra Stiles College", "Yale University")

        if testdata.iat[i,j] == 'Jonathan Edwards College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Jonathan Edwards College", "Yale University")

        if testdata.iat[i,j] == 'Benjamin Franklin College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Benjamin Franklin College", "Yale University")

        if testdata.iat[i,j] == 'Grace Hopper College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Grace Hopper College", "Yale University")

        if testdata.iat[i,j] == 'Morse College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Morse College", "Yale University")

        if testdata.iat[i,j] == 'Pauli Murray College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Pauli Murray College", "Yale University")

        if testdata.iat[i,j] == 'Pierson College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Pierson College", "Yale University")

        if testdata.iat[i,j] == 'Saybrook College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Saybrook College", "Yale University")

        if testdata.iat[i,j] == 'Silliman College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Silliman College", "Yale University")

        if testdata.iat[i,j] == 'Timothy Dwight College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Timothy Dwight College", "Yale University")

        if testdata.iat[i,j] == 'Trumbull College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Trumbull College", "Yale University")

# Cambridge
# Base Cambridge spelling
# University of Cambridge
        if testdata.iat[i,j] == 'Cambridge':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Cambridge", "University of Cambridge")

        if testdata.iat[i,j] == "Christ's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("Christ's College", "University of Cambridge")

        if testdata.iat[i,j] == 'Churchill College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Churchill College", "University of Cambridge")

        if testdata.iat[i,j] == 'Clare College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Clare College", "University of Cambridge")

        if testdata.iat[i,j] == 'Clare Hall':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Clare Hall", "University of Cambridge")

        if testdata.iat[i,j] == 'Corpus Christi College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Corpus Christi College", "University of Cambridge")

        if testdata.iat[i,j] == 'Darwin College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Darwin College", "University of Cambridge")

        if testdata.iat[i,j] == 'Downing College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Downing College", "University of Cambridge")

        if testdata.iat[i,j] == 'Emmanuel College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Emmanuel College", "University of Cambridge")

        if testdata.iat[i,j] == 'Fitzwilliam College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Fitzwilliam College", "University of Cambridge")

        if testdata.iat[i,j] == 'Girton College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Girton College", "University of Cambridge")

        if testdata.iat[i,j] == 'Gonville & Caius College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Gonville & Caius College", "University of Cambridge")

        if testdata.iat[i,j] == 'Homerton College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Homerton College", "University of Cambridge")

        if testdata.iat[i,j] == 'Jesus College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Jesus College", "University of Cambridge")

        if testdata.iat[i,j] == "King's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("King's College", "University of Cambridge")

        if testdata.iat[i,j] == 'Lucy Cavendish College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Lucy Cavendish College", "University of Cambridge")

        if testdata.iat[i,j] == 'Magdalene College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Magdalene College", "University of Cambridge")

        if testdata.iat[i,j] == 'Murray Edwards College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Murray Edwards College", "University of Cambridge")

        if testdata.iat[i,j] == 'Newnham College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Newnham College", "University of Cambridge")

        if testdata.iat[i,j] == 'Pembroke College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Pembroke College", "University of Cambridge")

        if testdata.iat[i,j] == 'Peterhouse':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Peterhouse", "University of Cambridge")
        
        if testdata.iat[i,j] == "Queens' College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("Queens' College", "University of Cambridge")

        if testdata.iat[i,j] == 'Robinson College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Robinson College", "University of Cambridge")

        if testdata.iat[i,j] == 'Selwyn College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Selwyn College", "University of Cambridge")

        if testdata.iat[i,j] == 'Sidney Sussex College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Sidney Sussex College", "University of Cambridge")

        if testdata.iat[i,j] == "St Catharine's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("St Catharine's College", "University of Cambridge")

        if testdata.iat[i,j] == "St Edmund's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("St Edmund's College", "University of Cambridge")

        if testdata.iat[i,j] == 'Trinity College':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Trinity College", "University of Cambridge")

        if testdata.iat[i,j] == "St John's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("St John's College", "University of Cambridge")

        if testdata.iat[i,j] == "Trinity Hall":
            testdata.iat[i,j] = testdata.iat[i,j].replace("Trinity Hall", "University of Cambridge")

        if testdata.iat[i,j] == "St Edmund's College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("St Edmund's College", "University of Cambridge")

        if testdata.iat[i,j] == "Wolfson College":
            testdata.iat[i,j] = testdata.iat[i,j].replace("Wolfson College", "University of Cambridge")

# Texas A&M University
        if testdata.iat[i,j] == 'Texas A And M University':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Texas A And M University", "Texas A&M University")

        if testdata.iat[i,j] == 'Texas A & M University':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Texas A & M University", "Texas A&M University")

        if testdata.iat[i,j] == 'Texas A. And M. University':
            testdata.iat[i,j] = testdata.iat[i,j].replace("Texas A. And M. University", "Texas A&M University")

# %%
# Removing duplicate entries of the same university

import numpy as np
testdata = testdata.replace(np.nan, '', regex=True)

#Range for affiliations in JPE
for i in range(len(testdata)):
    for j in range(9,19):
    #If 1 = 2, or 2 = 3
        if testdata.iat[i,j] == testdata.iat[i,j+1]:
            testdata.iat[i,j+1] = np.nan

    #If 1 = 3, 2 = 4, 3 = 5
    for j in range(9,18):
    #Replaceing title case and stripping leading space
        if testdata.iat[i,j] == testdata.iat[i,j+2]:
            testdata.iat[i,j+2] = np.nan

    #If 1 = 4, 2 = 5, 3 = 6
    for j in range(9,17):
    #Replaceing title case and stripping leading space
        if testdata.iat[i,j] == testdata.iat[i,j+3]:
            testdata.iat[i,j+3] = np.nan

testdata = testdata.replace('', np.nan, regex=True)

# %%
# Excel output to get an overview of the data
testdata.head
testdata.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/JPE/Test files/JPE_aff_ref_output_1940_2010_affs_out.xlsx')

# %%
# This is taking a dataframe with multiple affilitaion columns and melting these to be all one column.
melted = testdata.melt(id_vars= 'Article_ID', value_vars=['aff1','aff2','aff3','aff4','aff5','aff6','aff7','aff8','aff9','aff10']).dropna()
melted.rename(columns = {'variable':'Aff number'}, inplace = True)
melted.rename(columns = {'value':'Affiliation'}, inplace = True)
print(melted.head())
# Out:
#   Article_ID Aff number                           Affiliation
# 0   26549911       aff1                       Yale University
# 1   26549912       aff1  National Bureau Of Economic Research
# 2   26549913       aff1                     Purdue University
# 3   26549914       aff1                    Tilburg University
# 4   26549915       aff1                University Of Maryland

# %%
#Reading in the master file and correctly formatting the article ID to match back onto the meltef file

#Load in master from Github
JPE_master = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/main/1_Input%20files%20and%20processing%20input%20files/1_1_Input%20files/Master%20lists/Processed/JPE_processed.xlsx")

# Local master file
#JPE_master = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/1_Input files and processing input files/1_1_Input files/Master lists/Processed/JPE_processed.xlsx')

for i in range(len(JPE_master)):
    JPE_master.loc[i,['Article_ID']] = JPE_master.loc[i,['stable_url']].to_string().rsplit('/',1)[-1]

JPE_master_condenced  = JPE_master[['Article_ID','year']]
JPE_master_condenced.head()
# Out:
#   Article_ID    year
# 0   26549909  2016.0
# 1   26549910  2016.0
# 2   26549911  2016.0
# 3   26549912  2016.0
# 4   26549913  2016.0

# %%
# Merging the masterfile onto the new melted file to get additional data
JPE_melted_master = melted.merge(JPE_master_condenced, how = 'left', on = 'Article_ID')
JPE_melted_master = JPE_melted_master.sort_values(by=['year'])
JPE_melted_master.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/JPE/JPE_melted_master.xlsx') 
JPE_melted_master.head()
# Out:
#      Article_ID Aff number          Affiliation    year
# 3875    1825912       aff1      Duke University  1940.0
# 3852    1825510       aff1  New York University  1940.0
# 6740    1824379       aff7      Whitman College  1940.0
# 3851    1825509       aff1  New York University  1940.0
# 3850    1824214       aff1   Iowa State College  1940.0

# %%
# Counting the number of times a certain affiliton occurs
JPE_melted_master['aff_cum_counts'] = JPE_melted_master.groupby(['Affiliation']).cumcount()+1
JPE_melted_master.head()
JPE_melted_master.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/JPE/Test files/JPE_melted_master_aff_count.xlsx')

# %%
# Storing the master file to transer between notebooks
# %store JPE_melted_master
# Out:
# Stored 'JPE_melted_master' (DataFrame)

# %%
# Checking the top 20 occurances of Universities over the 70 years
highest_vals = JPE_melted_master.drop_duplicates(subset = ['Affiliation'], keep = 'last')
highest_vals_10 = highest_vals.nlargest(20,'aff_cum_counts')
highest_vals_10
# Out:
#      Article_ID Aff number                                     Affiliation  \
# 6697   26549859       aff7                           University Of Chicago
# 3902   26549873       aff2            National Bureau Of Economic Research
# 6605   26549858       aff6                              Harvard University
# 3907   26549861       aff2           Massachusetts Institute Of Technology
# 39     26549863       aff1                             Stanford University
# 2947    1829080       aff1  Icrea-Barcelona Institute Of Political Economy
# 13     26549906       aff1                             Columbia University
# 5532   26549883       aff3                      University Of Pennsylvania
# 0      26549911       aff1                                 Yale University
# 5527   26549890       aff3                            Princeton University
# 5529   26549893       aff3                         Northwestern University
# 8      26549901       aff1                                 York University
# 17     26549892       aff1           University Of California, Los Angeles
# 77       677253       aff1                          University Of Michigan
# 38     26549862       aff1              University Of California, Berkeley
# 5520   26549912       aff3                         University Of Minnesota
# 3879   26549916       aff2                             New York University
# 5558     679284       aff3                           Washington University
# 44       683989       aff1                    State University Of New York
# 4033     658496       aff2                         University Of Rochester
#
#         year  aff_cum_counts
# 6697  2016.0             446
# 3902  2016.0             429
# 6605  2016.0             222
# 3907  2016.0             194
# 39    2016.0             157
# 2947  1967.0             144
# 13    2016.0             137
# 5532  2016.0             133
# 0     2016.0             126
# 5527  2016.0             121
# 5529  2016.0             109
# 8     2016.0             101
# 17    2016.0             100
# 77    2014.0              95
# 38    2016.0              88
# 5520  2016.0              83
# 3879  2016.0              83
# 5558  2015.0              81
# 44    2015.0              80
# 4033  2010.0              77

# %%
#Stacked plot on all years
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

Combined_cumcount = JPE_melted_master
print(Combined_cumcount.head())

a = Combined_cumcount.loc[(Combined_cumcount['Affiliation'] == highest_vals_10.iat[0,2])]
b = Combined_cumcount.loc[(Combined_cumcount['Affiliation'] == highest_vals_10.iat[1,2])]
c = Combined_cumcount.loc[(Combined_cumcount['Affiliation'] == highest_vals_10.iat[2,2])]
d = Combined_cumcount.loc[(Combined_cumcount['Affiliation'] == highest_vals_10.iat[3,2])]
e = Combined_cumcount.loc[(Combined_cumcount['Affiliation'] == highest_vals_10.iat[4,2])]
f = Combined_cumcount.loc[(Combined_cumcount['Affiliation'] == highest_vals_10.iat[5,2])]
g = Combined_cumcount.loc[(Combined_cumcount['Affiliation'] == highest_vals_10.iat[6,2])]
h = Combined_cumcount.loc[(Combined_cumcount['Affiliation'] == highest_vals_10.iat[7,2])]
i = Combined_cumcount.loc[(Combined_cumcount['Affiliation'] == highest_vals_10.iat[8,2])]
j = Combined_cumcount.loc[(Combined_cumcount['Affiliation'] == highest_vals_10.iat[9,2])]
k = Combined_cumcount.loc[(Combined_cumcount['Affiliation'] == highest_vals_10.iat[10,2])]

plt.figure(figsize=(12,10))
plt.plot(a['year'],a['aff_cum_counts'], label = highest_vals_10.iat[0,2])
plt.plot(b['year'],b['aff_cum_counts'], label = highest_vals_10.iat[1,2])
plt.plot(c['year'],c['aff_cum_counts'], label = highest_vals_10.iat[2,2])
plt.plot(d['year'],d['aff_cum_counts'], label = highest_vals_10.iat[3,2])
plt.plot(e['year'],e['aff_cum_counts'], label = highest_vals_10.iat[4,2])
plt.plot(f['year'],f['aff_cum_counts'], label = highest_vals_10.iat[5,2])
plt.plot(g['year'],g['aff_cum_counts'], label = highest_vals_10.iat[6,2])
plt.plot(h['year'],h['aff_cum_counts'], label = highest_vals_10.iat[7,2])
plt.plot(i['year'],i['aff_cum_counts'], label = highest_vals_10.iat[8,2])
plt.plot(j['year'],j['aff_cum_counts'], label = highest_vals_10.iat[9,2])
plt.plot(k['year'],k['aff_cum_counts'], label = highest_vals_10.iat[10,2])

plt.title('Number of papers published by year in QJE, RES and JPE from different Universities', fontsize=20)
plt.xlabel('Year')
plt.ylabel('Number of papers published')

plt.legend()
plt.show()
# Out:
#      Article_ID Aff number          Affiliation    year  aff_cum_counts
# 3875    1825912       aff1      Duke University  1940.0               1
# 3852    1825510       aff1  New York University  1940.0               1
# 6740    1824379       aff7      Whitman College  1940.0               1
# 3851    1825509       aff1  New York University  1940.0               2
# 3850    1824214       aff1   Iowa State College  1940.0               1
