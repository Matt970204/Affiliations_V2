# %% [markdown]
# # Merging the AER files together
# AER is split into 7 files as shown in section 2.2. Fuzzy matching, this file reads them all in and merges them into 1 big AER merged file

# %%
import pandas as pd

#Read in the master sheet
#Local store of AER_master
AER_master = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/1_Input files and processing input files/1_1_Input files/Master lists/Processed/AER_processed.xlsx')
for i in range(len(AER_master)):
    AER_master.loc[i,['Article_ID']] = AER_master.loc[i,['stable_url']].to_string().rsplit('/',1)[-1]

AER_master_condenced  = AER_master[['Article_ID','year','content_type']]
AER_master_condenced['year'] = AER_master_condenced['year'].astype('int')
AER_master_condenced['Article_ID'] = AER_master_condenced['Article_ID'].astype('int')
AER_master_condenced.rename(columns = {'year':'year_master', 'content_type':'content_type_master'}, inplace = True)

list = []
for i in range(1940,2011):
    list.append(i)
print(list)
#mask_year = RES_master_condenced['year_master'].isin([2016,2015,2014,2013,2012,2011])
mask_year = AER_master_condenced['year_master'].isin(list)
AER_master_condenced = AER_master_condenced[mask_year]
#mask_type = RES_master_condenced['content_type_master'].isin(['Rejoiner','MISC','Review'])
#RES_master_condenced = RES_master_condenced[~mask_type]
mask_type = AER_master_condenced['content_type_master'].isin(['Article',])
AER_master_condenced = AER_master_condenced[mask_type]
#RES_master_condenced.drop(~RES_master_condenced.loc[RES_master_condenced['year_master'].isin([2016])].index, inplace=True)
print(AER_master_condenced.shape)
AER_master_condenced.head()
# Out:
# [1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
# (9340, 3)
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_2442/276321104.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AER_master_condenced['year'] = AER_master_condenced['year'].astype('int')
# ...

# %%
AER_master_condenced  = AER_master_condenced[['Article_ID']]
print(AER_master_condenced.shape)
AER_master_condenced.head()
# Out:
# (9340, 1)
#       Article_ID
# 2187    41038751
# 2188    41038752
# 2189    41038753
# 2190    41038754
# 2191    41038755

# %%
#1971 - 1999 1 auth
import pandas as pd
AER_1971_1999_1_author = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/Consolidation/Finalized/AER Screened/3 AER 1971-1999 1 auth Screened.xlsx', '1 Author 1971-1999')
print(AER_1971_1999_1_author.shape)
AER_1971_1999_1_author.head()

AER_1971_1999_1_author['Article_ID'] = AER_1971_1999_1_author['Article_ID'].astype('int')
mask_screened = AER_1971_1999_1_author['Screened'].isin(['y'])
AER_1971_1999_1_author = AER_1971_1999_1_author[mask_screened]
print(AER_1971_1999_1_author.shape)
AER_1971_1999_1_author.head()
# Out:
# (3351, 24)
# (2748, 24)
#    Column1 Journal_Name  Authors_count             Authors_list  \
# 0        1          AER              1        ['Branko Horvat']
# 1        2          AER              1       ['Leopoldo Solís']
# 2        3          AER              1    ['J. Phillip Cooper']
# 3        5          AER              1  ['Richard Schmalensee']
# 4        7          AER              1        ['Martin Shubik']
#
#                authors  Article_ID content_type  \
# 0        Branko Horvat     1813304      Article
# 1       Leopoldo Solís     1813303      Article
# 2    J. Phillip Cooper     1811872      Article
# 3  Richard Schmalensee     1811860      Article
# 4        Martin Shubik     1811866      Article
#
#                              stable_url  year_master Ref_type  ...  \
# 0  https://www.jstor.org/stable/1813304         1971    found  ...
# 1  https://www.jstor.org/stable/1813303         1971    found  ...
# ...

# %%
#1971 - 1999 2 authors
import pandas as pd
AER_1971_1999_2_authors = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/Consolidation/Finalized/AER Screened/3 AER_aff_output 1971 1999 2 authors.xlsx')
print(AER_1971_1999_2_authors.shape)
AER_1971_1999_2_authors.head()

AER_1971_1999_2_authors['Article_ID'] = AER_1971_1999_2_authors['Article_ID'].astype('int')
mask_screened = AER_1971_1999_2_authors['Screened'].isin(['y'])
AER_1971_1999_2_authors = AER_1971_1999_2_authors[mask_screened]
print(AER_1971_1999_2_authors.shape)
AER_1971_1999_2_authors.head()
# Out:
# (1478, 27)
# (1478, 27)
#    Column1 Journal_Name  Authors_count  \
# 0        0          AER              2
# 1        1          AER              2
# 2        2          AER              1
# 3        3          AER              2
# 4        4          AER              2
#
#                                 Authors_list  \
# 0  ['George J. Stigler', 'Claire Friedland']
# 1         ['Roger G. Noll', 'John Trijonis']
# 2                        ['Robert A. Meyer']
# 3  ['Peter A. Diamond', 'James A. Mirrlees']
# 4       ['Edgar L. Feige', 'Michael Parkin']
#
#                                   authors  Article_ID content_type  \
# 0  George J. Stigler and Claire Friedland     1811862      Article
# 1         Roger G. Noll and John Trijonis     1811870      Article
# 2                    Robert A. Meyer, Jr.     1811871      Article
# 3  Peter A. Diamond and James A. Mirrlees     1813425      Article
# 4       Edgar L. Feige and Michael Parkin     1813431      Article
#
# ...

# %%
#1971 - 1999 3 authors plus
import pandas as pd
AER_1971_1999_3_authors = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/Consolidation/Finalized/AER Screened/3 AER_aff_output 1971 1999 3+ authors.xlsx')
print(AER_1971_1999_3_authors.shape)
AER_1971_1999_3_authors.head()

AER_1971_1999_3_authors['Article_ID'] = AER_1971_1999_3_authors['Article_ID'].astype('int')
mask_screened = AER_1971_1999_3_authors['Screened'].isin(['y'])
AER_1971_1999_3_authors = AER_1971_1999_3_authors[mask_screened]
print(AER_1971_1999_3_authors.shape)
AER_1971_1999_3_authors.head()
# Out:
# (369, 45)
# (369, 45)
#    Unnamed: 0 Journal_Name  Authors_count  \
# 0           0          AER              4
# 1           1          AER              3
# 2           2          AER              3
# 3           3          AER              3
# 4           4          AER              3
#
#                                         Authors_list  \
# 0  ['Charles J. Cicchetti', 'A. Myrick Freeman Ii...
# 1    ['D. Nichols', 'E. Smolensky', 'T. N. Tideman']
# 2  ['Mordechai E. Kreinin', 'James B. Ramsey', 'J...
# 3  ['Maurice Mcmanus', 'Gary M. Walton', 'Richard...
# 4  ['Anthony C. Fisher', 'John V. Krutilla', 'Cha...
#
#                                              authors  Article_ID content_type  \
# 0  Charles J. Cicchetti, A. Myrick Freeman III, R...     1811867      Article
# 1         D. Nichols, E. Smolensky and T. N. Tideman     1813429      Article
# 2  Mordechai E. Kreinin, James B. Ramsey and Jan ...     1813149      Article
# ...

# %%
#2000 - 2010 1 auth
import pandas as pd
AER_2000_2010_1_author = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/Consolidation/Finalized/AER Screened/3 AER 2000-2010 1 auth Screened.xlsx')
print(AER_2000_2010_1_author.shape)
AER_2000_2010_1_author.head()

AER_2000_2010_1_author['Article_ID'] = AER_2000_2010_1_author['Article_ID'].astype('int')
mask_screened = AER_2000_2010_1_author['Screened'].isin(['y'])
AER_2000_2010_1_author = AER_2000_2010_1_author[mask_screened]
print(AER_2000_2010_1_author.shape)
AER_2000_2010_1_author.head()
# Out:
# (1992, 40)
# (603, 40)
#     Unnamed: 0 Journal_Name  Authors_count           Authors_list  \
# 0            0          AER              1   ['Edmund S. Cannon']
# 1            1          AER              1      ['Kim-Sau Chung']
# 5            5          AER              1     ['Peter Kooreman']
# 13          13          AER              1     ['Karen E. Dynan']
# 14          14          AER              1  ['Jeffrey C. Fuhrer']
#
#               authors  Article_ID content_type  \
# 0    Edmund S. Cannon      117294      Article
# 1       Kim-Sau Chung      117347      Article
# 5      Peter Kooreman      117343      Article
# 13     Karen E. Dynan      117335      Article
# 14  Jeffrey C. Fuhrer      117334      Article
#
#                              stable_url  year_master Ref_type  ...  \
# 0   https://www.jstor.org/stable/117294         2000    found  ...
# 1   https://www.jstor.org/stable/117347         2000    found  ...
# ...

# %%
#2000 - 2010 not 1 auth
import pandas as pd
AER_2000_2010_2_3_authors = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/Consolidation/Finalized/AER Screened/3 AER_aff_ref_output_1940_2010_affs_out authors 2000 2010 not 1 auth.xlsx')
print(AER_2000_2010_2_3_authors.shape)
AER_2000_2010_2_3_authors.head()

AER_2000_2010_2_3_authors['Article_ID'] = AER_2000_2010_2_3_authors['Article_ID'].astype('int')
mask_screened = AER_2000_2010_2_3_authors['Screened'].isin(['y'])
AER_2000_2010_2_3_authors = AER_2000_2010_2_3_authors[mask_screened]
print(AER_2000_2010_2_3_authors.shape)
AER_2000_2010_2_3_authors.head()
# Out:
# (1389, 44)
# (1389, 44)
#    Column1 Journal_Name  Authors_count  \
# 0        0          AER              2
# 1        1          AER              2
# 2        2          AER              2
# 3        3          AER              2
# 4        4          AER              2
#
#                                  Authors_list  \
# 0   ['Kenneth M. Kletzer', 'Brian D. Wright']
# 1  ['Brock Blomberg', 'Joseph E. Harrington']
# 2            ['Hope Corman', 'H. Naci Mocan']
# 3      ['Emmanuelle Auriol', 'Michel Benaim']
# 4        ['Henning Bohn', 'Robert T. Deacon']
#
#                                         authors  Article_ID content_type  \
# 0        Kenneth M. Kletzer and Brian D. Wright      117346      Article
# 1  Brock Blomberg and Joseph E. Harrington, Jr.      117345      Article
# 2                 Hope Corman and H. Naci Mocan      117344      Article
# 3           Emmanuelle Auriol and Michel Benaim      117342      Article
# ...

# %%
#1940 - 1969 all auth
import pandas as pd
AER_1940_1969 = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/Consolidation/Finalized/AER Screened/3 AER_aff_output 1940 1969 authors.xlsx')
print(AER_1940_1969.shape)
AER_1940_1969.head()

AER_1940_1969['Article_ID'] = AER_1940_1969['Article_ID'].astype('int')
mask_screened = AER_1940_1969['Screened'].isin(['y'])
AER_1940_1969 = AER_1940_1969[mask_screened]
print(AER_1940_1969.shape)
AER_1940_1969.head()
# Out:
# (2617, 36)
# (846, 36)
#     Column1 Journal_Name  Authors_count          Authors_list  \
# 2         2          AER            1.0  ['Edmund Whittaker']
# 4         4          AER            1.0    ['Lewis H. Haney']
# 6         6          AER            1.0     ['Simon Kuznets']
# 10       10          AER            1.0    ['John D. Sumner']
# 12       12          AER            1.0  ['Rollin G. Thomas']
#
#              authors  Article_ID content_type  \
# 2   Edmund Whittaker     1807589      Article
# 4     Lewis H. Haney     1807591      Article
# 6      Simon Kuznets     1807049      Article
# 10    John D. Sumner     1807053      Article
# 12  Rollin G. Thomas     1807055      Article
#
#                               stable_url  year_master Ref_type  ...  \
# 2   https://www.jstor.org/stable/1807589         1940    found  ...
# 4   https://www.jstor.org/stable/1807591         1940    found  ...
# 6   https://www.jstor.org/stable/1807049         1940    found  ...
# ...

# %%
#1970 - 1971 all
import pandas as pd
AER_1970_1971 = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/Consolidation/Finalized/AER Screened/3 AER_aff_output 1970 1971 authors.xlsx')
print(AER_1970_1971.shape)
AER_1970_1971.head()

AER_1970_1971['Article_ID'] = AER_1970_1971['Article_ID'].astype('int')
mask_screened = AER_1970_1971['Screened'].isin(['y'])
AER_1970_1971 = AER_1970_1971[mask_screened]
print(AER_1970_1971.shape)
AER_1970_1971.head()
# Out:
# (136, 27)
# (136, 27)
#    Unnamed: 0 Journal_Name  Authors_count     Authors_list  \
# 0           0          AER            1.0  ['Henry Aaron']
# 1           1          NaN            NaN              NaN
# 2           2          NaN            NaN              NaN
# 3           3          NaN            NaN              NaN
# 4           4          NaN            NaN              NaN
#
#                               authors  Article_ID content_type  \
# 0                         Henry Aaron     1818280      Article
# 1                       W. Lee Hansen     1815825          NaN
# 2          R. Radner and L. S. Miller     1815824          NaN
# 3  Bela Balassa and Trent J. Bertrand     1815822          NaN
# 4                   Richard D. Portes     1815821          NaN
#
#                              stable_url  year_master Ref_type  ...  \
# 0  https://www.jstor.org/stable/1818280         1970    found  ...
# 1                                   NaN         1970      NaN  ...
# ...

# %%
AER_1940_1969.rename(columns={"ref_string_found": "ref_string", "ref_string_clean_found": "ref_string_clean1"}, inplace= True)
AER_1940_1969['1_Auth_affs_4'] = ""
AER_1940_1969['2_Auth_affs_4'] = ""
AER_1940_1969['3_Auth_affs_1'] = ""
AER_1940_1969['3_Auth_affs_2'] = ""
AER_1940_1969['3_Auth_affs_3'] = ""
AER_1940_1969['3_Auth_affs_4'] = ""
AER_1940_1969['4_Auth_affs_1'] = ""
AER_1940_1969['4_Auth_affs_2'] = ""
AER_1940_1969['4_Auth_affs_3'] = ""
AER_1940_1969['5_Auth_affs_0'] = ""
AER_1940_1969['6_Auth_affs_0'] = ""
AER_1940_1969['7_Auth_affs_0'] = ""
print(AER_1940_1969.shape)


AER_1940_1969 = AER_1940_1969[['Journal_Name' ,'Authors_count', 'Authors_list', 'authors', 'Article_ID', 'content_type',
'stable_url', 'year_master', 'Ref_type' ,
'ref_string', 'ref_string_clean1', 'Screened', 'Manual',
'0_Auth_affs_0', '0_Auth_affs_1', '0_Auth_affs_2', '0_Auth_affs_3', '0_Auth_affs_4', 
'1_Auth_affs_0' , '1_Auth_affs_1', '1_Auth_affs_2', '1_Auth_affs_3', '1_Auth_affs_4',
'2_Auth_affs_0', '2_Auth_affs_1', '2_Auth_affs_2', '2_Auth_affs_3', '2_Auth_affs_4',
'3_Auth_affs_0', '3_Auth_affs_1', '3_Auth_affs_2', '3_Auth_affs_3', '3_Auth_affs_4',
'4_Auth_affs_0', '4_Auth_affs_1', '4_Auth_affs_2' , '4_Auth_affs_3',
'5_Auth_affs_0',
'6_Auth_affs_0','7_Auth_affs_0']]

#AER_1970_1971
AER_1970_1971['0_Auth_affs_4'] = ""
AER_1970_1971['1_Auth_affs_4'] = ""
AER_1970_1971['2_Auth_affs_2'] = ""
AER_1970_1971['2_Auth_affs_3'] = ""
AER_1970_1971['2_Auth_affs_4'] = ""
AER_1970_1971['3_Auth_affs_0'] = ""
AER_1970_1971['3_Auth_affs_1'] = ""
AER_1970_1971['3_Auth_affs_2'] = ""
AER_1970_1971['3_Auth_affs_3'] = ""
AER_1970_1971['3_Auth_affs_4'] = ""
AER_1970_1971['4_Auth_affs_0'] = ""
AER_1970_1971['4_Auth_affs_1'] = ""
AER_1970_1971['4_Auth_affs_2'] = ""
AER_1970_1971['4_Auth_affs_3'] = ""
AER_1970_1971['5_Auth_affs_0'] = ""
AER_1970_1971['6_Auth_affs_0'] = ""
AER_1970_1971['7_Auth_affs_0'] = ""
print(AER_1970_1971.shape)

AER_1970_1971 = AER_1970_1971[['Journal_Name' ,'Authors_count', 'Authors_list', 'authors', 'Article_ID', 'content_type',
'stable_url', 'year_master', 'Ref_type' ,
'ref_string', 'ref_string_clean1', 'Screened', 'Manual',
'0_Auth_affs_0', '0_Auth_affs_1', '0_Auth_affs_2', '0_Auth_affs_3', '0_Auth_affs_4', 
'1_Auth_affs_0' , '1_Auth_affs_1', '1_Auth_affs_2', '1_Auth_affs_3', '1_Auth_affs_4',
'2_Auth_affs_0', '2_Auth_affs_1', '2_Auth_affs_2', '2_Auth_affs_3', '2_Auth_affs_4',
'3_Auth_affs_0', '3_Auth_affs_1', '3_Auth_affs_2', '3_Auth_affs_3', '3_Auth_affs_4',
'4_Auth_affs_0', '4_Auth_affs_1', '4_Auth_affs_2' , '4_Auth_affs_3',
'5_Auth_affs_0',
'6_Auth_affs_0','7_Auth_affs_0']]

#AER_1971_1999_1_author
AER_1971_1999_1_author['1_Auth_affs_1'] = ""
AER_1971_1999_1_author['1_Auth_affs_2'] = ""
AER_1971_1999_1_author['1_Auth_affs_3'] = ""
AER_1971_1999_1_author['1_Auth_affs_4'] = ""
AER_1971_1999_1_author['2_Auth_affs_1'] = ""
AER_1971_1999_1_author['2_Auth_affs_2'] = ""
AER_1971_1999_1_author['2_Auth_affs_3'] = ""
AER_1971_1999_1_author['2_Auth_affs_4'] = ""
AER_1971_1999_1_author['3_Auth_affs_1'] = ""
AER_1971_1999_1_author['3_Auth_affs_2'] = ""
AER_1971_1999_1_author['3_Auth_affs_3'] = ""
AER_1971_1999_1_author['3_Auth_affs_4'] = ""
AER_1971_1999_1_author['4_Auth_affs_1'] = ""
AER_1971_1999_1_author['4_Auth_affs_2'] = ""
AER_1971_1999_1_author['4_Auth_affs_3'] = ""
AER_1971_1999_1_author['6_Auth_affs_0'] = ""
AER_1971_1999_1_author['7_Auth_affs_0'] = ""
print(AER_1971_1999_1_author.shape)

AER_1971_1999_1_author = AER_1971_1999_1_author[['Journal_Name' ,'Authors_count', 'Authors_list', 'authors', 'Article_ID', 'content_type',
'stable_url', 'year_master', 'Ref_type' ,
'ref_string', 'ref_string_clean1', 'Screened', 'Manual',
'0_Auth_affs_0', '0_Auth_affs_1', '0_Auth_affs_2', '0_Auth_affs_3', '0_Auth_affs_4', 
'1_Auth_affs_0' , '1_Auth_affs_1', '1_Auth_affs_2', '1_Auth_affs_3', '1_Auth_affs_4',
'2_Auth_affs_0', '2_Auth_affs_1', '2_Auth_affs_2', '2_Auth_affs_3', '2_Auth_affs_4',
'3_Auth_affs_0', '3_Auth_affs_1', '3_Auth_affs_2', '3_Auth_affs_3', '3_Auth_affs_4',
'4_Auth_affs_0', '4_Auth_affs_1', '4_Auth_affs_2' , '4_Auth_affs_3',
'5_Auth_affs_0',
'6_Auth_affs_0','7_Auth_affs_0']]

#AER_1971_1999_2_authors
AER_1971_1999_2_authors['2_Auth_affs_0'] = ""
AER_1971_1999_2_authors['2_Auth_affs_1'] = ""
AER_1971_1999_2_authors['2_Auth_affs_2'] = ""
AER_1971_1999_2_authors['2_Auth_affs_3'] = ""
AER_1971_1999_2_authors['2_Auth_affs_4'] = ""
AER_1971_1999_2_authors['3_Auth_affs_0'] = ""
AER_1971_1999_2_authors['3_Auth_affs_1'] = ""
AER_1971_1999_2_authors['3_Auth_affs_2'] = ""
AER_1971_1999_2_authors['3_Auth_affs_3'] = ""
AER_1971_1999_2_authors['3_Auth_affs_4'] = ""
AER_1971_1999_2_authors['3_Auth_affs_0'] = ""
AER_1971_1999_2_authors['4_Auth_affs_0'] = ""
AER_1971_1999_2_authors['4_Auth_affs_1'] = ""
AER_1971_1999_2_authors['4_Auth_affs_2'] = ""
AER_1971_1999_2_authors['4_Auth_affs_3'] = ""
AER_1971_1999_2_authors['5_Auth_affs_0'] = ""
AER_1971_1999_2_authors['6_Auth_affs_0'] = ""
AER_1971_1999_2_authors['7_Auth_affs_0'] = ""
print(AER_1971_1999_2_authors.shape)

AER_1971_1999_2_authors = AER_1971_1999_2_authors[['Journal_Name' ,'Authors_count', 'Authors_list', 'authors', 'Article_ID', 'content_type',
'stable_url', 'year_master', 'Ref_type' ,
'ref_string', 'ref_string_clean1', 'Screened', 'Manual',
'0_Auth_affs_0', '0_Auth_affs_1', '0_Auth_affs_2', '0_Auth_affs_3', '0_Auth_affs_4', 
'1_Auth_affs_0' , '1_Auth_affs_1', '1_Auth_affs_2', '1_Auth_affs_3', '1_Auth_affs_4',
'2_Auth_affs_0', '2_Auth_affs_1', '2_Auth_affs_2', '2_Auth_affs_3', '2_Auth_affs_4',
'3_Auth_affs_0', '3_Auth_affs_1', '3_Auth_affs_2', '3_Auth_affs_3', '3_Auth_affs_4',
'4_Auth_affs_0', '4_Auth_affs_1', '4_Auth_affs_2' , '4_Auth_affs_3',
'5_Auth_affs_0',
'6_Auth_affs_0','7_Auth_affs_0']]

#AER_1971_1999_3_authors
#AER_1971_1999_3_authors['5_Auth_affs_0'] = ""
#AER_1971_1999_3_authors['6_Auth_affs_0'] = ""
print(AER_1971_1999_3_authors.shape)

AER_1971_1999_3_authors = AER_1971_1999_3_authors[['Journal_Name' ,'Authors_count', 'Authors_list', 'authors', 'Article_ID', 'content_type',
'stable_url', 'year_master', 'Ref_type' ,
'ref_string', 'ref_string_clean1', 'Screened', 'Manual',
'0_Auth_affs_0', '0_Auth_affs_1', '0_Auth_affs_2', '0_Auth_affs_3', '0_Auth_affs_4', 
'1_Auth_affs_0' , '1_Auth_affs_1', '1_Auth_affs_2', '1_Auth_affs_3', '1_Auth_affs_4',
'2_Auth_affs_0', '2_Auth_affs_1', '2_Auth_affs_2', '2_Auth_affs_3', '2_Auth_affs_4',
'3_Auth_affs_0', '3_Auth_affs_1', '3_Auth_affs_2', '3_Auth_affs_3', '3_Auth_affs_4',
'4_Auth_affs_0', '4_Auth_affs_1', '4_Auth_affs_2' , '4_Auth_affs_3',
'5_Auth_affs_0',
'6_Auth_affs_0','7_Auth_affs_0']]

#AER_2000_2010_1_author
AER_2000_2010_1_author['4_Auth_affs_2'] = ""
AER_2000_2010_1_author['4_Auth_affs_3'] = ""
AER_2000_2010_1_author['5_Auth_affs_0'] = ""
AER_2000_2010_1_author['6_Auth_affs_0'] = ""
AER_2000_2010_1_author['7_Auth_affs_0'] = ""
print(AER_2000_2010_1_author.shape)

AER_2000_2010_1_author = AER_2000_2010_1_author[['Journal_Name' ,'Authors_count', 'Authors_list', 'authors', 'Article_ID', 'content_type',
'stable_url', 'year_master', 'Ref_type' ,
'ref_string', 'ref_string_clean1', 'Screened', 'Manual',
'0_Auth_affs_0', '0_Auth_affs_1', '0_Auth_affs_2', '0_Auth_affs_3', '0_Auth_affs_4', 
'1_Auth_affs_0' , '1_Auth_affs_1', '1_Auth_affs_2', '1_Auth_affs_3', '1_Auth_affs_4',
'2_Auth_affs_0', '2_Auth_affs_1', '2_Auth_affs_2', '2_Auth_affs_3', '2_Auth_affs_4',
'3_Auth_affs_0', '3_Auth_affs_1', '3_Auth_affs_2', '3_Auth_affs_3', '3_Auth_affs_4',
'4_Auth_affs_0', '4_Auth_affs_1', '4_Auth_affs_2' , '4_Auth_affs_3',
'5_Auth_affs_0',
'6_Auth_affs_0','7_Auth_affs_0']]

#AER_2000_2010_2_3_authors	
print(AER_2000_2010_2_3_authors.shape)
AER_2000_2010_2_3_authors['7_Auth_affs_0'] = ""

AER_2000_2010_2_3_authors = AER_2000_2010_2_3_authors[['Journal_Name' ,'Authors_count', 'Authors_list', 'authors', 'Article_ID', 'content_type',
'stable_url', 'year_master', 'Ref_type' ,
'ref_string', 'ref_string_clean1', 'Screened', 'Manual',
'0_Auth_affs_0', '0_Auth_affs_1', '0_Auth_affs_2', '0_Auth_affs_3', '0_Auth_affs_4', 
'1_Auth_affs_0' , '1_Auth_affs_1', '1_Auth_affs_2', '1_Auth_affs_3', '1_Auth_affs_4',
'2_Auth_affs_0', '2_Auth_affs_1', '2_Auth_affs_2', '2_Auth_affs_3', '2_Auth_affs_4',
'3_Auth_affs_0', '3_Auth_affs_1', '3_Auth_affs_2', '3_Auth_affs_3', '3_Auth_affs_4',
'4_Auth_affs_0', '4_Auth_affs_1', '4_Auth_affs_2' , '4_Auth_affs_3',
'5_Auth_affs_0',
'6_Auth_affs_0','7_Auth_affs_0']]
# Out:
# (846, 48)
# (136, 44)
# (2748, 41)
# (1478, 44)
# (369, 45)
# (603, 45)
# (1389, 44)

# %%
AER_Merge_base = pd.concat([AER_1940_1969, AER_1970_1971, AER_1971_1999_1_author, AER_1971_1999_2_authors, AER_1971_1999_3_authors, AER_2000_2010_1_author, AER_2000_2010_2_3_authors])

# %%
# Merging the masterfile onto the new melted file to get additional data
AER_Merged = AER_master_condenced.merge(AER_Merge_base, how = 'left', on = 'Article_ID')

# %%
# Excel output to get an overview of the data
AER_Merged.head
AER_Merged.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/3_consolidation/AER/AER_Merged.xlsx')
