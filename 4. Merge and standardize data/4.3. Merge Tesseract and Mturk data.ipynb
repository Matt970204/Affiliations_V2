# %% [markdown]
# # Standardizing the data from Mturk
# ## Inputs
# AER, JPE, QJE, RES Tesseract affiliation files
#
# ECTA cleaned file
#
# Mturk standardized file
#
# ## Outputs
# Master file with all data merged on it

# %%
#RES
import pandas as pd
RES = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/4.%20Merge%20and%20standardize%20data/4.A.%20Manually%20cleaned%20and%20checked%20data%20created%20from%202./RES_affiliations.xlsx")

#RES = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/Consolidation/Finalized/RES_affiliations.xlsx', 'Affiliations')

# Checks the number of missing author 0 aff 0
RES_missing = RES['0_author_affs_consolidated_0'].isnull().sum()
print("RES Missing", RES_missing)
print(RES.shape)
RES.head()
# Out:
# RES Missing 242
# (2609, 48)
#    Unnamed: 0  Article_ID  year_master            authors content_type_master  \
# 0           0     2967475         1940    S. S. Alexander             Article
# 1           1     2967408         1940       J. C. R. Dow             Article
# 2           2     2967408         1940       J. C. R. Dow             Article
# 3           3     2967405         1940  M. Bronfenbrenner             Article
# 4           4     2967406         1940       J. C. R. Dow             Article
#
#   Journal_Name  Authors_count           Authors_list content_type  \
# 0          RES            1.0    ['S. S. Alexander']      Article
# 1          RES            1.0       ['J. C. R. Dow']      Article
# 2          RES            1.0       ['J. C. R. Dow']      Article
# 3          RES            1.0  ['M. Bronfenbrenner']      Article
# 4          RES            1.0       ['J. C. R. Dow']      Article
#
#                              stable_url  ... 5_author_affs  \
# ...

# %%
#QJE
QJE = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/4.%20Merge%20and%20standardize%20data/4.A.%20Manually%20cleaned%20and%20checked%20data%20created%20from%202./QJE_affiliations.xlsx")
#QJE = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/Consolidation/Finalized/QJE_affiliations.xlsx', 'Affiliations')

# Checks the number of missing author 0 aff 0
QJE_missing = QJE['0_author_affs_consolidated_0'].isnull().sum()
print("QJE missing ", QJE_missing)
print(QJE.shape)
print(QJE.head())

# Correcting the naming of the manual column for when scopus was used
for i in range(len(QJE)):
    if pd.isna(QJE.iloc[i]['Manual']) and pd.notnull(QJE.iloc[i]['Scopus']):
        QJE.loc[i,'Manual'] = QJE.loc[i,'Scopus']

# Send the data to excel
#QJE.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/3_consolidation/Mturk/QJE_scopus_merge.xlsx')
# Out:
# QJE missing  118
# (2890, 62)
#    Unnamed: 0.2  Unnamed: 0.1  Article_ID  year_master                authors  \
# 0             0             0     1883343         1940      Wilfred Malenbaum
# 1             1             2     1883336         1940           A. P. Lerner
# 2             2             3     1883335         1940          Fritz Machlup
# 3             3             4     1883334         1940  Bennett S. White, Jr.
# 4             4             5     1883333         1940  Bennett S. White, Jr.
#
#   content_type_master  Unnamed: 0 Journal_Name  Authors_count Authors_list  \
# 0             Article         NaN          NaN            NaN          NaN
# 1             Article         NaN          NaN            NaN          NaN
# 2             Article         NaN          NaN            NaN          NaN
# 3             Article         NaN          NaN            NaN          NaN
# 4             Article         NaN          NaN            NaN          NaN
#
# ...

# %%
#JPE
JPE = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/4.%20Merge%20and%20standardize%20data/4.A.%20Manually%20cleaned%20and%20checked%20data%20created%20from%202./JPE_affiliations.xlsx")
#JPE = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/Consolidation/Finalized/JPE_affiliations.xlsx', 'Affiliations')

# Checks the number of missing author 0 aff 0
print(JPE['0_author_affs_consolidated_0'].isnull().sum())
print(JPE.shape)
print(JPE.head())
# Out:
# 37
# (3823, 38)
#    Unnamed: 0 Journal_Name  Authors_count  \
# 0           0          JPE              1
# 1           1          JPE              1
# 2           2          JPE              2
# 3           3          JPE              1
# 4           4          JPE              1
#
#                               Authors_list  Article_ID content_type  \
# 0                         ['Gerhard Colm']     1825913      Article
# 1                        ['Jules Backman']     1825487      Article
# 2  ['William Fellner', ' Howard S. Ellis']     1825486      Article
# 3                        ['Harvey Pinney']     1825485      Article
# 4                    ['George J. Stigler']     1825484      Article
#
#                              stable_url Ref_type  \
# 0  https://www.jstor.org/stable/1825913    found
# 1  https://www.jstor.org/stable/1825487    found
# 2  https://www.jstor.org/stable/1825486    found
# 3  https://www.jstor.org/stable/1825485      raw
# ...

# %%
#AER
AER = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/4.%20Merge%20and%20standardize%20data/4.A.%20Manually%20cleaned%20and%20checked%20data%20created%20from%202./AER_Merged.xlsx")
#AER = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/3_consolidation/AER/AER_Merged.xlsx') 
print(AER.shape)
AER_missing = AER['0_Auth_affs_0'].isna().sum()
print(AER_missing)
AER.head()
# Out:
# (9340, 41)
# 1949
#    Unnamed: 0  Article_ID Journal_Name  Authors_count  \
# 0           0    41038751          AER            1.0
# 1           1    41038752          AER            3.0
# 2           2    41038753          AER            2.0
# 3           3    41038754          AER            2.0
# 4           4    41038755          AER            2.0
#
#                                      Authors_list  \
# 0                          ['Enrique G. Mendoza']
# 1  ['Atif Mian', 'Amir Sufi', 'Francesco Trebbi']
# 2   ['Marc-Andreas Muendler', 'Sascha O. Becker']
# 3                  ['Diego Comin', 'Bart Hobijn']
# 4                  ['Yann Algan', 'Pierre Cahuc']
#
#                                       authors content_type  \
# 0                          Enrique G. Mendoza      Article
# 1   Atif Mian, Amir Sufi and Francesco Trebbi      Article
# 2  Marc-Andreas Muendler and Sascha O. Becker      Article
# 3                 Diego Comin and Bart Hobijn      Article
# ...

# %%
#ECTA

ECTA = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/4.%20Merge%20and%20standardize%20data/4.B.%20Data%20created%20in%204./4.2./ECTA_clean.xlsx")
#ECTA = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/3_consolidation/ECTA/ECTA_clean.xlsx')
print(ECTA.shape)
print(ECTA['0_Auth_affs_0'].isna().sum())
ECTA.head()
# Out:
# (4120, 41)
# 31
#    Unnamed: 0  Journal_Name  Authors_count  Authors_list  \
# 0           0  ECONOMETRICA              1           NaN
# 1           1  ECONOMETRICA              3           NaN
# 2           2  ECONOMETRICA              1           NaN
# 3           3  ECONOMETRICA              2           NaN
# 4           4  ECONOMETRICA              4           NaN
#
#                                              authors  Article_ID content_type  \
# 0                                           A. Pakes    40928462      Article
# 1  Veronica Guerrieri, Robert Shimer And Randall ...    40928463      Article
# 2                                       Melissa Dell    40928464      Article
# 3         Alejandro M. Manelli And Daniel R. Vincent    40928465      Article
# 4  Simon Grant, Atsushi Kajii, Ben Polak And Zvi ...    40928466      Article
#
#                               stable_url  year_master  Ref_type  ...  \
# ...

# %%
#Mturk
Mturk = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/4.%20Merge%20and%20standardize%20data/4.B.%20Data%20created%20in%204./4.2./Mturk_clean.xlsx")

#Mturk = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/3_consolidation/Mturk/Mturk_clean.xlsx') 
print(Mturk.shape)
Mturk.head()
# Out:
# (6377, 31)
#    Unnamed: 0  Article_ID Journal_Mturk Source  \
# 0           0     1906861          ECTA  MTURK
# 1           1     1907317          ECTA  MTURK
# 2           2     1909206          ECTA  MTURK
# 3           3     1906862          ECTA  MTURK
# 4           4     1907318          ECTA  MTURK
#
#                              0_Auth_affs_0_Mturk 0_Auth_affs_1_Mturk  \
# 0        United States Department Of Agriculture                 NaN
# 1  L'Agence Interalliée Des Réparations (France)                 NaN
# 2                          University Of Louvain                 NaN
# 3      Social Security Board,  Washington, D. C.                 NaN
# 4                          University Of Chicago                 NaN
#
#   0_Auth_affs_2_Mturk 0_Auth_affs_3_Mturk  0_Auth_affs_4_Mturk  \
# 0                 NaN                 NaN                  NaN
# 1                 NaN                 NaN                  NaN
# ...

# %%
# Merging the Mturk data onto AER
AER_mturk = AER.merge(Mturk, how = 'left', on = 'Article_ID')
print(AER_mturk.shape)
#print(AER_mturk['0_Auth_affs_0'].isna().sum())

# Wrting the Mturk data into the correct columns for AER
for i in range(len(AER_mturk)):
    #print(AER_mturk.iloc[i]['Article_ID'])
    #print(AER_mturk.loc[i,'0_Auth_affs_0'])

# If the manaul column is empty write the souce column which is from mturk
    if pd.isna(AER_mturk.iloc[i]['Manual']):
        AER_mturk.loc[i,'Manual'] = AER_mturk.loc[i,'Source']

# If the 0 auth affs 0 is empty then write the line from mturk into the data 
    if pd.isna(AER_mturk.iloc[i]['0_Auth_affs_0']):
        #print('n')
        AER_mturk.loc[i,'0_Auth_affs_0'] = AER_mturk.loc[i,'0_Auth_affs_0_Mturk']
        AER_mturk.loc[i,'0_Auth_affs_1'] = AER_mturk.loc[i,'0_Auth_affs_1_Mturk']
        AER_mturk.loc[i,'0_Auth_affs_2'] = AER_mturk.loc[i,'0_Auth_affs_2_Mturk']
        AER_mturk.loc[i,'0_Auth_affs_3'] = AER_mturk.loc[i,'0_Auth_affs_3_Mturk']
        AER_mturk.loc[i,'0_Auth_affs_4'] = AER_mturk.loc[i,'0_Auth_affs_4_Mturk']

        AER_mturk.loc[i,'1_Auth_affs_0'] = AER_mturk.loc[i,'1_Auth_affs_0_Mturk']
        AER_mturk.loc[i,'1_Auth_affs_1'] = AER_mturk.loc[i,'1_Auth_affs_1_Mturk']
        AER_mturk.loc[i,'1_Auth_affs_2'] = AER_mturk.loc[i,'1_Auth_affs_2_Mturk']
        AER_mturk.loc[i,'1_Auth_affs_3'] = AER_mturk.loc[i,'1_Auth_affs_3_Mturk']
        AER_mturk.loc[i,'1_Auth_affs_4'] = AER_mturk.loc[i,'1_Auth_affs_4_Mturk']

        AER_mturk.loc[i,'2_Auth_affs_0'] = AER_mturk.loc[i,'2_Auth_affs_0_Mturk']
        AER_mturk.loc[i,'2_Auth_affs_1'] = AER_mturk.loc[i,'2_Auth_affs_1_Mturk']
        AER_mturk.loc[i,'2_Auth_affs_2'] = AER_mturk.loc[i,'2_Auth_affs_2_Mturk']
        AER_mturk.loc[i,'2_Auth_affs_3'] = AER_mturk.loc[i,'2_Auth_affs_3_Mturk']
        AER_mturk.loc[i,'2_Auth_affs_4'] = AER_mturk.loc[i,'2_Auth_affs_4_Mturk']


        AER_mturk.loc[i,'3_Auth_affs_0'] = AER_mturk.loc[i,'3_Auth_affs_0_Mturk']
        AER_mturk.loc[i,'3_Auth_affs_1'] = AER_mturk.loc[i,'3_Auth_affs_1_Mturk']
        AER_mturk.loc[i,'3_Auth_affs_2'] = AER_mturk.loc[i,'3_Auth_affs_2_Mturk']
        AER_mturk.loc[i,'3_Auth_affs_3'] = AER_mturk.loc[i,'3_Auth_affs_3_Mturk']
        AER_mturk.loc[i,'3_Auth_affs_4'] = AER_mturk.loc[i,'3_Auth_affs_4_Mturk']

        AER_mturk.loc[i,'4_Auth_affs_0'] = AER_mturk.loc[i,'4_Auth_affs_0_Mturk']
        AER_mturk.loc[i,'4_Auth_affs_1'] = AER_mturk.loc[i,'4_Auth_affs_1_Mturk']
        AER_mturk.loc[i,'4_Auth_affs_2'] = AER_mturk.loc[i,'4_Auth_affs_2_Mturk']
        AER_mturk.loc[i,'4_Auth_affs_3'] = AER_mturk.loc[i,'4_Auth_affs_3_Mturk']

        AER_mturk.loc[i,'5_Auth_affs_0'] = AER_mturk.loc[i,'5_Auth_affs_0_Mturk']
        AER_mturk.loc[i,'6_Auth_affs_0'] = AER_mturk.loc[i,'5_Auth_affs_0_Mturk']
        AER_mturk.loc[i,'7_Auth_affs_0'] = AER_mturk.loc[i,'7_Auth_affs_0_Mturk']

AER_mturk_missing = AER_mturk['0_Auth_affs_0'].isna().sum()
print("AER initally missing", AER_missing ,"now missing", AER_mturk_missing )
#AER_mturk.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/3_consolidation/Mturk/AER_mturk.xlsx')
# Out:
# (9340, 71)
# AER initally missing 1949 now missign 114

# %%
# Merging the masterfile onto the new melted file to get additional data
RES_mturk = RES.merge(Mturk, how = 'left', on = 'Article_ID')

RES_mturk.rename(columns={"0_author_affs_consolidated_0": "0_Auth_affs_0", "0_author_affs_consolidated_1": "0_Auth_affs_1",
                    "0_author_affs_consolidated_2": "0_Auth_affs_2", "0_author_affs_consolidated_3": "0_Auth_affs_3",
                    "1_author_affs_consolidated_0": "1_Auth_affs_0", "1_author_affs_consolidated_1": "1_Auth_affs_1",
                    "2_author_affs_consolidated_0": "2_Auth_affs_0", "2_author_affs_consolidated_1": "2_Auth_affs_1",
                    "2_author_affs_consolidated_2": "2_Auth_affs_2",
                    "3_author_affs_consolidated_0": "3_Auth_affs_0", "3_author_affs_consolidated_1": "3_Auth_affs_1",
                    "4_author_affs_consolidated_0": "4_Auth_affs_0",
                    "5_author_affs_consolidated": "5_Auth_affs_0",}, inplace= True)

RES_mturk['0_Auth_affs_4'] = ""
RES_mturk['1_Auth_affs_2'] = ""
RES_mturk['1_Auth_affs_3'] = ""
RES_mturk['1_Auth_affs_4'] = ""
RES_mturk['2_Auth_affs_3'] = ""
RES_mturk['2_Auth_affs_4'] = ""
RES_mturk['3_Auth_affs_2'] = ""
RES_mturk['3_Auth_affs_3'] = ""
RES_mturk['3_Auth_affs_4'] = ""

RES_mturk['4_Auth_affs_1'] = ""
RES_mturk['4_Auth_affs_2'] = ""
RES_mturk['4_Auth_affs_3'] = ""
RES_mturk['6_Auth_affs_0'] = ""
RES_mturk['7_Auth_affs_0'] = ""

# Merging the masterfile onto AER for Mturk data
for i in range(len(RES_mturk)):
#for i in range(2,4):
   # print(RES_mturk.iloc[i]['Article_ID'])
    #print(RES_mturk.loc[i,'0_Auth_affs_0'])

    if pd.isna(RES_mturk.iloc[i]['Manual']):
        RES_mturk.loc[i,'Manual'] = RES_mturk.loc[i,'Source']
    if pd.isna(RES_mturk.iloc[i]['0_Auth_affs_0']):
        #print('n')
        
        RES_mturk.loc[i,'0_Auth_affs_0'] = RES_mturk.loc[i,'0_Auth_affs_0_Mturk']
        RES_mturk.loc[i,'0_Auth_affs_1'] = RES_mturk.loc[i,'0_Auth_affs_1_Mturk']
        AER_mturk.loc[i,'0_Auth_affs_2'] = RES_mturk.loc[i,'0_Auth_affs_2_Mturk']
        RES_mturk.loc[i,'0_Auth_affs_3'] = RES_mturk.loc[i,'0_Auth_affs_3_Mturk']
        RES_mturk.loc[i,'0_Auth_affs_4'] = RES_mturk.loc[i,'0_Auth_affs_4_Mturk']

        RES_mturk.loc[i,'1_Auth_affs_0'] = RES_mturk.loc[i,'1_Auth_affs_0_Mturk']
        RES_mturk.loc[i,'1_Auth_affs_1'] = RES_mturk.loc[i,'1_Auth_affs_1_Mturk']
        RES_mturk.loc[i,'1_Auth_affs_2'] = RES_mturk.loc[i,'1_Auth_affs_2_Mturk']
        RES_mturk.loc[i,'1_Auth_affs_3'] = RES_mturk.loc[i,'1_Auth_affs_3_Mturk']
        RES_mturk.loc[i,'1_Auth_affs_4'] = RES_mturk.loc[i,'1_Auth_affs_4_Mturk']

        RES_mturk.loc[i,'2_Auth_affs_0'] = RES_mturk.loc[i,'2_Auth_affs_0_Mturk']
        RES_mturk.loc[i,'2_Auth_affs_1'] = RES_mturk.loc[i,'2_Auth_affs_1_Mturk']
        RES_mturk.loc[i,'2_Auth_affs_2'] = RES_mturk.loc[i,'2_Auth_affs_2_Mturk']
        RES_mturk.loc[i,'2_Auth_affs_3'] = RES_mturk.loc[i,'2_Auth_affs_3_Mturk']
        RES_mturk.loc[i,'2_Auth_affs_4'] = RES_mturk.loc[i,'2_Auth_affs_4_Mturk']


        RES_mturk.loc[i,'3_Auth_affs_0'] = RES_mturk.loc[i,'3_Auth_affs_0_Mturk']
        RES_mturk.loc[i,'3_Auth_affs_1'] = RES_mturk.loc[i,'3_Auth_affs_1_Mturk']
        RES_mturk.loc[i,'3_Auth_affs_2'] = RES_mturk.loc[i,'3_Auth_affs_2_Mturk']
        RES_mturk.loc[i,'3_Auth_affs_3'] = RES_mturk.loc[i,'3_Auth_affs_3_Mturk']
        RES_mturk.loc[i,'3_Auth_affs_4'] = RES_mturk.loc[i,'3_Auth_affs_4_Mturk']

        RES_mturk.loc[i,'4_Auth_affs_0'] = RES_mturk.loc[i,'4_Auth_affs_0_Mturk']
        RES_mturk.loc[i,'4_Auth_affs_1'] = RES_mturk.loc[i,'4_Auth_affs_1_Mturk']
        RES_mturk.loc[i,'4_Auth_affs_2'] = RES_mturk.loc[i,'4_Auth_affs_2_Mturk']
        RES_mturk.loc[i,'4_Auth_affs_3'] = RES_mturk.loc[i,'4_Auth_affs_3_Mturk']

        RES_mturk.loc[i,'5_Auth_affs_0'] = RES_mturk.loc[i,'5_Auth_affs_0_Mturk']
        RES_mturk.loc[i,'6_Auth_affs_0'] = RES_mturk.loc[i,'5_Auth_affs_0_Mturk']
        RES_mturk.loc[i,'7_Auth_affs_0'] = RES_mturk.loc[i,'7_Auth_affs_0_Mturk']

RES_mturk_missing = RES_mturk['0_Auth_affs_0'].isna().sum()
print("RES initally missing", RES_missing ,"now missing", RES_mturk_missing )
#RES_mturk.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/3_consolidation/Mturk/RES_mturk.xlsx')
# Out:
# RES initally missing 242 now missing 69

# %%
# Merging the masterfile onto the new melted file to get additional data
QJE_mturk = QJE.merge(Mturk, how = 'left', on = 'Article_ID')

QJE_mturk.rename(columns={"ref_string_found": "ref_string", "ref_string_found_clean": "ref_string_clean1",
                    "0_author_affs_consolidated_0": "0_Auth_affs_0", "0_author_affs_consolidated_1": "0_Auth_affs_1",
                    "0_author_affs_consolidated_2": "0_Auth_affs_2", "0_author_affs_consolidated_3": "0_Auth_affs_3",
                    "0_author_affs_consolidated_4": "0_Auth_affs_4",
                    "1_author_affs_consolidated_0": "1_Auth_affs_0", "1_author_affs_consolidated_1": "1_Auth_affs_1",
                    "1_author_affs_consolidated_2": "1_Auth_affs_2", "1_author_affs_consolidated_3": "1_Auth_affs_3",
                    "2_author_affs_consolidated_0": "2_Auth_affs_0", "2_author_affs_consolidated_1": "2_Auth_affs_1",
                    "2_author_affs_consolidated_2": "2_Auth_affs_2", "2_author_affs_consolidated_3": "2_Auth_affs_3",
                    "3_author_affs_consolidated_0": "3_Auth_affs_0", "3_author_affs_consolidated_1": "3_Auth_affs_1",
                    "3_author_affs_consolidated_2": "3_Auth_affs_2",
                    "4_author_affs_consolidated_0": "4_Auth_affs_0",
                    "5_author_affs_consolidated": "5_Auth_affs_0",}, inplace= True)


QJE_mturk['1_Auth_affs_4'] = ""
QJE_mturk['2_Auth_affs_4'] = ""

QJE_mturk['3_Auth_affs_3'] = ""
QJE_mturk['3_Auth_affs_4'] = ""

QJE_mturk['4_Auth_affs_1'] = ""
QJE_mturk['4_Auth_affs_2'] = ""
QJE_mturk['4_Auth_affs_3'] = ""
QJE_mturk['6_Auth_affs_0'] = ""
QJE_mturk['7_Auth_affs_0'] = ""

for i in range(len(QJE_mturk)):
    #print(QJE_mturk.iloc[i]['Article_ID'])
    #print(QJE_mturk.loc[i,'0_Auth_affs_0'])

    if pd.isna(QJE_mturk.iloc[i]['Manual']):
        QJE_mturk.loc[i,'Manual'] = QJE_mturk.loc[i,'Source']

    if pd.isna(QJE_mturk.iloc[i]['0_Auth_affs_0']):
        #print('n')
        QJE_mturk.loc[i,'0_Auth_affs_0'] = QJE_mturk.loc[i,'0_Auth_affs_0_Mturk']
        QJE_mturk.loc[i,'0_Auth_affs_1'] = QJE_mturk.loc[i,'0_Auth_affs_1_Mturk']
        QJE_mturk.loc[i,'0_Auth_affs_2'] = QJE_mturk.loc[i,'0_Auth_affs_2_Mturk']
        QJE_mturk.loc[i,'0_Auth_affs_3'] = QJE_mturk.loc[i,'0_Auth_affs_3_Mturk']
        QJE_mturk.loc[i,'0_Auth_affs_4'] = QJE_mturk.loc[i,'0_Auth_affs_4_Mturk']

        QJE_mturk.loc[i,'1_Auth_affs_0'] = QJE_mturk.loc[i,'1_Auth_affs_0_Mturk']
        QJE_mturk.loc[i,'1_Auth_affs_1'] = QJE_mturk.loc[i,'1_Auth_affs_1_Mturk']
        QJE_mturk.loc[i,'1_Auth_affs_2'] = QJE_mturk.loc[i,'1_Auth_affs_2_Mturk']
        QJE_mturk.loc[i,'1_Auth_affs_3'] = QJE_mturk.loc[i,'1_Auth_affs_3_Mturk']
        QJE_mturk.loc[i,'1_Auth_affs_4'] = QJE_mturk.loc[i,'1_Auth_affs_4_Mturk']

        QJE_mturk.loc[i,'2_Auth_affs_0'] = QJE_mturk.loc[i,'2_Auth_affs_0_Mturk']
        QJE_mturk.loc[i,'2_Auth_affs_1'] = QJE_mturk.loc[i,'2_Auth_affs_1_Mturk']
        QJE_mturk.loc[i,'2_Auth_affs_2'] = QJE_mturk.loc[i,'2_Auth_affs_2_Mturk']
        QJE_mturk.loc[i,'2_Auth_affs_3'] = QJE_mturk.loc[i,'2_Auth_affs_3_Mturk']
        QJE_mturk.loc[i,'2_Auth_affs_4'] = QJE_mturk.loc[i,'2_Auth_affs_4_Mturk']


        QJE_mturk.loc[i,'3_Auth_affs_0'] = QJE_mturk.loc[i,'3_Auth_affs_0_Mturk']
        QJE_mturk.loc[i,'3_Auth_affs_1'] = QJE_mturk.loc[i,'3_Auth_affs_1_Mturk']
        QJE_mturk.loc[i,'3_Auth_affs_2'] = QJE_mturk.loc[i,'3_Auth_affs_2_Mturk']
        QJE_mturk.loc[i,'3_Auth_affs_3'] = QJE_mturk.loc[i,'3_Auth_affs_3_Mturk']
        QJE_mturk.loc[i,'3_Auth_affs_4'] = QJE_mturk.loc[i,'3_Auth_affs_4_Mturk']

        QJE_mturk.loc[i,'4_Auth_affs_0'] = QJE_mturk.loc[i,'4_Auth_affs_0_Mturk']
        QJE_mturk.loc[i,'4_Auth_affs_1'] = QJE_mturk.loc[i,'4_Auth_affs_1_Mturk']
        QJE_mturk.loc[i,'4_Auth_affs_2'] = QJE_mturk.loc[i,'4_Auth_affs_2_Mturk']
        QJE_mturk.loc[i,'4_Auth_affs_3'] = QJE_mturk.loc[i,'4_Auth_affs_3_Mturk']

        QJE_mturk.loc[i,'5_Auth_affs_0'] = QJE_mturk.loc[i,'5_Auth_affs_0_Mturk']
        QJE_mturk.loc[i,'6_Auth_affs_0'] = QJE_mturk.loc[i,'5_Auth_affs_0_Mturk']
        QJE_mturk.loc[i,'7_Auth_affs_0'] = QJE_mturk.loc[i,'7_Auth_affs_0_Mturk']

QJE_mturk_missing = QJE_mturk['0_Auth_affs_0'].isna().sum()
print("QJE initally missing", RES_missing ,"now missing", QJE_mturk_missing )

#QJE_mturk.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/3_consolidation/Mturk/QJE_mturk.xlsx')
# Out:
# QJE initally missing 242 now missing 29

# %%
print(AER.shape)
AER = AER_mturk.copy()
RES = RES_mturk.copy()
QJE = QJE_mturk.copy()
print(AER.shape)
print(RES.shape)
print(QJE.shape)
# Out:
# (9340, 41)
# (9340, 71)
# (2617, 92)
# (2890, 101)

# %%
# Getting the files into the correct format so they can all be concatinated together

RES.rename(columns={"0_author_affs_consolidated_0": "0_Auth_affs_0", "0_author_affs_consolidated_1": "0_Auth_affs_1",
                    "0_author_affs_consolidated_2": "0_Auth_affs_2", "0_author_affs_consolidated_3": "0_Auth_affs_3",
                    "1_author_affs_consolidated_0": "1_Auth_affs_0", "1_author_affs_consolidated_1": "1_Auth_affs_1",
                    "2_author_affs_consolidated_0": "2_Auth_affs_0", "2_author_affs_consolidated_1": "2_Auth_affs_1",
                    "2_author_affs_consolidated_2": "2_Auth_affs_2",
                    "3_author_affs_consolidated_0": "3_Auth_affs_0", "3_author_affs_consolidated_1": "3_Auth_affs_1",
                    "4_author_affs_consolidated_0": "4_Auth_affs_0",
                    "5_author_affs_consolidated": "5_Auth_affs_0",}, inplace= True)

RES['0_Auth_affs_4'] = ""
RES['1_Auth_affs_2'] = ""
RES['1_Auth_affs_3'] = ""
RES['1_Auth_affs_4'] = ""
RES['2_Auth_affs_3'] = ""
RES['2_Auth_affs_4'] = ""
RES['3_Auth_affs_2'] = ""
RES['3_Auth_affs_3'] = ""
RES['3_Auth_affs_4'] = ""

RES['4_Auth_affs_1'] = ""
RES['4_Auth_affs_2'] = ""
RES['4_Auth_affs_3'] = ""
RES['6_Auth_affs_0'] = ""
RES['7_Auth_affs_0'] = ""

print(RES.shape)

RES = RES[['Journal_Name' ,'Authors_count', 'Authors_list', 'authors', 'Article_ID', 'content_type',
'stable_url', 'year_master', 'Ref_type' ,
'ref_string', 'ref_string_clean1', 'Screened', 'Manual',
'0_Auth_affs_0', '0_Auth_affs_1', '0_Auth_affs_2', '0_Auth_affs_3', '0_Auth_affs_4', 
'1_Auth_affs_0' , '1_Auth_affs_1', '1_Auth_affs_2', '1_Auth_affs_3', '1_Auth_affs_4',
'2_Auth_affs_0', '2_Auth_affs_1', '2_Auth_affs_2', '2_Auth_affs_3', '2_Auth_affs_4',
'3_Auth_affs_0', '3_Auth_affs_1', '3_Auth_affs_2', '3_Auth_affs_3', '3_Auth_affs_4',
'4_Auth_affs_0', '4_Auth_affs_1', '4_Auth_affs_2' , '4_Auth_affs_3',
'5_Auth_affs_0',
'6_Auth_affs_0','7_Auth_affs_0']]

print(RES.shape)

#QJE
QJE.rename(columns={"ref_string_found": "ref_string", "ref_string_found_clean": "ref_string_clean1",
                    "0_author_affs_consolidated_0": "0_Auth_affs_0", "0_author_affs_consolidated_1": "0_Auth_affs_1",
                    "0_author_affs_consolidated_2": "0_Auth_affs_2", "0_author_affs_consolidated_3": "0_Auth_affs_3",
                    "0_author_affs_consolidated_4": "0_Auth_affs_4",
                    "1_author_affs_consolidated_0": "1_Auth_affs_0", "1_author_affs_consolidated_1": "1_Auth_affs_1",
                    "1_author_affs_consolidated_2": "1_Auth_affs_2", "1_author_affs_consolidated_3": "1_Auth_affs_3",
                    "2_author_affs_consolidated_0": "2_Auth_affs_0", "2_author_affs_consolidated_1": "2_Auth_affs_1",
                    "2_author_affs_consolidated_2": "2_Auth_affs_2", "2_author_affs_consolidated_3": "2_Auth_affs_3",
                    "3_author_affs_consolidated_0": "3_Auth_affs_0", "3_author_affs_consolidated_1": "3_Auth_affs_1",
                    "3_author_affs_consolidated_2": "3_Auth_affs_2",
                    "4_author_affs_consolidated_0": "4_Auth_affs_0",
                    "5_author_affs_consolidated": "5_Auth_affs_0",}, inplace= True)


QJE['1_Auth_affs_4'] = ""
QJE['2_Auth_affs_4'] = ""

QJE['3_Auth_affs_3'] = ""
QJE['3_Auth_affs_4'] = ""

QJE['4_Auth_affs_1'] = ""
QJE['4_Auth_affs_2'] = ""
QJE['4_Auth_affs_3'] = ""
QJE['6_Auth_affs_0'] = ""
QJE['7_Auth_affs_0'] = ""

print(QJE.shape)

QJE = QJE[['Journal_Name' ,'Authors_count', 'Authors_list', 'authors', 'Article_ID', 'content_type',
'stable_url', 'year_master', 'Ref_type' ,
'ref_string', 'ref_string_clean1', 'Screened', 'Manual',
'0_Auth_affs_0', '0_Auth_affs_1', '0_Auth_affs_2', '0_Auth_affs_3', '0_Auth_affs_4', 
'1_Auth_affs_0' , '1_Auth_affs_1', '1_Auth_affs_2', '1_Auth_affs_3', '1_Auth_affs_4',
'2_Auth_affs_0', '2_Auth_affs_1', '2_Auth_affs_2', '2_Auth_affs_3', '2_Auth_affs_4',
'3_Auth_affs_0', '3_Auth_affs_1', '3_Auth_affs_2', '3_Auth_affs_3', '3_Auth_affs_4',
'4_Auth_affs_0', '4_Auth_affs_1', '4_Auth_affs_2' , '4_Auth_affs_3',
'5_Auth_affs_0',
'6_Auth_affs_0','7_Auth_affs_0']]

print(QJE.shape)

#JPE
JPE.rename(columns={"year": "year_master","0_author_affs_consolidated_0": "0_Auth_affs_0", "0_author_affs_consolidated_1": "0_Auth_affs_1",
                    "0_author_affs_consolidated_2": "0_Auth_affs_2", 
                    "1_author_affs_consolidated_0": "1_Auth_affs_0", "1_author_affs_consolidated_1": "1_Auth_affs_1",
                    "1_author_affs_consolidated_2": "1_Auth_affs_2",
                    "2_author_affs_consolidated_0": "2_Auth_affs_0", "2_author_affs_consolidated_1": "2_Auth_affs_1",
                    "2_author_affs_consolidated_2": "2_Auth_affs_2",
                    "3_author_affs_consolidated_0": "3_Auth_affs_0", "3_author_affs_consolidated_1": "3_Auth_affs_1",
                    "4_author_affs_consolidated_0": "4_Auth_affs_0",
                    "5_author_affs_consolidated": "5_Auth_affs_0",}, inplace= True)

JPE['authors'] = ""

JPE['0_Auth_affs_3'] = ""
JPE['0_Auth_affs_4'] = ""

JPE['1_Auth_affs_3'] = ""
JPE['1_Auth_affs_4'] = ""
JPE['2_Auth_affs_3'] = ""
JPE['2_Auth_affs_4'] = ""
JPE['3_Auth_affs_2'] = ""
JPE['3_Auth_affs_3'] = ""
JPE['3_Auth_affs_4'] = ""

JPE['4_Auth_affs_1'] = ""
JPE['4_Auth_affs_2'] = ""
JPE['4_Auth_affs_3'] = ""
JPE['6_Auth_affs_0'] = ""
JPE['7_Auth_affs_0'] = ""

print(JPE.shape)

JPE = JPE[['Journal_Name' ,'Authors_count', 'Authors_list', 'authors', 'Article_ID', 'content_type',
'stable_url', 'year_master', 'Ref_type' ,
'ref_string', 'ref_string_clean1', 'Screened', 'Manual',
'0_Auth_affs_0', '0_Auth_affs_1', '0_Auth_affs_2', '0_Auth_affs_3', '0_Auth_affs_4', 
'1_Auth_affs_0' , '1_Auth_affs_1', '1_Auth_affs_2', '1_Auth_affs_3', '1_Auth_affs_4',
'2_Auth_affs_0', '2_Auth_affs_1', '2_Auth_affs_2', '2_Auth_affs_3', '2_Auth_affs_4',
'3_Auth_affs_0', '3_Auth_affs_1', '3_Auth_affs_2', '3_Auth_affs_3', '3_Auth_affs_4',
'4_Auth_affs_0', '4_Auth_affs_1', '4_Auth_affs_2' , '4_Auth_affs_3',
'5_Auth_affs_0',
'6_Auth_affs_0','7_Auth_affs_0']]

#AER
AER = AER[['Journal_Name' ,'Authors_count', 'Authors_list', 'authors', 'Article_ID', 'content_type',
'stable_url', 'year_master', 'Ref_type' ,
'ref_string', 'ref_string_clean1', 'Screened', 'Manual',
'0_Auth_affs_0', '0_Auth_affs_1', '0_Auth_affs_2', '0_Auth_affs_3', '0_Auth_affs_4', 
'1_Auth_affs_0' , '1_Auth_affs_1', '1_Auth_affs_2', '1_Auth_affs_3', '1_Auth_affs_4',
'2_Auth_affs_0', '2_Auth_affs_1', '2_Auth_affs_2', '2_Auth_affs_3', '2_Auth_affs_4',
'3_Auth_affs_0', '3_Auth_affs_1', '3_Auth_affs_2', '3_Auth_affs_3', '3_Auth_affs_4',
'4_Auth_affs_0', '4_Auth_affs_1', '4_Auth_affs_2' , '4_Auth_affs_3',
'5_Auth_affs_0',
'6_Auth_affs_0','7_Auth_affs_0']]

print(AER.shape)
# Out:
# (2617, 92)
# (2617, 40)
# (2890, 101)
# (2890, 40)
# (3823, 53)
# (9340, 40)

# %%
#Concat the files together to form one large dataset
Merged_all = pd.concat([RES, QJE, JPE, AER,ECTA])

# %% [markdown]
# The next section of code will be to add in additional metadata for articles.
# Not all of the files from Mturk and scopus have authors, year and author count yet so this is just to add on that correct data

# %%
# Filling in blanks
#Read in the master sheet
Article_master = pd.read_excel("https://raw.githubusercontent.com/Matt970204/Affiliations_V2/Clean-online-hosted/1.%20Input%20Data/Processed/article_masterlist.xlsx",'article_masterlist')
#Article_master = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/Consolidation/Finalized/article_masterlist.xlsx','article_masterlist')
Article_master_list  = Article_master[['article_id','year','authors','content_type','journal', 'stable_url']]

# %%
# Trimming down the master list to only the needed columns
Article_master_list.rename(columns={"article_id": "Article_ID",
                    "authors": "authors_master", 
                    "content_type": "content_type_master", 
                    "journal": "journal_master",
                    "stable_url": "stable_url_master"}, inplace= True)
print(Article_master_list.columns.values)
# Out:
# ['Article_ID' 'year' 'authors_master' 'content_type_master'
#  'journal_master' 'stable_url_master']
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_57839/240871017.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Article_master_list.rename(columns={"article_id": "Article_ID",

# %%
# Creating a new master list and count of authors
# Also corretcs the issue of Jr being split and counted as an author in original master list
import re

for i in range(len(Article_master_list)):
    print(Article_master_list.iloc[i]['authors_master'])

    if pd.isna(Article_master_list.iloc[i]['authors_master']):
        print("Null")
    else:
        authors = Article_master_list.iloc[i]['authors_master'].strip().title()
        authors_clean = re.sub(', Jr', ' Jr', authors)
        Article_master_list.loc[i,['authors_master']] = authors_clean
        print(Article_master_list.iloc[i]['authors_master'])

        Authors_list =re.split(' And |, ', authors_clean)

        Authors_Count = len(Authors_list)
        Article_master_list.loc[i,['Authors_count_master']] = Authors_Count
        print(Authors_list)
        print(len(Authors_list))
# Out:
# Enrique G. Mendoza
# Enrique G. Mendoza
# ['Enrique G. Mendoza']
# 1
# Atif Mian, Amir Sufi and Francesco Trebbi
# Atif Mian, Amir Sufi And Francesco Trebbi
# ['Atif Mian', 'Amir Sufi', 'Francesco Trebbi']
# 3
# Marc-Andreas Muendler and Sascha O. Becker
# Marc-Andreas Muendler And Sascha O. Becker
# ['Marc-Andreas Muendler', 'Sascha O. Becker']
# 2
# Diego Comin and Bart Hobijn
# Diego Comin And Bart Hobijn
# ['Diego Comin', 'Bart Hobijn']
# 2
# Yann Algan and Pierre Cahuc
# Yann Algan And Pierre Cahuc
# ['Yann Algan', 'Pierre Cahuc']
# 2
# Michael E. Waugh
# Michael E. Waugh
# ['Michael E. Waugh']
# 1
# Christopher Avery and Jonathan Levin
# Christopher Avery And Jonathan Levin
# ['Christopher Avery', 'Jonathan Levin']
# 2
# James E. Anderson and Yoto V. Yotov
# James E. Anderson And Yoto V. Yotov
# ['James E. Anderson', 'Yoto V. Yotov']
# 2
# Brit Grosskopf and Rajiv Sarin
# Brit Grosskopf And Rajiv Sarin
# ['Brit Grosskopf', 'Rajiv Sarin']
# 2
# ...

# %%
# Merging the masterfile onto merged all file so that any missing data can be added in
merged_all_master = Merged_all.merge(Article_master_list, how = 'left', on = 'Article_ID')
print(merged_all_master['Article_ID'].isnull().sum())
print(merged_all_master['Journal_Name'].isnull().sum())
print(merged_all_master['journal_master'].isnull().sum())
print(merged_all_master['year'].isnull().sum())
print(merged_all_master['year_master'].isnull().sum())
print(merged_all_master['authors'].isnull().sum())
print(merged_all_master['authors_master'].isnull().sum())

# Filling in blanks on data based on the master file
for i in range(len(merged_all_master)):
    if pd.isna(merged_all_master.iloc[i]['Journal_Name']):
        merged_all_master.loc[i,'Journal_Name'] = merged_all_master.loc[i,'journal_master']
    
    if pd.isna(merged_all_master.iloc[i]['Authors_count']):
        merged_all_master.loc[i,'Authors_count'] = merged_all_master.loc[i,'Authors_count_master']
    
    #if pd.isna(merged_all_master.iloc[i]['authors']):
    merged_all_master.loc[i,'authors'] = merged_all_master.loc[i,'authors_master']

    if pd.isna(merged_all_master.iloc[i]['content_type']):
        merged_all_master.loc[i,'content_type'] = merged_all_master.loc[i,'content_type_master']
        merged_all_master.loc[i,'stable_url'] = merged_all_master.loc[i,'stable_url_master']

    if pd.isna(merged_all_master.iloc[i]['year_master']):
        merged_all_master.loc[i,'year_master'] = merged_all_master.loc[i,'year']
# Out:
# 0
# 1899
# 0
# 0
# 1771
# 1799
# 30

# %%
#Renaming the columns to be standard across what is wantwed
merged_all_master = merged_all_master[['Journal_Name' ,'Authors_count', 'Authors_list', 'authors_master', 'Article_ID', 'content_type',
'stable_url', 'year_master', 'Ref_type' ,
'ref_string', 'ref_string_clean1', 'Screened', 'Manual',
'0_Auth_affs_0', '0_Auth_affs_1', '0_Auth_affs_2', '0_Auth_affs_3', '0_Auth_affs_4', 
'1_Auth_affs_0' , '1_Auth_affs_1', '1_Auth_affs_2', '1_Auth_affs_3', '1_Auth_affs_4',
'2_Auth_affs_0', '2_Auth_affs_1', '2_Auth_affs_2', '2_Auth_affs_3', '2_Auth_affs_4',
'3_Auth_affs_0', '3_Auth_affs_1', '3_Auth_affs_2', '3_Auth_affs_3', '3_Auth_affs_4',
'4_Auth_affs_0', '4_Auth_affs_1', '4_Auth_affs_2' , '4_Auth_affs_3',
'5_Auth_affs_0',
'6_Auth_affs_0','7_Auth_affs_0']]

# %%
# Checkign where it is null
print(merged_all_master['Article_ID'].isnull().sum())
Total_articles = merged_all_master['Article_ID'].notnull().sum()
print(Total_articles)
print(merged_all_master['Journal_Name'].isnull().sum())
print(merged_all_master['Authors_count'].isnull().sum())
print(merged_all_master['authors_master'].isnull().sum())
print(merged_all_master['year_master'].isnull().sum())
print(merged_all_master['content_type'].isnull().sum())
print(merged_all_master['stable_url'].isnull().sum())
print(merged_all_master['0_Auth_affs_0'].isnull().sum())
Total_affiliations = merged_all_master['0_Auth_affs_0'].notnull().sum()

print("Total articles = " ,Total_articles)
print("Total affiliations = " ,Total_affiliations)
print("Percentage of articles with affiliation = ", Total_affiliations/Total_articles*100 ,"%")
print("Percentage of articles missing an affiliation = ", (1-Total_affiliations/Total_articles)*100 ,"%")
# Out:
# 0
# 22790
# 0
# 30
# 30
# 0
# 0
# 0
# 280
# Total articles =  22790
# Total affiliations =  22510
# Percentage of articles with affiliation =  98.77139096094778 %
# Percentage of articles missing an affiliation =  1.2286090390522197 %

# %%
# Checking data types
print(merged_all_master.dtypes)
# Out:
# Journal_Name          object
# Authors_count        float64
# Authors_list          object
# authors_master        object
# Article_ID             int64
# content_type          object
# stable_url            object
# year_master          float64
# Ref_type              object
# ref_string            object
# ref_string_clean1     object
# Screened              object
# Manual                object
# 0_Auth_affs_0         object
# 0_Auth_affs_1         object
# 0_Auth_affs_2         object
# 0_Auth_affs_3         object
# 0_Auth_affs_4         object
# 1_Auth_affs_0         object
# 1_Auth_affs_1         object
# 1_Auth_affs_2         object
# 1_Auth_affs_3         object
# 1_Auth_affs_4         object
# 2_Auth_affs_0         object
# 2_Auth_affs_1         object
# 2_Auth_affs_2         object
# 2_Auth_affs_3         object
# 2_Auth_affs_4         object
# 3_Auth_affs_0         object
# 3_Auth_affs_1         object
# 3_Auth_affs_2         object
# 3_Auth_affs_3         object
# ...

# %%
# Excel output to get an overview of the data
#merged_all_master.head
#merged_all_master.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/3_consolidation/merged_all_master.xlsx')

# %%
Merged_all_scopus = merged_all_master.copy(deep=True)

# %%
# There are so issues with the scopus data in where there are multiple authors but only 1 affililiation and this affiliation actually belongs to all the authors and not just 1

for i in range(len(Merged_all_scopus)):

# 2 Authors
#Correcting scopus
    #1_Auth_affs_0 = blank and 0_Auth_affs_1 not blank
    if pd.isna(merged_all_master.iloc[i]['1_Auth_affs_0']) and pd.notna(merged_all_master.iloc[i]['0_Auth_affs_1']) and Merged_all_scopus.iloc[i]['Manual'] == 'Scopus' and Merged_all_scopus.iloc[i]['Authors_count'] == 2:
        print(i)
        Merged_all_scopus.loc[i,'1_Auth_affs_0'] = Merged_all_scopus.loc[i,'0_Auth_affs_1']
        Merged_all_scopus.loc[i,'0_Auth_affs_1'] = ''
        Merged_all_scopus.loc[i,'Manual'] = 'Scopus corrected'
    
    #1_Auth_affs_0 = blank and 0_Auth_affs_1 blank

    if pd.isna(merged_all_master.iloc[i]['1_Auth_affs_0']) and pd.isna(merged_all_master.iloc[i]['0_Auth_affs_1']) and Merged_all_scopus.iloc[i]['Manual'] == 'Scopus' and Merged_all_scopus.iloc[i]['Authors_count'] == 2:
        print(i)
        Merged_all_scopus.loc[i,'1_Auth_affs_0'] = Merged_all_scopus.loc[i,'0_Auth_affs_0']
        Merged_all_scopus.loc[i,'Manual'] = 'Scopus corrected'

# Correcting QJE
    if pd.isna(merged_all_master.iloc[i]['1_Auth_affs_0']) and pd.notna(merged_all_master.iloc[i]['0_Auth_affs_1']) and Merged_all_scopus.iloc[i]['Manual'] == 'm' and Merged_all_scopus.iloc[i]['Authors_count'] == 2:
        print(i)
        Merged_all_scopus.loc[i,'1_Auth_affs_0'] = Merged_all_scopus.loc[i,'0_Auth_affs_1']
        Merged_all_scopus.loc[i,'0_Auth_affs_1'] = ''
        Merged_all_scopus.loc[i,'Manual'] = 'm corrected'

    if pd.isna(merged_all_master.iloc[i]['1_Auth_affs_0']) and pd.isna(merged_all_master.iloc[i]['0_Auth_affs_1']) and Merged_all_scopus.iloc[i]['Manual'] == 'm' and Merged_all_scopus.iloc[i]['Authors_count'] == 2:
        print(i)
        Merged_all_scopus.loc[i,'1_Auth_affs_0'] = Merged_all_scopus.loc[i,'0_Auth_affs_0']
        Merged_all_scopus.loc[i,'Manual'] = 'm corrected'

# 3 Authors
#Correcting scopus
    #1_Auth_affs_0 = blank and 0_Auth_affs_1 not blank
    if pd.isna(merged_all_master.iloc[i]['1_Auth_affs_0']) and pd.isna(merged_all_master.iloc[i]['2_Auth_affs_0']) and pd.isna(merged_all_master.iloc[i]['0_Auth_affs_1']) and Merged_all_scopus.iloc[i]['Manual'] == 'Scopus' and Merged_all_scopus.iloc[i]['Authors_count'] == 3:
        print(i)
        Merged_all_scopus.loc[i,'1_Auth_affs_0'] = Merged_all_scopus.loc[i,'0_Auth_affs_0']
        Merged_all_scopus.loc[i,'2_Auth_affs_0'] = Merged_all_scopus.loc[i,'0_Auth_affs_0']
        Merged_all_scopus.loc[i,'Manual'] = 'Scopus corrected'
# Out:
# 537
# 1259
# 1275
# 1302
# 1306
# 1307
# 1321
# 1329
# 1336
# 1341
# 1347
# 1349
# 1353
# 1354
# 1362
# 1368
# 1374
# 1375
# 1380
# 1382
# 1384
# 1451
# 1466
# 1470
# 1573
# 1579
# 1580
# 1595
# 1618
# 1619
# 1620
# 1624
# 1629
# 1641
# 1676
# 1681
# 1682
# 1685
# 1686
# 1713
# 1714
# 1731
# 2658
# 2659
# 2675
# 2683
# 2685
# 2693
# 2698
# 2739
# 2771
# 2775
# 2781
# 2783
# 2798
# 2817
# 2826
# 2832
# 2834
# 2856
# 2871
# 2920
# 2928
# 2931
# 2965
# 2983
# 2985
# 2989
# 3029
# 3047
# 3097
# 3110
# 3114
# 3132
# 3134
# 3146
# 3167
# 3192
# 3194
# 3203
# 3210
# 3224
# 3260
# 3272
# 3274
# 3279
# 3285
# 3314
# 3325
# 3360
# 3376
# 3427
# 3430
# 3447
# 3450
# 3456
# 3490
# 3494
# 3503
# 3509
# 3515
# 3517
# 3519
# 3520
# 3521
# 3522
# 3538
# 3542
# 3544
# 3555
# 3559
# 3573
# 3584
# 3588
# 3594
# 3596
# 3604
# 3607
# 3633
# 3635
# 3641
# 3646
# 3647
# 3651
# 3660
# 3667
# 3671
# 3673
# 3679
# 3716
# 3717
# 3723
# 3745
# 3746
# 3749
# 3757
# 3802
# 3811
# 3823
# 3835
# 3838
# 3848
# 3855
# ...

# %%
#Excel output to get an overview of the data
#Merged_all_scopus.head
#Merged_all_scopus.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/3_consolidation/Merged_all_scopus.xlsx')
