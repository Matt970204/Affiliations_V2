# %% [markdown]
# # Plotting a graph over time of the affilitions

# %%
import pandas as pd
import numpy as np
All_Data = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/5. Final consolidation of all data/5.A. Data created in 5./5.2./Final affiliations.xlsx') 
print(All_Data.shape)
# Out:
# (22790, 40)

# %%
All_Data.rename(columns = {'Year':'year'}, inplace = True)

melted_master_condenced = All_Data[['Authors_count','year']]

# %%
melted_master_condenced['decade'] = ''
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1940) & (melted_master_condenced['year'] < 1950), '[1940,1949]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1950) & (melted_master_condenced['year'] < 1960), '[1950,1959]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1960) & (melted_master_condenced['year'] < 1970), '[1960,1969]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1970) & (melted_master_condenced['year'] < 1980), '[1970,1979]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1980) & (melted_master_condenced['year'] < 1990), '[1980,1989]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1990) & (melted_master_condenced['year'] < 2000), '[1990,1999]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 2000) & (melted_master_condenced['year'] < 2011), '[2000,2010]', melted_master_condenced['decade'])
print(melted_master_condenced.head())
print(melted_master_condenced.tail())
# Out:
#    Authors_count  year       decade
# 0            1.0  1940  [1940,1949]
# 1            1.0  1940  [1940,1949]
# 2            1.0  1940  [1940,1949]
# 3            1.0  1940  [1940,1949]
# 4            1.0  1940  [1940,1949]
#        Authors_count  year       decade
# 22785            1.0  1940  [1940,1949]
# 22786            1.0  1940  [1940,1949]
# 22787            1.0  1940  [1940,1949]
# 22788            1.0  1940  [1940,1949]
# 22789            1.0  1940  [1940,1949]
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_17240/3615562485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melted_master_condenced['decade'] = ''
# ...

# %%
melted_master_condenced['sum authors'] = melted_master_condenced.groupby(['decade'])['Authors_count'].cumsum()
melted_master_condenced['count'] = 1
melted_master_condenced['sum papers'] = melted_master_condenced.groupby(['decade'])['count'].cumsum()
melted_master_condenced.head()
a = melted_master_condenced.drop_duplicates(subset = ['decade'], keep = 'last')
a['Average authors'] = a['sum authors']/a['sum papers']
a
# Out:
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_17240/1784397265.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melted_master_condenced['sum authors'] = melted_master_condenced.groupby(['decade'])['Authors_count'].cumsum()
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_17240/1784397265.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melted_master_condenced['count'] = 1
# ...

# %%
Data = All_Data.copy()
Data['Same University'] = 0
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_0'] != Data['1_Auth_affs_0'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_0'] != Data['1_Auth_affs_1'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_0'] != Data['1_Auth_affs_2'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_0'] != Data['1_Auth_affs_3'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_0'] != Data['1_Auth_affs_4'], 1)

Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_1'] != Data['1_Auth_affs_0'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_1'] != Data['1_Auth_affs_1'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_1'] != Data['1_Auth_affs_2'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_1'] != Data['1_Auth_affs_3'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_1'] != Data['1_Auth_affs_4'], 1)

Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_2'] != Data['1_Auth_affs_0'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_2'] != Data['1_Auth_affs_1'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_2'] != Data['1_Auth_affs_2'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_2'] != Data['1_Auth_affs_3'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_2'] != Data['1_Auth_affs_4'], 1)

Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_3'] != Data['1_Auth_affs_0'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_3'] != Data['1_Auth_affs_1'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_3'] != Data['1_Auth_affs_2'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_3'] != Data['1_Auth_affs_3'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_3'] != Data['1_Auth_affs_4'], 1)

Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_4'] != Data['1_Auth_affs_0'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_4'] != Data['1_Auth_affs_1'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_4'] != Data['1_Auth_affs_2'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_4'] != Data['1_Auth_affs_3'], 1)
Data['Same University'] = Data['Same University'].where(Data['0_Auth_affs_4'] != Data['1_Auth_affs_4'], 1)

Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_0'] != Data['2_Auth_affs_0'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_0'] != Data['2_Auth_affs_1'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_0'] != Data['2_Auth_affs_2'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_0'] != Data['2_Auth_affs_3'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_0'] != Data['2_Auth_affs_4'], 1)

Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_1'] != Data['2_Auth_affs_0'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_1'] != Data['2_Auth_affs_1'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_1'] != Data['2_Auth_affs_2'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_1'] != Data['2_Auth_affs_3'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_1'] != Data['2_Auth_affs_4'], 1)

Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_2'] != Data['2_Auth_affs_0'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_2'] != Data['2_Auth_affs_1'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_2'] != Data['2_Auth_affs_2'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_2'] != Data['1_Auth_affs_3'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_2'] != Data['1_Auth_affs_4'], 1)

Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_3'] != Data['2_Auth_affs_0'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_3'] != Data['2_Auth_affs_1'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_3'] != Data['2_Auth_affs_2'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_3'] != Data['2_Auth_affs_3'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_3'] != Data['2_Auth_affs_4'], 1)

Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_4'] != Data['2_Auth_affs_0'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_4'] != Data['2_Auth_affs_1'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_4'] != Data['2_Auth_affs_2'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_4'] != Data['2_Auth_affs_3'], 1)
Data['Same University'] = Data['Same University'].where(Data['1_Auth_affs_4'] != Data['2_Auth_affs_4'], 1)

# %%
Data['Diff University'] = 0
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_0'] == Data['1_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_0'] == Data['1_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_0'] == Data['1_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_0'] == Data['1_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_0'] == Data['1_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_1'] == Data['1_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_1'] == Data['1_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_1'] == Data['1_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_1'] == Data['1_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_1'] == Data['1_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_2'] == Data['1_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_2'] == Data['1_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_2'] == Data['1_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_2'] == Data['1_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_2'] == Data['1_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_3'] == Data['1_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_3'] == Data['1_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_3'] == Data['1_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_3'] == Data['1_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_3'] == Data['1_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_4'] == Data['1_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_4'] == Data['1_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_4'] == Data['1_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_4'] == Data['1_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_4'] == Data['1_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_0'] == Data['2_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_0'] == Data['2_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_0'] == Data['2_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_0'] == Data['2_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_0'] == Data['2_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_1'] == Data['2_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_1'] == Data['2_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_1'] == Data['2_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_1'] == Data['2_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_1'] == Data['2_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_2'] == Data['2_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_2'] == Data['2_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_2'] == Data['2_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_2'] == Data['1_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_2'] == Data['1_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_3'] == Data['2_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_3'] == Data['2_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_3'] == Data['2_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_3'] == Data['2_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_3'] == Data['2_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_4'] == Data['2_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_4'] == Data['2_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_4'] == Data['2_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_4'] == Data['2_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_4'] == Data['2_Auth_affs_4'], 1)

# %%
melted_master_condenced = Data[['year','Authors_count','Same University','Diff University']]
print(melted_master_condenced.head())

melted_master_condenced['decade'] = ''
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1940) & (melted_master_condenced['year'] < 1950), '[1940,1949]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1950) & (melted_master_condenced['year'] < 1960), '[1950,1959]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1960) & (melted_master_condenced['year'] < 1970), '[1960,1969]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1970) & (melted_master_condenced['year'] < 1980), '[1970,1979]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1980) & (melted_master_condenced['year'] < 1990), '[1980,1989]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1990) & (melted_master_condenced['year'] < 2000), '[1990,1999]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 2000) & (melted_master_condenced['year'] < 2011), '[2000,2010]', melted_master_condenced['decade'])

#melted_master_condenced['aff_cum_counts'] = melted_master_condenced.groupby(['decade'])['Same University'].cumcount()+1
melted_master_condenced['Same University'] = melted_master_condenced['Same University'].astype(int)
melted_master_condenced['sum same university'] = melted_master_condenced.groupby(['decade','Authors_count'])['Same University'].cumsum()
#melted_master_condenced['sum diff university'] = melted_master_condenced.groupby(['decade','Authors_count'])['Diff University'].cumsum()
melted_master_condenced['count'] = 1
melted_master_condenced['sum papers'] = melted_master_condenced.groupby(['decade','Authors_count'])['count'].cumsum()

melted_master_condenced['sum diff university'] = np.where(melted_master_condenced['Authors_count'] > 1, melted_master_condenced['sum papers'] - melted_master_condenced['sum same university'] , 0)

a = melted_master_condenced.drop_duplicates(subset = ['decade','Authors_count'], keep = 'last')
mask_journal = a['Authors_count'].isin([2,3,4,5])
a = a[mask_journal]
#a['Average authors'] = a['sum authors']/a['sum papers']
a
# Out:
#    year  Authors_count  Same University  Diff University
# 0  1940            1.0                0                1
# 1  1940            1.0                0                1
# 2  1940            1.0                0                1
# 3  1940            1.0                0                1
# 4  1940            1.0                0                1
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_17240/796660524.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melted_master_condenced['decade'] = ''
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_17240/796660524.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
melted_master_condenced = Data[['year','Authors_count','Same University','Diff University']]
print(melted_master_condenced.head())

melted_master_condenced['decade'] = ''
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1940) & (melted_master_condenced['year'] < 1950), '[1940,1949]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1950) & (melted_master_condenced['year'] < 1960), '[1950,1959]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1960) & (melted_master_condenced['year'] < 1970), '[1960,1969]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1970) & (melted_master_condenced['year'] < 1980), '[1970,1979]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1980) & (melted_master_condenced['year'] < 1990), '[1980,1989]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 1990) & (melted_master_condenced['year'] < 2000), '[1990,1999]', melted_master_condenced['decade'])
melted_master_condenced['decade'] = np.where((melted_master_condenced['year'] >= 2000) & (melted_master_condenced['year'] < 2011), '[2000,2010]', melted_master_condenced['decade'])

#melted_master_condenced['aff_cum_counts'] = melted_master_condenced.groupby(['decade'])['Same University'].cumcount()+1
melted_master_condenced['Same University'] = melted_master_condenced['Same University'].astype(int)
melted_master_condenced['sum same university'] = melted_master_condenced.groupby(['decade'])['Same University'].cumsum()
#melted_master_condenced['sum diff university'] = melted_master_condenced.groupby(['decade','Authors_count'])['Diff University'].cumsum()
melted_master_condenced['count'] = 1

mask_journal = melted_master_condenced['Authors_count'].isin([1])
melted_master_condenced = melted_master_condenced[~mask_journal]
melted_master_condenced['sum papers'] = melted_master_condenced.groupby(['decade'])['count'].cumsum()

melted_master_condenced['sum diff university'] = np.where(melted_master_condenced['Authors_count'] > 1, melted_master_condenced['sum papers'] - melted_master_condenced['sum same university'] , 0)

a = melted_master_condenced.drop_duplicates(subset = ['decade'], keep = 'last')

#a['Average authors'] = a['sum authors']/a['sum papers']
a
# Out:
#    year  Authors_count  Same University  Diff University
# 0  1940            1.0                0                1
# 1  1940            1.0                0                1
# 2  1940            1.0                0                1
# 3  1940            1.0                0                1
# 4  1940            1.0                0                1
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_17240/1727776855.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melted_master_condenced['decade'] = ''
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_17240/1727776855.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
