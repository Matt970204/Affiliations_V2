# %%
Data = All_Data.copy()
Data['Diff University'] = 0
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_0'] == Data['1_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_0'] == Data['1_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_0'] == Data['1_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_0'] == Data['1_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_0'] == Data['1_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_1'] == Data['1_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_1'] == Data['1_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_1'] == Data['1_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_1'] == Data['1_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_1'] == Data['1_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_2'] == Data['1_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_2'] == Data['1_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_2'] == Data['1_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_2'] == Data['1_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_2'] == Data['1_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_3'] == Data['1_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_3'] == Data['1_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_3'] == Data['1_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_3'] == Data['1_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_3'] == Data['1_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_4'] == Data['1_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_4'] == Data['1_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_4'] == Data['1_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_4'] == Data['1_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['0_Auth_affs_4'] == Data['1_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_0'] == Data['2_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_0'] == Data['2_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_0'] == Data['2_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_0'] == Data['2_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_0'] == Data['2_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_1'] == Data['2_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_1'] == Data['2_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_1'] == Data['2_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_1'] == Data['2_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_1'] == Data['2_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_2'] == Data['2_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_2'] == Data['2_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_2'] == Data['2_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_2'] == Data['1_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_2'] == Data['1_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_3'] == Data['2_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_3'] == Data['2_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_3'] == Data['2_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_3'] == Data['2_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_3'] == Data['2_Auth_affs_4'], 1)

Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_4'] == Data['2_Auth_affs_0'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_4'] == Data['2_Auth_affs_1'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_4'] == Data['2_Auth_affs_2'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_4'] == Data['2_Auth_affs_3'], 1)
Data['Diff University'] = Data['Diff University'].where(Data['1_Auth_affs_4'] == Data['2_Auth_affs_4'], 1)
