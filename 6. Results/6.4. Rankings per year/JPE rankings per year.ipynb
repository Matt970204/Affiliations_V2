# %% [markdown]
# # Plotting a graph over time of the affilitions

# %%
import pandas as pd
import numpy as np
melted_master_condenced = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/6. Results/6.A. Data created in 6./6.2/JPE_Melted_Weights_applied.xlsx') 
print(melted_master_condenced.shape)
melted_master_condenced = melted_master_condenced[['Article_ID','Weight','Affiliation','year']]
melted_master_condenced = melted_master_condenced.reset_index(drop=True)
melted_master_condenced.head()
# Out:
# (6304, 7)
#    Article_ID  Weight              Affiliation  year
# 0     1825913     1.0     Washington Dc (City)  1940
# 1     1825908     1.0    University Of Chicago  1940
# 2     1824384     1.0      Columbia University  1940
# 3     1824382     1.0       Cornell University  1940
# 4     1824381     1.0  University Of Edinburgh  1940

# %% [markdown]
# # Ranking the Universities based on their number of papers per published per decade

# %%
#Gets the top 10 overall
melted_master_condenced = melted_master_condenced.sort_values(by=['year'])
melted_master_condenced['aff_cum_sum'] = melted_master_condenced.groupby(['Affiliation'])['Weight'].cumsum()

mask_journal = melted_master_condenced['Affiliation'].isin(['National Bureau Of Economic Research'])
melted_master_condenced = melted_master_condenced[~mask_journal]

highest_vals = melted_master_condenced.drop_duplicates(subset = ['Affiliation'], keep = 'last')
highest_vals_10 = highest_vals.nlargest(10,'aff_cum_sum')
print(highest_vals_10.shape)
#print(highest_vals_10.head())
print(highest_vals_10.iat[6,2])

melted_master_condenced_decade = melted_master_condenced[['Article_ID','Weight','Affiliation','year']]

a = melted_master_condenced_decade.loc[melted_master_condenced_decade['Affiliation'] == highest_vals_10.iat[6,2]]
a['aff_cum_sum_yearly'] = a.groupby(['Affiliation','year'])['Weight'].cumsum()
a = a.drop_duplicates(subset = ['year'], keep = 'last')
print(a.head())
print(a.shape)
# Out:
# (10, 5)
# University Of Pennsylvania
#      Article_ID    Weight                 Affiliation  year  \
# 89      1825228  0.333333  University Of Pennsylvania  1942
# 604     1826829  1.000000  University Of Pennsylvania  1956
# 668     1826994  1.000000  University Of Pennsylvania  1958
# 706     1825393  1.000000  University Of Pennsylvania  1959
# 771     1829944  1.000000  University Of Pennsylvania  1960
#
#      aff_cum_sum_yearly
# 89                  1.0
# 604                 1.0
# 668                 1.0
# 706                 1.0
# 771                 1.0
# (47, 5)
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_40442/3774528098.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['aff_cum_sum_yearly'] = a.groupby(['Affiliation','year'])['Weight'].cumsum()

# %%
yearly_index = []
for i in range(1940,2011):
    yearly_index.append(i)

#print(list)
a = melted_master_condenced.loc[melted_master_condenced['Affiliation'] == highest_vals_10.iat[0,2]]
a['aff_cum_sum_yearly'] = a.groupby(['Affiliation','year'])['Weight'].cumsum()
a = a.drop_duplicates(subset = ['year'], keep = 'last')
print(a.shape)
#print(a)
a.set_index('year', inplace= True)
a = a.reindex(yearly_index, fill_value=0)
a['Affiliation'] = highest_vals_10.iat[0,2]
print(a.shape)

b = melted_master_condenced.loc[melted_master_condenced['Affiliation'] == highest_vals_10.iat[1,2]]
b['aff_cum_sum_yearly'] = b.groupby(['Affiliation','year'])['Weight'].cumsum()
b = b.drop_duplicates(subset = ['year'], keep = 'last')
print(b.shape)
#print(b)
b.set_index('year', inplace= True)
b = b.reindex(yearly_index, fill_value=0)
b['Affiliation'] = highest_vals_10.iat[1,2]
print(b.shape)

c = melted_master_condenced.loc[melted_master_condenced['Affiliation'] == highest_vals_10.iat[2,2]]
c['aff_cum_sum_yearly'] = c.groupby(['Affiliation','year'])['Weight'].cumsum()
c = c.drop_duplicates(subset = ['year'], keep = 'last')
print(c.shape)
#print(c)
c.set_index('year', inplace= True)
c = c.reindex(yearly_index, fill_value=0)
c['Affiliation'] = highest_vals_10.iat[2,2]
print(c.shape)

d = melted_master_condenced.loc[melted_master_condenced['Affiliation'] == highest_vals_10.iat[3,2]]
d['aff_cum_sum_yearly'] = d.groupby(['Affiliation','year'])['Weight'].cumsum()
d = d.drop_duplicates(subset = ['year'], keep = 'last')
print(d.shape)
#print(c)
d.set_index('year', inplace= True)
d = d.reindex(yearly_index, fill_value=0)
d['Affiliation'] = highest_vals_10.iat[3,2]
print(d.shape)

e = melted_master_condenced.loc[melted_master_condenced['Affiliation'] == highest_vals_10.iat[4,2]]
e['aff_cum_sum_yearly'] = e.groupby(['Affiliation','year'])['Weight'].cumsum()
e = e.drop_duplicates(subset = ['year'], keep = 'last')
print(e.shape)
#print(c)
e.set_index('year', inplace= True)
e = e.reindex(yearly_index, fill_value=0)
e['Affiliation'] = highest_vals_10.iat[4,2]
print(e.shape)

#6
f = melted_master_condenced.loc[melted_master_condenced['Affiliation'] == highest_vals_10.iat[5,2]]
f['aff_cum_sum_yearly'] = f.groupby(['Affiliation','year'])['Weight'].cumsum()
f = f.drop_duplicates(subset = ['year'], keep = 'last')
print(f.shape)
#print(c)
f.set_index('year', inplace= True)
f = f.reindex(yearly_index, fill_value=0)
f['Affiliation'] = highest_vals_10.iat[5,2]
print(f.shape)

#7
g = melted_master_condenced.loc[melted_master_condenced['Affiliation'] == highest_vals_10.iat[6,2]]
g['aff_cum_sum_yearly'] = g.groupby(['Affiliation','year'])['Weight'].cumsum()
g = g.drop_duplicates(subset = ['year'], keep = 'last')
print(g.shape)
#print(c)
g.set_index('year', inplace= True)
g = g.reindex(yearly_index, fill_value=0)
g['Affiliation'] = highest_vals_10.iat[6,2]
print(g.shape)

#8
h = melted_master_condenced.loc[melted_master_condenced['Affiliation'] == highest_vals_10.iat[7,2]]
h['aff_cum_sum_yearly'] = h.groupby(['Affiliation','year'])['Weight'].cumsum()
h = h.drop_duplicates(subset = ['year'], keep = 'last')
print(h.shape)
h.set_index('year', inplace= True)
h = h.reindex(yearly_index, fill_value=0)
h['Affiliation'] = highest_vals_10.iat[7,2]
print(h.shape)

#9
i = melted_master_condenced.loc[melted_master_condenced['Affiliation'] == highest_vals_10.iat[8,2]]
i['aff_cum_sum_yearly'] = i.groupby(['Affiliation','year'])['Weight'].cumsum()
i = i.drop_duplicates(subset = ['year'], keep = 'last')
print(i.shape)
i.set_index('year', inplace= True)
i = i.reindex(yearly_index, fill_value=0)
i['Affiliation'] = highest_vals_10.iat[8,2]
print(i.shape)

#10
j = melted_master_condenced.loc[melted_master_condenced['Affiliation'] == highest_vals_10.iat[9,2]]
j['aff_cum_sum_yearly'] = j.groupby(['Affiliation','year'])['Weight'].cumsum()
j = j.drop_duplicates(subset = ['year'], keep = 'last')
print(j.shape)
j.set_index('year', inplace= True)
j = j.reindex(yearly_index, fill_value=0)
j['Affiliation'] = highest_vals_10.iat[9,2]
print(j.shape)
# Out:
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_40442/1992162566.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['aff_cum_sum_yearly'] = a.groupby(['Affiliation','year'])['Weight'].cumsum()
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_40442/1992162566.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['aff_cum_sum_yearly'] = b.groupby(['Affiliation','year'])['Weight'].cumsum()
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_40442/1992162566.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['aff_cum_sum_yearly'] = c.groupby(['Affiliation','year'])['Weight'].cumsum()
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_40442/1992162566.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['aff_cum_sum_yearly'] = d.groupby(['Affiliation','year'])['Weight'].cumsum()
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_40442/1992162566.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   e['aff_cum_sum_yearly'] = e.groupby(['Affiliation','year'])['Weight'].cumsum()
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_40442/1992162566.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f['aff_cum_sum_yearly'] = f.groupby(['Affiliation','year'])['Weight'].cumsum()
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_40442/1992162566.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   g['aff_cum_sum_yearly'] = g.groupby(['Affiliation','year'])['Weight'].cumsum()
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_40442/1992162566.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h['aff_cum_sum_yearly'] = h.groupby(['Affiliation','year'])['Weight'].cumsum()
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_40442/1992162566.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['aff_cum_sum_yearly'] = i.groupby(['Affiliation','year'])['Weight'].cumsum()
# (71, 6)
# (71, 5)
# (63, 6)
# (71, 5)
# (57, 6)
# (71, 5)
# (57, 6)
# (71, 5)
# (53, 6)
# (71, 5)
# (54, 6)
# (71, 5)
# (47, 6)
# (71, 5)
# (49, 6)
# (71, 5)
# (46, 6)
# (71, 5)
# (49, 6)
# (71, 5)
# /var/folders/23/ft9qf9c11rj_vqhbjml910f40000gn/T/ipykernel_40442/1992162566.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   j['aff_cum_sum_yearly'] = j.groupby(['Affiliation','year'])['Weight'].cumsum()

# %%
ranked = pd.concat([a,b,c,d,e,f,g,h,i,j], axis=0)

ranked = ranked.sort_values(by=['year','Affiliation'])
ranked = ranked.reset_index()
print(ranked.shape)

ranked['Rank'] = ranked.groupby(['year'])['aff_cum_sum_yearly'].rank(method = 'max', ascending= False)
print(ranked.shape)
print(ranked.tail(20))
#ranked.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/2_Fuzzy matching/Combined journals/Combined journal yearly rank.xlsx')
# Out:
# (710, 6)
# (710, 7)
#      year  Article_ID    Weight                            Affiliation  \
# 690  2009      648432  0.250000                    Columbia University
# 691  2009      605583  0.166667                     Harvard University
# 692  2009      605583  0.250000  Massachusetts Institute Of Technology
# 693  2009      605358  0.500000                Northwestern University
# 694  2009           0  0.000000                   Princeton University
# 695  2009      599022  0.500000                    Stanford University
# 696  2009           0  0.000000  University Of California, Los Angeles
# 697  2009      597301  0.333333                  University Of Chicago
# 698  2009      648882  0.166667             University Of Pennsylvania
# 699  2009           0  0.000000                        Yale University
# 700  2010      655858  0.250000                    Columbia University
# 701  2010      653714  0.333333                     Harvard University
# 702  2010      653714  0.333333  Massachusetts Institute Of Technology
# 703  2010      658161  0.250000                Northwestern University
# 704  2010      653138  0.333333                   Princeton University
# 705  2010      651673  0.250000                    Stanford University
# 706  2010      653690  0.250000  University Of California, Los Angeles
# 707  2010      652462  1.000000                  University Of Chicago
# 708  2010      655844  0.250000             University Of Pennsylvania
# 709  2010      650315  0.333333                        Yale University
#
#      aff_cum_sum  aff_cum_sum_yearly  Rank
# 690    80.000000            0.750000   3.0
# 691   113.194444            0.166667   7.0
# 692   121.644444            0.666667   4.0
# 693    69.138889            0.500000   6.0
# 694     0.000000            0.000000  10.0
# 695    92.250000            1.416667   1.0
# 696     0.000000            0.000000  10.0
# 697   332.763889            0.666667   5.0
# 698    74.277778            1.333333   2.0
# 699     0.000000            0.000000  10.0
# 700    80.750000            0.750000   5.0
# 701   114.027778            0.833333   4.0
# 702   123.727778            2.083333   1.0
# 703    69.388889            0.250000  10.0
# 704    91.250000            0.333333   8.0
# 705    93.750000            1.500000   3.0
# 706    68.027778            0.416667   7.0
# 707   334.263889            1.500000   3.0
# 708    74.527778            0.250000  10.0
# 709    73.027778            0.666667   6.0

# %%
ranked.to_excel('/Users/MattJohnson/Desktop/Affiliations/6. Results/6.A. Data created in 6./6.4/JPE_Ranked_data_yearly.xlsx')

# %%
pivot = ranked.pivot(index='year', columns='Affiliation', values='Rank')
pivot
# Out:
# Affiliation  Columbia University  Harvard University  \
# year
# 1940                         4.0                 2.0
# 1941                         3.0                10.0
# 1942                         5.0                 1.0
# 1943                        10.0                10.0
# 1944                        10.0                10.0
# ...                          ...                 ...
# 2006                         2.0                 5.0
# 2007                         6.0                 1.0
# 2008                         8.0                 2.0
# 2009                         3.0                 7.0
# 2010                         5.0                 4.0
#
# Affiliation  Massachusetts Institute Of Technology  Northwestern University  \
# year
# 1940                                          10.0                     10.0
# 1941                                          10.0                     10.0
# 1942                                           5.0                     10.0
# 1943                                           2.0                     10.0
# 1944                                           3.0                     10.0
# ...                                            ...                      ...
# 2006                                           7.0                      8.0
# 2007                                           3.0                     10.0
# 2008                                           3.0                      4.0
# 2009                                           4.0                      6.0
# 2010                                           1.0                     10.0
#
# Affiliation  Princeton University  Stanford University  \
# year
# 1940                         10.0                  4.0
# 1941                          2.0                 10.0
# 1942                         10.0                 10.0
# 1943                          1.0                  4.0
# 1944                         10.0                 10.0
# ...                           ...                  ...
# 2006                         10.0                  6.0
# 2007                          5.0                 10.0
# 2008                          7.0                  9.0
# 2009                         10.0                  1.0
# 2010                          8.0                  3.0
#
# Affiliation  University Of California, Los Angeles  University Of Chicago  \
# year
# 1940                                          10.0                    1.0
# 1941                                          10.0                    1.0
# 1942                                          10.0                    2.0
# 1943                                          10.0                    4.0
# 1944                                           3.0                    1.0
# ...                                            ...                    ...
# 2006                                           4.0                    1.0
# 2007                                          10.0                    2.0
# 2008                                           7.0                    1.0
# 2009                                          10.0                    5.0
# 2010                                           7.0                    3.0
#
# Affiliation  University Of Pennsylvania  Yale University
# year
# 1940                               10.0             10.0
# 1941                               10.0             10.0
# 1942                                5.0             10.0
# 1943                               10.0             10.0
# 1944                               10.0             10.0
# ...                                 ...              ...
# 2006                               10.0              3.0
# 2007                                4.0              7.0
# 2008                               10.0              7.0
# 2009                                2.0             10.0
# 2010                               10.0              6.0
#
# [71 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = pivot.plot(xticks=pivot.index, ylabel='Rank')
leg = plt.legend( loc = 'upper right')
plt.show()

# %%
invert_pivot = ranked.pivot_table(index='year', columns='Affiliation', values='aff_cum_sum_yearly', aggfunc= 'sum')
invert_pivot
#invert_pivot.sort_values(by=2000, ascending=False)
# Out:
# Affiliation  Columbia University  Harvard University  \
# year
# 1940                        1.00            2.000000
# 1941                        2.00            0.000000
# 1942                        1.00            2.500000
# 1943                        0.00            0.000000
# 1944                        0.00            0.000000
# ...                          ...                 ...
# 2006                        1.75            1.250000
# 2007                        0.50            3.666667
# 2008                        0.50            2.500000
# 2009                        0.75            0.166667
# 2010                        0.75            0.833333
#
# Affiliation  Massachusetts Institute Of Technology  Northwestern University  \
# year
# 1940                                      0.000000                 0.000000
# 1941                                      0.000000                 0.000000
# 1942                                      1.000000                 0.000000
# 1943                                      2.000000                 0.000000
# 1944                                      1.000000                 0.000000
# ...                                            ...                      ...
# 2006                                      0.416667                 0.333333
# 2007                                      2.000000                 0.000000
# 2008                                      2.416667                 2.000000
# 2009                                      0.666667                 0.500000
# 2010                                      2.083333                 0.250000
#
# Affiliation  Princeton University  Stanford University  \
# year
# 1940                     0.000000             1.000000
# 1941                     3.000000             0.000000
# 1942                     0.000000             0.000000
# 1943                     3.000000             1.000000
# 1944                     0.000000             0.000000
# ...                           ...                  ...
# 2006                     0.000000             0.500000
# 2007                     0.666667             0.000000
# 2008                     1.000000             0.333333
# 2009                     0.000000             1.416667
# 2010                     0.333333             1.500000
#
# Affiliation  University Of California, Los Angeles  University Of Chicago  \
# year
# 1940                                      0.000000               3.000000
# 1941                                      0.000000               7.000000
# 1942                                      0.000000               2.000000
# 1943                                      0.000000               1.000000
# 1944                                      1.000000               4.000000
# ...                                            ...                    ...
# 2006                                      1.333333               3.500000
# 2007                                      0.000000               3.000000
# 2008                                      1.000000               3.500000
# 2009                                      0.000000               0.666667
# 2010                                      0.416667               1.500000
#
# Affiliation  University Of Pennsylvania  Yale University
# year
# 1940                           0.000000         0.000000
# 1941                           0.000000         0.000000
# 1942                           1.000000         0.000000
# 1943                           0.000000         0.000000
# 1944                           0.000000         0.000000
# ...                                 ...              ...
# 2006                           0.000000         1.500000
# 2007                           1.500000         0.333333
# 2008                           0.000000         1.000000
# 2009                           1.333333         0.000000
# 2010                           0.250000         0.666667
#
# [71 rows x 10 columns]

# %%
import seaborn as sns
f, ax = plt.subplots(figsize=(15, 6))
sns.heatmap(invert_pivot, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# /usr/local/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       1 import seaborn as sns
#       2 f, ax = plt.subplots(figsize=(15, 6))
# ----> 3 sns.heatmap(invert_pivot, annot=True, fmt="d", linewidths=.5, ax=ax)
#
# File /usr/local/lib/python3.9/site-packages/seaborn/matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File /usr/local/lib/python3.9/site-packages/seaborn/matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# --> 352     self._annotate_heatmap(ax, mesh)
#
# File /usr/local/lib/python3.9/site-packages/seaborn/matrix.py:260, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     258 lum = relative_luminance(color)
#     259 text_color = ".15" if lum > .408 else "w"
# --> 260 annotation = ("{:" + self.fmt + "}").format(val)
#     261 text_kwargs = dict(color=text_color, ha="center", va="center")
#     262 text_kwargs.update(self.annot_kws)
#
# ValueError: Unknown format code 'd' for object of type 'float'
