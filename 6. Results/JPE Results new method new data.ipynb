# %%
import pandas as pd
import numpy as np
JPE = pd.read_excel('/Users/MattJohnson/Library/CloudStorage/OneDrive-UniversityofCapeTown/Masters_thesis/Data checks/Consolidation/Finalized/JPE_affiliations.xlsx')
print(JPE.shape)
# Out:
# (3823, 38)

# %%
# Limiting the columns to what is needed for results
JPE = JPE[['Journal_Name' ,'Authors_count', 'Authors_list', 'Article_ID', 'year',
 
 '0_author_affs_consolidated_0',
 '0_author_affs_consolidated_1', 
 '0_author_affs_consolidated_2', 

 '1_author_affs_consolidated_0',
 '1_author_affs_consolidated_1',
 '1_author_affs_consolidated_2',

 '2_author_affs_consolidated_0',
 '2_author_affs_consolidated_1', 
 '2_author_affs_consolidated_2' ,

 '3_author_affs_consolidated_0',
 '3_author_affs_consolidated_1',

 '4_author_affs_consolidated_0',

 '5_author_affs_consolidated']]

# %%
#Renaming columns to be consistant with other journals
#'year':'year_master'
JPE.rename(columns = {'0_author_affs_consolidated_0':'0_Auth_affs_0', '0_author_affs_consolidated_1':'0_Auth_affs_1', '0_author_affs_consolidated_2':'0_Auth_affs_2',
                      '1_author_affs_consolidated_0':'1_Auth_affs_0', '1_author_affs_consolidated_1':'1_Auth_affs_1', '1_author_affs_consolidated_2':'1_Auth_affs_2',
                      '2_author_affs_consolidated_0':'2_Auth_affs_0', '2_author_affs_consolidated_1':'2_Auth_affs_1', '2_author_affs_consolidated_2':'2_Auth_affs_2',
                      '3_author_affs_consolidated_0':'3_Auth_affs_0', '3_author_affs_consolidated_1':'3_Auth_affs_1',
                      '4_author_affs_consolidated_0':'4_Auth_affs_0',
                      '5_author_affs_consolidated':'5_Auth_affs_0', 
                            }, inplace = True)

#Creating blank columns to match size of other journlas
JPE['0_Auth_affs_3'] = np.nan
JPE['0_Auth_affs_4'] = np.nan

JPE['1_Auth_affs_3'] = np.nan
JPE['1_Auth_affs_4'] = np.nan

JPE['2_Auth_affs_3'] = np.nan
JPE['2_Auth_affs_4'] = np.nan

JPE['3_Auth_affs_2'] = np.nan
JPE['3_Auth_affs_3'] = np.nan
JPE['3_Auth_affs_4'] = np.nan

JPE['4_Auth_affs_1'] = np.nan
JPE['4_Auth_affs_2'] = np.nan
JPE['4_Auth_affs_3'] = np.nan

JPE['6_Auth_affs_0'] = np.nan

# %%
JPE['0_auth_affs_count'] = ""
JPE['1_auth_affs_count'] = ""
JPE['2_auth_affs_count'] = ""
JPE['3_auth_affs_count'] = ""
JPE['4_auth_affs_count'] = ""
JPE['5_auth_affs_count'] = ""
JPE['6_auth_affs_count'] = ""

JPE['0_auth_affs_0_weight'] = ""
JPE['0_auth_affs_1_weight'] = ""
JPE['0_auth_affs_2_weight'] = ""
JPE['0_auth_affs_3_weight'] = ""
JPE['0_auth_affs_4_weight'] = ""

JPE['1_auth_affs_0_weight'] = ""
JPE['1_auth_affs_1_weight'] = ""
JPE['1_auth_affs_2_weight'] = ""
JPE['1_auth_affs_3_weight'] = ""
JPE['1_auth_affs_4_weight'] = ""

JPE['2_auth_affs_0_weight'] = ""
JPE['2_auth_affs_1_weight'] = ""
JPE['2_auth_affs_2_weight'] = ""
JPE['2_auth_affs_3_weight'] = ""
JPE['2_auth_affs_4_weight'] = ""

JPE['3_auth_affs_0_weight'] = ""
JPE['3_auth_affs_1_weight'] = ""
JPE['3_auth_affs_2_weight'] = ""
JPE['3_auth_affs_3_weight'] = ""
JPE['3_auth_affs_4_weight'] = ""

JPE['4_auth_affs_0_weight'] = ""
JPE['4_auth_affs_1_weight'] = ""
JPE['4_auth_affs_2_weight'] = ""
JPE['4_auth_affs_3_weight'] = ""

JPE['5_auth_affs_0_weight'] = ""

JPE['6_auth_affs_0_weight'] = ""


#for i in range(3600,3823):
    
for i in range(len(JPE)):
    # Check the number of authors
    if JPE.iloc[i]['Authors_count'] == 1:
        # Apply the weighting to each author and their affiliations
        author_weight = 1
        
        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.isnull().iloc[i]['0_Auth_affs_1'] and JPE.isnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '0_auth_affs_count'] = affiliations
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.isnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '0_auth_affs_count'] = affiliations
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '0_auth_affs_count'] = 3
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.notnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 4
            JPE.loc[i, '0_auth_affs_count'] = 4
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.notnull().iloc[i]['0_Auth_affs_3'] and JPE.notnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 5
            JPE.loc[i, '0_auth_affs_count'] = 5
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_4_weight'] = author_weight/affiliations
        
    if JPE.iloc[i]['Authors_count'] == 2:
        # Apply the weighting to each author and their affiliations
        author_weight = 1/2

        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.isnull().iloc[i]['0_Auth_affs_1'] and JPE.isnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '0_auth_affs_count'] = affiliations
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.isnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '0_auth_affs_count'] = affiliations
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '0_auth_affs_count'] = 3
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.notnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 4
            JPE.loc[i, '0_auth_affs_count'] = 4
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.notnull().iloc[i]['0_Auth_affs_3'] and JPE.notnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 5
            JPE.loc[i, '0_auth_affs_count'] = 5
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_4_weight'] = author_weight/affiliations
        
        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.isnull().iloc[i]['1_Auth_affs_1'] and JPE.isnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '1_auth_affs_count'] = affiliations
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.isnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '1_auth_affs_count'] = affiliations
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '1_auth_affs_count'] = 3
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.notnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 4
            JPE.loc[i, '1_auth_affs_count'] = 4
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.notnull().iloc[i]['1_Auth_affs_3'] and JPE.notnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 5
            JPE.loc[i, '1_auth_affs_count'] = 5
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_4_weight'] = author_weight/affiliations

    if JPE.iloc[i]['Authors_count'] == 3:
        # Apply the weighting to each author and their affiliations
        author_weight = 1/3

        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.isnull().iloc[i]['0_Auth_affs_1'] and JPE.isnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '0_auth_affs_count'] = affiliations
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.isnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '0_auth_affs_count'] = affiliations
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '0_auth_affs_count'] = 3
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.notnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 4
            JPE.loc[i, '0_auth_affs_count'] = 4
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.notnull().iloc[i]['0_Auth_affs_3'] and JPE.notnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 5
            JPE.loc[i, '0_auth_affs_count'] = 5
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_4_weight'] = author_weight/affiliations
        
        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.isnull().iloc[i]['1_Auth_affs_1'] and JPE.isnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '1_auth_affs_count'] = affiliations
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.isnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '1_auth_affs_count'] = affiliations
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '1_auth_affs_count'] = 3
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.notnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 4
            JPE.loc[i, '1_auth_affs_count'] = 4
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.notnull().iloc[i]['1_Auth_affs_3'] and JPE.notnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 5
            JPE.loc[i, '1_auth_affs_count'] = 5
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_4_weight'] = author_weight/affiliations

        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.isnull().iloc[i]['2_Auth_affs_1'] and JPE.isnull().iloc[i]['2_Auth_affs_2'] and JPE.isnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '2_auth_affs_count'] = affiliations
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.isnull().iloc[i]['2_Auth_affs_2'] and JPE.isnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '2_auth_affs_count'] = affiliations
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.notnull().iloc[i]['2_Auth_affs_2'] and JPE.isnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '2_auth_affs_count'] = 3
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.notnull().iloc[i]['2_Auth_affs_2'] and JPE.notnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('3 aff 4')
            affiliations = 4
            JPE.loc[i, '2_auth_affs_count'] = 4
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.notnull().iloc[i]['2_Auth_affs_2'] and JPE.notnull().iloc[i]['2_Auth_affs_3'] and JPE.notnull().iloc[i]['2_Auth_affs_4']:
            print('3 aff 5')
            affiliations = 5
            JPE.loc[i, '2_auth_affs_count'] = 5
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_4_weight'] = author_weight/affiliations


    if JPE.iloc[i]['Authors_count'] == 4:
        # Apply the weighting to each author and their affiliations
        author_weight = 1/4

        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.isnull().iloc[i]['0_Auth_affs_1'] and JPE.isnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '0_auth_affs_count'] = affiliations
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.isnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '0_auth_affs_count'] = affiliations
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '0_auth_affs_count'] = 3
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.notnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 4
            JPE.loc[i, '0_auth_affs_count'] = 4
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.notnull().iloc[i]['0_Auth_affs_3'] and JPE.notnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 5
            JPE.loc[i, '0_auth_affs_count'] = 5
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_4_weight'] = author_weight/affiliations
        
        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.isnull().iloc[i]['1_Auth_affs_1'] and JPE.isnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '1_auth_affs_count'] = affiliations
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.isnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '1_auth_affs_count'] = affiliations
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '1_auth_affs_count'] = 3
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.notnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 4
            JPE.loc[i, '1_auth_affs_count'] = 4
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.notnull().iloc[i]['1_Auth_affs_3'] and JPE.notnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 5
            JPE.loc[i, '1_auth_affs_count'] = 5
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_4_weight'] = author_weight/affiliations

        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.isnull().iloc[i]['2_Auth_affs_1'] and JPE.isnull().iloc[i]['2_Auth_affs_2'] and JPE.isnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '2_auth_affs_count'] = affiliations
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.isnull().iloc[i]['2_Auth_affs_2'] and JPE.isnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '2_auth_affs_count'] = affiliations
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.notnull().iloc[i]['2_Auth_affs_2'] and JPE.isnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '2_auth_affs_count'] = 3
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.notnull().iloc[i]['2_Auth_affs_2'] and JPE.notnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('3 aff 4')
            affiliations = 4
            JPE.loc[i, '2_auth_affs_count'] = 4
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.notnull().iloc[i]['2_Auth_affs_2'] and JPE.notnull().iloc[i]['2_Auth_affs_3'] and JPE.notnull().iloc[i]['2_Auth_affs_4']:
            print('3 aff 5')
            affiliations = 5
            JPE.loc[i, '2_auth_affs_count'] = 5
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_4_weight'] = author_weight/affiliations

        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['3_Auth_affs_0'] and JPE.isnull().iloc[i]['3_Auth_affs_1'] and JPE.isnull().iloc[i]['3_Auth_affs_2'] and JPE.isnull().iloc[i]['3_Auth_affs_3']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '3_auth_affs_count'] = affiliations
            JPE.loc[i, '3_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['3_Auth_affs_0'] and JPE.notnull().iloc[i]['3_Auth_affs_1'] and JPE.isnull().iloc[i]['3_Auth_affs_2'] and JPE.isnull().iloc[i]['3_Auth_affs_3']:
            print('3 aff 0')
            affiliations = 2
            JPE.loc[i, '3_auth_affs_count'] = affiliations
            JPE.loc[i, '3_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['3_Auth_affs_0'] and JPE.notnull().iloc[i]['3_Auth_affs_1'] and JPE.notnull().iloc[i]['3_Auth_affs_2'] and JPE.isnull().iloc[i]['3_Auth_affs_3']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '3_auth_affs_count'] = 3
            JPE.loc[i, '3_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['3_Auth_affs_0'] and JPE.notnull().iloc[i]['3_Auth_affs_1'] and JPE.notnull().iloc[i]['3_Auth_affs_2'] and JPE.notnull().iloc[i]['3_Auth_affs_3']:
            print('3 aff 4')
            affiliations = 4
            JPE.loc[i, '3_auth_affs_count'] = 4
            JPE.loc[i, '3_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_3_weight'] = author_weight/affiliations


    if JPE.iloc[i]['Authors_count'] == 5:
        # Apply the weighting to each author and their affiliations
        author_weight = 1/5

        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.isnull().iloc[i]['0_Auth_affs_1'] and JPE.isnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '0_auth_affs_count'] = affiliations
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.isnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '0_auth_affs_count'] = affiliations
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '0_auth_affs_count'] = 3
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.notnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 4
            JPE.loc[i, '0_auth_affs_count'] = 4
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.notnull().iloc[i]['0_Auth_affs_3'] and JPE.notnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 5
            JPE.loc[i, '0_auth_affs_count'] = 5
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_4_weight'] = author_weight/affiliations
        
        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.isnull().iloc[i]['1_Auth_affs_1'] and JPE.isnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '1_auth_affs_count'] = affiliations
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.isnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '1_auth_affs_count'] = affiliations
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '1_auth_affs_count'] = 3
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.notnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 4
            JPE.loc[i, '1_auth_affs_count'] = 4
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.notnull().iloc[i]['1_Auth_affs_3'] and JPE.notnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 5
            JPE.loc[i, '1_auth_affs_count'] = 5
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_4_weight'] = author_weight/affiliations

        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.isnull().iloc[i]['2_Auth_affs_1'] and JPE.isnull().iloc[i]['2_Auth_affs_2'] and JPE.isnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '2_auth_affs_count'] = affiliations
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.isnull().iloc[i]['2_Auth_affs_2'] and JPE.isnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '2_auth_affs_count'] = affiliations
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.notnull().iloc[i]['2_Auth_affs_2'] and JPE.isnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '2_auth_affs_count'] = 3
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.notnull().iloc[i]['2_Auth_affs_2'] and JPE.notnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('3 aff 4')
            affiliations = 4
            JPE.loc[i, '2_auth_affs_count'] = 4
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.notnull().iloc[i]['2_Auth_affs_2'] and JPE.notnull().iloc[i]['2_Auth_affs_3'] and JPE.notnull().iloc[i]['2_Auth_affs_4']:
            print('3 aff 5')
            affiliations = 5
            JPE.loc[i, '2_auth_affs_count'] = 5
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_4_weight'] = author_weight/affiliations

        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['3_Auth_affs_0'] and JPE.isnull().iloc[i]['3_Auth_affs_1'] and JPE.isnull().iloc[i]['3_Auth_affs_2'] and JPE.isnull().iloc[i]['3_Auth_affs_3']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '3_auth_affs_count'] = affiliations
            JPE.loc[i, '3_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['3_Auth_affs_0'] and JPE.notnull().iloc[i]['3_Auth_affs_1'] and JPE.isnull().iloc[i]['3_Auth_affs_2'] and JPE.isnull().iloc[i]['3_Auth_affs_3']:
            print('3 aff 0')
            affiliations = 2
            JPE.loc[i, '3_auth_affs_count'] = affiliations
            JPE.loc[i, '3_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['3_Auth_affs_0'] and JPE.notnull().iloc[i]['3_Auth_affs_1'] and JPE.notnull().iloc[i]['3_Auth_affs_2'] and JPE.isnull().iloc[i]['3_Auth_affs_3']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '3_auth_affs_count'] = 3
            JPE.loc[i, '3_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['3_Auth_affs_0'] and JPE.notnull().iloc[i]['3_Auth_affs_1'] and JPE.notnull().iloc[i]['3_Auth_affs_2'] and JPE.notnull().iloc[i]['3_Auth_affs_3']:
            print('3 aff 4')
            affiliations = 4
            JPE.loc[i, '3_auth_affs_count'] = 4
            JPE.loc[i, '3_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_3_weight'] = author_weight/affiliations
    
        if JPE.notnull().iloc[i]['4_Auth_affs_0']:
            print('3 aff 4')
            affiliations = 1
            JPE.loc[i, '4_auth_affs_count'] = 4
            JPE.loc[i, '4_auth_affs_0_weight'] = author_weight/affiliations


    if JPE.iloc[i]['Authors_count'] == 6:
        # Apply the weighting to each author and their affiliations
        author_weight = 1/6

        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.isnull().iloc[i]['0_Auth_affs_1'] and JPE.isnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '0_auth_affs_count'] = affiliations
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.isnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '0_auth_affs_count'] = affiliations
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.isnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '0_auth_affs_count'] = 3
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.notnull().iloc[i]['0_Auth_affs_3'] and JPE.isnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 4
            JPE.loc[i, '0_auth_affs_count'] = 4
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['0_Auth_affs_0'] and JPE.notnull().iloc[i]['0_Auth_affs_1'] and JPE.notnull().iloc[i]['0_Auth_affs_2'] and JPE.notnull().iloc[i]['0_Auth_affs_3'] and JPE.notnull().iloc[i]['0_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 5
            JPE.loc[i, '0_auth_affs_count'] = 5
            JPE.loc[i, '0_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '0_auth_affs_4_weight'] = author_weight/affiliations
        
        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.isnull().iloc[i]['1_Auth_affs_1'] and JPE.isnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '1_auth_affs_count'] = affiliations
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.isnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '1_auth_affs_count'] = affiliations
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.isnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '1_auth_affs_count'] = 3
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.notnull().iloc[i]['1_Auth_affs_3'] and JPE.isnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 4
            JPE.loc[i, '1_auth_affs_count'] = 4
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['1_Auth_affs_0'] and JPE.notnull().iloc[i]['1_Auth_affs_1'] and JPE.notnull().iloc[i]['1_Auth_affs_2'] and JPE.notnull().iloc[i]['1_Auth_affs_3'] and JPE.notnull().iloc[i]['1_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 5
            JPE.loc[i, '1_auth_affs_count'] = 5
            JPE.loc[i, '1_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '1_auth_affs_4_weight'] = author_weight/affiliations

        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.isnull().iloc[i]['2_Auth_affs_1'] and JPE.isnull().iloc[i]['2_Auth_affs_2'] and JPE.isnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '2_auth_affs_count'] = affiliations
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.isnull().iloc[i]['2_Auth_affs_2'] and JPE.isnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('2 aff 0')
            affiliations = 2
            JPE.loc[i, '2_auth_affs_count'] = affiliations
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.notnull().iloc[i]['2_Auth_affs_2'] and JPE.isnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '2_auth_affs_count'] = 3
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.notnull().iloc[i]['2_Auth_affs_2'] and JPE.notnull().iloc[i]['2_Auth_affs_3'] and JPE.isnull().iloc[i]['2_Auth_affs_4']:
            print('3 aff 4')
            affiliations = 4
            JPE.loc[i, '2_auth_affs_count'] = 4
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['2_Auth_affs_0'] and JPE.notnull().iloc[i]['2_Auth_affs_1'] and JPE.notnull().iloc[i]['2_Auth_affs_2'] and JPE.notnull().iloc[i]['2_Auth_affs_3'] and JPE.notnull().iloc[i]['2_Auth_affs_4']:
            print('3 aff 5')
            affiliations = 5
            JPE.loc[i, '2_auth_affs_count'] = 5
            JPE.loc[i, '2_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_3_weight'] = author_weight/affiliations
            JPE.loc[i, '2_auth_affs_4_weight'] = author_weight/affiliations

        # Check the number of affiliations from each author
        if JPE.notnull().iloc[i]['3_Auth_affs_0'] and JPE.isnull().iloc[i]['3_Auth_affs_1'] and JPE.isnull().iloc[i]['3_Auth_affs_2'] and JPE.isnull().iloc[i]['3_Auth_affs_3']:
            print('1 aff 0')
            affiliations = 1
            JPE.loc[i, '3_auth_affs_count'] = affiliations
            JPE.loc[i, '3_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['3_Auth_affs_0'] and JPE.notnull().iloc[i]['3_Auth_affs_1'] and JPE.isnull().iloc[i]['3_Auth_affs_2'] and JPE.isnull().iloc[i]['3_Auth_affs_3']:
            print('3 aff 0')
            affiliations = 2
            JPE.loc[i, '3_auth_affs_count'] = affiliations
            JPE.loc[i, '3_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_1_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['3_Auth_affs_0'] and JPE.notnull().iloc[i]['3_Auth_affs_1'] and JPE.notnull().iloc[i]['3_Auth_affs_2'] and JPE.isnull().iloc[i]['3_Auth_affs_3']:
            print('3 aff 0')
            affiliations = 3
            JPE.loc[i, '3_auth_affs_count'] = 3
            JPE.loc[i, '3_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_2_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['3_Auth_affs_0'] and JPE.notnull().iloc[i]['3_Auth_affs_1'] and JPE.notnull().iloc[i]['3_Auth_affs_2'] and JPE.notnull().iloc[i]['3_Auth_affs_3']:
            print('3 aff 4')
            affiliations = 4
            JPE.loc[i, '3_auth_affs_count'] = 4
            JPE.loc[i, '3_auth_affs_0_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_1_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_2_weight'] = author_weight/affiliations
            JPE.loc[i, '3_auth_affs_3_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['4_Auth_affs_0']:
            print('3 aff 4')
            affiliations = 1
            JPE.loc[i, '4_auth_affs_count'] = 4
            JPE.loc[i, '4_auth_affs_0_weight'] = author_weight/affiliations

        if JPE.notnull().iloc[i]['5_Auth_affs_0']:
            print('3 aff 4')
            affiliations = 1
            JPE.loc[i, '5_auth_affs_count'] = 4
            JPE.loc[i, '5_auth_affs_0_weight'] = author_weight/affiliations



    print(i)
# Out:
# 1 aff 0
# 0
# 1 aff 0
# 1
# 1 aff 0
# 1 aff 0
# 2
# 1 aff 0
# 3
# 1 aff 0
# 4
# 1 aff 0
# 5
# 1 aff 0
# 6
# 1 aff 0
# 7
# 1 aff 0
# 1 aff 0
# 8
# 1 aff 0
# 9
# 1 aff 0
# 10
# 1 aff 0
# 11
# 1 aff 0
# 12
# 1 aff 0
# 13
# 1 aff 0
# 14
# 1 aff 0
# 1 aff 0
# 15
# 1 aff 0
# 16
# 1 aff 0
# 17
# 1 aff 0
# 18
# 1 aff 0
# 19
# 1 aff 0
# 20
# 1 aff 0
# 21
# 1 aff 0
# 22
# 1 aff 0
# 23
# 1 aff 0
# 24
# 1 aff 0
# 25
# 1 aff 0
# 26
# 1 aff 0
# 27
# 1 aff 0
# 28
# 1 aff 0
# 29
# 1 aff 0
# 30
# 1 aff 0
# 31
# 1 aff 0
# 32
# 1 aff 0
# 33
# 1 aff 0
# 34
# 1 aff 0
# 35
# 1 aff 0
# 36
# 1 aff 0
# 37
# 1 aff 0
# 38
# 1 aff 0
# 39
# 1 aff 0
# 40
# 1 aff 0
# 41
# 1 aff 0
# 42
# 1 aff 0
# 43
# 1 aff 0
# 44
# 1 aff 0
# 45
# 1 aff 0
# 46
# 1 aff 0
# 47
# 1 aff 0
# 48
# 1 aff 0
# 49
# 1 aff 0
# 50
# 1 aff 0
# 51
# 1 aff 0
# 52
# 1 aff 0
# 53
# 1 aff 0
# 54
# 1 aff 0
# 55
# 1 aff 0
# 56
# 1 aff 0
# 57
# 1 aff 0
# 58
# 1 aff 0
# 59
# 1 aff 0
# 60
# 1 aff 0
# 61
# 1 aff 0
# 62
# 1 aff 0
# 63
# 1 aff 0
# 64
# ...

# %%
# Excel output to get an overview of the data
JPE.head
JPE.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/4_Results/JPE/Weighting/JPE_Weights_applied.xlsx')

# %%
import pandas as pd
import numpy as np
JPE_to_melt = pd.read_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/4_Results/JPE/Weighting/JPE_Weights_applied.xlsx')
print(JPE_to_melt.shape)
# Out:
# (3823, 65)

# %%
JPE_to_melt= JPE.copy()
print(JPE_to_melt.shape)
# Out:
# (3823, 64)

# %%
JPE_to_melt["0_Auth_affs_0 + Weight"] = JPE_to_melt["0_Auth_affs_0"].astype(str) + "+" + JPE_to_melt["0_auth_affs_0_weight"].astype(str)
JPE_to_melt["0_Auth_affs_1 + Weight"] = JPE_to_melt["0_Auth_affs_1"].astype(str) + "+" + JPE_to_melt["0_auth_affs_1_weight"].astype(str)
JPE_to_melt["0_Auth_affs_2 + Weight"] = JPE_to_melt["0_Auth_affs_2"].astype(str) + "+" + JPE_to_melt["0_auth_affs_2_weight"].astype(str)
JPE_to_melt["0_Auth_affs_3 + Weight"] = JPE_to_melt["0_Auth_affs_3"].astype(str) + "+" + JPE_to_melt["0_auth_affs_3_weight"].astype(str)
JPE_to_melt["0_Auth_affs_4 + Weight"] = JPE_to_melt["0_Auth_affs_4"].astype(str) + "+" + JPE_to_melt["0_auth_affs_4_weight"].astype(str)

JPE_to_melt["1_Auth_affs_0 + Weight"] = JPE_to_melt["1_Auth_affs_0"].astype(str) + "+" + JPE_to_melt["1_auth_affs_0_weight"].astype(str)
JPE_to_melt["1_Auth_affs_1 + Weight"] = JPE_to_melt["1_Auth_affs_1"].astype(str) + "+" + JPE_to_melt["1_auth_affs_1_weight"].astype(str)
JPE_to_melt["1_Auth_affs_2 + Weight"] = JPE_to_melt["1_Auth_affs_2"].astype(str) + "+" + JPE_to_melt["1_auth_affs_2_weight"].astype(str)
JPE_to_melt["1_Auth_affs_3 + Weight"] = JPE_to_melt["1_Auth_affs_3"].astype(str) + "+" + JPE_to_melt["1_auth_affs_3_weight"].astype(str)
JPE_to_melt["1_Auth_affs_4 + Weight"] = JPE_to_melt["1_Auth_affs_4"].astype(str) + "+" + JPE_to_melt["1_auth_affs_4_weight"].astype(str)

JPE_to_melt["2_Auth_affs_0 + Weight"] = JPE_to_melt["2_Auth_affs_0"].astype(str) + "+" + JPE_to_melt["2_auth_affs_0_weight"].astype(str)
JPE_to_melt["2_Auth_affs_1 + Weight"] = JPE_to_melt["2_Auth_affs_1"].astype(str) + "+" + JPE_to_melt["2_auth_affs_1_weight"].astype(str)
JPE_to_melt["2_Auth_affs_2 + Weight"] = JPE_to_melt["2_Auth_affs_2"].astype(str) + "+" + JPE_to_melt["2_auth_affs_2_weight"].astype(str)
JPE_to_melt["2_Auth_affs_3 + Weight"] = JPE_to_melt["2_Auth_affs_3"].astype(str) + "+" + JPE_to_melt["2_auth_affs_3_weight"].astype(str)
JPE_to_melt["2_Auth_affs_4 + Weight"] = JPE_to_melt["2_Auth_affs_4"].astype(str) + "+" + JPE_to_melt["2_auth_affs_4_weight"].astype(str)

JPE_to_melt["3_Auth_affs_0 + Weight"] = JPE_to_melt["3_Auth_affs_0"].astype(str) + "+" + JPE_to_melt["3_auth_affs_0_weight"].astype(str)
JPE_to_melt["3_Auth_affs_1 + Weight"] = JPE_to_melt["3_Auth_affs_1"].astype(str) + "+" + JPE_to_melt["3_auth_affs_1_weight"].astype(str)
JPE_to_melt["3_Auth_affs_2 + Weight"] = JPE_to_melt["3_Auth_affs_2"].astype(str) + "+" + JPE_to_melt["3_auth_affs_2_weight"].astype(str)
JPE_to_melt["3_Auth_affs_3 + Weight"] = JPE_to_melt["3_Auth_affs_3"].astype(str) + "+" + JPE_to_melt["3_auth_affs_3_weight"].astype(str)
#JPE_to_melt["3_Auth_affs_4 + Weight"] = JPE_to_melt["3_Auth_affs_4"].astype(str) + "+" + JPE_to_melt["3_auth_affs_4_weight"].astype(str)

JPE_to_melt["4_Auth_affs_0 + Weight"] = JPE_to_melt["4_Auth_affs_0"].astype(str) + "+" + JPE_to_melt["4_auth_affs_0_weight"].astype(str)
JPE_to_melt["4_Auth_affs_1 + Weight"] = JPE_to_melt["4_Auth_affs_1"].astype(str) + "+" + JPE_to_melt["4_auth_affs_1_weight"].astype(str)
JPE_to_melt["4_Auth_affs_2 + Weight"] = JPE_to_melt["4_Auth_affs_2"].astype(str) + "+" + JPE_to_melt["4_auth_affs_2_weight"].astype(str)
JPE_to_melt["4_Auth_affs_3 + Weight"] = JPE_to_melt["4_Auth_affs_3"].astype(str) + "+" + JPE_to_melt["4_auth_affs_3_weight"].astype(str)

JPE_to_melt["5_Auth_affs_0 + Weight"] = JPE_to_melt["5_Auth_affs_0"].astype(str) + "+" + JPE_to_melt["5_auth_affs_0_weight"].astype(str)

JPE_to_melt["6_Auth_affs_0 + Weight"] = JPE_to_melt["6_Auth_affs_0"].astype(str) + "+" + JPE_to_melt["6_auth_affs_0_weight"].astype(str)


print(JPE_to_melt.shape)
JPE_to_melt.replace("nan+nan", np.nan, inplace= True)
print(JPE_to_melt.head())
# Out:
# (3823, 90)
#    Unnamed: 0 Journal_Name  Authors_count  \
# 0           0          JPE              1
# 1           1          JPE              1
# 2           2          JPE              2
# 3           3          JPE              1
# 4           4          JPE              1
#
#                               Authors_list  Article_ID  year  \
# 0                         ['Gerhard Colm']     1825913  1940
# 1                        ['Jules Backman']     1825487  1940
# 2  ['William Fellner', ' Howard S. Ellis']     1825486  1940
# 3                        ['Harvey Pinney']     1825485  1940
# 4                    ['George J. Stigler']     1825484  1940
#
#              0_Auth_affs_0 0_Auth_affs_1 0_Auth_affs_2 1_Auth_affs_0  ...  \
# 0     Washington DC (City)           NaN           NaN           NaN  ...
# 1      New York University           NaN           NaN           NaN  ...
# 2                      UCB           NaN           NaN           UCB  ...
# ...

# %%
# Excel output to get an overview of the data
JPE_to_melt.head
JPE_to_melt.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/4_Results/JPE/Weighting/JPE_to_melt.xlsx')

# %%
melted = JPE_to_melt.melt(id_vars= ['Article_ID','year'], value_vars=["0_Auth_affs_0 + Weight","0_Auth_affs_1 + Weight","0_Auth_affs_2 + Weight","0_Auth_affs_3 + Weight", "0_Auth_affs_4 + Weight",
                                                              "1_Auth_affs_0 + Weight","1_Auth_affs_1 + Weight","1_Auth_affs_2 + Weight","1_Auth_affs_3 + Weight", "1_Auth_affs_4 + Weight",
                                                              "2_Auth_affs_0 + Weight","2_Auth_affs_1 + Weight","2_Auth_affs_2 + Weight","2_Auth_affs_3 + Weight", "2_Auth_affs_4 + Weight",
                                                              "3_Auth_affs_0 + Weight","3_Auth_affs_1 + Weight","3_Auth_affs_2 + Weight","3_Auth_affs_3 + Weight",
                                                              "4_Auth_affs_0 + Weight","4_Auth_affs_1 + Weight","4_Auth_affs_2 + Weight","4_Auth_affs_3 + Weight",
                                                              "5_Auth_affs_0 + Weight","6_Auth_affs_0 + Weight"]).dropna()

melted.rename(columns = {'variable':'Aff Number + Weight'}, inplace = True)
melted.rename(columns = {'value':'Aff + Weight'}, inplace = True)

melted = melted.sort_values(by=['year'])

print(melted.head())
print(melted.shape)
# Out:
#     Article_ID  year     Aff Number + Weight                 Aff + Weight
# 0      1825913  1940  0_Auth_affs_0 + Weight     Washington DC (City)+1.0
# 23     1825908  1940  0_Auth_affs_0 + Weight    University Of Chicago+1.0
# 24     1824384  1940  0_Auth_affs_0 + Weight      Columbia University+1.0
# 25     1824382  1940  0_Auth_affs_0 + Weight       Cornell University+1.0
# 26     1824381  1940  0_Auth_affs_0 + Weight  University Of Edinburgh+1.0
# (6426, 4)

# %%
melted[['Affiliation','Weight']] = melted['Aff + Weight'].str.split("+",expand=True) 
melted.replace("", np.nan, inplace= True)
melted["Weight"]= melted["Weight"].astype(float)
print(melted.head())
print(melted.shape)
# Out:
#     Article_ID  year     Aff Number + Weight                 Aff + Weight  \
# 0      1825913  1940  0_Auth_affs_0 + Weight     Washington DC (City)+1.0
# 23     1825908  1940  0_Auth_affs_0 + Weight    University Of Chicago+1.0
# 24     1824384  1940  0_Auth_affs_0 + Weight      Columbia University+1.0
# 25     1824382  1940  0_Auth_affs_0 + Weight       Cornell University+1.0
# 26     1824381  1940  0_Auth_affs_0 + Weight  University Of Edinburgh+1.0
#
#                 Affiliation  Weight
# 0      Washington DC (City)     1.0
# 23    University Of Chicago     1.0
# 24      Columbia University     1.0
# 25       Cornell University     1.0
# 26  University Of Edinburgh     1.0
# (6426, 6)

# %%
# Excel output to get an overview of the data
melted.head
melted.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/4_Results/JPE/Weighting/JPE_melted.xlsx')

# %%
Melted_to_aggregate= melted.copy()
Melted_to_aggregate = Melted_to_aggregate[['Article_ID','year', 'Affiliation', 'Weight']]
print(Melted_to_aggregate.head())
print(Melted_to_aggregate.shape)
Melted_to_aggregate.dtypes

Melted_to_count= melted.copy()
Melted_to_sum= melted.copy()
# Out:
#     Article_ID  year              Affiliation  Weight
# 0      1825913  1940     Washington DC (City)     1.0
# 23     1825908  1940    University Of Chicago     1.0
# 24     1824384  1940      Columbia University     1.0
# 25     1824382  1940       Cornell University     1.0
# 26     1824381  1940  University Of Edinburgh     1.0
# (6426, 4)

# %%
# Sums the weights per year of each affilation

aggregate = Melted_to_aggregate.groupby(['Affiliation','year']).sum()
aggregate = aggregate.sort_values('Weight', ascending=False)
aggregate.head()
#aggregate.shape
# Out:
#                                            Article_ID    Weight
# Affiliation                          year
# National Bureau Of Economic Research 2004    16295185  9.138889
# University Of Chicago                1971    18314709  9.000000
#                                      1991    29377070  8.666667
# Washington DC (City)                 1942    18258692  8.500000
# University Of Chicago                1968    16470108  8.500000

# %%
# Sums the weights per year of each affilation

aggregate = Melted_to_aggregate.groupby(['Affiliation'])['Weight'].sum()
#aggregate = aggregate.sort_values('Weight', ascending=False)
aggregate.head()
#aggregate.shape
# Out:
# Affiliation
#  Christian-Albrechts-University At Kiel            0.250000
#  Pennsylania State University                      0.333333
# 1Bm Research Center, Yorktown Heights, New York    1.000000
# 1Bm, Chicago Insurance Office                      0.500000
# A B Laffer Associates                              1.000000
# Name: Weight, dtype: float64

# %%
# Cum sums on affilation

Melted_to_count['aff_cum_counts'] = Melted_to_count.groupby(['Affiliation']).cumcount()+1

Melted_to_count = Melted_to_count[['Article_ID' , 'Affiliation','year', 'aff_cum_counts', 'Weight']]

# Checking the top 20 occurances of Universities over the 70 years
highest_vals_count = Melted_to_count.drop_duplicates(subset = ['Affiliation'], keep = 'last')
highest_vals_count = highest_vals_count.nlargest(20,'aff_cum_counts')
highest_vals_count

highest_vals_count.tail()
print(highest_vals_count.head())

lowest_vals_count = Melted_to_count.drop_duplicates(subset = ['Affiliation'], keep = False)


# Excel output to get an overview of the data
lowest_vals_count.head
lowest_vals_count.to_excel('/Users/MattJohnson/Desktop/Affiliations/2_Extracting affilitations/4_Results/JPE/Weighting/lowest_vals_count.xlsx')
# Out:
#        Article_ID                            Affiliation  year  \
# 3814       652462                  University Of Chicago  2010
# 26743      655858   National Bureau Of Economic Research  2010
# 22934      653714                     Harvard University  2010
# 3819       653714  Massachusetts Institute Of Technology  2010
# 22918      655844             University Of Pennsylvania  2010
#
#        aff_cum_counts    Weight
# 3814              491  1.000000
# 26743             413  0.250000
# 22934             202  0.333333
# 3819              196  0.333333
# 22918             152  0.166667

# %%
Melted_to_sum['aff_cum_sum'] = Melted_to_sum.groupby(['Affiliation'])['Weight'].cumsum()

Melted_to_sum = Melted_to_sum[['Article_ID' , 'Affiliation','year', 'aff_cum_sum', 'Weight']]

Melted_to_sum = Melted_to_sum[['Article_ID' , 'Weight','Affiliation','year', 'aff_cum_sum'] ]
# Checking the top 20 occurances of Universities over the 70 years
highest_vals_sum = Melted_to_sum.drop_duplicates(subset = ['Affiliation'], keep = 'last')
highest_vals_sum = highest_vals_sum.nlargest(20,'aff_cum_sum')
highest_vals_sum

Melted_to_sum.tail()
print(highest_vals_sum)
# Out:
#        Article_ID    Weight                            Affiliation  year  \
# 3814       652462  1.000000                  University Of Chicago  2010
# 26743      655858  0.250000   National Bureau Of Economic Research  2010
# 3819       653714  0.333333  Massachusetts Institute Of Technology  2010
# 22934      653714  0.333333                     Harvard University  2010
# 3820       653138  0.333333                   Princeton University  2010
# 3809       651673  0.250000                    Stanford University  2010
# 3822       652463  0.250000                    Columbia University  2010
# 3800       657949  0.333333                        Yale University  2010
# 22918      655844  0.166667             University Of Pennsylvania  2010
# 3821       653690  0.166667                                   UCLA  2010
# 22913      658161  0.250000                Northwestern University  2010
# 41997      649760  0.166667                 University Of Michigan  2009
# ...

# %%
#Stacked plot on all years
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#print(melted.head())

a = Melted_to_sum.loc[(Melted_to_sum['Affiliation'] == highest_vals_sum.iat[0,2])].drop_duplicates(subset = ['year'], keep = 'last')
print(a.shape)
print(a.head())
print(a.tail())
b = Melted_to_sum.loc[(Melted_to_sum['Affiliation'] == highest_vals_sum.iat[1,2])].drop_duplicates(subset = ['year'], keep = 'last')
print(b.shape)
c = Melted_to_sum.loc[(Melted_to_sum['Affiliation'] == highest_vals_sum.iat[2,2])].drop_duplicates(subset = ['year'], keep = 'last')
d = Melted_to_sum.loc[(Melted_to_sum['Affiliation'] == highest_vals_sum.iat[3,2])].drop_duplicates(subset = ['year'], keep = 'last')
e = Melted_to_sum.loc[(Melted_to_sum['Affiliation'] == highest_vals_sum.iat[4,2])].drop_duplicates(subset = ['year'], keep = 'last')
f = Melted_to_sum.loc[(Melted_to_sum['Affiliation'] == highest_vals_sum.iat[5,2])].drop_duplicates(subset = ['year'], keep = 'last')
g = Melted_to_sum.loc[(Melted_to_sum['Affiliation'] == highest_vals_sum.iat[6,2])].drop_duplicates(subset = ['year'], keep = 'last')
h = Melted_to_sum.loc[(Melted_to_sum['Affiliation'] == highest_vals_sum.iat[7,2])].drop_duplicates(subset = ['year'], keep = 'last')
i = Melted_to_sum.loc[(Melted_to_sum['Affiliation'] == highest_vals_sum.iat[8,2])].drop_duplicates(subset = ['year'], keep = 'last')
j = Melted_to_sum.loc[(Melted_to_sum['Affiliation'] == highest_vals_sum.iat[9,2])].drop_duplicates(subset = ['year'], keep = 'last')
k = Melted_to_sum.loc[(Melted_to_sum['Affiliation'] == highest_vals_sum.iat[10,2])].drop_duplicates(subset = ['year'], keep = 'last')

plt.figure(figsize=(12,10))
plt.plot(a['year'],a['aff_cum_sum'], label = highest_vals_sum.iat[0,2])
plt.plot(b['year'],b['aff_cum_sum'], label = highest_vals_sum.iat[1,2])
plt.plot(c['year'],c['aff_cum_sum'], label = highest_vals_sum.iat[2,2])
plt.plot(d['year'],d['aff_cum_sum'], label = highest_vals_sum.iat[3,2])
plt.plot(e['year'],e['aff_cum_sum'], label = highest_vals_sum.iat[4,2])
plt.plot(f['year'],f['aff_cum_sum'], label = highest_vals_sum.iat[5,2])
plt.plot(g['year'],g['aff_cum_sum'], label = highest_vals_sum.iat[6,2])
plt.plot(h['year'],h['aff_cum_sum'], label = highest_vals_sum.iat[7,2])
plt.plot(i['year'],i['aff_cum_sum'], label = highest_vals_sum.iat[8,2])
plt.plot(j['year'],j['aff_cum_sum'], label = highest_vals_sum.iat[9,2])
#plt.plot(k['year'],k['aff_cum_counts'], label = highest_vals_10.iat[10,2])

plt.title('Weighted number of papers published by year in JPE from different Universities', fontsize=20)
plt.xlabel('Year')
plt.ylabel('Number of papers published')

plt.legend()
plt.show()
# Out:
# (71, 5)
#      Article_ID    Weight            Affiliation  year  aff_cum_sum
# 13      1824211  1.000000  University Of Chicago  1940          3.0
# 49      1825328  1.000000  University Of Chicago  1941         10.0
# 90      1825229  0.500000  University Of Chicago  1942         12.0
# 132     1826593  0.333333  University Of Chicago  1943         13.0
# 156     1826964  1.000000  University Of Chicago  1944         17.0
#        Article_ID    Weight            Affiliation  year  aff_cum_sum
# 3665       508031  0.500000  University Of Chicago  2006   315.708333
# 22843      514347  0.250000  University Of Chicago  2007   318.708333
# 3745       589756  1.000000  University Of Chicago  2008   322.208333
# 22894      597301  0.333333  University Of Chicago  2009   322.875000
# 3814       652462  1.000000  University Of Chicago  2010   324.375000
# (49, 5)

# %%
# Checking the top 20 occurances of Universities over the 70 years
highest_vals_sum = Melted_to_sum.drop_duplicates(subset = ['Affiliation'], keep = 'last')
highest_vals_sum = highest_vals_sum.nsmallest(20,'aff_cum_sum')
highest_vals_sum

Melted_to_sum.tail()
print(highest_vals_sum)
# Out:
#        Article_ID                                   Affiliation  year  \
# 64614      318600               Instituto De Análisis Económico  2001
# 30245      343744   Centre De Recerca In Economia Internacional  2002
# 25461     1833059                           Rochester Center F»  1985
# 48932     2138819                              Bank Of Portugal  1993
# 41519      250006                           Università Di Pavia  1998
# 7098       250034                                 Institute For  1998
# 3464       340780                            Th Aviv University  2002
# 26507      421172                                Levy Economics  2004
# 41843      379947                  Centre For Microdata Methods  2004
# 49449      422565           China Center For Financial Research  2004
# 49489      379947                            University College  2004
# 45666      379947        Practice, Institute for Fiscal Studies  2004
# ...
