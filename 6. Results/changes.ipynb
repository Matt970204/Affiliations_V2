# %%
        # Check the number of affiliations from each author
        if Data.notnull().iloc[i]['4_Auth_affs_0'] and Data.isnull().iloc[i]['4_Auth_affs_1'] and Data.isnull().iloc[i]['4_Auth_affs_2'] and Data.isnull().iloc[i]['4_Auth_affs_3']:
            print('1 aff 0')
            affiliations = 1
            Data.loc[i, '4_auth_affs_count'] = affiliations
            Data.loc[i, '4_auth_affs_0_weight'] = author_weight/affiliations

        if Data.notnull().iloc[i]['4_Auth_affs_0'] and Data.notnull().iloc[i]['4_Auth_affs_1'] and Data.isnull().iloc[i]['4_Auth_affs_2'] and Data.isnull().iloc[i]['4_Auth_affs_3']:
            print('4 aff 0')
            affiliations = 2
            Data.loc[i, '4_auth_affs_count'] = affiliations
            Data.loc[i, '4_auth_affs_0_weight'] = author_weight/affiliations
            Data.loc[i, '4_auth_affs_1_weight'] = author_weight/affiliations

        if Data.notnull().iloc[i]['4_Auth_affs_0'] and Data.notnull().iloc[i]['4_Auth_affs_1'] and Data.notnull().iloc[i]['4_Auth_affs_2'] and Data.isnull().iloc[i]['4_Auth_affs_3']:
            print('4 aff 0')
            affiliations = 4
            Data.loc[i, '4_auth_affs_count'] = 4
            Data.loc[i, '4_auth_affs_0_weight'] = author_weight/affiliations
            Data.loc[i, '4_auth_affs_1_weight'] = author_weight/affiliations
            Data.loc[i, '4_auth_affs_2_weight'] = author_weight/affiliations

        if Data.notnull().iloc[i]['4_Auth_affs_0'] and Data.notnull().iloc[i]['4_Auth_affs_1'] and Data.notnull().iloc[i]['4_Auth_affs_2'] and Data.notnull().iloc[i]['4_Auth_affs_3']:
            print('4 aff 4')
            affiliations = 4
            Data.loc[i, '4_auth_affs_count'] = 4
            Data.loc[i, '4_auth_affs_0_weight'] = author_weight/affiliations
            Data.loc[i, '4_auth_affs_1_weight'] = author_weight/affiliations
            Data.loc[i, '4_auth_affs_2_weight'] = author_weight/affiliations
            Data.loc[i, '4_auth_affs_3_weight'] = author_weight/affiliations

# %%
import re
for i in range(len(Data)):
    print(i)
    for key in consolidated_affiliations_dict.keys():
        
        if key in Data.iloc[i]['0_Auth_affs_0']: 
            if len(key) == len(Data.iloc[i]['0_Auth_affs_0']):
                Data.loc[i,'0_Auth_affs_0']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['0_Auth_affs_1']: 
            if len(key) == len(Data.iloc[i]['0_Auth_affs_1']):
                Data.loc[i,'0_Auth_affs_1']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['0_Auth_affs_2']: 
            if len(key) == len(Data.iloc[i]['0_Auth_affs_2']):
                Data.loc[i,'0_Auth_affs_2']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['0_Auth_affs_3']: 
            if len(key) == len(Data.iloc[i]['0_Auth_affs_3']):
                Data.loc[i,'0_Auth_affs_3']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['0_Auth_affs_4']: 
            if len(key) == len(Data.iloc[i]['0_Auth_affs_4']):
                Data.loc[i,'0_Auth_affs_4']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['1_Auth_affs_0']: 
            if len(key) == len(Data.iloc[i]['1_Auth_affs_0']):
                Data.loc[i,'1_Auth_affs_0']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['1_Auth_affs_1']: 
            if len(key) == len(Data.iloc[i]['1_Auth_affs_1']):
                Data.loc[i,'1_Auth_affs_1']  = consolidated_affiliations_dict[key]
    
        if key in Data.iloc[i]['1_Auth_affs_2']: 
            if len(key) == len(Data.iloc[i]['1_Auth_affs_2']):
                Data.loc[i,'1_Auth_affs_2']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['1_Auth_affs_3']: 
            if len(key) == len(Data.iloc[i]['1_Auth_affs_3']):
                Data.loc[i,'1_Auth_affs_3']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['1_Auth_affs_4']: 
            if len(key) == len(Data.iloc[i]['1_Auth_affs_4']):
                Data.loc[i,'1_Auth_affs_4']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['2_Auth_affs_0']: 
            if len(key) == len(Data.iloc[i]['2_Auth_affs_0']):
                Data.loc[i,'2_Auth_affs_0']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['2_Auth_affs_1']: 
            if len(key) == len(Data.iloc[i]['2_Auth_affs_1']):
                Data.loc[i,'2_Auth_affs_1']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['2_Auth_affs_2']: 
            if len(key) == len(Data.iloc[i]['2_Auth_affs_2']):
                Data.loc[i,'2_Auth_affs_2']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['2_Auth_affs_3']: 
            if len(key) == len(Data.iloc[i]['2_Auth_affs_3']):
                Data.loc[i,'2_Auth_affs_3']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['2_Auth_affs_4']: 
            if len(key) == len(Data.iloc[i]['2_Auth_affs_4']):
                Data.loc[i,'2_Auth_affs_4']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['3_Auth_affs_0']: 
            if len(key) == len(Data.iloc[i]['3_Auth_affs_0']):
                Data.loc[i,'3_Auth_affs_0']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['3_Auth_affs_1']: 
            if len(key) == len(Data.iloc[i]['3_Auth_affs_1']):
                Data.loc[i,'3_Auth_affs_1']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['3_Auth_affs_2']: 
            if len(key) == len(Data.iloc[i]['3_Auth_affs_2']):
                Data.loc[i,'3_Auth_affs_2']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['3_Auth_affs_3']: 
            if len(key) == len(Data.iloc[i]['3_Auth_affs_3']):
                Data.loc[i,'3_Auth_affs_3']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['3_Auth_affs_4']: 
            if len(key) == len(Data.iloc[i]['3_Auth_affs_4']):
                Data.loc[i,'3_Auth_affs_4']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['4_Auth_affs_0']: 
            if len(key) == len(Data.iloc[i]['4_Auth_affs_0']):
                Data.loc[i,'4_Auth_affs_0']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['4_Auth_affs_1']: 
            if len(key) == len(Data.iloc[i]['4_Auth_affs_1']):
                Data.loc[i,'4_Auth_affs_1']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['4_Auth_affs_2']: 
            if len(key) == len(Data.iloc[i]['4_Auth_affs_2']):
                Data.loc[i,'4_Auth_affs_2']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['4_Auth_affs_3']: 
            if len(key) == len(Data.iloc[i]['4_Auth_affs_3']):
                Data.loc[i,'4_Auth_affs_3']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['5_Auth_affs_0']: 
            if len(key) == len(Data.iloc[i]['5_Auth_affs_0']):
                Data.loc[i,'5_Auth_affs_0']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['6_Auth_affs_0']: 
            if len(key) == len(Data.iloc[i]['6_Auth_affs_0']):
                Data.loc[i,'6_Auth_affs_0']  = consolidated_affiliations_dict[key]

        if key in Data.iloc[i]['7_Auth_affs_0']: 
            if len(key) == len(Data.iloc[i]['7_Auth_affs_0']):
                Data.loc[i,'7_Auth_affs_0']  = consolidated_affiliations_dict[key]

# %%
import re

#for i in range(start,end):
for i in range(len(unique)):
    #print(i)

    list = []
    for key in consolidated_affiliations_dict.keys():
        if key in unique.iloc[i]['Affiliation']:
            print(key)
            #unique.loc[i,'Affiliation']  = re.sub(key, consolidated_affiliations_dict[key],unique.iloc[i]['Affiliation']).strip().rstrip(',')
            list.append(key)
            print(list)
    #If there is more than 1 match in the consolidation it needs to match on the longer one, solves for college issue
            if len(list) <= 1:
                unique.loc[i,'Affiliation']  = re.sub(key, consolidated_affiliations_dict[key],unique.iloc[i]['Affiliation']).strip().rstrip(',')
            else:
                print(consolidated_affiliations_dict[list[0]])
                print(consolidated_affiliations_dict[list[1]])
                # For colleges
                if(len(consolidated_affiliations_dict[list[0]]) == len(consolidated_affiliations_dict[list[1]])):
                    #print("HERE")
                    if len(list[0]) > len(list[1]):
                        print("If")
                        unique.loc[i,'Affiliation']  = re.sub(list[0], consolidated_affiliations_dict[list[0]],unique.iloc[i]['Affiliation']).strip().rstrip(',')
                        #print(list[0])
                    # Full  University Of Illinois System Urbana-Champaign issue
                    elif len(list[1]) > len(list[0]):
                        print("Elif")
                        unique.loc[i,'Affiliation']  = re.sub(list[1], consolidated_affiliations_dict[list[1]],unique.iloc[i]['Affiliation']).strip().rstrip(',')
                    else:
                        print("else")
                        first_fix = re.sub(list[1], consolidated_affiliations_dict[list[1]],unique.iloc[i]['Affiliation']).strip().rstrip(',') 
                        unique.loc[i,'Affiliation']  = re.sub(key, consolidated_affiliations_dict[key],first_fix).strip().rstrip(',') 
                else:
                    first_fix = re.sub(list[0], consolidated_affiliations_dict[list[0]],unique.iloc[i]['Affiliation']).strip().rstrip(',') 
                    #print(first_fix)
                    unique.loc[i,'Affiliation']  = re.sub(key, consolidated_affiliations_dict[key],first_fix).strip().rstrip(',') 
            print(unique.loc[i,'Affiliation'])

print(len(unique.Affiliation.unique()))
print(3632 - len(unique.Affiliation.unique()))

# %%
import re

unique["Affiliation_consolidated"] = ""
start = 3516
end = 3538
for i in range(start,end):
#for i in range(len(unique)):
    #print(i)
    list = []
    for key in consolidated_affiliations_dict.keys():
        if key in unique.iloc[i]['Affiliation']: 
            if len(key) == len(unique.iloc[i]['Affiliation']):
                print(len(key), len(unique.iloc[i]['Affiliation']))
                print(key)
                unique.loc[i,'Affiliation_consolidated']  = re.sub(key, consolidated_affiliations_dict[key],unique.iloc[i]['Affiliation']).strip().rstrip(',')
                #list.append(key)
                print(consolidated_affiliations_dict[key])
                print(unique.loc[i,'Affiliation_consolidated'])
                #print(list)

print(len(unique.Affiliation.unique()))
print(3632 - len(unique.Affiliation.unique()))
print(unique.iloc[start:end,0])

# %%
import numpy as np
#for i in range(15,16):
for i in range(len(AER_Merged)):
    
    # Checking 0 aff column replace with 1
    if AER_Merged.isnull().iloc[i]['0_Auth_affs_0']:
        # If 1 is also blank
        if AER_Merged.isnull().iloc[i]['0_Auth_affs_1']:
            print("aff1 blank")

            # If 2 is blank
            if AER_Merged.isnull().iloc[i]['0_Auth_affs_2']:
                print("Aff2 blank")

                # If 2 is blank
                if AER_Merged.isnull().iloc[i]['0_Auth_affs_3']:
                    print("Aff3 blank")

                    # If 4 is blank
                    if AER_Merged.isnull().iloc[i]['0_Auth_affs_4']:
                        print("Aff4 blank")

                    # If 4 contains
                    else:
                        AER_Merged.loc[i,['0_Auth_affs_0']] = AER_Merged.iloc[i]['0_Auth_affs_4']
                        AER_Merged.loc[i,['0_Auth_affs_4']] = np.nan

                # If 3 contains
                else:
                    AER_Merged.loc[i,['0_Auth_affs_0']] = AER_Merged.iloc[i]['0_Auth_affs_3']
                    AER_Merged.loc[i,['0_Auth_affs_3']] = np.nan
            
            # If 2 contains
            else:
                AER_Merged.loc[i,['0_Auth_affs_0']] = AER_Merged.iloc[i]['0_Auth_affs_2']
                AER_Merged.loc[i,['0_Auth_affs_2']] = np.nan

        # If 1 contains an aff
        else:
            #print(AER_Merged.iloc[i]['0_Auth_affs_1'])
            #print("Affiliation 1")
            AER_Merged.loc[i,['0_Auth_affs_0']] = AER_Merged.iloc[i]['0_Auth_affs_1']
            AER_Merged.loc[i,['0_Auth_affs_1']] = np.nan
        #print("found nan")
    # If 0 contains
    else:
        print("False")



    if AER_Merged.isnull().iloc[i]['0_Auth_affs_1']:
        print("aff1 blank")

        # If 2 is blank
        if AER_Merged.isnull().iloc[i]['0_Auth_affs_2']:
            print("Aff2 blank")

            # If 2 is blank
            if AER_Merged.isnull().iloc[i]['0_Auth_affs_3']:
                print("Aff3 blank")

                # If 4 is blank
                if AER_Merged.isnull().iloc[i]['0_Auth_affs_4']:
                    print("Aff4 blank")

                # If 4 contains
                else:
                    AER_Merged.loc[i,['0_Auth_affs_1']] = AER_Merged.iloc[i]['0_Auth_affs_4']
                    AER_Merged.loc[i,['0_Auth_affs_4']] = np.nan

            # If 3 contains
            else:
                AER_Merged.loc[i,['0_Auth_affs_1']] = AER_Merged.iloc[i]['0_Auth_affs_3']
                AER_Merged.loc[i,['0_Auth_affs_3']] = np.nan
        
        # If 2 contains
        else:
            AER_Merged.loc[i,['0_Auth_affs_1']] = AER_Merged.iloc[i]['0_Auth_affs_2']
            AER_Merged.loc[i,['0_Auth_affs_2']] = np.nan

    # If 1 contains an aff
    else:
        print("False")

    
    # Checking 0 aff column replace with 1
    if AER_Merged.isnull().iloc[i]['1_Auth_affs_0']:
        # If 1 is also blank
        if AER_Merged.isnull().iloc[i]['1_Auth_affs_1']:
            print("aff1 blank")

            # If 2 is blank
            if AER_Merged.isnull().iloc[i]['1_Auth_affs_2']:
                print("Aff2 blank")

                # If 2 is blank
                if AER_Merged.isnull().iloc[i]['1_Auth_affs_3']:
                    print("Aff3 blank")

                    # If 4 is blank
                    if AER_Merged.isnull().iloc[i]['1_Auth_affs_4']:
                        print("Aff4 blank")

                    # If 4 contains
                    else:
                        AER_Merged.loc[i,['1_Auth_affs_0']] = AER_Merged.iloc[i]['1_Auth_affs_4']
                        AER_Merged.loc[i,['1_Auth_affs_4']] = np.nan

                # If 3 contains
                else:
                    AER_Merged.loc[i,['1_Auth_affs_0']] = AER_Merged.iloc[i]['1_Auth_affs_3']
                    AER_Merged.loc[i,['1_Auth_affs_3']] = np.nan
            
            # If 2 contains
            else:
                AER_Merged.loc[i,['1_Auth_affs_0']] = AER_Merged.iloc[i]['1_Auth_affs_2']
                AER_Merged.loc[i,['1_Auth_affs_2']] = np.nan

        # If 1 contains an aff
        else:
            #print(AER_Merged.iloc[i]['0_Auth_affs_1'])
            #print("Affiliation 1")
            AER_Merged.loc[i,['1_Auth_affs_0']] = AER_Merged.iloc[i]['1_Auth_affs_1']
            AER_Merged.loc[i,['1_Auth_affs_1']] = np.nan
        #print("found nan")
    # If 0 contains
    else:
        print("False")



    if AER_Merged.isnull().iloc[i]['1_Auth_affs_1']:
        print("aff1 blank")

        # If 2 is blank
        if AER_Merged.isnull().iloc[i]['1_Auth_affs_2']:
            print("Aff2 blank")

            # If 2 is blank
            if AER_Merged.isnull().iloc[i]['1_Auth_affs_3']:
                print("Aff3 blank")

                # If 4 is blank
                if AER_Merged.isnull().iloc[i]['1_Auth_affs_4']:
                    print("Aff4 blank")

                # If 4 contains
                else:
                    AER_Merged.loc[i,['1_Auth_affs_1']] = AER_Merged.iloc[i]['1_Auth_affs_4']
                    AER_Merged.loc[i,['1_Auth_affs_4']] = np.nan

            # If 3 contains
            else:
                AER_Merged.loc[i,['1_Auth_affs_1']] = AER_Merged.iloc[i]['1_Auth_affs_3']
                AER_Merged.loc[i,['1_Auth_affs_3']] = np.nan
        
        # If 2 contains
        else:
            AER_Merged.loc[i,['1_Auth_affs_1']] = AER_Merged.iloc[i]['1_Auth_affs_2']
            AER_Merged.loc[i,['1_Auth_affs_2']] = np.nan

    # If 1 contains an aff
    else:
        print("False")

    print(AER_Merged.iloc[i]['0_Auth_affs_0'])
    print(AER_Merged.iloc[i]['0_Auth_affs_1'])
    print(AER_Merged.iloc[i]['0_Auth_affs_2'])
    print(AER_Merged.iloc[i]['0_Auth_affs_3'])
    print(AER_Merged.iloc[i]['0_Auth_affs_4'])

    print(AER_Merged.iloc[i]['1_Auth_affs_0'])
    print(AER_Merged.iloc[i]['1_Auth_affs_1'])
    print(AER_Merged.iloc[i]['1_Auth_affs_2'])
    print(AER_Merged.iloc[i]['1_Auth_affs_3'])
    print(AER_Merged.iloc[i]['1_Auth_affs_4'])

    print(i)
