# %%
import pandas as pd
from fuzzywuzzy import process
RES_2000_test = pd.read_json('RES_aff_output_2000_2009.json')
RES_2000_test.to_excel('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/RES/Fuzzy matching/RES_2000_2009_test.xlsx')

test = 'PATRICK BOLTON\n\nBarbara and David Zalaznick Professor of Business, Columbia Business School\nand\nANTOINE FAURE-GRIMAUD\n\nProfessor of Finance, London School of Economics\n'
#test = RES_2000.iloc[0,0]
choices = ['London School of Economics','Columbia Business School']

process.extract(test,choices)[0][0]
# Out:
# 'London School of Economics'

# %%
RES_2000_test.iloc[0,0]
# Out:
# {'found': 'DIRK BERGEMANN\n\nYale University\n\nand\nSTEPHEN MORRIS\n\nPrinceton University\n'}

# %%
# For JPE_ref_output_2001_2010.json
import json
import re
import pandas as pd
import string
import openpyxl
from rapidfuzz import fuzz

# Import JSON file
#f = open('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/RES/affs/RES_aff_output_1971_1979.json')
f = open('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/JPE/JPE_affiliation_output_1940_2010_1_3095.json')
#f = open('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/JPE/JPE_affiliation_output_1940_2010_3096_4326.json')
#f = open('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/AER/Aff/AER_aff_output_2001_2010.json')


json_data = json.load(f)

# Define Journal and Dataframe
Journal_Name = 'RES'
Reference_Data_List = []

# Extract Json Data into dataframe
for key1, value1 in json_data.items():
    Article_ID = key1
    content_type = value1["content_type"]
    author_list = value1["authors"]
    authorsNo = len(author_list)
    stable_url = value1["stable_url"]
    for key2 in value1["affiliations"]:
        Ref_type = key2
        if key2 == "found":
            ref_string = value1["affiliations"][key2]

    Reference_Data_List.append({'Journal_Name' : Journal_Name,
    'Authors_count' : authorsNo, 
    'Article_ID' : Article_ID, 'content_type' : content_type,
    'stable_url' : stable_url, 
    'Ref_type': Ref_type,  'ref_string':ref_string })

#RES_2000_2009 = pd.DataFrame.from_records(Reference_Data_List)     
#RES_2000_2009.to_excel('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/RES/Fuzzy matching/RES_2000_2009.xlsx') 
JPE_1940_2010 = pd.DataFrame.from_records(Reference_Data_List)     
JPE_1940_2010.to_excel('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/RES/Fuzzy matching/AER.xlsx')

# %%
# Import JSON file
f = open('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/RES/affs/RES_aff_output_1990_1999.json')
json_data = json.load(f)

# Define Journal and Dataframe
Journal_Name = 'RES'
Reference_Data_List = []

# Extract Json Data into dataframe
for key1, value1 in json_data.items():
    Article_ID = key1
    content_type = value1["content_type"]
    author_list = value1["authors"]
    authors = author_list[0]
    stable_url = value1["stable_url"]
    for key2 in value1["affiliations"]:
        Ref_type = key2
        if key2 == "found":
            ref_string = value1["affiliations"][key2]

    Reference_Data_List.append({'Journal_Name' : Journal_Name,
    'Authors' : authors, 
    'Article_ID' : Article_ID, 'content_type' : content_type,
    'stable_url' : stable_url, 
    'Ref_type': Ref_type,  'ref_string':ref_string })

RES_1990_1999 = pd.DataFrame.from_records(Reference_Data_List)     
RES_1990_1999.to_excel('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/RES/Fuzzy matching/RES_1990_1999.xlsx')

# %%
#RES_2000_2009['ref_string'][0]
# Out:
# 'DONALD J. BROWN\nCowles Foundation for Research in Economics at Yale University\n\nand\n\nGEOFFREY HEAL\nUniversity of Sussex\n'

# %%
import pandas as pd
from fuzzywuzzy import process

affs = pd.read_excel('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/Unique Universities.xlsx')
print(affs.shape)

#data = RES_1990_1999
data = JPE_1940_2010.loc[500:1000].reset_index(drop = True)

for i in range(len(affs)):
    #Replaceing title case and stripping leading space
    affs.iat[i,0] = affs.iat[i,0].strip().title()
Affiliation_choices = affs['Affilliation'].values.tolist()

for i in range(len(data)):
    #Replaceing title case and stripping leading space
    data.iat[i,6] = data.iat[i,6].strip().title()



#test = 'PATRICK BOLTON\n\nBarbara and David Zalaznick Professor of Business, Columbia Business School\nand\nANTOINE FAURE-GRIMAUD\n\nProfessor of Finance, London School Of Economics\n'
#test = 'PATRICK BOLTON\n\nBarbara and David Zalaznick Professor of Business, Columbia Business School\nand\nANTOINE FAURE-GRIMAUD\n\nProfessor of Finance, London School Of Economics \n'
#test = data.iat[5,6]
#test = RES_2000.iloc[0,0]
#choices = ['London School Of Economics','Columbia Business School']

#process.extract(test,Affiliation_choices)[0][0]
#for i in range(20):
  #  print(process.extractBests(data.iat[i,6],Affiliation_choices, score_cutoff = 90 ))
# Out:
# (792, 2)

# %%
choices = ['Impatience','RiskTaking']
print(process.extract(data.iat[9,6].replace('\n',''),choices))
print(process.extract('Impatience, Information And RiskTaking',choices))
print(process.extract('tytt thhh.h..hthtImpatience, dog goodd',choices))
print(data.iat[9,6].replace('\n',''))
print(JPE_1940_2010.shape)
# Out:
# [('RiskTaking', 30), ('Impatience', 23)]
# [('Impatience', 90), ('RiskTaking', 90)]
# [('Impatience', 90), ('RiskTaking', 36)]
# Resale Markets And TheAssignment Of Property RightsPhilippe JehielCeras, Paris And University College, LondonAndBenny MoldovanuUniversity Of Mannheim
# (3096, 7)

# %%
#testdata = RES_2000_2009.loc[0:10]
testdata = JPE_1940_2010.loc[500:1000].reset_index(drop = True)

for i in range(len(testdata)):
    affiliations = process.extractBests(testdata.iat[i,6],Affiliation_choices, score_cutoff = 90 )
    print("Length = " , len(affiliations), ", Number = ",i)
    if len(affiliations) == 0:
        testdata.loc[i,['Missing aff']] = "Missing"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 1:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 2:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 3:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 4:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 5:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 6:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['aff6']] = affiliations[5][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    else: 
        testdata['Missing aff'] = "More than 6"
# Out:
# Length =  3 , Number =  0
# Length =  0 , Number =  1
# Length =  2 , Number =  2
# Length =  2 , Number =  3
# Length =  1 , Number =  4
# Length =  2 , Number =  5
# Length =  2 , Number =  6
# Length =  1 , Number =  7
# Length =  1 , Number =  8
# Length =  2 , Number =  9
# Length =  3 , Number =  10
# Length =  3 , Number =  11
# Length =  3 , Number =  12
# Length =  3 , Number =  13
# Length =  5 , Number =  14
# Length =  0 , Number =  15
# Length =  2 , Number =  16
# Length =  1 , Number =  17
# Length =  3 , Number =  18
# Length =  0 , Number =  19
# Length =  2 , Number =  20
# Length =  2 , Number =  21
# Length =  2 , Number =  22
# Length =  0 , Number =  23
# Length =  1 , Number =  24
# Length =  1 , Number =  25
# Length =  2 , Number =  26
# Length =  3 , Number =  27
# Length =  3 , Number =  28
# Length =  1 , Number =  29
# Length =  2 , Number =  30
# Length =  1 , Number =  31
# Length =  3 , Number =  32
# Length =  3 , Number =  33
# Length =  1 , Number =  34
# Length =  2 , Number =  35
# Length =  1 , Number =  36
# Length =  3 , Number =  37
# Length =  5 , Number =  38
# Length =  0 , Number =  39
# Length =  1 , Number =  40
# Length =  0 , Number =  41
# Length =  1 , Number =  42
# Length =  1 , Number =  471
# Length =  4 , Number =  472
# Length =  1 , Number =  473
# Length =  1 , Number =  474
# Length =  4 , Number =  475
# Length =  2 , Number =  476
# Length =  2 , Number =  477
# Length =  1 , Number =  478
# Length =  1 , Number =  479
# Length =  1 , Number =  480
# Length =  1 , Number =  481
# Length =  1 , Number =  482
# Length =  2 , Number =  483
# Length =  1 , Number =  484
# Length =  1 , Number =  485
# Length =  1 , Number =  486
# Length =  0 , Number =  487
# Length =  1 , Number =  488
# Length =  0 , Number =  489
# Length =  2 , Number =  490
# Length =  2 , Number =  491
# Length =  2 , Number =  492
# Length =  1 , Number =  493
# Length =  1 , Number =  494
# Length =  2 , Number =  495
# Length =  1 , Number =  496
# Length =  2 , Number =  497
# Length =  1 , Number =  498
# Length =  2 , Number =  499
# Length =  1 , Number =  500

# %%
testdata.head
testdata.to_excel('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/RES/Fuzzy matching/JPE_1940_2010_500_1000_Fuzzy.xlsx')

# %%
process.extract()
#RES_2000_2009.loc[0:10]
# Out:
#    Journal_Name             Authors Article_ID content_type  \
# 0           RES     Donald J. Brown    2297028      Article
# 1           RES       Avinash Dixit    2297029      Article
# 2           RES           J. A. Kay    2297030      Article
# 3           RES        Peter Howitt    2297031      Article
# 4           RES  Andrew Feltenstein    2297032      Article
# 5           RES       Perry Shapiro    2297033      Article
# 6           RES    Douglas H. Blair    2297034      Article
# 7           RES  John S. Pettengill    2297035      Article
# 8           RES  William R. Johnson    2297036      Article
# 9           RES        S. M. Kanbur    2297037      Article
# 10          RES  James M. Malcomson    2297038      Article
#
#                               stable_url Ref_type  \
# 0   https://www.jstor.org/stable/2297028    found
# 1   https://www.jstor.org/stable/2297029    found
# 2   https://www.jstor.org/stable/2297030    found
# 3   https://www.jstor.org/stable/2297031    found
# 4   https://www.jstor.org/stable/2297032    found
# 5   https://www.jstor.org/stable/2297033    found
# 6   https://www.jstor.org/stable/2297034    found
# 7   https://www.jstor.org/stable/2297035    found
# 8   https://www.jstor.org/stable/2297036    found
# 9   https://www.jstor.org/stable/2297037    found
# 10  https://www.jstor.org/stable/2297038    found
#
#                                            ref_string
# 0   Donald J. Brown\nCowles Foundation For Researc...
# 1                Avinash Dixit\nUniversity Of Warwick
# 2     J. A. Kay\nInstitute For Fiscal Studies, London
# 3         Peter Howitt\nUniversity Of Western Ontario
# 4     Andrew Feltenstein\nInternational Monetary Fund
# 5   Perry Shapiro\nUniversity Of California, Santa...
# 6        Douglas H. Blair\nUniversity Of Pennsylvania
# 7   Labour Unions And The Wage\nStructure: A Gener...
# 8   The Demand For General And\nSpecific Education...
# 9   Impatience, Information And Risk\nTaking In A ...
# 10  James M. Malcomson\nUniversity Of York\n\nAnd\...

# %%
print(process.extractBests(testdata.iat[4,6].replace('\n',''),Affiliation_choices,score_cutoff = 90, limit = 10))
print(process.extract('National Bureau Of Economic Research',Affiliation_choices))
print(process.extract('National Bureau Of Economic Research University of Chicago, National Bureau of Economic Research, and Centre for Economic Policy Research',Affiliation_choices))
print(testdata.iat[4,6])
# Out:
# [('National Bureau Of Economic Research', 90)]
# [('National Bureau Of Economic Research', 100), ('National Bureau Of Economic Research Massachusetts', 95), ('National Bureau Of Economic Research Federal Reserve Board', 90), ('National Bureau Of Economic Research Universidad Torcuato', 90), ('National Bureau Of Economic Research University Of Maryland', 90)]
# [('Centre For Economic', 90), ('Centre For Economic Policy Research', 90), ('Centre For Economic Policy Research', 90), ('National Bureau Of Economic Research', 90), ('University Of Chicago', 90)]
# Lubos Pástor
#
# University of Chicago, National Bureau of Economic Research, and Centre for Economic Policy
# Research
#
# Robert F. Stambaugh
#
# University of Pennsylvania and National Bureau of Economic Research

# %%
a = testdata.iat[4,6].split('\n\n')[1]
print(process.extractBests(a,Affiliation_choices, limit= 10))

print(len(testdata.iat[4,6].split('\n\n')))

# %%
testdata = JPE_1940_2010.loc[500:1000].reset_index(drop = True)

split = testdata.iat[4,6].split('\n\n')
split_len = len(testdata.iat[4,6].split('\n\n'))
list = []
for j in range(split_len):
    if len(process.extractBests(split[j],Affiliation_choices, limit= 10, score_cutoff= 90)) >0:
        list = list + process.extractBests(split[j],Affiliation_choices, limit= 10, score_cutoff= 90)
        #print(list)
        print(len(list))
        #print(process.extractBests(split[i],Affiliation_choices, limit= 10, score_cutoff= 90))
        #print(i)
# Out:
# 6
# 8

# %%
testdata = JPE_1940_2010.loc[0:100].reset_index(drop = True)

for i in range(len(testdata)):
    split = testdata.iat[i,6].split('\n\n')
    split_len = len(testdata.iat[i,6].split('\n\n'))
    affiliations = []
    for j in range(split_len):
        #print(i)
        if len(process.extractBests(split[j],Affiliation_choices, limit= 10, score_cutoff= 90)) > 0:
            affiliations = affiliations + process.extractBests(split[j],Affiliation_choices, limit= 10, score_cutoff= 90)
        #affiliations = process.extractBests(testdata.iat[i,6],Affiliation_choices, score_cutoff = 90 )
            #print("Length = " , len(affiliations), ", Number = ",j)
            #print("Length = " , len(affiliations), ", Number = ",j,'below')
        #print(i,split_len)
        if i == split_len:
            break

    print("Length = " , len(affiliations), ", Number = ",i)
    if len(affiliations) == 0:
        testdata.loc[i,['Missing aff']] = "Missing"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 1:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 2:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 3:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 4:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 5:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 6:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['aff6']] = affiliations[5][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 7:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['aff6']] = affiliations[5][0]
        testdata.loc[i,['aff7']] = affiliations[6][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 8:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['aff6']] = affiliations[5][0]
        testdata.loc[i,['aff7']] = affiliations[6][0]
        testdata.loc[i,['aff8']] = affiliations[7][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    elif len(affiliations) == 9:
        testdata.loc[i,['aff1']] = affiliations[0][0]
        testdata.loc[i,['aff2']] = affiliations[1][0]
        testdata.loc[i,['aff3']] = affiliations[2][0]
        testdata.loc[i,['aff4']] = affiliations[3][0]
        testdata.loc[i,['aff5']] = affiliations[4][0]
        testdata.loc[i,['aff6']] = affiliations[5][0]
        testdata.loc[i,['aff7']] = affiliations[6][0]
        testdata.loc[i,['aff8']] = affiliations[7][0]
        testdata.loc[i,['aff9']] = affiliations[8][0]
        testdata.loc[i,['Missing aff']] = "Contains"
        testdata.loc[i,['No of Affs']] = len(affiliations)
    else: 
        testdata.loc[i,['Missing aff']] = "More than 9"
# Out:
