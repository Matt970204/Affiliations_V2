# %%
# For JPE_ref_output_2001_2010.json
import json
import re
import pandas as pd
import string
import openpyxl
from rapidfuzz import fuzz

# Import JSON file
f = open('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/RES/affs/RES_aff_output_1971_1979.json')
json_data = json.load(f)

# Def regex search
def find_reference(word):
    return re.compile(r'\b({0})\b'.format(word)).search

# Def character search
def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)

# Define Journal and Dataframe
Journal_Name = 'RES'
Reference_Data_List = []

# Extract Json Data into dataframe
for key1, value1 in json_data.items():
    Article_ID = key1
    content_type = value1["content_type"]
    author_list = value1["authors"]
    authorscount = len(author_list)
    if len(author_list) == 1:
        author_1 = author_list[0]
        author_2 = ''
        author_3 = ''
        author_4 = ''
        author_5 = ''
        author_6 = ''
    elif len(author_list) == 2:
        author_1 = author_list[0]
        author_2 = author_list[1]
        author_3 = ''
        author_4 = ''
        author_5 = ''
        author_6 = ''
    elif len(author_list) == 3:
        author_1 = author_list[0]
        author_2 = author_list[1]
        author_3 = author_list[2]
        author_4 = ''
        author_5 = ''
        author_6 = ''
    elif len(author_list) == 4:
        author_1 = author_list[0]
        author_2 = author_list[1]
        author_3 = author_list[2]
        author_4 = author_list[3]
        author_5 = ''
        author_6 = ''
    elif len(author_list) == 5:
        author_1 = author_list[0]
        author_2 = author_list[1]
        author_3 = author_list[2]
        author_4 = author_list[3]
        author_5 = author_list[4]
        author_6 = ''
    else:
        author_1 = author_list[0]
        author_2 = author_list[1]
        author_3 = author_list[2]
        author_4 = author_list[3]
        author_5 = author_list[4]
        author_6 = author_list[5]

    author_1 = author_1.strip().upper()
    author_2 = author_2.strip().upper()
    author_3 = author_3.strip().upper()
    author_4 = author_4.strip().upper()
    author_5 = author_5.strip().upper()
    author_6 = author_6.strip().upper()

    #print(author_list)
    if len(author_list) > 1:
        authors = ",".join(author_list)
    else:
        authors = author_list[0]
        stable_url = value1["stable_url"]
    for key2 in value1["affiliations"]:
        Ref_type = key2
        if key2 == "found":
            ref_string = value1["affiliations"][key2]

            #reference_string_list = ref_string.split("\n\n")
            #ref_string_1 = ref_string.upper()
            ref_string_1 = re.sub(r"[.]","",ref_string)
            #reference_string_list = re.findall('\w+\s[\w.-]+\s*\w*\n',ref_string_1)
            reference_string_list = re.findall('.+',ref_string_1)
            #reference_string_list = reference_string_list1[1:3095]

            #Removing the text infront of author and aff
            n = 0
            while fuzz.ratio(author_1,reference_string_list[0]) < 30:
                print(reference_string_list)
                print(fuzz.ratio(author_1,reference_string_list[0]))
                reference_string_list = reference_string_list[1:]
                print(reference_string_list)
                n = n+1
                if len(reference_string_list) == 0:
                    break
            #Remving and inbetween references
            for i in reference_string_list:
                if i == 'and':
                    reference_string_list.remove(i)

                #auth = re.findall('\sand\s',i)
            if len(reference_string_list) >= 2:
                if re.findall(' and ',reference_string_list[0]):
                    x = re.split(' and', reference_string_list[0])
                    reference_string_list[0] = x[0]
                    if len(x) == 2:
                        reference_string_list.append(x[1])


            ref_length = len(reference_string_list)

            if len(reference_string_list) == 1:
                Author1 = reference_string_list[0]
                Affilliation1 = ''
                Author2 = ''
                Affilliation2 = ''
                Author3 = ''
                Affilliation3 = ''
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 2:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = ''
                Affilliation2 = ''
                Author3 = ''
                Affilliation3 = ''
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 3:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = ''
                Author3 = ''
                Affilliation3 = ''
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 4:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]
                Author3 = ''
                Affilliation3 = ''
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 5:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]  
                Affilliation3 = ''
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = '' 
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 6:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]
                Affilliation3 = reference_string_list[5]     
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = '' 
                Author6 = ''
                Affilliation6 = ''   
            elif len(reference_string_list) == 7:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]
                Affilliation3 = reference_string_list[5] 
                Author4 = reference_string_list[6]
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 8:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]
                Affilliation3 = reference_string_list[5] 
                Author4 = reference_string_list[6]
                Affilliation4 = reference_string_list[7]
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 9:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]
                Affilliation3 = reference_string_list[5] 
                Author4 = reference_string_list[6]
                Affilliation4 = reference_string_list[7]
                Author5 = reference_string_list[8]
                Affilliation5 = ''
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 10:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]
                Affilliation3 = reference_string_list[5] 
                Author4 = reference_string_list[6]
                Affilliation4 = reference_string_list[7]
                Author5 = reference_string_list[8]
                Affilliation5 = reference_string_list[9]
                Author6 = ''
                Affilliation6 = ''
            elif len(reference_string_list) == 11:
                Author1 = reference_string_list[0]
                Affilliation1 = reference_string_list[1]
                Author2 = reference_string_list[2]
                Affilliation2 = reference_string_list[3]   
                Author3 = reference_string_list[4]
                Affilliation3 = reference_string_list[5] 
                Author4 = reference_string_list[6]
                Affilliation4 = reference_string_list[7]
                Author5 = reference_string_list[8]
                Affilliation5 = reference_string_list[9]
                Author6 = reference_string_list[10]
                Affilliation6 = ''
            else:
                Author1 = ''
                Affilliation1 = ''
                Author2 = ''
                Affilliation2 = ''
                Author3 = ''
                Affilliation3 = ''
                Author4 = ''
                Affilliation4 = ''
                Author5 = ''
                Affilliation5 = ''
                Author6 = ''
                # Author1 = reference_string_list[0]
                # Affilliation1 = reference_string_list[1]
                # Author2 = reference_string_list[2]
                # Affilliation2 = reference_string_list[3]   
                # Author3 = reference_string_list[4]
                # Affilliation3 = reference_string_list[5] 
                # Author4 = reference_string_list[6]
                # Affilliation4 = reference_string_list[7]
                # Author5 = reference_string_list[8]
                # Affilliation5 = reference_string_list[9]
                # Author6 = reference_string_list[10]
                #Affilliation6 = reference_string_list[11]

            Author1 = Author1.strip()
            Affilliation1 = Affilliation1.strip()
            Author2 = Author2.strip()
            Affilliation2 = Affilliation2.strip() 
            Author3 = Author3.strip()
            Affilliation3 = Affilliation3.strip()
            Author4 = Author4.strip()
            Affilliation4 = Affilliation4.strip()
            Author5 = Author5.strip()
            Affilliation5 = Affilliation5.strip()
            Author6 = Author6.strip()
            Affilliation6 = Affilliation6.strip()
# for i in range(1,7):
#     if author_(i) == 0
#     else: 
#         print(no)

    

    a1fuzz = fuzz.ratio(author_1,Author1)
    if author_1 == Author1 == "":
        a1 = 'Empty' 
    elif author_1 == Author1:
        a1 = 'True'
    else:
        a1 = 'False'
    if author_2 == Author2 == "":
        a2 = 'Empty' 
    elif author_2 == Author2:
        a2 = 'True'
    else:
        a2 = 'False'
    if author_3 == Author3 == "":
        a3 = 'Empty' 
    elif author_3 == Author3:
        a3 = 'True'
    else:
        a3 = 'False'
    if author_4 == Author4 == "":
        a4 = 'Empty' 
    elif author_4 == Author4:
        a4 = 'True'
    else:
        a4 = 'False'
    if author_5 == Author5 == "":
        a5 = 'Empty' 
    elif author_5 == Author5:
        a5 = 'True'
    else:
        a5 = 'False'
    if author_6 == Author6 == "":
        a6 = 'Empty' 
    elif author_6 == Author6:
        a6 = 'True'
    else:
        a6 = 'False'
                
    #print(Author1)
    Reference_Data_List.append({'Journal_Name' : Journal_Name,'Author1':Author1, 'Affilliation1':Affilliation1, 'Author2':Author2,'Affilliation2':Affilliation2,
     
    'authorscount':authorscount,
    'Authors' : authors, 'a1fuzz':a1fuzz,
    'author_1':author_1, 'Author1':Author1,
    'author_2':author_2 , 'author_3':author_3, 'author_4':author_4, 'author_5':author_5 , 'author_6':author_6,
    'Article_ID' : Article_ID, 'content_type' : content_type,
    #'stable_url' : stable_url, 
    'Ref_type': Ref_type, 
     'Author3':Author3,'Affilliation3':Affilliation3,
    'Author4':Author4, 'Affilliation4':Affilliation4, 'Author5':Author5, 'Affilliation5':Affilliation5, 'Author6':Author6, 'Affilliation6':Affilliation6, 
    'ref_length':ref_length, 'ref_string':ref_string,
    'a1':a1,'a2':a2,'a3':a3,'a4':a4,'a5':a5,'a6':a6 })

Reference_Data = pd.DataFrame.from_records(Reference_Data_List)     
Reference_Data.to_excel('/Users/MattJohnson/Desktop/Refs + affiliations/Affiliations/RES/JPE_affiliation_output_2000_2009_1.xlsx')
#Reference_Data.to_excel('/Users/danaebouwer/Documents/Work/Matthew sheets/drive-download-20220901T140508Z-001/JPE/JPE_ref_output_2001_2010/JPE_ref_output_2001_2010.xlsx')
# Out:
# ['Labour Unions and the Wage', 'Structure: A General Equilibrium', 'Approach', 'JOHN S PETTENGILL', 'University of Virginia']
# 9.090909090909093
# ['Structure: A General Equilibrium', 'Approach', 'JOHN S PETTENGILL', 'University of Virginia']
# ['Structure: A General Equilibrium', 'Approach', 'JOHN S PETTENGILL', 'University of Virginia']
# 12.0
# ['Approach', 'JOHN S PETTENGILL', 'University of Virginia']
# ['Approach', 'JOHN S PETTENGILL', 'University of Virginia']
# 0.0
# ['JOHN S PETTENGILL', 'University of Virginia']
# ['The Demand for General and', 'Specific Education with Occupational', 'Mobility', 'WILLIAM R JOHNSON', 'University of Virginia']
# 9.090909090909093
# ['Specific Education with Occupational', 'Mobility', 'WILLIAM R JOHNSON', 'University of Virginia']
# ['Specific Education with Occupational', 'Mobility', 'WILLIAM R JOHNSON', 'University of Virginia']
# 11.111111111111116
# ['Mobility', 'WILLIAM R JOHNSON', 'University of Virginia']
# ['Mobility', 'WILLIAM R JOHNSON', 'University of Virginia']
# 7.692307692307687
# ['WILLIAM R JOHNSON', 'University of Virginia']
# ['Impatience, Information and Risk', 'Taking in a General Equilibrium', 'Model of Occupational Choice', 'S M KANBUR', 'Oxford University and Cambridge University']
# 13.636363636363635
# ['Taking in a General Equilibrium', 'Model of Occupational Choice', 'S M KANBUR', 'Oxford University and Cambridge University']
# ['Taking in a General Equilibrium', 'Model of Occupational Choice', 'S M KANBUR', 'Oxford University and Cambridge University']
# 9.302325581395355
# ['Model of Occupational Choice', 'S M KANBUR', 'Oxford University and Cambridge University']
# ['Model of Occupational Choice', 'S M KANBUR', 'Oxford University and Cambridge University']
# 9.999999999999998
# ['S M KANBUR', 'Oxford University and Cambridge University']
# ['State Preference and the Riskless', 'Interest Rate: A Markov Model', 'of Capital Markets', 'AVRAHAM BEJA', 'New York University and Tel- Aviv University']
# 4.444444444444439
# ['Interest Rate: A Markov Model', 'of Capital Markets', 'AVRAHAM BEJA', 'New York University and Tel- Aviv University']
# ['Interest Rate: A Markov Model', 'of Capital Markets', 'AVRAHAM BEJA', 'New York University and Tel- Aviv University']
# 19.512195121951216
# ['of Capital Markets', 'AVRAHAM BEJA', 'New York University and Tel- Aviv University']
# ['of Capital Markets', 'AVRAHAM BEJA', 'New York University and Tel- Aviv University']
# 6.666666666666665
# ['AVRAHAM BEJA', 'New York University and Tel- Aviv University']
# ['Human Capital and Earnings: British', 'Evidence and a Critique', 'GEORGE PSACHAROPOULOS and RICHARD LAYARD', 'London School of Economics']
# 7.14285714285714
# ['Evidence and a Critique', 'GEORGE PSACHAROPOULOS and RICHARD LAYARD', 'London School of Economics']
# ['Evidence and a Critique', 'GEORGE PSACHAROPOULOS and RICHARD LAYARD', 'London School of Economics']
# 13.636363636363635
# ['GEORGE PSACHAROPOULOS and RICHARD LAYARD', 'London School of Economics']
# ['Long-run Tax Incidence: A', 'Comparative Dynamic Approach', 'ROBIN BOADWAY', "Queen's University"]
# 15.789473684210531
# ['Comparative Dynamic Approach', 'ROBIN BOADWAY', "Queen's University"]
# ['Comparative Dynamic Approach', 'ROBIN BOADWAY', "Queen's University"]
# 14.634146341463417
# ['ROBIN BOADWAY', "Queen's University"]
# ['Diversification Theorems for Subsets', 'of Risk Averters', 'WILLIAM R RUSSELL and TAE KUN SEO', 'Southern Methodist University']
# 11.111111111111116
# ['of Risk Averters', 'WILLIAM R RUSSELL and TAE KUN SEO', 'Southern Methodist University']
# ['of Risk Averters', 'WILLIAM R RUSSELL and TAE KUN SEO', 'Southern Methodist University']
# 17.647058823529417
# ['WILLIAM R RUSSELL and TAE KUN SEO', 'Southern Methodist University']
# ['straightforward Individual Incentive', 'Compatibility in Large Economies', 'PETER J HAMMOND', 'University of Essex']
# 7.692307692307687
# ['Compatibility in Large Economies', 'PETER J HAMMOND', 'University of Essex']
# ['Compatibility in Large Economies', 'PETER J HAMMOND', 'University of Essex']
# 8.333333333333337
# ['PETER J HAMMOND', 'University of Essex']
# ['surplus-sharing Local Games in', 'Dynamic Exchange Processes', 'HENRY TULKENS', 'CORE, Université Catholique de Louvain', 'and', 'SHMUEL ZAMIR', 'Hebrew University of Jeruslaem']
# 9.302325581395355
# ['Dynamic Exchange Processes', 'HENRY TULKENS', 'CORE, Université Catholique de Louvain', 'and', 'SHMUEL ZAMIR', 'Hebrew University of Jeruslaem']
# ['Dynamic Exchange Processes', 'HENRY TULKENS', 'CORE, Université Catholique de Louvain', 'and', 'SHMUEL ZAMIR', 'Hebrew University of Jeruslaem']
# 10.256410256410254
# ['HENRY TULKENS', 'CORE, Université Catholique de Louvain', 'and', 'SHMUEL ZAMIR', 'Hebrew University of Jeruslaem']
# ['Unemployment Equilibrium with', 'Myopic Complete Information', 'WALTER PERRIN HELLER', 'University of California, San Diego', 'and', 'ROSS M STARR', 'University of California, Davis']
# 12.244897959183676
# ['Myopic Complete Information', 'WALTER PERRIN HELLER', 'University of California, San Diego', 'and', 'ROSS M STARR', 'University of California, Davis']
# ['Myopic Complete Information', 'WALTER PERRIN HELLER', 'University of California, San Diego', 'and', 'ROSS M STARR', 'University of California, Davis']
# 8.510638297872342
# ['WALTER PERRIN HELLER', 'University of California, San Diego', 'and', 'ROSS M STARR', 'University of California, Davis']
# ['Temporary Equilibria with Quantity', 'Rationing', 'VOLKER BÓHM', 'Centre for Operations Research and Econometrics', 'and', 'PIERRE LÉVINE', 'University of Paris VI']
# 8.888888888888891
# ['Rationing', 'VOLKER BÓHM', 'Centre for Operations Research and Econometrics', 'and', 'PIERRE LÉVINE', 'University of Paris VI']
# ['Rationing', 'VOLKER BÓHM', 'Centre for Operations Research and Econometrics', 'and', 'PIERRE LÉVINE', 'University of Paris VI']
# 9.999999999999998
# ['VOLKER BÓHM', 'Centre for Operations Research and Econometrics', 'and', 'PIERRE LÉVINE', 'University of Paris VI']
# ['Optimal Population and Capital', 'over Time: The Maximin', 'Perspective', 'GUILLERMO A CALVO', 'Columbia University', 'INTRODUCTION', 'A well-known implication of the Solow-Swan growth model with non-overlapping gener-', 'ations is that if individuals do not care about the number or well-being of their descendants,', 'the present generation will gain nothing from having children (see Phelps (1966)) The', 'non-overlapping assumption is quite crucial for such a result Consider instead the case', 'where generations overlap in Samuelson-Diamond fashion (Diamond (1965)), ie indi-', 'viduals live for two periods—they work in the first and retire in the second At present,', 'period zero, there are, therefore, two generations alive, one of which is old and the other', 'which is young and will survive until the end of the next period Again, the old at time', 'zero do not, in principle, benefit from future generations but that is no longer true for the', 'young at time zero because their capital will be operated by the young in period one In', 'a competitive environment, for instance, with no childbearing costs and positive cross-', 'partial derivatives between capital and labour, the utility of the young at time zero never', 'decreases by adding one more member to generation 1, ie the set of individuals born in', 'period one, because ceteris paribus the rate of return on capital in period one also goes up', 'It is clear that we must adopt some allocation rule in order to be able to be more', 'specific about the number of children that present generations must have if they want to', 'maximize their utility In this paper I will examine the case where present and future', 'generations are constrained to be *\' fair ", in the sense of the Rawlsian maximin, to every', 'individual who lives or is going to live during any subinterval of the planning period (stretch-', 'ing from zero to the indefinite future) under the assumption that it is possible to allocate', 'consumpdüon freely among individuals subject only to the technological constraints', 'Consequently, we are going to be looking at a typical problem of a central planning agency', 'when its objective is to maximize the welfare of present generations but it is constrained to', 'abide by the dictates of the maximin principle', 'The present approach, with its emphasis on the welfare of the living generations, is', 'by no means typical of the optimal population literature, most of which is instead con-', 'cerned with the maximization of a sum of utilities (see, eg Meade (1955), Dasgupta (1969,', "1974), Pitchford (1972)) This objective may very well imply sacrificing present generations'", 'utilities in favour of the future ones Consider, for instance, the Meade-Dasgupta maxi-', 'mand (see Meade (1955), Dasgupta (1969)), consisting of a discounted or undiscounted', 'sum of utilities weighted by the number of individuals in each generation As shown by', 'Dasgupta (1969), it is possible to find conditions under which, in the Solow-Swan model', 'with non-overlapping generations, it would be optimal (according to his criterion) to have', 'positive population at every point in time, implying that present generations would have to', 'refrain from consuming all the available capital Therefore, in a Dasgupta optimal plan', 'the present generation is worse off than it would be if it had no descendants and ate up all', '59']
# 16.666666666666664
# ['over Time: The Maximin', 'Perspective', 'GUILLERMO A CALVO', 'Columbia University', 'INTRODUCTION', 'A well-known implication of the Solow-Swan growth model with non-overlapping gener-', 'ations is that if individuals do not care about the number or well-being of their descendants,', 'the present generation will gain nothing from having children (see Phelps (1966)) The', 'non-overlapping assumption is quite crucial for such a result Consider instead the case', 'where generations overlap in Samuelson-Diamond fashion (Diamond (1965)), ie indi-', 'viduals live for two periods—they work in the first and retire in the second At present,', 'period zero, there are, therefore, two generations alive, one of which is old and the other', 'which is young and will survive until the end of the next period Again, the old at time', 'zero do not, in principle, benefit from future generations but that is no longer true for the', 'young at time zero because their capital will be operated by the young in period one In', 'a competitive environment, for instance, with no childbearing costs and positive cross-', 'partial derivatives between capital and labour, the utility of the young at time zero never', 'decreases by adding one more member to generation 1, ie the set of individuals born in', 'period one, because ceteris paribus the rate of return on capital in period one also goes up', 'It is clear that we must adopt some allocation rule in order to be able to be more', 'specific about the number of children that present generations must have if they want to', 'maximize their utility In this paper I will examine the case where present and future', 'generations are constrained to be *\' fair ", in the sense of the Rawlsian maximin, to every', 'individual who lives or is going to live during any subinterval of the planning period (stretch-', 'ing from zero to the indefinite future) under the assumption that it is possible to allocate', 'consumpdüon freely among individuals subject only to the technological constraints', 'Consequently, we are going to be looking at a typical problem of a central planning agency', 'when its objective is to maximize the welfare of present generations but it is constrained to', 'abide by the dictates of the maximin principle', 'The present approach, with its emphasis on the welfare of the living generations, is', 'by no means typical of the optimal population literature, most of which is instead con-', 'cerned with the maximization of a sum of utilities (see, eg Meade (1955), Dasgupta (1969,', "1974), Pitchford (1972)) This objective may very well imply sacrificing present generations'", 'utilities in favour of the future ones Consider, for instance, the Meade-Dasgupta maxi-', 'mand (see Meade (1955), Dasgupta (1969)), consisting of a discounted or undiscounted', 'sum of utilities weighted by the number of individuals in each generation As shown by', 'Dasgupta (1969), it is possible to find conditions under which, in the Solow-Swan model', 'with non-overlapping generations, it would be optimal (according to his criterion) to have', 'positive population at every point in time, implying that present generations would have to', 'refrain from consuming all the available capital Therefore, in a Dasgupta optimal plan', 'the present generation is worse off than it would be if it had no descendants and ate up all', '59']
# ['over Time: The Maximin', 'Perspective', 'GUILLERMO A CALVO', 'Columbia University', 'INTRODUCTION', 'A well-known implication of the Solow-Swan growth model with non-overlapping gener-', 'ations is that if individuals do not care about the number or well-being of their descendants,', 'the present generation will gain nothing from having children (see Phelps (1966)) The', 'non-overlapping assumption is quite crucial for such a result Consider instead the case', 'where generations overlap in Samuelson-Diamond fashion (Diamond (1965)), ie indi-', 'viduals live for two periods—they work in the first and retire in the second At present,', 'period zero, there are, therefore, two generations alive, one of which is old and the other', 'which is young and will survive until the end of the next period Again, the old at time', 'zero do not, in principle, benefit from future generations but that is no longer true for the', 'young at time zero because their capital will be operated by the young in period one In', 'a competitive environment, for instance, with no childbearing costs and positive cross-', 'partial derivatives between capital and labour, the utility of the young at time zero never', 'decreases by adding one more member to generation 1, ie the set of individuals born in', 'period one, because ceteris paribus the rate of return on capital in period one also goes up', 'It is clear that we must adopt some allocation rule in order to be able to be more', 'specific about the number of children that present generations must have if they want to', 'maximize their utility In this paper I will examine the case where present and future', 'generations are constrained to be *\' fair ", in the sense of the Rawlsian maximin, to every', 'individual who lives or is going to live during any subinterval of the planning period (stretch-', 'ing from zero to the indefinite future) under the assumption that it is possible to allocate', 'consumpdüon freely among individuals subject only to the technological constraints', 'Consequently, we are going to be looking at a typical problem of a central planning agency', 'when its objective is to maximize the welfare of present generations but it is constrained to', 'abide by the dictates of the maximin principle', 'The present approach, with its emphasis on the welfare of the living generations, is', 'by no means typical of the optimal population literature, most of which is instead con-', 'cerned with the maximization of a sum of utilities (see, eg Meade (1955), Dasgupta (1969,', "1974), Pitchford (1972)) This objective may very well imply sacrificing present generations'", 'utilities in favour of the future ones Consider, for instance, the Meade-Dasgupta maxi-', 'mand (see Meade (1955), Dasgupta (1969)), consisting of a discounted or undiscounted', 'sum of utilities weighted by the number of individuals in each generation As shown by', 'Dasgupta (1969), it is possible to find conditions under which, in the Solow-Swan model', 'with non-overlapping generations, it would be optimal (according to his criterion) to have', 'positive population at every point in time, implying that present generations would have to', 'refrain from consuming all the available capital Therefore, in a Dasgupta optimal plan', 'the present generation is worse off than it would be if it had no descendants and ate up all', '59']
# 9.999999999999998
# ['Perspective', 'GUILLERMO A CALVO', 'Columbia University', 'INTRODUCTION', 'A well-known implication of the Solow-Swan growth model with non-overlapping gener-', 'ations is that if individuals do not care about the number or well-being of their descendants,', 'the present generation will gain nothing from having children (see Phelps (1966)) The', 'non-overlapping assumption is quite crucial for such a result Consider instead the case', 'where generations overlap in Samuelson-Diamond fashion (Diamond (1965)), ie indi-', 'viduals live for two periods—they work in the first and retire in the second At present,', 'period zero, there are, therefore, two generations alive, one of which is old and the other', 'which is young and will survive until the end of the next period Again, the old at time', 'zero do not, in principle, benefit from future generations but that is no longer true for the', 'young at time zero because their capital will be operated by the young in period one In', 'a competitive environment, for instance, with no childbearing costs and positive cross-', 'partial derivatives between capital and labour, the utility of the young at time zero never', 'decreases by adding one more member to generation 1, ie the set of individuals born in', 'period one, because ceteris paribus the rate of return on capital in period one also goes up', 'It is clear that we must adopt some allocation rule in order to be able to be more', 'specific about the number of children that present generations must have if they want to', 'maximize their utility In this paper I will examine the case where present and future', 'generations are constrained to be *\' fair ", in the sense of the Rawlsian maximin, to every', 'individual who lives or is going to live during any subinterval of the planning period (stretch-', 'ing from zero to the indefinite future) under the assumption that it is possible to allocate', 'consumpdüon freely among individuals subject only to the technological constraints', 'Consequently, we are going to be looking at a typical problem of a central planning agency', 'when its objective is to maximize the welfare of present generations but it is constrained to', 'abide by the dictates of the maximin principle', 'The present approach, with its emphasis on the welfare of the living generations, is', 'by no means typical of the optimal population literature, most of which is instead con-', 'cerned with the maximization of a sum of utilities (see, eg Meade (1955), Dasgupta (1969,', "1974), Pitchford (1972)) This objective may very well imply sacrificing present generations'", 'utilities in favour of the future ones Consider, for instance, the Meade-Dasgupta maxi-', 'mand (see Meade (1955), Dasgupta (1969)), consisting of a discounted or undiscounted', 'sum of utilities weighted by the number of individuals in each generation As shown by', 'Dasgupta (1969), it is possible to find conditions under which, in the Solow-Swan model', 'with non-overlapping generations, it would be optimal (according to his criterion) to have', 'positive population at every point in time, implying that present generations would have to', 'refrain from consuming all the available capital Therefore, in a Dasgupta optimal plan', 'the present generation is worse off than it would be if it had no descendants and ate up all', '59']
# ['Perspective', 'GUILLERMO A CALVO', 'Columbia University', 'INTRODUCTION', 'A well-known implication of the Solow-Swan growth model with non-overlapping gener-', 'ations is that if individuals do not care about the number or well-being of their descendants,', 'the present generation will gain nothing from having children (see Phelps (1966)) The', 'non-overlapping assumption is quite crucial for such a result Consider instead the case', 'where generations overlap in Samuelson-Diamond fashion (Diamond (1965)), ie indi-', 'viduals live for two periods—they work in the first and retire in the second At present,', 'period zero, there are, therefore, two generations alive, one of which is old and the other', 'which is young and will survive until the end of the next period Again, the old at time', 'zero do not, in principle, benefit from future generations but that is no longer true for the', 'young at time zero because their capital will be operated by the young in period one In', 'a competitive environment, for instance, with no childbearing costs and positive cross-', 'partial derivatives between capital and labour, the utility of the young at time zero never', 'decreases by adding one more member to generation 1, ie the set of individuals born in', 'period one, because ceteris paribus the rate of return on capital in period one also goes up', 'It is clear that we must adopt some allocation rule in order to be able to be more', 'specific about the number of children that present generations must have if they want to', 'maximize their utility In this paper I will examine the case where present and future', 'generations are constrained to be *\' fair ", in the sense of the Rawlsian maximin, to every', 'individual who lives or is going to live during any subinterval of the planning period (stretch-', 'ing from zero to the indefinite future) under the assumption that it is possible to allocate', 'consumpdüon freely among individuals subject only to the technological constraints', 'Consequently, we are going to be looking at a typical problem of a central planning agency', 'when its objective is to maximize the welfare of present generations but it is constrained to', 'abide by the dictates of the maximin principle', 'The present approach, with its emphasis on the welfare of the living generations, is', 'by no means typical of the optimal population literature, most of which is instead con-', 'cerned with the maximization of a sum of utilities (see, eg Meade (1955), Dasgupta (1969,', "1974), Pitchford (1972)) This objective may very well imply sacrificing present generations'", 'utilities in favour of the future ones Consider, for instance, the Meade-Dasgupta maxi-', 'mand (see Meade (1955), Dasgupta (1969)), consisting of a discounted or undiscounted', 'sum of utilities weighted by the number of individuals in each generation As shown by', 'Dasgupta (1969), it is possible to find conditions under which, in the Solow-Swan model', 'with non-overlapping generations, it would be optimal (according to his criterion) to have', 'positive population at every point in time, implying that present generations would have to', 'refrain from consuming all the available capital Therefore, in a Dasgupta optimal plan', 'the present generation is worse off than it would be if it had no descendants and ate up all', '59']
# 0.0
# ['GUILLERMO A CALVO', 'Columbia University', 'INTRODUCTION', 'A well-known implication of the Solow-Swan growth model with non-overlapping gener-', 'ations is that if individuals do not care about the number or well-being of their descendants,', 'the present generation will gain nothing from having children (see Phelps (1966)) The', 'non-overlapping assumption is quite crucial for such a result Consider instead the case', 'where generations overlap in Samuelson-Diamond fashion (Diamond (1965)), ie indi-', 'viduals live for two periods—they work in the first and retire in the second At present,', 'period zero, there are, therefore, two generations alive, one of which is old and the other', 'which is young and will survive until the end of the next period Again, the old at time', 'zero do not, in principle, benefit from future generations but that is no longer true for the', 'young at time zero because their capital will be operated by the young in period one In', 'a competitive environment, for instance, with no childbearing costs and positive cross-', 'partial derivatives between capital and labour, the utility of the young at time zero never', 'decreases by adding one more member to generation 1, ie the set of individuals born in', 'period one, because ceteris paribus the rate of return on capital in period one also goes up', 'It is clear that we must adopt some allocation rule in order to be able to be more', 'specific about the number of children that present generations must have if they want to', 'maximize their utility In this paper I will examine the case where present and future', 'generations are constrained to be *\' fair ", in the sense of the Rawlsian maximin, to every', 'individual who lives or is going to live during any subinterval of the planning period (stretch-', 'ing from zero to the indefinite future) under the assumption that it is possible to allocate', 'consumpdüon freely among individuals subject only to the technological constraints', 'Consequently, we are going to be looking at a typical problem of a central planning agency', 'when its objective is to maximize the welfare of present generations but it is constrained to', 'abide by the dictates of the maximin principle', 'The present approach, with its emphasis on the welfare of the living generations, is', 'by no means typical of the optimal population literature, most of which is instead con-', 'cerned with the maximization of a sum of utilities (see, eg Meade (1955), Dasgupta (1969,', "1974), Pitchford (1972)) This objective may very well imply sacrificing present generations'", 'utilities in favour of the future ones Consider, for instance, the Meade-Dasgupta maxi-', 'mand (see Meade (1955), Dasgupta (1969)), consisting of a discounted or undiscounted', 'sum of utilities weighted by the number of individuals in each generation As shown by', 'Dasgupta (1969), it is possible to find conditions under which, in the Solow-Swan model', 'with non-overlapping generations, it would be optimal (according to his criterion) to have', 'positive population at every point in time, implying that present generations would have to', 'refrain from consuming all the available capital Therefore, in a Dasgupta optimal plan', 'the present generation is worse off than it would be if it had no descendants and ate up all', '59']
# ['Implicit Contracts and Employment', 'Theory', 'H M POLEMARCHAKIS', 'Harvard University']
# 11.538461538461542
# ['Theory', 'H M POLEMARCHAKIS', 'Harvard University']
# ['Theory', 'H M POLEMARCHAKIS', 'Harvard University']
# 0.0
# ['H M POLEMARCHAKIS', 'Harvard University']
# ['On the Definition and Measurement', 'of Instability and the Costs of', 'Buffering Export Fluctuations', 'A H GELB', "University of Essex and Queen's University"]
# 9.302325581395355
# ['of Instability and the Costs of', 'Buffering Export Fluctuations', 'A H GELB', "University of Essex and Queen's University"]
# ['of Instability and the Costs of', 'Buffering Export Fluctuations', 'A H GELB', "University of Essex and Queen's University"]
# 9.756097560975608
# ['Buffering Export Fluctuations', 'A H GELB', "University of Essex and Queen's University"]
# ['Buffering Export Fluctuations', 'A H GELB', "University of Essex and Queen's University"]
# 10.256410256410254
# ['A H GELB', "University of Essex and Queen's University"]
# ['The Stability of a Generalized Tobin Model', 'MICHAEL G HADJIMICHALAKIS', 'University of Washington', 'and', 'KOJI OKUGUCHI', 'Tokyo Metropolitan University']
# 11.764705882352944
# ['MICHAEL G HADJIMICHALAKIS', 'University of Washington', 'and', 'KOJI OKUGUCHI', 'Tokyo Metropolitan University']
# ['The Balance of Trade in a Model', 'of Temporary Equilibrium with', 'Rationing', 'AVINASH DIXIT', 'University of Warwick, Coventry']
# 9.090909090909093
# ['of Temporary Equilibrium with', 'Rationing', 'AVINASH DIXIT', 'University of Warwick, Coventry']
# ['of Temporary Equilibrium with', 'Rationing', 'AVINASH DIXIT', 'University of Warwick, Coventry']
# 9.523809523809524
# ['Rationing', 'AVINASH DIXIT', 'University of Warwick, Coventry']
# ['Rationing', 'AVINASH DIXIT', 'University of Warwick, Coventry']
# 0.0
# ['AVINASH DIXIT', 'University of Warwick, Coventry']
# ['Intermediation with Costly Bilateral', 'Exchange', 'ROBERT M TOWNSEND', 'Carnegie-Mellon University']
# 7.4074074074074066
# ['Exchange', 'ROBERT M TOWNSEND', 'Carnegie-Mellon University']
# ['Exchange', 'ROBERT M TOWNSEND', 'Carnegie-Mellon University']
# 7.692307692307687
# ['ROBERT M TOWNSEND', 'Carnegie-Mellon University']
# ['Estimation of a Vintage Capital', 'Model for Electricity Generating', 'HUGH R WILLS', 'London School of Economics']
# 9.090909090909093
# ['Model for Electricity Generating', 'HUGH R WILLS', 'London School of Economics']
# ['Model for Electricity Generating', 'HUGH R WILLS', 'London School of Economics']
# 8.888888888888891
# ['HUGH R WILLS', 'London School of Economics']
# ['Growth Accounting with', 'Intermediate Inputs', 'CHARLES R HULTEN', 'Urban Institute, Washington DC']
# 10.256410256410254
# ['Intermediate Inputs', 'CHARLES R HULTEN', 'Urban Institute, Washington DC']
# ['Intermediate Inputs', 'CHARLES R HULTEN', 'Urban Institute, Washington DC']
# 5.555555555555558
# ['CHARLES R HULTEN', 'Urban Institute, Washington DC']
# ['On Stochastic Entry and Exit', 'without Expectations', 'FREDERICK S INABA', 'Washington State University']
# 13.043478260869568
# ['without Expectations', 'FREDERICK S INABA', 'Washington State University']
# ['without Expectations', 'FREDERICK S INABA', 'Washington State University']
# 5.263157894736848
# ['FREDERICK S INABA', 'Washington State University']
# ['Ordering Uncertain Prospects: The', 'Multivariate Utility Functions Case', 'WILLIAM R RUSSELL and TAE KUN SEO', 'Southern Methodist University']
# 7.843137254901967
# ['Multivariate Utility Functions Case', 'WILLIAM R RUSSELL and TAE KUN SEO', 'Southern Methodist University']
# ['Multivariate Utility Functions Case', 'WILLIAM R RUSSELL and TAE KUN SEO', 'Southern Methodist University']
# 11.32075471698113
# ['WILLIAM R RUSSELL and TAE KUN SEO', 'Southern Methodist University']
# ['Expectations and Stability with', 'Gross Complements', 'DAVID G TARR', 'Federal Trade Commission, Washington']
# 9.090909090909093
# ['Gross Complements', 'DAVID G TARR', 'Federal Trade Commission, Washington']
# ['Gross Complements', 'DAVID G TARR', 'Federal Trade Commission, Washington']
# 13.33333333333333
# ['DAVID G TARR', 'Federal Trade Commission, Washington']
# ['Lumpy Investments', 'DAVID A STARRETT', 'Stanford University']
# 5.882352941176472
# ['DAVID A STARRETT', 'Stanford University']
# ['A Limit Theorem on the Core of', 'an Economy with Individual Risks', 'YAFFA MACHNES CASPI', 'The Hebrew University of Jerusalem']
# 16.326530612244895
# ['an Economy with Individual Risks', 'YAFFA MACHNES CASPI', 'The Hebrew University of Jerusalem']
# ['an Economy with Individual Risks', 'YAFFA MACHNES CASPI', 'The Hebrew University of Jerusalem']
# 15.686274509803921
# ['YAFFA MACHNES CASPI', 'The Hebrew University of Jerusalem']
# ['On the Dynamics of Disequilibrium :', 'A Simple Remark', 'GUY LAROQUE', 'Insee, Paris']
# 4.347826086956519
# ['A Simple Remark', 'GUY LAROQUE', 'Insee, Paris']
# ['A Simple Remark', 'GUY LAROQUE', 'Insee, Paris']
# 15.384615384615385
# ['GUY LAROQUE', 'Insee, Paris']
# ['substitution Among Exhaustible', 'Resources and [ntergenerational', 'Equity', 'JOHN M HARTWICK', "Queen's University"]
# 8.695652173913048
# ['Resources and [ntergenerational', 'Equity', 'JOHN M HARTWICK', "Queen's University"]
# ['Resources and [ntergenerational', 'Equity', 'JOHN M HARTWICK', "Queen's University"]
# 8.510638297872342
# ['Equity', 'JOHN M HARTWICK', "Queen's University"]
# ['Equity', 'JOHN M HARTWICK', "Queen's University"]
# 0.0
# ['JOHN M HARTWICK', "Queen's University"]
# ['Economic Welfare with Rank Order Price', 'Weighting', 'PETER J HAMMOND', 'University of Essex']
# 14.814814814814813
# ['Weighting', 'PETER J HAMMOND', 'University of Essex']
# ['Weighting', 'PETER J HAMMOND', 'University of Essex']
# 0.0
# ['PETER J HAMMOND', 'University of Essex']
# ['Distributional Goals and Optimal Growth', 'OWEN STANLEY', 'Australian National University']
# 7.843137254901967
# ['OWEN STANLEY', 'Australian National University']
# ['A Note on Conjectural Equilibria', 'DOUGLAS GALE', 'University of Cambridge', 'This note is a gloss on a paper by F Hahn (1978) There is nothing really new here except', 'the method of proving the two main results: existence of a non-Walrasian conjectural', "equilibrium and impossibility of rational conjectural equilibrium (in Hahn's sense) A great", 'deal of use is made of the fact that competitive behaviour is a special case of conjectural', 'behaviour and this helps draw out the connection between conjectural equilibria and', 'W-equilibria']
# 13.636363636363635
# ['DOUGLAS GALE', 'University of Cambridge', 'This note is a gloss on a paper by F Hahn (1978) There is nothing really new here except', 'the method of proving the two main results: existence of a non-Walrasian conjectural', "equilibrium and impossibility of rational conjectural equilibrium (in Hahn's sense) A great", 'deal of use is made of the fact that competitive behaviour is a special case of conjectural', 'behaviour and this helps draw out the connection between conjectural equilibria and', 'W-equilibria']
# ['Planning Algorithms to deal with', 'Increasing Returns', 'C HENRY and A ZYLBERBERG', 'Ecole Polytechnique, Paris']
# 5.000000000000004
# ['Increasing Returns', 'C HENRY and A ZYLBERBERG', 'Ecole Polytechnique, Paris']
# ['Increasing Returns', 'C HENRY and A ZYLBERBERG', 'Ecole Polytechnique, Paris']
# 15.384615384615385
# ['C HENRY and A ZYLBERBERG', 'Ecole Polytechnique, Paris']
# ['Cheatproofness Properties of the', 'Plurality Rule in Large Societies', 'ELISHA A PAZNER', 'Northwestern University and Tel-Aviv University', 'and', 'EUGENE WESLEY', 'Northwestern University']
# 8.333333333333337
# ['Plurality Rule in Large Societies', 'ELISHA A PAZNER', 'Northwestern University and Tel-Aviv University', 'and', 'EUGENE WESLEY', 'Northwestern University']
# ['Plurality Rule in Large Societies', 'ELISHA A PAZNER', 'Northwestern University and Tel-Aviv University', 'and', 'EUGENE WESLEY', 'Northwestern University']
# 8.163265306122447
# ['ELISHA A PAZNER', 'Northwestern University and Tel-Aviv University', 'and', 'EUGENE WESLEY', 'Northwestern University']
# ['Optimal Exhaustible Resource', 'Depletion with Endogenous', 'Technical Change', 'MORTON I KAMIEN and NANCY L SCHWARTZ', 'Northwestern University']
# 13.636363636363635
# ['Depletion with Endogenous', 'Technical Change', 'MORTON I KAMIEN and NANCY L SCHWARTZ', 'Northwestern University']
# ['Depletion with Endogenous', 'Technical Change', 'MORTON I KAMIEN and NANCY L SCHWARTZ', 'Northwestern University']
# 14.634146341463417
# ['Technical Change', 'MORTON I KAMIEN and NANCY L SCHWARTZ', 'Northwestern University']
# ['Technical Change', 'MORTON I KAMIEN and NANCY L SCHWARTZ', 'Northwestern University']
# 12.5
# ['MORTON I KAMIEN and NANCY L SCHWARTZ', 'Northwestern University']
# ["A Note on Feldstein's Criticism of Mean-", 'Variance Analysis', 'JORAM MAYSHAR', 'The Hebrew University of Jerusalem']
# 11.32075471698113
# ['Variance Analysis', 'JORAM MAYSHAR', 'The Hebrew University of Jerusalem']
# ['Variance Analysis', 'JORAM MAYSHAR', 'The Hebrew University of Jerusalem']
# 13.33333333333333
# ['JORAM MAYSHAR', 'The Hebrew University of Jerusalem']
# ["A Note on Feldstein's Criticism of Mean-Variance", 'Analysis: A Reply', 'MARTIN S FELDSTEIN', 'Harvard University']
# 14.925373134328357
# ['Analysis: A Reply', 'MARTIN S FELDSTEIN', 'Harvard University']
# ['Analysis: A Reply', 'MARTIN S FELDSTEIN', 'Harvard University']
# 16.666666666666664
# ['MARTIN S FELDSTEIN', 'Harvard University']
# ['Prices vs Quantities: A Critical Note on the Use', 'of Approximations', 'JAMES M MALCOMSON', 'University of York']
# 15.151515151515149
# ['of Approximations', 'JAMES M MALCOMSON', 'University of York']
# ['of Approximations', 'JAMES M MALCOMSON', 'University of York']
# 11.428571428571432
# ['JAMES M MALCOMSON', 'University of York']
# ['Bargains and Ripoffs: A Model of', 'Monopolistically Competitive', 'Price Dispersion', 'STEVEN SALOP', 'Federal Reserve Board', 'and', 'JOSEPH STIGLITZ', 'Stanford University and Oxford University']
# 9.090909090909093
# ['Monopolistically Competitive', 'Price Dispersion', 'STEVEN SALOP', 'Federal Reserve Board', 'and', 'JOSEPH STIGLITZ', 'Stanford University and Oxford University']
# ['Monopolistically Competitive', 'Price Dispersion', 'STEVEN SALOP', 'Federal Reserve Board', 'and', 'JOSEPH STIGLITZ', 'Stanford University and Oxford University']
# 5.000000000000004
# ['Price Dispersion', 'STEVEN SALOP', 'Federal Reserve Board', 'and', 'JOSEPH STIGLITZ', 'Stanford University and Oxford University']
# ['Price Dispersion', 'STEVEN SALOP', 'Federal Reserve Board', 'and', 'JOSEPH STIGLITZ', 'Stanford University and Oxford University']
# 7.14285714285714
# ['STEVEN SALOP', 'Federal Reserve Board', 'and', 'JOSEPH STIGLITZ', 'Stanford University and Oxford University']
# ['A Bidding Model of Perfect', 'Competition', 'ROBERT WILSON', 'Stanford University']
# 10.256410256410254
# ['Competition', 'ROBERT WILSON', 'Stanford University']
# ['Competition', 'ROBERT WILSON', 'Stanford University']
# 0.0
# ['ROBERT WILSON', 'Stanford University']
# ['A Bayesian Approach to the', 'Production of Information and', 'Learning By Doing', 'SANFORD J GROSSMAN', 'Stanford University', 'RICHARD E KIHLSTROM and LEONARD J MIRMAN', 'University of Illinois']
# 17.777777777777782
# ['Production of Information and', 'Learning By Doing', 'SANFORD J GROSSMAN', 'Stanford University', 'RICHARD E KIHLSTROM and LEONARD J MIRMAN', 'University of Illinois']
# ['Production of Information and', 'Learning By Doing', 'SANFORD J GROSSMAN', 'Stanford University', 'RICHARD E KIHLSTROM and LEONARD J MIRMAN', 'University of Illinois']
# 8.333333333333337
# ['Learning By Doing', 'SANFORD J GROSSMAN', 'Stanford University', 'RICHARD E KIHLSTROM and LEONARD J MIRMAN', 'University of Illinois']
# ['Learning By Doing', 'SANFORD J GROSSMAN', 'Stanford University', 'RICHARD E KIHLSTROM and LEONARD J MIRMAN', 'University of Illinois']
# 11.111111111111116
# ['SANFORD J GROSSMAN', 'Stanford University', 'RICHARD E KIHLSTROM and LEONARD J MIRMAN', 'University of Illinois']
# ['A Characterization of Societies with', 'Consistent Majority Decision', 'STEVEN SLUTSKY', 'Cornell University']
# 7.9999999999999964
# ['Consistent Majority Decision', 'STEVEN SLUTSKY', 'Cornell University']
# ['Consistent Majority Decision', 'STEVEN SLUTSKY', 'Cornell University']
# 4.761904761904767
# ['STEVEN SLUTSKY', 'Cornell University']
# ['Aggregate Production Functions:', 'some CES Experiments', 'FRANKLIN M FISHER and ROBERT M SOLOW', 'Massachusetts Institute of Technology', 'and', 'JAMES M KEARL', 'Brigham Young University']
# 16.326530612244895
# ['some CES Experiments', 'FRANKLIN M FISHER and ROBERT M SOLOW', 'Massachusetts Institute of Technology', 'and', 'JAMES M KEARL', 'Brigham Young University']
# ['some CES Experiments', 'FRANKLIN M FISHER and ROBERT M SOLOW', 'Massachusetts Institute of Technology', 'and', 'JAMES M KEARL', 'Brigham Young University']
# 15.789473684210531
# ['FRANKLIN M FISHER and ROBERT M SOLOW', 'Massachusetts Institute of Technology', 'and', 'JAMES M KEARL', 'Brigham Young University']
# ['A Rawlsian Intertemporal', 'Consumption Rule', 'PAUL GROUT', 'Manchester University']
# 17.647058823529417
# ['Consumption Rule', 'PAUL GROUT', 'Manchester University']
# ['Consumption Rule', 'PAUL GROUT', 'Manchester University']
# 15.384615384615385
# ['PAUL GROUT', 'Manchester University']
# ['Portfolio Theory, Asset Demand', 'and Taxation: Comparative Statics', 'with Many Assets', 'AGNAR SANDMO', 'Norwegian School of Economics and Business Administration, Bergen']
# 14.28571428571429
# ['and Taxation: Comparative Statics', 'with Many Assets', 'AGNAR SANDMO', 'Norwegian School of Economics and Business Administration, Bergen']
# ['and Taxation: Comparative Statics', 'with Many Assets', 'AGNAR SANDMO', 'Norwegian School of Economics and Business Administration, Bergen']
# 8.888888888888891
# ['with Many Assets', 'AGNAR SANDMO', 'Norwegian School of Economics and Business Administration, Bergen']
# ['with Many Assets', 'AGNAR SANDMO', 'Norwegian School of Economics and Business Administration, Bergen']
# 14.28571428571429
# ['AGNAR SANDMO', 'Norwegian School of Economics and Business Administration, Bergen']
# ['Durable Goods in the Extended Linear', 'Expenditure System', 'PETER B DIXON', 'Industries Assistance Commission and Monash University', 'and', 'CONSTANTINO LLUCH', 'Development Research Center, World Bank']
# 7.9999999999999964
# ['Expenditure System', 'PETER B DIXON', 'Industries Assistance Commission and Monash University', 'and', 'CONSTANTINO LLUCH', 'Development Research Center, World Bank']
# ['Expenditure System', 'PETER B DIXON', 'Industries Assistance Commission and Monash University', 'and', 'CONSTANTINO LLUCH', 'Development Research Center, World Bank']
# 12.5
# ['PETER B DIXON', 'Industries Assistance Commission and Monash University', 'and', 'CONSTANTINO LLUCH', 'Development Research Center, World Bank']
# ['Price Distortion and the Second', 'Best Optimum', 'KUNIO KAWAMATA', 'Keio University']
# 4.444444444444439
# ['Best Optimum', 'KUNIO KAWAMATA', 'Keio University']
# ['Best Optimum', 'KUNIO KAWAMATA', 'Keio University']
# 7.692307692307687
# ['KUNIO KAWAMATA', 'Keio University']
# ['A Model of Short-Term Capital', 'Movements, the Foreign Exchange', 'Market and Official Intervention', 'in the UK, 1963-1970', 'JOHN P HUTTON', 'University of York']
# 13.953488372093027
# ['Movements, the Foreign Exchange', 'Market and Official Intervention', 'in the UK, 1963-1970', 'JOHN P HUTTON', 'University of York']
# ['Movements, the Foreign Exchange', 'Market and Official Intervention', 'in the UK, 1963-1970', 'JOHN P HUTTON', 'University of York']
# 8.888888888888891
# ['Market and Official Intervention', 'in the UK, 1963-1970', 'JOHN P HUTTON', 'University of York']
# ['Market and Official Intervention', 'in the UK, 1963-1970', 'JOHN P HUTTON', 'University of York']
# 13.043478260869568
# ['in the UK, 1963-1970', 'JOHN P HUTTON', 'University of York']
# ['in the UK, 1963-1970', 'JOHN P HUTTON', 'University of York']
# 17.647058823529417
# ['JOHN P HUTTON', 'University of York']
# ['A Variable-Parameter Model of', 'Exporting Behaviour', 'R A BATCHELOR', 'National Institute of Economic and Social Research']
# 9.090909090909093
# ['Exporting Behaviour', 'R A BATCHELOR', 'National Institute of Economic and Social Research']
# ['Exporting Behaviour', 'R A BATCHELOR', 'National Institute of Economic and Social Research']
# 11.764705882352944
# ['R A BATCHELOR', 'National Institute of Economic and Social Research']
# ['Optimal Time Paths with', 'Age-Dependence: A Theory of', 'Population Policy', 'W BRIAN ARTHUR and GEOFFREY McNICOLL', 'The Population Council, New York']
# 10.526315789473683
# ['Age-Dependence: A Theory of', 'Population Policy', 'W BRIAN ARTHUR and GEOFFREY McNICOLL', 'The Population Council, New York']
# ['Age-Dependence: A Theory of', 'Population Policy', 'W BRIAN ARTHUR and GEOFFREY McNICOLL', 'The Population Council, New York']
# 19.047619047619047
# ['Population Policy', 'W BRIAN ARTHUR and GEOFFREY McNICOLL', 'The Population Council, New York']
# ['Population Policy', 'W BRIAN ARTHUR and GEOFFREY McNICOLL', 'The Population Council, New York']
# 6.25
# ['W BRIAN ARTHUR and GEOFFREY McNICOLL', 'The Population Council, New York']
# ['More on Prices vs Quantities', 'JEAN JACQUES LAFFONT', "Laboratoire d' Econométrie de l' Ecole Polytechnique, Paris"]
# 8.333333333333337
# ['JEAN JACQUES LAFFONT', "Laboratoire d' Econométrie de l' Ecole Polytechnique, Paris"]
# ['Exact Maximum Likelihood', 'Estimation of Regression Models', 'with Finite Order Moving', 'Average Errors', 'A R PAGAN and D F NICHOLLS', 'Australian National University']
# 11.428571428571432
# ['Estimation of Regression Models', 'with Finite Order Moving', 'Average Errors', 'A R PAGAN and D F NICHOLLS', 'Australian National University']
# ['Estimation of Regression Models', 'with Finite Order Moving', 'Average Errors', 'A R PAGAN and D F NICHOLLS', 'Australian National University']
# 14.28571428571429
# ['with Finite Order Moving', 'Average Errors', 'A R PAGAN and D F NICHOLLS', 'Australian National University']
# ['with Finite Order Moving', 'Average Errors', 'A R PAGAN and D F NICHOLLS', 'Australian National University']
# 11.428571428571432
# ['Average Errors', 'A R PAGAN and D F NICHOLLS', 'Australian National University']
# ['Average Errors', 'A R PAGAN and D F NICHOLLS', 'Australian National University']
# 16.000000000000004
# ['A R PAGAN and D F NICHOLLS', 'Australian National University']
# ['Soviet Pricing, Profits and', 'Technological Choice', 'MICHAEL MANOVE', 'Boston University']
# 4.878048780487809
# ['Technological Choice', 'MICHAEL MANOVE', 'Boston University']
# ['Technological Choice', 'MICHAEL MANOVE', 'Boston University']
# 5.882352941176472
# ['MICHAEL MANOVE', 'Boston University']
# ['Money, Expectations and the', 'Existence of a Temporary', 'Equilibrium', 'BRYCE HOOL', 'University of Wisconsin, Madison']
# 10.81081081081081
# ['Existence of a Temporary', 'Equilibrium', 'BRYCE HOOL', 'University of Wisconsin, Madison']
# ['Existence of a Temporary', 'Equilibrium', 'BRYCE HOOL', 'University of Wisconsin, Madison']
# 11.764705882352944
# ['Equilibrium', 'BRYCE HOOL', 'University of Wisconsin, Madison']
# ['Equilibrium', 'BRYCE HOOL', 'University of Wisconsin, Madison']
# 9.523809523809524
# ['BRYCE HOOL', 'University of Wisconsin, Madison']
# ['Exact Measures of Welfare and the', 'Cost of Living', 'GEORGE McKENZIE and IVOR PEARCE', 'Southampton University']
# 12.5
# ['Cost of Living', 'GEORGE McKENZIE and IVOR PEARCE', 'Southampton University']
# ['Cost of Living', 'GEORGE McKENZIE and IVOR PEARCE', 'Southampton University']
# 6.896551724137934
# ['GEORGE McKENZIE and IVOR PEARCE', 'Southampton University']
# ['Optimal Control with Integral', 'State Equations', 'M I KAMIEN and E MULLER', 'Graduate School of Management, Northwestern University']
# 14.634146341463417
# ['State Equations', 'M I KAMIEN and E MULLER', 'Graduate School of Management, Northwestern University']
# ['State Equations', 'M I KAMIEN and E MULLER', 'Graduate School of Management, Northwestern University']
# 14.814814814814813
# ['M I KAMIEN and E MULLER', 'Graduate School of Management, Northwestern University']
# ['Portfolio Adjustment and', 'Monetary Growth', 'LEWIS JOHNSON', 'Federal Reserve System']
# 5.405405405405405
# ['Monetary Growth', 'LEWIS JOHNSON', 'Federal Reserve System']
# ['Monetary Growth', 'LEWIS JOHNSON', 'Federal Reserve System']
# 7.14285714285714
# ['LEWIS JOHNSON', 'Federal Reserve System']
# ['On the Estimation of Income', 'Inequality Measures from', 'Grouped Observations', 'NANAK KAKWANI', 'University of New South Wales']
# 9.999999999999998
# ['Inequality Measures from', 'Grouped Observations', 'NANAK KAKWANI', 'University of New South Wales']
# ['Inequality Measures from', 'Grouped Observations', 'NANAK KAKWANI', 'University of New South Wales']
# 5.405405405405405
# ['Grouped Observations', 'NANAK KAKWANI', 'University of New South Wales']
# ['Grouped Observations', 'NANAK KAKWANI', 'University of New South Wales']
# 6.060606060606055
# ['NANAK KAKWANI', 'University of New South Wales']
# ['A Brief Note on the Efficiency of', 'Equilibria with Costly Transactions', 'J GREEN and H POLEMARCHAKIS', 'Harvard University']
# 9.756097560975608
# ['Equilibria with Costly Transactions', 'J GREEN and H POLEMARCHAKIS', 'Harvard University']
# ['Equilibria with Costly Transactions', 'J GREEN and H POLEMARCHAKIS', 'Harvard University']
# 4.651162790697672
# ['J GREEN and H POLEMARCHAKIS', 'Harvard University']
# ['A Note on Representing Partial Orderings', 'MUKUL MAJUMDAR and AMARTYA SEN', 'London School of Economics']
# 7.4074074074074066
# ['MUKUL MAJUMDAR and AMARTYA SEN', 'London School of Economics']
# ['Money Wage Inflation in Industrial Countries:', 'An Alternative Explanation', 'R L THOMAS', 'University of Salford']
# 7.017543859649122
# ['An Alternative Explanation', 'R L THOMAS', 'University of Salford']
# ['An Alternative Explanation', 'R L THOMAS', 'University of Salford']
# 10.526315789473683
# ['R L THOMAS', 'University of Salford']
# ...
# 14.634146341463417
# ['WERNER HILDENBRAND', 'University of Bonn and CORE', 'and', 'ALAN P KIRMAN', 'CORE']
# ['Afriat and Revealed Preference', 'Theory "', 'W E DIEWERT', 'University of British Columbia']
# 13.953488372093027
# ['Theory "', 'W E DIEWERT', 'University of British Columbia']
# ['Theory "', 'W E DIEWERT', 'University of British Columbia']
# 9.523809523809524
# ['W E DIEWERT', 'University of British Columbia']
# ['Systematic Job Search and', 'Unemployment "', 'S C SALOP', 'Board of Governors of the Federal Reserve']
# 22.22222222222222
# ['Unemployment "', 'S C SALOP', 'Board of Governors of the Federal Reserve']
# ['Unemployment "', 'S C SALOP', 'Board of Governors of the Federal Reserve']
# 7.9999999999999964
# ['S C SALOP', 'Board of Governors of the Federal Reserve']
# ['A Generalization of the Phillips', 'Curve for a Developing Country', 'FRANCO MODIGLIANI', 'MIT', 'and', 'EZIO TARANTELLI', 'University of Rome']
# 12.244897959183676
# ['Curve for a Developing Country', 'FRANCO MODIGLIANI', 'MIT', 'and', 'EZIO TARANTELLI', 'University of Rome']
# ['Curve for a Developing Country', 'FRANCO MODIGLIANI', 'MIT', 'and', 'EZIO TARANTELLI', 'University of Rome']
# 12.765957446808507
# ['FRANCO MODIGLIANI', 'MIT', 'and', 'EZIO TARANTELLI', 'University of Rome']
# ['Applications of a Model of', 'Endogenous Technical Change', 'to US Industry Data "', 'JON A RASMUSSEN', 'Wesleyan University']
# 14.28571428571429
# ['Endogenous Technical Change', 'to US Industry Data "', 'JON A RASMUSSEN', 'Wesleyan University']
# ['Endogenous Technical Change', 'to US Industry Data "', 'JON A RASMUSSEN', 'Wesleyan University']
# 9.302325581395355
# ['to US Industry Data "', 'JON A RASMUSSEN', 'Wesleyan University']
# ['to US Industry Data "', 'JON A RASMUSSEN', 'Wesleyan University']
# 16.216216216216218
# ['JON A RASMUSSEN', 'Wesleyan University']
# ['Consistent Intertemporal Decision', 'Making', 'CHARLES BLACKORBY', 'Southern Illinois University', 'DAVID NISSEN', 'Resource Management Corporation', 'DANIEL PRIMONT', 'University of Massachusetts, Boston', 'and', 'R ROBERT RUSSELL', 'UC San Diego and UC Santa Barbara']
# 7.9999999999999964
# ['Making', 'CHARLES BLACKORBY', 'Southern Illinois University', 'DAVID NISSEN', 'Resource Management Corporation', 'DANIEL PRIMONT', 'University of Massachusetts, Boston', 'and', 'R ROBERT RUSSELL', 'UC San Diego and UC Santa Barbara']
# ['Making', 'CHARLES BLACKORBY', 'Southern Illinois University', 'DAVID NISSEN', 'Resource Management Corporation', 'DANIEL PRIMONT', 'University of Massachusetts, Boston', 'and', 'R ROBERT RUSSELL', 'UC San Diego and UC Santa Barbara']
# 0.0
# ['CHARLES BLACKORBY', 'Southern Illinois University', 'DAVID NISSEN', 'Resource Management Corporation', 'DANIEL PRIMONT', 'University of Massachusetts, Boston', 'and', 'R ROBERT RUSSELL', 'UC San Diego and UC Santa Barbara']
# ['Adjustment Costs, Price and Wage', 'Uncertainty, and Investment', 'RICHARD HARTMAN', 'University of Washington']
# 8.510638297872342
# ['Uncertainty, and Investment', 'RICHARD HARTMAN', 'University of Washington']
# ['Uncertainty, and Investment', 'RICHARD HARTMAN', 'University of Washington']
# 4.761904761904767
# ['RICHARD HARTMAN', 'University of Washington']
# ['A Note on Fixed Factor Proportions and Net', 'Saving Rates "\'', 'M A M SMITH', 'London School of Economics']
# 10.71428571428571
# ['Saving Rates "\'', 'M A M SMITH', 'London School of Economics']
# ['Saving Rates "\'', 'M A M SMITH', 'London School of Economics']
# 13.793103448275868
# ['M A M SMITH', 'London School of Economics']
# ['Monetary and Fiscal Policy in a World of', "Capital Mobility: A Reply '", 'JOHN E FLOYD', 'University of Toronto']
# 11.32075471698113
# ["Capital Mobility: A Reply '", 'JOHN E FLOYD', 'University of Toronto']
# ["Capital Mobility: A Reply '", 'JOHN E FLOYD', 'University of Toronto']
# 9.999999999999998
# ['JOHN E FLOYD', 'University of Toronto']
# ['Optimal Growth with Inter-', 'temporally Dependent Preferences "\'', 'HARL E RYDER, Jr', 'Brown University', 'and', 'GEOFFREY M HEAL', 'University of Sussex']
# 10.256410256410254
# ['temporally Dependent Preferences "\'', 'HARL E RYDER, Jr', 'Brown University', 'and', 'GEOFFREY M HEAL', 'University of Sussex']
# ['temporally Dependent Preferences "\'', 'HARL E RYDER, Jr', 'Brown University', 'and', 'GEOFFREY M HEAL', 'University of Sussex']
# 8.333333333333337
# ['HARL E RYDER, Jr', 'Brown University', 'and', 'GEOFFREY M HEAL', 'University of Sussex']
# ['The Demand for Money:', 'A General-Equilibrium Inventory-', 'Theoretic Approach', 'GEORGE A AKERLOF', 'University of California, Berkeley']
# 10.526315789473683
# ['A General-Equilibrium Inventory-', 'Theoretic Approach', 'GEORGE A AKERLOF', 'University of California, Berkeley']
# ['A General-Equilibrium Inventory-', 'Theoretic Approach', 'GEORGE A AKERLOF', 'University of California, Berkeley']
# 12.244897959183676
# ['Theoretic Approach', 'GEORGE A AKERLOF', 'University of California, Berkeley']
# ['Theoretic Approach', 'GEORGE A AKERLOF', 'University of California, Berkeley']
# 11.428571428571432
# ['GEORGE A AKERLOF', 'University of California, Berkeley']
# ['Prices for Individual Consumption,', 'Quantity Indicators for Collective', 'Consumption "\'', 'E MALINVAUD', 'Direction de la Prévision, Paris']
# 8.695652173913048
# ['Quantity Indicators for Collective', 'Consumption "\'', 'E MALINVAUD', 'Direction de la Prévision, Paris']
# ['Quantity Indicators for Collective', 'Consumption "\'', 'E MALINVAUD', 'Direction de la Prévision, Paris']
# 8.695652173913048
# ['Consumption "\'', 'E MALINVAUD', 'Direction de la Prévision, Paris']
# ['Consumption "\'', 'E MALINVAUD', 'Direction de la Prévision, Paris']
# 7.692307692307687
# ['E MALINVAUD', 'Direction de la Prévision, Paris']
# ['Optimum Investment in Human', 'Capital', 'ASSAF RAZIN', 'Tel-Aviv University']
# 10.526315789473683
# ['Capital', 'ASSAF RAZIN', 'Tel-Aviv University']
# ['Capital', 'ASSAF RAZIN', 'Tel-Aviv University']
# 0.0
# ['ASSAF RAZIN', 'Tel-Aviv University']
# ['A Four-Flagged Lemma "*', 'MURAT R SERTEL', 'MIT and International Institute of Management, Berlin']
# 21.052631578947366
# ['MURAT R SERTEL', 'MIT and International Institute of Management, Berlin']
# ['The Stability of the Competitive System', 'which contains', "Gross Complementary Goods '*", 'RYUZO SATO', 'Brown University']
# 8.163265306122447
# ['which contains', "Gross Complementary Goods '*", 'RYUZO SATO', 'Brown University']
# ['which contains', "Gross Complementary Goods '*", 'RYUZO SATO', 'Brown University']
# 8.333333333333337
# ["Gross Complementary Goods '*", 'RYUZO SATO', 'Brown University']
# ["Gross Complementary Goods '*", 'RYUZO SATO', 'Brown University']
# 5.263157894736848
# ['RYUZO SATO', 'Brown University']
# ['Monetary and Fiscal Policy in a', 'World of Capital Mobility: a', 'Respecification', 'EDWARD TOWER', 'University of Auckland']
# 4.651162790697672
# ['World of Capital Mobility: a', 'Respecification', 'EDWARD TOWER', 'University of Auckland']
# ['World of Capital Mobility: a', 'Respecification', 'EDWARD TOWER', 'University of Auckland']
# 9.999999999999998
# ['Respecification', 'EDWARD TOWER', 'University of Auckland']
# ['Respecification', 'EDWARD TOWER', 'University of Auckland']
# 7.4074074074074066
# ['EDWARD TOWER', 'University of Auckland']
# ['Demand for Consumer Durables:', 'Stock Adjustment Models and', 'Alternative Specifications of Stock', 'Depletion *', 'ROSS A WILLIAMS', 'Monash University']
# 8.888888888888891
# ['Stock Adjustment Models and', 'Alternative Specifications of Stock', 'Depletion *', 'ROSS A WILLIAMS', 'Monash University']
# ['Stock Adjustment Models and', 'Alternative Specifications of Stock', 'Depletion *', 'ROSS A WILLIAMS', 'Monash University']
# 23.25581395348837
# ['Alternative Specifications of Stock', 'Depletion *', 'ROSS A WILLIAMS', 'Monash University']
# ['Alternative Specifications of Stock', 'Depletion *', 'ROSS A WILLIAMS', 'Monash University']
# 15.686274509803921
# ['Depletion *', 'ROSS A WILLIAMS', 'Monash University']
# ['Depletion *', 'ROSS A WILLIAMS', 'Monash University']
# 7.4074074074074066
# ['ROSS A WILLIAMS', 'Monash University']
# ['Private Wealth as an Obstacle to', "Pareto Optimality ? '", 'J K WHITAKER', 'University of Virginia']
# 8.695652173913048
# ["Pareto Optimality ? '", 'J K WHITAKER', 'University of Virginia']
# ["Pareto Optimality ? '", 'J K WHITAKER', 'University of Virginia']
# 11.428571428571432
# ['J K WHITAKER', 'University of Virginia']
# ['On the Role of Money and the', 'Existence of a Monetary', 'Equilibrium', 'JEAN-MICHEL GRANDMONT and YVES YOUNES', 'CEPREMAP, Paris']
# 12.244897959183676
# ['Existence of a Monetary', 'Equilibrium', 'JEAN-MICHEL GRANDMONT and YVES YOUNES', 'CEPREMAP, Paris']
# ['Existence of a Monetary', 'Equilibrium', 'JEAN-MICHEL GRANDMONT and YVES YOUNES', 'CEPREMAP, Paris']
# 13.636363636363635
# ['Equilibrium', 'JEAN-MICHEL GRANDMONT and YVES YOUNES', 'CEPREMAP, Paris']
# ['Equilibrium', 'JEAN-MICHEL GRANDMONT and YVES YOUNES', 'CEPREMAP, Paris']
# 6.25
# ['JEAN-MICHEL GRANDMONT and YVES YOUNES', 'CEPREMAP, Paris']
# ['Efficiency Prices in Infinite', 'Dimensional Spaces: a Synthesis', 'MORDECAI KURZ and MUKUL MAJUMDAR', 'Stanford University']
# 9.523809523809524
# ['Dimensional Spaces: a Synthesis', 'MORDECAI KURZ and MUKUL MAJUMDAR', 'Stanford University']
# ['Dimensional Spaces: a Synthesis', 'MORDECAI KURZ and MUKUL MAJUMDAR', 'Stanford University']
# 9.090909090909093
# ['MORDECAI KURZ and MUKUL MAJUMDAR', 'Stanford University']
# ['General Possibility Theorems', 'for Group Decisions', 'ANDREU MAS-COLELL', 'University of Minnesota', 'and', 'HUGO SONNENSCHEIN', 'University of Massachusetts']
# 4.444444444444439
# ['for Group Decisions', 'ANDREU MAS-COLELL', 'University of Minnesota', 'and', 'HUGO SONNENSCHEIN', 'University of Massachusetts']
# ['for Group Decisions', 'ANDREU MAS-COLELL', 'University of Minnesota', 'and', 'HUGO SONNENSCHEIN', 'University of Massachusetts']
# 5.555555555555558
# ['ANDREU MAS-COLELL', 'University of Minnesota', 'and', 'HUGO SONNENSCHEIN', 'University of Massachusetts']
# ['Open Economies', 'POLLY REYNOLDS ALLEN', 'Princeton University']
# 17.647058823529417
# ['POLLY REYNOLDS ALLEN', 'Princeton University']
# ['Corporate Taxation and Dividend Behaviour :', 'a Reply and Extension', 'MARTIN S FELDSTEIN', 'Harvard University']
# 12.903225806451612
# ['a Reply and Extension', 'MARTIN S FELDSTEIN', 'Harvard University']
# ['a Reply and Extension', 'MARTIN S FELDSTEIN', 'Harvard University']
# 19.999999999999996
# ['MARTIN S FELDSTEIN', 'Harvard University']
# ['A Theory of Monopolistic Price', 'Adjustment "\'', 'ROBERT J BARRO', 'The University of Chicago and Brown University']
# 13.33333333333333
# ['Adjustment "\'', 'ROBERT J BARRO', 'The University of Chicago and Brown University']
# ['Adjustment "\'', 'ROBERT J BARRO', 'The University of Chicago and Brown University']
# 7.14285714285714
# ['ROBERT J BARRO', 'The University of Chicago and Brown University']
# ['Trade Unions and the Rate of', 'Change of Money Wages in United', 'States Manufacturing Industry "\'', 'O C ASHENFELTER G E JOHNSON', 'Princeton University University of Michigan']
# 13.33333333333333
# ['Change of Money Wages in United', 'States Manufacturing Industry "\'', 'O C ASHENFELTER G E JOHNSON', 'Princeton University University of Michigan']
# ['Change of Money Wages in United', 'States Manufacturing Industry "\'', 'O C ASHENFELTER G E JOHNSON', 'Princeton University University of Michigan']
# 8.333333333333337
# ['States Manufacturing Industry "\'', 'O C ASHENFELTER G E JOHNSON', 'Princeton University University of Michigan']
# ['States Manufacturing Industry "\'', 'O C ASHENFELTER G E JOHNSON', 'Princeton University University of Michigan']
# 8.163265306122447
# ['O C ASHENFELTER G E JOHNSON', 'Princeton University University of Michigan']
# ['The Formulation of the Dependent', "Variable in the Wage Equation '", 'S W BLACK', 'Vanderbilt University', 'and', 'H H KELEJIAN', 'New York University']
# 9.302325581395355
# ["Variable in the Wage Equation '", 'S W BLACK', 'Vanderbilt University', 'and', 'H H KELEJIAN', 'New York University']
# ["Variable in the Wage Equation '", 'S W BLACK', 'Vanderbilt University', 'and', 'H H KELEJIAN', 'New York University']
# 14.28571428571429
# ['S W BLACK', 'Vanderbilt University', 'and', 'H H KELEJIAN', 'New York University']
# ['Wage Adjustment, Productivity and', 'Price Change Expectations', 'JOHN VANDERKAMP', 'University of Guelph']
# 12.5
# ['Price Change Expectations', 'JOHN VANDERKAMP', 'University of Guelph']
# ['Price Change Expectations', 'JOHN VANDERKAMP', 'University of Guelph']
# 9.999999999999998
# ['JOHN VANDERKAMP', 'University of Guelph']
# ['Liquidity Preference and Risk Aversion', "with an Exponential Utility Function '", 'ERROL GLUSTOFF', 'The University of Tennessee', 'and', 'NIC NIGRO', 'University of Washington']
# 7.692307692307687
# ["with an Exponential Utility Function '", 'ERROL GLUSTOFF', 'The University of Tennessee', 'and', 'NIC NIGRO', 'University of Washington']
# ["with an Exponential Utility Function '", 'ERROL GLUSTOFF', 'The University of Tennessee', 'and', 'NIC NIGRO', 'University of Washington']
# 15.384615384615385
# ['ERROL GLUSTOFF', 'The University of Tennessee', 'and', 'NIC NIGRO', 'University of Washington']
# ['Additive Utility Functions and', 'Linear Engel Curves"', 'ROBERT A POLLAK', 'University of Pennsylvania']
# 8.695652173913048
# ['Linear Engel Curves"', 'ROBERT A POLLAK', 'University of Pennsylvania']
# ['Linear Engel Curves"', 'ROBERT A POLLAK', 'University of Pennsylvania']
# 11.111111111111116
# ['ROBERT A POLLAK', 'University of Pennsylvania']
# ['Weak Experimental Verification of', 'the Expected Utility Hypothesis', 'R N ROSETT', 'University of Rochester']
# 8.888888888888891
# ['the Expected Utility Hypothesis', 'R N ROSETT', 'University of Rochester']
# ['the Expected Utility Hypothesis', 'R N ROSETT', 'University of Rochester']
# 9.302325581395355
# ['R N ROSETT', 'University of Rochester']
# ['An Investment Planning Process', 'for an Economy with', "Increasing Returns'", 'M AOKI', 'Harvard University and', 'Kyoto University']
# 10.81081081081081
# ['for an Economy with', "Increasing Returns'", 'M AOKI', 'Harvard University and', 'Kyoto University']
# ['for an Economy with', "Increasing Returns'", 'M AOKI', 'Harvard University and', 'Kyoto University']
# 7.692307692307687
# ["Increasing Returns'", 'M AOKI', 'Harvard University and', 'Kyoto University']
# ["Increasing Returns'", 'M AOKI', 'Harvard University and', 'Kyoto University']
# 7.692307692307687
# ['M AOKI', 'Harvard University and', 'Kyoto University']
# ['Planning, Prices and', 'Increasing Returns "\'', 'G M HEAL', "Christ's College, Cambridge"]
# 13.33333333333333
# ['Increasing Returns "\'', 'G M HEAL', "Christ's College, Cambridge"]
# ['Increasing Returns "\'', 'G M HEAL', "Christ's College, Cambridge"]
# 12.903225806451612
# ['G M HEAL', "Christ's College, Cambridge"]
# ['The Dynamic Effects of Fiscal Policy', "in an Economy with Foresight'", 'R E HALL', 'University of California, Berkeley']
# 13.043478260869568
# ["in an Economy with Foresight'", 'R E HALL', 'University of California, Berkeley']
# ["in an Economy with Foresight'", 'R E HALL', 'University of California, Berkeley']
# 15.384615384615385
# ['R E HALL', 'University of California, Berkeley']
# ['On the Theory of Foreign Exchange', 'Reserve Requirements "\'', 'G C ARCHIBALD', 'and', 'J RICHMOND', 'University of Essex']
# 8.333333333333337
# ['Reserve Requirements "\'', 'G C ARCHIBALD', 'and', 'J RICHMOND', 'University of Essex']
# ['Reserve Requirements "\'', 'G C ARCHIBALD', 'and', 'J RICHMOND', 'University of Essex']
# 10.526315789473683
# ['G C ARCHIBALD', 'and', 'J RICHMOND', 'University of Essex']
# ["Majority Voting and Social Choice '*", 'J CRAVEN', "King's College, Cambridge"]
# 8.888888888888891
# ['J CRAVEN', "King's College, Cambridge"]
# ['A Non-cooperative Equilibrium for', 'Supergames "', 'JAMES W FRIEDMAN', 'University of Rochester']
# 16.000000000000004
# ['Supergames "', 'JAMES W FRIEDMAN', 'University of Rochester']
# ['Supergames "', 'JAMES W FRIEDMAN', 'University of Rochester']
# 13.793103448275868
# ['JAMES W FRIEDMAN', 'University of Rochester']

# %%
Reference_Data
# Out:
#     Journal_Name                                    Author1  \
# 0            RES
# 1            RES
# 2            RES  Carnegie-Mellon University K R MACCRIMMON
# 3            RES
# 4            RES
# ..           ...                                        ...
# 313          RES         New Haven, Connecticut JAMES TOBIN
# 314          RES
# 315          RES                                     Oxford
# 316          RES
# 317          RES       Frankfvrt am Main HANS JURGEN JAKSCH
#
#                                          Affilliation1  \
# 0
# 1
# 2                          Hokkaido University M Topna
# 3
# 4
# ..                                                 ...
# 313                       This content downloaded from
# 314
# 315                       This content downloaded from
# 316
# 317  1 While writing this note in October 1958, the...
#
#                                                Author2  \
# 0
# 1
# 2    First version received 151267; final version r...
# 3
# 4
# ..                                                 ...
# 313       13715815862 on Sun, 13 Feb 2022 05:40:17 UTC
# 314
# 315       13715815862 on Sun, 13 Feb 2022 05:41:22 UTC
# 316
# 317  Chusetts Institute of Technology With this not...
#
#                                          Affilliation2  authorscount  \
# 0                                                                  1
# 1                                                                  1
# 2                                           REFERENCES             2
# 3                                                                  1
# 4                                                                  2
# ..                                                 ...           ...
# 313     AII use subject to https://aboutjstororg/terms             1
# 314                                                                1
# 315     AII use subject to https://aboutjstororg/terms             1
# 316                                                                1
# 317  porated in the relevant part of his doctoral t...             1
#
#                                   Authors     a1fuzz            author_1  \
# 0                          J. W. Friedman   0.000000      J. W. FRIEDMAN
# 1                           A. C. Hoggatt   0.000000       A. C. HOGGATT
# 2               K. R. MacCrimmon, M. Toda  49.122807    K. R. MACCRIMMON
# 3                           Roger Sherman   0.000000       ROGER SHERMAN
# 4    John A. Carlson, Terrence B. O'Keefe   0.000000     JOHN A. CARLSON
# ..                                    ...        ...                 ...
# 313                           James Tobin  48.888889         JAMES TOBIN
# 314                       Nicholas Kaldor   0.000000     NICHOLAS KALDOR
# 315                              H. Myint   0.000000            H. MYINT
# 316                      R. D. Theocharis   0.000000    R. D. THEOCHARIS
# 317                    Hans Jurgen Jaksch  66.666667  HANS JURGEN JAKSCH
#
#                 author_2  ... Author6 Affilliation6 ref_length  \
# 0                         ...                               31
# 1                         ...                               21
# 2                M. TODA  ...                                9
# 3                         ...                               35
# 4    TERRENCE B. O'KEEFE  ...                               21
# ..                   ...  ...     ...           ...        ...
# 313                       ...                                4
# 314                       ...                               12
# 315                       ...                                5
# 316                       ...                               34
# 317                       ...                                6
#
#                                             ref_string     a1     a2     a3  \
# 0    414 REVIEW OF ECONOMIC STUDIES\n\nThe advantag...  False  Empty  Empty
# 1    BEHAVIOUR OF ROBOTS IN BIFURCATED DUOPOLY GAME...  False  Empty  Empty
# 2    450 REVIEW OF ECONOMIC STUDIES\n\nindifference...  False  False  False
# 3    464 REVIEW OF ECONOMIC STUDIES\n\nobserve no m...  False  Empty  Empty
# 4    484 REVIEW OF ECONOMIC STUDIES\n\nAs in any ex...  False  False  Empty
# ..                                                 ...    ...    ...    ...
# 313  120 REVIEW OF ECONOMIC STUDIES\n\nMeanwhile, h...  False  False  Empty
# 314  A REJOINDER TO MR. ATSUMI AND PROFESSOR TOBIN ...  False  Empty  Empty
# 315  132 REVIEW OF ECONOMIC STUDIES\n\nquite have t...  False  False  False
# 316  134 REVIEW OF ECONOMIC STUDIES\n\n9\n(0) a5, G...  False  Empty  Empty
# 317  138 REVIEW OF ECONOMIC STUDIES\n\nAlso, note t...  False  False  False
#
#         a4     a5     a6
# 0    Empty  Empty  Empty
# 1    Empty  Empty  Empty
# 2    False  False  Empty
# 3    Empty  Empty  Empty
# 4    Empty  Empty  Empty
# ..     ...    ...    ...
# 313  Empty  Empty  Empty
# 314  Empty  Empty  Empty
# 315  Empty  Empty  Empty
# 316  Empty  Empty  Empty
# 317  Empty  Empty  Empty
#
# [318 rows x 33 columns]

# %%
True_count = 0
False_count = 0
for item in Reference_Data['a1fuzz'][1:429]:
    if item >50:
        True_count += 1
    else:
        False_count +=1
print(True_count)
print(False_count)
print(True_count/(True_count+False_count))
# Out:
# 415
# 13
# 0.969626168224299

# %%
list = ['1','2','3','4']
list.remove('2')
list
# Out:
# ['1', '3', '4']

# %%
string = ("""JAN POTTERS and tim cook
Tilburg University, The Netherlands

and

SIGRID SUETENS and matt
Tilburg University, The Netherlands
""")

list = re.findall('.+',string)
for i in list:
    if i == 'and':
        list.remove(i)

for i in list:
    #auth = re.findall('\sand\s',i)
    if len(re.split(' and',i)) == 2:
        list[0] = re.split(' and',i)[0]
        list.append(re.split(' and',i)[1])

    
print(list)
len(list)
    
#list[0]
# Out:
# ['SIGRID SUETENS', 'Tilburg University, The Netherlands', 'SIGRID SUETENS and matt', 'Tilburg University, The Netherlands', ' tim cook', ' matt']
# 6
